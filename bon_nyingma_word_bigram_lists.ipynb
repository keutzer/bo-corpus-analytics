# %%
from collections import Counter
from nltk import ngrams

import itertools
import os
import pybo

import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# Store texts in the following directory structure:
#
#     texts
#       Bon
#         file1.txt
#         file2.txt
#         ...
#       Nyingma
#         file1.txt
#         file2.txt
#         ...

# %%
tok = pybo.BoTokenizer('POS')
# Out:
# Loading Trie...
# Time: 6.913856029510498

# %% [markdown]
# Assumptions here:
# 1. Drop all non-bo text
# 2. Drop all phrase delimiters (shad)
# 3. Reduce words to lemmas
# 4. Strip beginning and ending tseks from lemmas

# %%
tsek = '་'

# Create dictionary to map document index back to filename
bon_idx2fname = {}
bon_texts = []
for filename in sorted(os.listdir("texts/Bon")):
    if ".txt" in filename:
        with open("texts/Bon/" + filename, 'r', encoding='utf-8-sig') as f:
            bon_idx2fname[len(bon_texts)] = filename
            tokens = [t for t in tok.tokenize(f.read()) if t.type != "non-bo" and t.pos != "punct"]
            lemmas = [t.lemma.strip(tsek) if t.lemma else t.content.strip(tsek) for t in tokens]
            bon_texts.append(lemmas)
            
bon_large_idx2fname = {}
bon_large_texts = []
for filename in sorted(os.listdir("texts/Bon-Large")):
    if ".txt" in filename:
        with open("texts/Bon-Large/" + filename, 'r', encoding='utf-8-sig') as f:
            bon_large_idx2fname[len(bon_large_texts)] = filename
            tokens = [t for t in tok.tokenize(f.read()) if t.type != "non-bo" and t.pos != "punct"]
            lemmas = [t.lemma.strip(tsek) if t.lemma else t.content.strip(tsek) for t in tokens]
            bon_large_texts.append(lemmas)
            
# Now process nyingma
nyingma_idx2fname = {}
nyingma_texts = []
for filename in sorted(os.listdir("texts/Nyingma")):
    if ".txt" in filename:
        with open("texts/Nyingma/" + filename, 'r', encoding='utf-8-sig') as f:
            nyingma_idx2fname[len(nyingma_texts)] = filename
            tokens = [t for t in tok.tokenize(f.read()) if t.type != "non-bo" and t.pos != "punct"]
            lemmas = [t.lemma.strip(tsek) if t.lemma else t.content.strip(tsek) for t in tokens]
            nyingma_texts.append(lemmas)
            
nyingma_large_idx2fname = {}
nyingma_large_texts = []
for filename in sorted(os.listdir("texts/Nyingma-Large")):
    if ".txt" in filename:
        with open("texts/Nyingma-Large/" + filename, 'r', encoding='utf-8-sig') as f:
            nyingma_large_idx2fname[len(nyingma_large_texts)] = filename
            tokens = [t for t in tok.tokenize(f.read()) if t.type != "non-bo" and t.pos != "punct"]
            lemmas = [t.lemma.strip(tsek) if t.lemma else t.content.strip(tsek) for t in tokens]
            nyingma_large_texts.append(lemmas)
            
nyingma_GN_idx2fname = {}
nyingma_GN_texts = []
for filename in sorted(os.listdir("texts/Nyingma-GN")):
    if ".txt" in filename:
        with open("texts/Nyingma-GN/" + filename, 'r', encoding='utf-8-sig') as f:
            nyingma_GN_idx2fname[len(nyingma_GN_texts)] = filename
            tokens = [t for t in tok.tokenize(f.read()) if t.type != "non-bo" and t.pos != "punct"]
            lemmas = [t.lemma.strip(tsek) if t.lemma else t.content.strip(tsek) for t in tokens]
            nyingma_GN_texts.append(lemmas)

# %%
filter_list = ['གི','ལ','གིས','དང','ནི','ནས','པ','གོ','ཀྱང','དུ','ཀྱིས','དེ','ཏེ','མ','སྟེ','སུ','ཀྱི','གྱིས','ན','ཅེས','འདི','གྱི','ཅི','བ','པར','ཡིས','ཅིང','མོ','ཅེས་པ','རྣམས','ཏུ']

bon_texts_f = []
for t in bon_texts:
    t_f = [x for x in t if x not in filter_list]
    bon_texts_f.append(t_f)
    
bon_large_texts_f = []
for t in bon_large_texts:
    t_f = [x for x in t if x not in filter_list]
    bon_large_texts_f.append(t_f)

nyingma_texts_f = []
for t in nyingma_texts:
    t_f = [x for x in t if x not in filter_list]
    nyingma_texts_f.append(t_f)
    
nyingma_GN_texts_f = []
for t in nyingma_GN_texts:
    t_f = [x for x in t if x not in filter_list]
    nyingma_GN_texts_f.append(t_f)
    
nyingma_large_texts_f = []
for t in nyingma_large_texts:
    t_f = [x for x in t if x not in filter_list]
    nyingma_large_texts_f.append(t_f)
    
    
bon_bigrams_f = []
for t in bon_texts:
    grams = [tsek.join(x) for x in ngrams(t, 2) if not set(x).intersection(filter_list)]
    bon_bigrams_f.append(grams)
    
bon_large_bigrams_f = []
for t in bon_large_texts:
    grams = [tsek.join(x) for x in ngrams(t, 2) if not set(x).intersection(filter_list)]
    bon_large_bigrams_f.append(grams)
    
nyingma_bigrams_f = []
for t in nyingma_texts:
    grams = [tsek.join(x) for x in ngrams(t, 2) if not set(x).intersection(filter_list)]
    nyingma_bigrams_f.append(grams)
    
nyingma_GN_bigrams_f = []
for t in nyingma_GN_texts:
    grams = [tsek.join(x) for x in ngrams(t, 2) if not set(x).intersection(filter_list)]
    nyingma_GN_bigrams_f.append(grams)
    
nyingma_large_bigrams_f = []
for t in nyingma_large_texts:
    grams = [tsek.join(x) for x in ngrams(t, 2) if not set(x).intersection(filter_list)]
    nyingma_large_bigrams_f.append(grams)

# %%
bon_bigrams = []
for t in bon_texts:
    grams = [tsek.join(x) for x in ngrams(t, 2)]
    bon_bigrams.append(grams)
    
bon_large_bigrams = []
for t in bon_large_texts:
    grams = [tsek.join(x) for x in ngrams(t, 2)]
    bon_large_bigrams.append(grams)
    
nyingma_bigrams = []
for t in nyingma_texts:
    grams = [tsek.join(x) for x in ngrams(t, 2)]
    nyingma_bigrams.append(grams)
    
nyingma_GN_bigrams = []
for t in nyingma_GN_texts:
    grams = [tsek.join(x) for x in ngrams(t, 2)]
    nyingma_GN_bigrams.append(grams)
    
nyingma_large_bigrams = []
for t in nyingma_large_texts:
    grams = [tsek.join(x) for x in ngrams(t, 2)]
    nyingma_large_bigrams.append(grams)

# %% [markdown]
# ## Overall top words/bigrams

# %%
bon_words_counter = Counter(list(itertools.chain(*bon_texts_f)))
bon_large_words_counter = Counter(list(itertools.chain(*bon_large_texts_f)))
nyingma_words_counter = Counter(list(itertools.chain(*nyingma_texts_f)))
nyingma_large_words_counter = Counter(list(itertools.chain(*nyingma_large_texts_f)))


bon_bigrams_counter = Counter(list(itertools.chain(*bon_bigrams_f)))
bon_large_bigrams_counter = Counter(list(itertools.chain(*bon_large_bigrams_f)))
nyingma_bigrams_counter = Counter(list(itertools.chain(*nyingma_bigrams_f)))
nyingma_large_bigrams_counter = Counter(list(itertools.chain(*nyingma_large_bigrams_f)))

# %%
N = 100

print("Bon Texts Top {} words".format(N))
for k, v in bon_words_counter.most_common(N):
    print("{}: {}\n".format(k, v))

print("Nyingma Texts Top {} words".format(N))
for k, v in nyingma_words_counter.most_common(N):
    print("{}: {}\n".format(k, v))

print("Bon Texts Top {} bigrams".format(N))
for k, v in bon_bigrams_counter.most_common(N):
    print("{}: {}\n".format(k, v))

print("Nyingma Top {} bigrams".format(N))
for k, v in nyingma_bigrams_counter.most_common(N):
    print("{}: {}\n".format(k, v))
    

print("Bon Large Texts Top {} words".format(N))
for k, v in bon_large_words_counter.most_common(N):
    print("{}: {}\n".format(k, v))
    
print("Nyingma Large Texts Top {} words".format(N))
for k, v in nyingma_large_words_counter.most_common(N):
    print("{}: {}\n".format(k, v))
# Out:
# Bon Texts Top 100 words
# སེམས: 716
#
# མི: 634
#
# ལས: 516
#
# མྱེད: 451
#
# བྱ: 445
#
# དོན: 439
#
# ཉིད: 409
#
# ཡེ་ཤེས: 341
#
# ཐམས་ཅད: 316
#
# བོན: 304
#
# ཡིན: 280
#
# བྱང་ཆུབ: 263
#
# ངང: 261
#
# མེད་པ: 258
#
# མཚན་མ: 255
#
# གསལ་བ: 239
#
# ཆེན་པོ: 234
#
# ཁུ་བྱུག: 221
#
# གསུམ: 218
#
# གཉིས: 209
#
# བདག: 206
#
# རིག་པ: 204
#
# མེད: 197
#
# ནམ་མཁའ: 191
#
# དབྱིངས: 190
#
# ལུང: 189
#
# གསལ: 184
#
# བྱ་བ: 179
#
# ཞིང: 177
#
# ལྷ: 176
#
# གནས: 171
#
# དུས: 168
#
# ཀུན: 165
#
# ལྔ: 163
#
# རང: 162
#
# སེམས་ཉིད: 161
#
# རང་བཞིན: 161
#
# བསྒོམ: 161
#
# སྟོན་པ: 160
#
# རྟོགས: 159
#
# ཙམ: 153
#
# ཡེ་ནས: 149
#
# འོད: 143
#
# བཞི: 140
#
# ཤེས་པ: 140
#
# བསྟན་པ: 136
#
# པས: 134
#
# སྤྲུལ་པ: 134
#
# སྐྱེ་བ: 133
#
# འབྱུང: 131
#
# ལྟར: 131
#
# རྟོགས་པ: 130
#
# རྣམ་པར: 124
#
# ཏིང་ངེ་འཛིན: 123
#
# གཤེན་ལྷ: 121
#
# པོ: 121
#
# ཅིག: 120
#
# བྱུང: 118
#
# གནས་པ: 116
#
# གཤེན: 114
#
# བག་ཆགས: 114
#
# སྐུ: 114
#
# ཅན: 113
#
# ཡིད: 113
#
# སེམས་ཅན: 112
#
# བརྣན: 111
#
# དེ་ལྟར: 109
#
# སྣང: 108
#
# ཐབས: 108
#
# དེས: 107
#
# རྣམ་པ: 104
#
# བདེ་བ: 104
#
# སྟོན: 103
#
# བཤད: 103
#
# འདྲ: 103
#
# རུ: 102
#
# གཅིག: 97
#
# ལུས: 96
#
# རྒྱལ་པོ: 96
#
# ལྡན་པ: 95
#
# འབྲས་བུ: 93
#
# དོན་དམ: 92
#
# ཐིག་ལེ: 91
#
# རྒྱུ: 90
#
# གང: 90
#
# འབྱུང་བ: 89
#
# བསྒོམ་པ: 89
#
# སྙིང་པོ: 88
#
# འགྱུར: 88
#
# མན་ངག: 86
#
# ཀུན་གཞི: 86
#
# ཚིག: 86
#
# མཐའ: 86
#
# དཔེ: 85
#
# གཡུང་དྲུང: 85
#
# དཔེར་ན: 85
#
# དངོས་པོ: 83
#
# བྱེད: 83
#
# ཐུགས: 82
#
# མེད་པར: 80
#
# Nyingma Texts Top 100 words
# མི: 420
#
# མེད: 391
#
# ཀུན: 243
#
# ལས: 196
#
# ཉིད: 183
#
# མེད་པ: 157
#
# ཆོས: 151
#
# གནས: 148
#
# བྱང་ཆུབ: 145
#
# ལམ: 132
#
# ཡིན: 128
#
# ཆེན་པོ: 122
#
# སེམས: 121
#
# དོན: 121
#
# དབྱིངས: 102
#
# མཆོག: 96
#
# སངས་རྒྱས: 96
#
# ཐམས་ཅད: 95
#
# རྡོ་རྗེ: 93
#
# རང་བཞིན: 90
#
# ཡེ་ཤེས: 88
#
# བཅོམ་ལྡན་འདས: 85
#
# སྙིང་པོ: 85
#
# གཉིས: 84
#
# རྒྱུད: 78
#
# སྐུ: 76
#
# རྫོགས: 73
#
# འགྱུར: 69
#
# གཞན: 69
#
# ཕྱིར: 68
#
# བཞིན: 67
#
# ཡི: 65
#
# གསུམ: 65
#
# ཡེ་ནས: 64
#
# དེ་བཞིན: 63
#
# དེ་ནས: 63
#
# གཅིག: 62
#
# དཔལ: 61
#
# གང: 61
#
# རྣམ་པར: 61
#
# མཐའ: 60
#
# བྲལ: 60
#
# ལྷུན: 60
#
# དག་པ: 57
#
# བདེ་བ: 56
#
# དག: 55
#
# འདས: 53
#
# བདག: 51
#
# བྱ: 50
#
# དཀྱིལ་འཁོར: 50
#
# ཚིག: 48
#
# ནམ་མཁའ: 48
#
# གནས་པ: 48
#
# རྟོག: 47
#
# བཟང་པོ: 45
#
# རྒྱལ་བ: 45
#
# འཁྲུལ: 44
#
# ཕྱག: 43
#
# ཞིང: 42
#
# འཚལ: 41
#
# སྤྱོད་པ: 41
#
# རྫོགས་པ: 41
#
# ཆེན: 41
#
# སྐྱེ: 41
#
# བསྟན་པ: 41
#
# ངང: 41
#
# ཆེ: 40
#
# རྟོག་པ: 40
#
# ཐབས: 39
#
# རྒྱལ་པོ: 39
#
# འདས་པ: 38
#
# སེམས་དཔའ: 37
#
# ལུང: 37
#
# ལེའུ: 37
#
# ཐུགས: 36
#
# ཡུལ: 36
#
# གྱུར: 35
#
# པས: 35
#
# རྣལ་འབྱོར: 35
#
# ཕྱག་རྒྱ: 35
#
# དེ་བཞིན་ཉིད: 34
#
# རང: 34
#
# བསྒོམ: 34
#
# མེད་པར: 33
#
# མིན: 33
#
# ལ་སོགས: 33
#
# ཤིང: 32
#
# སྣ་ཚོགས: 32
#
# དེ་ཉིད: 32
#
# ཐིག་ལེ: 32
#
# ཡི་གེ: 32
#
# བརྗོད་པ: 31
#
# མཉམ: 31
#
# བརྗོད: 31
#
# ཡོད: 31
#
# བྱེད: 31
#
# འབྱུང: 31
#
# སྒྱུ་མ: 31
#
# ཐེག་པ: 30
#
# རྒྱུ: 30
#
# Bon Texts Top 100 bigrams
# བོན་ཉིད: 156
#
# བྱང་ཆུབ་སེམས: 110
#
# ལུང་བརྣན: 105
#
# གཤེན་ལྷ་འོད: 66
#
# འོད་དཀར: 65
#
# རྣམ་པར་ཤེས་པ: 63
#
# བདེ་བ་ཆེན་པོ: 60
#
# མྱེད་པས: 57
#
# རང་ཤེས་རིག: 56
#
# ལས་འདས་པ: 55
#
# སེམས་རིག་པ: 48
#
# སྤྲོ་ཞིང: 47
#
# ཞིང་དྭང: 42
#
# དེ་ལྟ་བུ: 40
#
# རྟོགས་ཙམ: 38
#
# རང་འབྱུང: 38
#
# རྣམ་པ་གསུམ: 37
#
# ཀུན་གཞི་བྱང་ཆུབ: 37
#
# སྙམ་བྱེད: 35
#
# མི་དམིགས: 34
#
# བརྒྱུད་དེས: 34
#
# ཙམ་ཉིད: 32
#
# ཁྱབ་བདལ: 32
#
# ངང་ཉིད: 31
#
# སེམས་ཅན་ཐམས་ཅད: 31
#
# ཡེ་ཤེས་ཆེན་པོ: 30
#
# མཚན་མ་མྱེད: 30
#
# འགྱུར་རོ: 30
#
# ཉིད་བདེ་བ: 29
#
# མཚན་མ་ཐམས་ཅད: 29
#
# མི་དམིགས་པ: 28
#
# མི་འགྱུར: 28
#
# ལས་འདས: 27
#
# རྣམ་པར་དག་པ: 27
#
# མི་ཁྱབ་པ: 26
#
# རིག་པ་ཐབས: 25
#
# སེམས་རང: 25
#
# བདག་སྒོམ་པ: 25
#
# རྒྱལ་པོ་བྱང་ཆུབ: 24
#
# ཐིག་ལེ་གཅིག: 24
#
# བོན་ཐམས་ཅད: 23
#
# སླུ་བ་ཡིན: 23
#
# མི་དམྱིགས: 23
#
# མཚོན་པ་མྱ་ངན: 23
#
# རྒྱལ་པོ་ཀུན་གཞི: 23
#
# འཆི་མེད་གཙུག་ཕུད: 22
#
# ཉམས་སོད: 22
#
# ལས་སོགས: 22
#
# དཔེར་ན་ནམ་མཁའ: 22
#
# རེ་སྤྲོ: 22
#
# གཤེན་ལྷ་ཀ: 22
#
# གཉིས་མེད: 21
#
# སྣང་བ་ཐམས་ཅད: 21
#
# མྱ་ངན་ལས: 21
#
# གཤེན་ཕྲན: 21
#
# སྤྲོ་བ་སྐྱེ་བ: 20
#
# ལས་བྱུང་བ: 20
#
# ཐུགས་རྗེ་ཆེན་པོ: 20
#
# བཅུ་རྩ: 20
#
# ཡེ་གཤེན་གཙུག་ཕུད: 19
#
# སྣང་སྲིད་ཐམས་ཅད: 19
#
# སྤྱན་དྲངས: 19
#
# འཕྲག་དོག: 19
#
# རང་བཞིན་མེད་པ: 18
#
# ཡེ་ཤེས་ལྔ: 18
#
# སྣང་ཞིང: 18
#
# འཁོར་གཤེན: 18
#
# རྒྱུན་ཐག: 18
#
# བཟང་པོ་གཤེན་ལྷ: 17
#
# མི་འབྱུང: 17
#
# སླུ་བ་པོ: 17
#
# མི་བསྒོམ: 17
#
# གཤེན་ལྷ་དཀར་པོ: 17
#
# སེམས་སྤྲོ་བ: 17
#
# སྐྱེ་བ་མྱེད: 17
#
# བཞི་བཅུ: 17
#
# ཡིད་ཆེས་པས: 17
#
# སྤྲུལ་ལོ: 17
#
# དབྱིངས་ཡིན: 16
#
# ཕྱག་འཚལ: 16
#
# དུས་ཅིག: 16
#
# ཐམས་ཅད་སེམས: 16
#
# སེམས་བདེ་བ: 16
#
# མཚན་མ་རྡུལ: 16
#
# རྣམ་པར་རྟོག་པ: 16
#
# གསལ་ལ་མ: 16
#
# འདུ་འབྲལ: 16
#
# དུག་ལྔ: 16
#
# སྟོན་པ་གཤེན་ལྷ: 15
#
# ཏན་ཏྲ: 15
#
# རང་བཞིན་མྱེད: 15
#
# ཐིག་ལེ་ཉག་གཅིག: 15
#
# དེ་ལྟར་རྟོགས: 15
#
# ནམ་མཁའ་ལྟར: 15
#
# ཐིག་ལེ་ཆེན་པོ: 15
#
# སྤྲུལ་པ་ལས: 15
#
# ཁམས་གསུམ: 15
#
# ཐམས་ཅད་བོན: 15
#
# རྩ་ལྔ: 15
#
# རིགས་ཅན་ཡིན་པ: 15
#
# Nyingma Top 100 bigrams
# བཅོམ་ལྡན་འདས་དཔལ: 45
#
# མི་གནས: 41
#
# གཉིས་མེད: 40
#
# དེ་ནས་བཅོམ་ལྡན་འདས: 39
#
# བྱང་ཆུབ་སེམས: 39
#
# དཔལ་ཀུན: 38
#
# ཕྱག་འཚལ: 30
#
# རྒྱུད་ལས: 30
#
# རྡོ་རྗེ་སེམས་དཔའ: 28
#
# ལས་འདས: 27
#
# མི་རྟོག: 27
#
# ལས་འདས་པ: 22
#
# མི་དགོས: 21
#
# མི་འགྱུར: 21
#
# ལྷུན་རྫོགས: 19
#
# དབྱེར་མེད: 18
#
# བྱང་ཆུབ་སྙིང་པོ: 17
#
# མི་དམིགས: 16
#
# ཡི་གེ་མེད་པ: 16
#
# རྣམ་པར་དག: 15
#
# སྐྱེ་མེད: 15
#
# མི་རྙེད: 15
#
# བདེ་བ་ཆེན་པོ: 13
#
# རྣམ་པར་དག་པ: 13
#
# བཀའ་སྩལ: 13
#
# ཁམས་གསུམ: 13
#
# རྩལ་ཆེན: 13
#
# དབྱིངས་ལས: 13
#
# མི་བྱེད: 13
#
# དེ་བཞིན་གཤེགས་པ: 12
#
# ཡེ་ནས་དག་པ: 12
#
# མཐའ་ལས: 12
#
# ཕྱི་ནང: 12
#
# འཚལ་ལོ: 11
#
# རྡོ་རྗེ་ཐེག་པ: 11
#
# སེམས་ཁྱུང་ཆེན: 11
#
# ཕྲ་བཀོད་པ: 11
#
# ངོ་བོ་ཉིད: 10
#
# མི་སྐྱེ: 10
#
# དཔལ་རྡོ་རྗེ: 10
#
# མྱ་ངན་འདས: 10
#
# ཡེ་སངས་རྒྱས: 10
#
# སེམས་རྩལ: 10
#
# བཟང་པོ་ཉིད: 10
#
# གནས་མེད: 10
#
# མེད་ཕྱིར: 10
#
# མི་བལྟ: 9
#
# རང་བཞིན་གནས་པ: 9
#
# སངས་རྒྱས་ཀུན: 9
#
# དབྱིངས་ཉིད: 9
#
# ཆོས་ཐམས་ཅད: 8
#
# ཡེ་ཤེས་སྙིང་པོ: 8
#
# ཡེ་ཤེས་དབྱིངས: 8
#
# མི་གཡོ: 8
#
# ཐམས་ཅད་ཀུན: 8
#
# མེད་མི: 8
#
# བརྗོད་མེད: 8
#
# ལམ་ཆེན: 8
#
# རྡོ་རྗེ་འཛིན་པ: 8
#
# ཐེག་པ་ཆེན་པོ: 7
#
# རྣམ་པར་མི: 7
#
# མྱ་ངན་འདས་པ: 7
#
# མི་བྱ: 7
#
# སྙིང་པོ་བྱང་ཆུབ: 7
#
# རྒྱལ་བ་ཀུན: 7
#
# སངས་རྒྱས་སེམས་ཅན: 7
#
# འདུ་འབྲལ: 7
#
# རང་བྱུང་ཡེ་ཤེས: 7
#
# དོན་མི: 7
#
# བྱང་ཆུབ་ཆེན་པོ: 7
#
# ཀུན་ལས: 7
#
# རྡུལ་ཙམ: 7
#
# མེད་ཡེ: 7
#
# རྒྱ་གར་སྐད: 6
#
# བཅོམ་ལྡན་འདས་ཆེན་པོ: 6
#
# འཁོར་བ་མྱ་ངན: 6
#
# མི་སྲིད: 6
#
# བཅོམ་ལྡན་འདས་ཀུན: 6
#
# ཀུན་འདུས: 6
#
# བྱང་ཆུབ་ལམ: 6
#
# མི་རུང: 6
#
# རོ་གཅིག: 6
#
# བཀྲ་ཤིས་པ་རིག་པ: 6
#
# ཡིན་རྡོ་རྗེ: 6
#
# སྙིང་པོ་ཉིད: 6
#
# འབྱུང་འཇུག: 6
#
# མེད་ནམ་མཁའ: 6
#
# སངས་རྒྱས་ཉིད: 6
#
# ཕ་རོལ་ཕྱིན: 6
#
# བཟང་པོས་ཉིད: 6
#
# མེད་ཆོས: 6
#
# མེད་སངས་རྒྱས: 6
#
# ཇི་བཞིན་གནས: 6
#
# གནས་མི: 6
#
# ཚིག་ལས: 6
#
# མི་འབྱུང: 6
#
# མི་ཤེས: 6
#
# ཙམ་མེད: 6
#
# རྣམ་དག་བྱང་ཆུབ: 6
#
# བྲལ་ཚིག: 6
#
# Bon Large Texts Top 100 words
# ལས: 2006
#
# སེམས: 1121
#
# མི: 1115
#
# མེད་པ: 847
#
# དོན: 754
#
# མེད: 730
#
# ཉིད: 642
#
# བྱང་ཆུབ: 624
#
# བྱ: 544
#
# ཐམས་ཅད: 525
#
# ཡེ་ཤེས: 500
#
# བོན: 447
#
# གཉིས: 441
#
# ཆེན་པོ: 434
#
# ཡིན: 400
#
# རྟོགས་པ: 386
#
# ཡེ་ནས: 359
#
# གསལ་བ: 308
#
# ངང: 308
#
# ནམ་མཁའ: 302
#
# འབྲུ: 300
#
# བྱ་བ: 292
#
# རྟོགས: 279
#
# མཚན་མ: 275
#
# དབྱིངས: 268
#
# ཀུན: 258
#
# བཤད: 258
#
# ཞིང: 255
#
# མེད་པར: 241
#
# གནས: 239
#
# འདྲ: 234
#
# སེམས་ཉིད: 228
#
# བསྟན་པ: 220
#
# ཁུ་བྱུག: 220
#
# གསུམ: 216
#
# ལྟ་བ: 215
#
# རིག་པ: 214
#
# སྟོན་པ: 212
#
# གསལ: 210
#
# བདག: 205
#
# ལུང: 205
#
# གནས་པ: 201
#
# གང: 198
#
# རང་བཞིན: 197
#
# དུས: 196
#
# གཅིག: 192
#
# ཤེས་པ: 192
#
# བཅའ: 183
#
# བདེ་བ: 181
#
# རང: 181
#
# དེ་ལས: 178
#
# ལམ: 172
#
# གམ: 168
#
# ཙམ: 167
#
# འབྱུང: 165
#
# ཐག: 164
#
# བཅོས: 163
#
# ལྟར: 162
#
# སེམས་ཅན: 161
#
# རྣམ་པར: 161
#
# ཐིག་ལེ: 160
#
# འབྲས་བུ: 160
#
# ཡིད: 160
#
# འགྱུར: 159
#
# གཡུང་དྲུང: 158
#
# མན་ངག: 154
#
# ཅན: 151
#
# པས: 144
#
# སྒྲ: 143
#
# ཐབས: 142
#
# ཏིང་ངེ་འཛིན: 142
#
# འོད: 140
#
# བྱུང: 140
#
# སྐྱེ་བ: 138
#
# ཏིག: 137
#
# སེམས་ལས: 136
#
# བཞི: 136
#
# གྱུར་པ: 135
#
# ཡི: 135
#
# བསྒོམས་པ: 133
#
# ངོས: 133
#
# དགོངས་པ: 131
#
# བསྟན: 131
#
# བསྒོམ: 130
#
# གཤེན་ལྷ: 129
#
# བག་ཆགས: 127
#
# འཕྲུལ: 124
#
# རུ: 123
#
# སྤྲུལ་པ: 123
#
# པོ: 122
#
# སྣང: 122
#
# གཤེན: 122
#
# ཕྱིར: 122
#
# ལྔ: 121
#
# ཚད: 121
#
# ལྡན་པ: 121
#
# སྔོན་པོ: 120
#
# དམར: 119
#
# དེ་ནས: 118
#
# ལྡེ་མིག: 118
#
# Nyingma Large Texts Top 100 words
# ཀུན: 804
#
# ང: 650
#
# མི: 649
#
# མེད: 618
#
# བྱེད: 553
#
# སེམས: 513
#
# བྱང་ཆུབ: 488
#
# ལས: 432
#
# ཡི: 424
#
# ཡིན: 415
#
# རང་བཞིན: 403
#
# ཆོས: 344
#
# རང: 305
#
# གསུམ: 301
#
# དོན: 300
#
# བསྟན་པ: 296
#
# སྟོན་པ: 289
#
# ཆེན་པོ: 266
#
# ཡེ་ཤེས: 266
#
# ཐམས་ཅད: 257
#
# སེམས་དཔའ: 248
#
# བསྟན: 246
#
# སངས་རྒྱས: 246
#
# ཉིད: 245
#
# མེད་པ: 244
#
# རྒྱལ་པོ: 239
#
# ཀྱེ: 211
#
# འབྱུང: 209
#
# གཉིས: 195
#
# འཁོར: 191
#
# གནས: 189
#
# ལྔ: 183
#
# ཆོས་ཉིད: 178
#
# གཅིག: 175
#
# ངོ་བོ: 163
#
# འགྱུར: 163
#
# བྱ: 160
#
# ལམ: 158
#
# བཤད: 153
#
# སྙིང་པོ: 151
#
# ཡུལ: 149
#
# གསུངས: 148
#
# ཕྱིར: 148
#
# རྟོག: 147
#
# ཡེ་ནས: 144
#
# དེ་བཞིན་ཉིད: 138
#
# ཅིག: 132
#
# ལུང: 130
#
# ནམ་མཁའ: 123
#
# སྐུ: 116
#
# དེས: 115
#
# རྣམ: 109
#
# དེ་ནས: 108
#
# སེམས་ཅན: 104
#
# ཉོན: 104
#
# ཁམས: 103
#
# གཞན: 100
#
# བྱ་བ: 99
#
# བྱུང་བ: 99
#
# སྣང་བ: 98
#
# ཡིན་པ: 96
#
# བྱས: 95
#
# རྡོ་རྗེ: 94
#
# འབྲས་བུ: 94
#
# ལེའུ: 93
#
# གནས་པ: 92
#
# རྣམ་པ: 91
#
# རྫོགས་པ: 89
#
# རྟོགས: 88
#
# བཙལ: 86
#
# པས: 86
#
# འདོད་པ: 86
#
# ཕྱུང་བ: 85
#
# བཞིན: 84
#
# ཚིག: 84
#
# མཐོང: 84
#
# གང: 83
#
# རྒྱུ་འབྲས: 83
#
# བྱུང: 82
#
# སྐུ་གསུམ: 82
#
# བྱེད་པ: 79
#
# ཇི་ལྟ: 77
#
# རྒྱུད: 76
#
# རྒྱུ: 76
#
# ཏིང་འཛིན: 76
#
# ས: 74
#
# མངོན་དུ: 74
#
# བསྒོམ: 73
#
# དྲུག: 73
#
# དགོས: 71
#
# སྟོན: 71
#
# ངེས་པ: 69
#
# གྲུབ་པ: 67
#
# རྩ་བ: 66
#
# ཁྱོད: 65
#
# རྣལ་འབྱོར: 64
#
# རྟོག་པ: 64
#
# འདས་པ: 63
#
# མེད་པར: 63
#
# རུ: 61

# %%
nyingma5_words_counter = Counter(list(itertools.chain(*nyingma_texts_f[:5])))
nyingma13_words_counter = Counter(list(itertools.chain(*nyingma_texts_f[5:])))


nyingma5_bigrams_counter = Counter(list(itertools.chain(*nyingma_texts_f[:5])))
nyingma13_bigrams_counter = Counter(list(itertools.chain(*nyingma_texts_f[5:])))

N = 100

print("Nyingma Earlier 5 Texts Top {} words".format(N))
for k, v in nyingma5_words_counter.most_common(N):
    print("{}: {}\n".format(k, v))

print("Nyingma Later 13 Texts Top {} words".format(N))
for k, v in nyingma13_words_counter.most_common(N):
    print("{}: {}\n".format(k, v))

print("Nyingma Earlier 5 Texts Top {} bigrams".format(N))
for k, v in nyingma5_bigrams_counter.most_common(N):
    print("{}: {}\n".format(k, v))

print("Nyingma Later 13 Top {} bigrams".format(N))
for k, v in nyingma13_bigrams_counter.most_common(N):
    print("{}: {}\n".format(k, v))
# Out:
# Nyingma Earlier 5 Texts Top 100 words
# མི: 304
#
# མེད: 209
#
# ཀུན: 160
#
# ཉིད: 136
#
# ལས: 124
#
# གནས: 111
#
# ལམ: 107
#
# ཆོས: 102
#
# བྱང་ཆུབ: 88
#
# ཡིན: 86
#
# མེད་པ: 84
#
# ཆེན་པོ: 77
#
# བཅོམ་ལྡན་འདས: 76
#
# དོན: 75
#
# རྡོ་རྗེ: 74
#
# མཆོག: 72
#
# ཐམས་ཅད: 67
#
# སེམས: 65
#
# སངས་རྒྱས: 65
#
# རྒྱུད: 65
#
# རང་བཞིན: 63
#
# དེ་ནས: 60
#
# སྙིང་པོ: 58
#
# ཡི: 56
#
# གཉིས: 55
#
# ཡེ་ཤེས: 54
#
# དེ་བཞིན: 51
#
# སྐུ: 51
#
# ཕྱིར: 51
#
# དཔལ: 50
#
# གཞན: 49
#
# གང: 46
#
# འགྱུར: 45
#
# དག་པ: 44
#
# གསུམ: 43
#
# བཞིན: 42
#
# བྱ: 40
#
# རྣམ་པར: 38
#
# གནས་པ: 38
#
# རྫོགས: 38
#
# གཅིག: 37
#
# བསྟན་པ: 34
#
# ལེའུ: 34
#
# ཕྱག: 33
#
# འཚལ: 32
#
# མཐའ: 32
#
# དེ་བཞིན་ཉིད: 31
#
# འདས: 31
#
# རྟོག: 31
#
# ཞིང: 31
#
# དབྱིངས: 31
#
# དག: 30
#
# མིན: 30
#
# དཀྱིལ་འཁོར: 30
#
# སེམས་དཔའ: 29
#
# ལྷུན: 29
#
# ལ་སོགས: 29
#
# ཕྱག་རྒྱ: 29
#
# ཡི་གེ: 29
#
# བཟང་པོ: 28
#
# བརྗོད་པ: 28
#
# ཆེན: 28
#
# ཡེ་ནས: 28
#
# བྲལ: 28
#
# ཐེག་པ: 26
#
# མེད་པར: 26
#
# གྱུར: 26
#
# སྤྱོད་པ: 26
#
# ཚུལ: 26
#
# བདག: 25
#
# ཤིང: 25
#
# ལྔ: 25
#
# རྒྱལ་པོ: 25
#
# ཁྱོད: 25
#
# བདེ་བ: 24
#
# ཡང་དག: 24
#
# བྱེད: 24
#
# འཁྲུལ: 24
#
# ཡོད: 23
#
# ཤེས: 23
#
# འབྱུང: 23
#
# དགོས: 23
#
# གྱུར་པ: 22
#
# བྱ་བ: 22
#
# རྒྱལ་བ: 22
#
# ཚིག: 21
#
# སྣང: 21
#
# སྐྱེ: 21
#
# སྣ་ཚོགས: 21
#
# རབ་ཏུ: 21
#
# ཡུལ: 21
#
# ངང: 21
#
# ཐབས: 21
#
# འབྲས་བུ: 21
#
# རྙེད: 21
#
# རྩལ: 21
#
# གཤེགས་པ: 20
#
# ཐུགས: 20
#
# ནམ་མཁའ: 20
#
# འཛིན་པ: 20
#
# Nyingma Later 13 Texts Top 100 words
# མེད: 182
#
# མི: 116
#
# ཀུན: 83
#
# མེད་པ: 73
#
# ལས: 72
#
# དབྱིངས: 71
#
# བྱང་ཆུབ: 57
#
# སེམས: 56
#
# ཆོས: 49
#
# ཉིད: 47
#
# དོན: 46
#
# ཆེན་པོ: 45
#
# ཡིན: 42
#
# གནས: 37
#
# ཡེ་ནས: 36
#
# རྫོགས: 35
#
# ཡེ་ཤེས: 34
#
# བདེ་བ: 32
#
# བྲལ: 32
#
# ལྷུན: 31
#
# སངས་རྒྱས: 31
#
# གཉིས: 29
#
# ཐམས་ཅད: 28
#
# མཐའ: 28
#
# ནམ་མཁའ: 28
#
# རྣལ་འབྱོར: 27
#
# རང་བཞིན: 27
#
# སྙིང་པོ: 27
#
# ཚིག: 27
#
# བདག: 26
#
# ལུང: 26
#
# སྐུ: 25
#
# ལམ: 25
#
# བཞིན: 25
#
# གཅིག: 25
#
# དག: 25
#
# མཆོག: 24
#
# འགྱུར: 24
#
# རྣམ་པར: 23
#
# རྒྱལ་བ: 23
#
# གསུམ: 22
#
# རྫོགས་པ: 22
#
# ཆེ: 22
#
# འདས: 22
#
# རང: 22
#
# འདས་པ: 21
#
# རྟོག་པ: 21
#
# རྣམ་དག: 20
#
# འཁྲུལ: 20
#
# དཀྱིལ་འཁོར: 20
#
# སྐྱེ: 20
#
# བདེ: 20
#
# གཞན: 20
#
# ངང: 20
#
# རྡོ་རྗེ: 19
#
# ཐབས: 18
#
# རྒྱ་མཚོ: 18
#
# པས: 18
#
# བཟང་པོ: 17
#
# ཕྱིར: 17
#
# སྒྱུ་མ: 17
#
# བྲལ་བ: 17
#
# ཀློང: 17
#
# ཐིག་ལེ: 17
#
# ཐུགས: 16
#
# རྒྱུ: 16
#
# རྟོག: 16
#
# གང: 15
#
# སེམས་ཅན: 15
#
# གྲུབ་པ: 15
#
# སྤྱོད་པ: 15
#
# གསལ: 15
#
# གསལ་བ: 15
#
# བསྒོམ: 15
#
# དེ་ཉིད: 15
#
# ཡུལ: 15
#
# རྒྱལ་པོ: 14
#
# མཉམ: 14
#
# བཀོད་པ: 14
#
# དབྱེར: 14
#
# བསྒོམ་པ: 14
#
# རྒྱུད: 13
#
# བརྗོད: 13
#
# ཐུགས་རྗེ: 13
#
# ཆེན: 13
#
# མཉམ་པ: 13
#
# ཙམ: 13
#
# དག་པ: 13
#
# ཡེ: 13
#
# ཁམས: 12
#
# དེ་བཞིན: 12
#
# ལྟ་བ: 12
#
# རྟོགས: 12
#
# ཆོས་ཉིད: 12
#
# ཕྱི: 12
#
# ཚོལ: 12
#
# བསམ: 12
#
# ཕྲ: 12
#
# ཞིང: 11
#
# རྟོགས་པ: 11
#
# Nyingma Earlier 5 Texts Top 100 bigrams
# མི: 304
#
# མེད: 209
#
# ཀུན: 160
#
# ཉིད: 136
#
# ལས: 124
#
# གནས: 111
#
# ལམ: 107
#
# ཆོས: 102
#
# བྱང་ཆུབ: 88
#
# ཡིན: 86
#
# མེད་པ: 84
#
# ཆེན་པོ: 77
#
# བཅོམ་ལྡན་འདས: 76
#
# དོན: 75
#
# རྡོ་རྗེ: 74
#
# མཆོག: 72
#
# ཐམས་ཅད: 67
#
# སེམས: 65
#
# སངས་རྒྱས: 65
#
# རྒྱུད: 65
#
# རང་བཞིན: 63
#
# དེ་ནས: 60
#
# སྙིང་པོ: 58
#
# ཡི: 56
#
# གཉིས: 55
#
# ཡེ་ཤེས: 54
#
# དེ་བཞིན: 51
#
# སྐུ: 51
#
# ཕྱིར: 51
#
# དཔལ: 50
#
# གཞན: 49
#
# གང: 46
#
# འགྱུར: 45
#
# དག་པ: 44
#
# གསུམ: 43
#
# བཞིན: 42
#
# བྱ: 40
#
# རྣམ་པར: 38
#
# གནས་པ: 38
#
# རྫོགས: 38
#
# གཅིག: 37
#
# བསྟན་པ: 34
#
# ལེའུ: 34
#
# ཕྱག: 33
#
# འཚལ: 32
#
# མཐའ: 32
#
# དེ་བཞིན་ཉིད: 31
#
# འདས: 31
#
# རྟོག: 31
#
# ཞིང: 31
#
# དབྱིངས: 31
#
# དག: 30
#
# མིན: 30
#
# དཀྱིལ་འཁོར: 30
#
# སེམས་དཔའ: 29
#
# ལྷུན: 29
#
# ལ་སོགས: 29
#
# ཕྱག་རྒྱ: 29
#
# ཡི་གེ: 29
#
# བཟང་པོ: 28
#
# བརྗོད་པ: 28
#
# ཆེན: 28
#
# ཡེ་ནས: 28
#
# བྲལ: 28
#
# ཐེག་པ: 26
#
# མེད་པར: 26
#
# གྱུར: 26
#
# སྤྱོད་པ: 26
#
# ཚུལ: 26
#
# བདག: 25
#
# ཤིང: 25
#
# ལྔ: 25
#
# རྒྱལ་པོ: 25
#
# ཁྱོད: 25
#
# བདེ་བ: 24
#
# ཡང་དག: 24
#
# བྱེད: 24
#
# འཁྲུལ: 24
#
# ཡོད: 23
#
# ཤེས: 23
#
# འབྱུང: 23
#
# དགོས: 23
#
# གྱུར་པ: 22
#
# བྱ་བ: 22
#
# རྒྱལ་བ: 22
#
# ཚིག: 21
#
# སྣང: 21
#
# སྐྱེ: 21
#
# སྣ་ཚོགས: 21
#
# རབ་ཏུ: 21
#
# ཡུལ: 21
#
# ངང: 21
#
# ཐབས: 21
#
# འབྲས་བུ: 21
#
# རྙེད: 21
#
# རྩལ: 21
#
# གཤེགས་པ: 20
#
# ཐུགས: 20
#
# ནམ་མཁའ: 20
#
# འཛིན་པ: 20
#
# Nyingma Later 13 Top 100 bigrams
# མེད: 182
#
# མི: 116
#
# ཀུན: 83
#
# མེད་པ: 73
#
# ལས: 72
#
# དབྱིངས: 71
#
# བྱང་ཆུབ: 57
#
# སེམས: 56
#
# ཆོས: 49
#
# ཉིད: 47
#
# དོན: 46
#
# ཆེན་པོ: 45
#
# ཡིན: 42
#
# གནས: 37
#
# ཡེ་ནས: 36
#
# རྫོགས: 35
#
# ཡེ་ཤེས: 34
#
# བདེ་བ: 32
#
# བྲལ: 32
#
# ལྷུན: 31
#
# སངས་རྒྱས: 31
#
# གཉིས: 29
#
# ཐམས་ཅད: 28
#
# མཐའ: 28
#
# ནམ་མཁའ: 28
#
# རྣལ་འབྱོར: 27
#
# རང་བཞིན: 27
#
# སྙིང་པོ: 27
#
# ཚིག: 27
#
# བདག: 26
#
# ལུང: 26
#
# སྐུ: 25
#
# ལམ: 25
#
# བཞིན: 25
#
# གཅིག: 25
#
# དག: 25
#
# མཆོག: 24
#
# འགྱུར: 24
#
# རྣམ་པར: 23
#
# རྒྱལ་བ: 23
#
# གསུམ: 22
#
# རྫོགས་པ: 22
#
# ཆེ: 22
#
# འདས: 22
#
# རང: 22
#
# འདས་པ: 21
#
# རྟོག་པ: 21
#
# རྣམ་དག: 20
#
# འཁྲུལ: 20
#
# དཀྱིལ་འཁོར: 20
#
# སྐྱེ: 20
#
# བདེ: 20
#
# གཞན: 20
#
# ངང: 20
#
# རྡོ་རྗེ: 19
#
# ཐབས: 18
#
# རྒྱ་མཚོ: 18
#
# པས: 18
#
# བཟང་པོ: 17
#
# ཕྱིར: 17
#
# སྒྱུ་མ: 17
#
# བྲལ་བ: 17
#
# ཀློང: 17
#
# ཐིག་ལེ: 17
#
# ཐུགས: 16
#
# རྒྱུ: 16
#
# རྟོག: 16
#
# གང: 15
#
# སེམས་ཅན: 15
#
# གྲུབ་པ: 15
#
# སྤྱོད་པ: 15
#
# གསལ: 15
#
# གསལ་བ: 15
#
# བསྒོམ: 15
#
# དེ་ཉིད: 15
#
# ཡུལ: 15
#
# རྒྱལ་པོ: 14
#
# མཉམ: 14
#
# བཀོད་པ: 14
#
# དབྱེར: 14
#
# བསྒོམ་པ: 14
#
# རྒྱུད: 13
#
# བརྗོད: 13
#
# ཐུགས་རྗེ: 13
#
# ཆེན: 13
#
# མཉམ་པ: 13
#
# ཙམ: 13
#
# དག་པ: 13
#
# ཡེ: 13
#
# ཁམས: 12
#
# དེ་བཞིན: 12
#
# ལྟ་བ: 12
#
# རྟོགས: 12
#
# ཆོས་ཉིད: 12
#
# ཕྱི: 12
#
# ཚོལ: 12
#
# བསམ: 12
#
# ཕྲ: 12
#
# ཞིང: 11
#
# རྟོགས་པ: 11

# %% [markdown]
# ## Per text top words/bigrams

# %%
N = 20

print("bon texts")
for i in range(len(bon_idx2fname)):
    words = Counter(bon_texts_f[i])
    bigrams = Counter(bon_bigrams_f[i])
    print("{} top {} words".format(bon_idx2fname[i], N))
    for k, v in words.most_common(N):
        print("{}: {}\n".format(k, v))
    print("{} top {} bigrams".format(bon_idx2fname[i], N))
    for k, v in bigrams.most_common(N):
        print("{}: {}\n".format(k, v))

print("nyingma texts")       
for i in range(len(nyingma_idx2fname)):
    words = Counter(nyingma_texts_f[i])
    bigrams = Counter(nyingma_bigrams_f[i])
    print("{} top {} words".format(nyingma_idx2fname[i], N))
    for k, v in words.most_common(N):
        print("{}: {}\n".format(k, v))
    print("{} top {} bigrams".format(nyingma_idx2fname[i], N))
    for k, v in bigrams.most_common(N):
        print("{}: {}\n".format(k, v))
# Out:
# bon texts
# 01-SMDG-gser-lung-non-che.txt top 20 words
# སེམས: 166
#
# བདག: 157
#
# ལས: 156
#
# མི: 146
#
# ལུང: 111
#
# ཡིན: 95
#
# བརྣན: 86
#
# བསྒོམ: 84
#
# མེད་པ: 81
#
# སླུ་བ: 74
#
# དོན: 72
#
# ཉིད: 72
#
# ཡིད: 66
#
# ཏིང་ངེ་འཛིན: 65
#
# ཆེན་པོ: 62
#
# མེད: 61
#
# བྱང་ཆུབ: 59
#
# གཉིས: 58
#
# བཞི: 58
#
# མཚན་མ: 58
#
# 01-SMDG-gser-lung-non-che.txt top 20 bigrams
# ལུང་བརྣན: 80
#
# སྙམ་བྱེད: 34
#
# བདག་སྒོམ་པ: 24
#
# སླུ་བ་ཡིན: 23
#
# ཉམས་སོད: 21
#
# རྣམ་པར་ཤེས་པ: 19
#
# འཕྲག་དོག: 18
#
# བོན་ཉིད: 15
#
# སླུ་བ་པོ: 15
#
# མི་ཁྱབ་པ: 13
#
# ཏན་ཏྲ: 12
#
# ཏྲ་ལས: 12
#
# རྗེས་སུ་མི: 12
#
# ལས་བྱུང་བ: 12
#
# སྤྲུལ་པ་ལས: 12
#
# འོད་དཀར: 11
#
# ཡེ་ཤེས་ཆེན་པོ: 11
#
# གཤེན་ལྷ་འོད: 10
#
# རྣམ་པ་གསུམ: 10
#
# བྱིན་ཆེ: 10
#
# 02-SMDG-gser-lung-non-chung.txt top 20 words
# མཚན་མ: 54
#
# མྱེད: 48
#
# ཐམས་ཅད: 39
#
# སེམས: 38
#
# ཉིད: 34
#
# ལས: 31
#
# ལུང: 28
#
# སེམས་ཉིད: 26
#
# བརྣན: 25
#
# དོན: 22
#
# བསྒོམ: 21
#
# བག་ཆགས: 20
#
# འབྱུང: 19
#
# བྱ་བ: 18
#
# གཤེན་ལྷ: 15
#
# རང: 15
#
# དཀར་པོ: 15
#
# ཞིང: 14
#
# མི: 14
#
# ཡེ་ཤེས: 13
#
# 02-SMDG-gser-lung-non-chung.txt top 20 bigrams
# ལུང་བརྣན: 25
#
# མཚན་མ་ཐམས་ཅད: 21
#
# སེམས་རང: 14
#
# རང་འབྱུང: 14
#
# གཤེན་ལྷ་དཀར་པོ: 14
#
# མཚན་མ་མྱེད: 10
#
# ཐམས་ཅད་ཞི: 10
#
# ཞི་ཞིང: 10
#
# ཞིང་མི་སྣང་བ: 9
#
# སེམས་མཚན་མ: 8
#
# མཐུ་རྟས་པ: 7
#
# གདོས་པ་ཅན: 6
#
# མཚན་མ་གཞོམ་པ: 6
#
# ལས་མཚན་མ: 6
#
# རྟོག་པ་མྱེད: 6
#
# ཕུང་པོ་གདོས་པ: 5
#
# སྙིང་པོ་དེས: 5
#
# འདུ་བྱེད་ལས: 5
#
# ཅེས་བྱ་བ་སེམས: 5
#
# རྣམ་པར་རྟོག་པ: 4
#
# 03-SMDG-sems-phran-rig-pa-khu-byug-sa-gcod.txt top 20 words
# སེམས: 17
#
# ཁུ་བྱུག: 14
#
# རིག་པ: 12
#
# བྱང་ཆུབ: 11
#
# བསྟན་པ: 9
#
# གསུང: 8
#
# དོན: 8
#
# བྱ: 8
#
# མྱེད: 7
#
# ལས: 7
#
# གསུམ: 7
#
# ཡན་ལག: 7
#
# སྟོན་པ: 6
#
# མཚན: 6
#
# དགུ: 5
#
# ཐམས་ཅད: 4
#
# སྙིང་པོ: 4
#
# སེམས་ཅན: 4
#
# གཉིས: 4
#
# དཔེ: 4
#
# 03-SMDG-sems-phran-rig-pa-khu-byug-sa-gcod.txt top 20 bigrams
# བྱང་ཆུབ་སེམས: 6
#
# སེམས་རིག་པ: 6
#
# ལས་མཚན: 4
#
# དངོས་མྱེད: 3
#
# མྱེད་གསུང: 3
#
# ཁུ་བྱུག་དགུ: 3
#
# རིག་པ་ཁུ་བྱུག: 2
#
# ས་གཅོད: 2
#
# སྟོན་པ་གཤེན་ལྷ: 2
#
# གཤེན་ལྷ་འོད: 2
#
# འོད་དཀར: 2
#
# རིག་པ་ལྷ: 2
#
# གདགས་ལུགས: 2
#
# དཔེ་ལས: 2
#
# དོན་ལས: 2
#
# ཅིའི་ཕྱིར་ཅེ་ན: 2
#
# སེམས་ཅན་ཐམས་ཅད: 2
#
# སེམས་སྤྲོ་བ: 2
#
# སྐྱབས་འོག: 2
#
# ཉི་ཤུ་རྩ: 2
#
# 04-SMDG-rig-pa-khu-byug-gzhung.txt top 20 words
# ཁུ་བྱུག: 62
#
# མི: 52
#
# ཡེ་ཤེས: 30
#
# མེད: 25
#
# རེ: 21
#
# སྤྲོ: 21
#
# སྒྲོགས: 20
#
# ཉིད: 19
#
# ཙམ: 19
#
# དམིགས: 19
#
# ཇི: 17
#
# ངང: 16
#
# བོན: 15
#
# རང་བཞིན: 15
#
# དཔེ: 15
#
# རྟགས: 15
#
# སྤྲུལ་པ: 14
#
# ཀུན: 14
#
# མཚན་མ: 14
#
# རིག་པ: 13
#
# 04-SMDG-rig-pa-khu-byug-gzhung.txt top 20 bigrams
# རེ་སྤྲོ: 21
#
# མི་དམིགས: 18
#
# བོན་ཉིད: 12
#
# མཚན་མ་མེད: 10
#
# དམིགས་ཡེ་ཤེས: 8
#
# ཁུ་བྱུག་བོན: 8
#
# རིག་པ་ཆེ: 8
#
# མཚོན་པ་མྱ་ངན: 8
#
# མྱ་ངན་འདས: 8
#
# རྟགས་ཅན: 7
#
# ཁུ་བྱུག་སེམས་ཉིད: 7
#
# བཅོས་ངང: 7
#
# ངང་དོན: 7
#
# ཕྱིར་ཡང་ཁུ་བྱུག: 7
#
# ཐིག་འདེབས: 7
#
# འདེབས་རིག་པ: 7
#
# འདས་སྤྲུལ་པ: 7
#
# ཁུ་བྱུག་ནམ་མཁར: 6
#
# མི་སྐྱེ: 5
#
# ཐིག་ལེ་གཅིག: 4
#
# 05-SMDG-rig-pa-khu-byug-grel.txt top 20 words
# སེམས: 207
#
# མི: 173
#
# ཁུ་བྱུག: 143
#
# བོན: 126
#
# ཉིད: 123
#
# ལས: 122
#
# བྱ: 112
#
# ཐམས་ཅད: 108
#
# རིག་པ: 105
#
# མེད་པ: 105
#
# ཆེན་པོ: 101
#
# རྟོགས: 99
#
# དོན: 96
#
# གསལ་བ: 92
#
# ནམ་མཁའ: 89
#
# བྱང་ཆུབ: 88
#
# ཞིང: 84
#
# ཡེ་ཤེས: 75
#
# སྐྱེ་བ: 75
#
# ཡིན: 70
#
# 05-SMDG-rig-pa-khu-byug-grel.txt top 20 bigrams
# བོན་ཉིད: 61
#
# རང་ཤེས་རིག: 47
#
# སྤྲོ་ཞིང: 46
#
# ཞིང་དྭང: 42
#
# སེམས་རིག་པ: 39
#
# རྣམ་པར་ཤེས་པ: 38
#
# བདེ་བ་ཆེན་པོ: 34
#
# རྟོགས་ཙམ: 32
#
# གཤེན་ལྷ་འོད: 29
#
# འོད་དཀར: 28
#
# ཉིད་བདེ་བ: 25
#
# སེམས་ཅན་ཐམས་ཅད: 22
#
# རྒྱལ་པོ་བྱང་ཆུབ: 21
#
# ཀུན་གཞི་བྱང་ཆུབ: 20
#
# གཤེན་ཕྲན: 20
#
# རིག་པ་ཐབས: 19
#
# དཔེར་ན་ནམ་མཁའ: 19
#
# བྱང་ཆུབ་སེམས: 18
#
# རྒྱལ་པོ་ཀུན་གཞི: 18
#
# འཁོར་གཤེན: 18
#
# 06-SMDG-cog-bzhag-sa-gcod.txt top 20 words
# ཅོག: 5
#
# བཞག: 5
#
# སྟོན་པ: 4
#
# སེམས: 4
#
# དོན: 4
#
# མྱེད: 3
#
# སྟོན: 3
#
# གསུམ: 3
#
# ས: 2
#
# གཅོད: 2
#
# ནང: 2
#
# གསལ: 2
#
# གསལ་བ: 2
#
# མན་ངག: 2
#
# དཀྱིལ: 2
#
# ཀླད: 2
#
# རྒྱངས: 2
#
# བསྟན: 2
#
# མདོ: 2
#
# མདོའ: 2
#
# 06-SMDG-cog-bzhag-sa-gcod.txt top 20 bigrams
# ཅོག་བཞག: 4
#
# ས་གཅོད: 2
#
# གསལ་བ་མྱེད: 2
#
# ཀླད་རྒྱངས: 2
#
# གཅོད་བཞུགས་པ: 1
#
# བཞུགས་པ་ལགས་སོ: 1
#
# ལགས་སོ་ཨེ་མ་ཧོ: 1
#
# ཨེ་མ་ཧོ་སྤུངས: 1
#
# སྨར་རོ: 1
#
# རོ་བར་སྣང: 1
#
# བར་སྣང་མཁའ: 1
#
# ཟླ་ཤར་པ: 1
#
# ཤར་པ་རྒྱ་མཚོ: 1
#
# རྒྱ་མཚོ་ཆུ: 1
#
# ཆུ་བྲན: 1
#
# བྲན་ནང: 1
#
# གསལ་རྡོ: 1
#
# རྡོ་ཤིང: 1
#
# ཤིང་ས་ལ: 1
#
# ས་ལ་གསལ་བ: 1
#
# 07-SMDG-cog-bzhag-gzhung.txt top 20 words
# རྣམ་པ: 9
#
# གསུམ་པོ: 9
#
# འདྲ: 9
#
# ཅོག: 5
#
# བཞག: 4
#
# མི: 4
#
# མྱེད: 3
#
# སྟངས: 3
#
# ཐབས: 3
#
# སྟོན་པ: 2
#
# གསུམ: 2
#
# དགུ: 2
#
# ཕྱེ: 2
#
# བཞག་པ: 2
#
# གསལ་བ: 2
#
# མཁའ: 2
#
# མན་ངག: 2
#
# ངང: 2
#
# གཞུང: 1
#
# བཞུགས: 1
#
# 07-SMDG-cog-bzhag-gzhung.txt top 20 bigrams
# རྣམ་པ་གསུམ་པོ: 9
#
# ཅོག་བཞག: 4
#
# སྟངས་རྣམ་པ: 3
#
# ཐབས་རྣམ་པ: 3
#
# གཞུང་བཞུགས: 1
#
# སྟོན་པ་ཀུན: 1
#
# བཟང་པོ་གཤེན་ལྷ: 1
#
# གཤེན་ལྷ་འོད: 1
#
# འོད་དཀར: 1
#
# དཀར་ལོ་ཕྱག: 1
#
# ལོ་ཕྱག་འཚལ: 1
#
# འཚལ་ལོ: 1
#
# ལོ་སྟོན་པ: 1
#
# སྟོན་པ་ཚད: 1
#
# ཚད་མྱེད: 1
#
# མྱེད་བཞི: 1
#
# གསུམ་གསུམ: 1
#
# གསུམ་དགུ: 1
#
# དགུ་རུ: 1
#
# རུ་ཕྱེ: 1
#
# 08-SMDG-cog-bzhag-grel.txt top 20 words
# མྱེད: 95
#
# མི: 60
#
# ཉིད: 36
#
# དོན: 32
#
# གསུམ: 30
#
# བྱ: 29
#
# ངང: 28
#
# སེམས: 27
#
# གཉིས: 25
#
# ལས: 24
#
# རྣམ་པ: 23
#
# གཞག: 23
#
# གསལ: 22
#
# ཅོག: 21
#
# པས: 20
#
# ཤེས་པ: 20
#
# བསྒོམ: 20
#
# ཆེན་པོ: 19
#
# བོན: 19
#
# འབྲས་བུ: 19
#
# 08-SMDG-cog-bzhag-grel.txt top 20 bigrams
# རྣམ་པ་གསུམ: 15
#
# བོན་ཉིད: 14
#
# མྱེད་པས: 13
#
# ཉམ་མི: 11
#
# མི་ང: 11
#
# ཙམ་ཉིད: 9
#
# ང་བར: 8
#
# ལས་འཕྲོ་དག་པ: 8
#
# འབྲས་བུ་ཐོབ: 8
#
# ཐོབ་ངེས་པ: 8
#
# བྱང་ཆུབ་སེམས: 8
#
# བདེ་བ་ཆེན་པོ: 7
#
# ཚད་མྱེད: 6
#
# རྣམ་པ་གསུམ་པོ: 6
#
# ཨེ་མ་ཧོ་གང་ཞིག: 6
#
# ཨེ་མ་ཧོ་བསྒྲུབ: 6
#
# གང་ཞིག་སྐྱེས་བུ: 5
#
# དག་ལས་འཕྲོ: 5
#
# སྟངས་རྣམ་པ: 5
#
# ལྡན་པ་ཞིག: 5
#
# 09-SMDG-rgyun-thag-sa-gcod-gzhung-grel.txt top 20 words
# མྱེད: 149
#
# སེམས: 118
#
# དོན: 72
#
# ཐམས་ཅད: 60
#
# བྱང་ཆུབ: 51
#
# པས: 51
#
# བྱ: 49
#
# ཡེ་ནས: 48
#
# ཀུན: 40
#
# མི: 39
#
# བོན: 39
#
# མཚན་མ: 36
#
# དབྱིངས: 35
#
# ཡིན: 33
#
# བརྗོད: 32
#
# རང་བཞིན: 29
#
# རིག་པ: 28
#
# ཉིད: 27
#
# ཡེ་ཤེས: 26
#
# བསྟན་པ: 26
#
# 09-SMDG-rgyun-thag-sa-gcod-gzhung-grel.txt top 20 bigrams
# བྱང་ཆུབ་སེམས: 43
#
# མྱེད་པས: 26
#
# ཡིད་ཆེས་པས: 17
#
# མཚན་མ་མྱེད: 16
#
# འདུ་འབྲལ: 15
#
# བོན་ཐམས་ཅད: 15
#
# རྒྱུན་ཐག: 14
#
# བོན་ཉིད: 14
#
# གཤེན་ལྷ་འོད: 13
#
# ཕོ་བྲང་ཡིན: 12
#
# སྐྱེ་བ་མྱེད: 12
#
# འབྲལ་མྱེད: 11
#
# བཟང་པོ་གཤེན་ལྷ: 11
#
# ཀུན་གཞི་བྱང་ཆུབ: 11
#
# སྣང་སྲིད་ཐམས་ཅད: 10
#
# འོད་དཀར: 10
#
# རིག་པ་ཀུན: 9
#
# སྐྱེ་འཆི་མྱེད: 9
#
# རྣམ་པར་དག་པ: 8
#
# དེ་ལྟ་བུ: 8
#
# 10-SMDG-sems-lung-rgyun-thag.txt top 20 words
# མི: 9
#
# མྱེད: 7
#
# བཅོས: 6
#
# དོན: 5
#
# དམྱིགས: 5
#
# ཉིད: 5
#
# སེམས: 3
#
# རྒྱུན: 3
#
# འབྲས་བུ: 3
#
# དག་པ: 3
#
# ཤེས: 3
#
# རྟོགས: 3
#
# གཡོས: 3
#
# ངང: 3
#
# འདས: 3
#
# ལུང: 2
#
# ཐག: 2
#
# སྟོན་པ: 2
#
# ཐུགས: 2
#
# ལས: 2
#
# 10-SMDG-sems-lung-rgyun-thag.txt top 20 bigrams
# མི་དམྱིགས: 5
#
# སེམས་ལུང: 2
#
# རྒྱུན་ཐག: 2
#
# ལས་དག་པ: 2
#
# མི་གཡོ: 2
#
# ཉིད་ནམ་མཁའ: 2
#
# སྤྱོད་འདས: 2
#
# བོན་ཉིད: 2
#
# ཐག་བཞུགས་པ: 1
#
# དབུ་ཕྱོགས: 1
#
# ཕྱོགས་ལགས་སོ: 1
#
# ལགས་སོ་སྟོན་པ: 1
#
# སྟོན་པ་གཤེན་ལྷ: 1
#
# གཤེན་ལྷ་འོད: 1
#
# འོད་དཀར: 1
#
# ཐུགས་ཡང་དག: 1
#
# འབྲས་བུ་ངེས་པ: 1
#
# དོན་ཕྱིས: 1
#
# ཕྱིས་བྱོན་པ: 1
#
# ཨེ་མ་ཧོ་གང: 1
#
# 11-SMDG-sems-lung-rgyun-thag-'grel.txt top 20 words
# ཉིད: 30
#
# སེམས: 23
#
# བྱ: 22
#
# ཡིན: 20
#
# ངང: 19
#
# ལས: 15
#
# མྱེད: 15
#
# ནམ་མཁའ: 14
#
# དོན: 14
#
# མི: 14
#
# བོན: 13
#
# ཡེ་ཤེས: 13
#
# བྱང་ཆུབ: 12
#
# གསལ་བ: 11
#
# དམྱིགས: 11
#
# རང་བཞིན: 9
#
# བཅོས: 9
#
# གཅིག: 8
#
# རྟོགས་པ: 8
#
# གནས་པ: 8
#
# 11-SMDG-sems-lung-rgyun-thag-'grel.txt top 20 bigrams
# བོན་ཉིད: 11
#
# བྱང་ཆུབ་སེམས: 10
#
# མི་དམྱིགས: 9
#
# ལས་འདས་པ: 5
#
# ནམ་མཁའ་ལྟར: 5
#
# ཡེ་ཤེས་ཆེན་པོ: 5
#
# ངང་ཉིད: 4
#
# ཉིད་ནམ་མཁའ: 4
#
# ཕྱི་ནང: 3
#
# མྱ་ངན་ལས: 3
#
# ལ་མ་ཡེངས་པ: 3
#
# སེམས་ནམ་མཁའ: 3
#
# ལྟར་ཡེ་ཤེས: 3
#
# ཁྱབ་བདལ: 3
#
# རང་བཞིན་མྱེད: 3
#
# ཙམ་ཉིད: 3
#
# རྒྱུན་ཐག: 2
#
# གཤེན་ལྷ་འོད: 2
#
# འོད་དཀར: 2
#
# དེ་ཡན་ཆད: 2
#
# 12-SMDG-lhug-par-bzhag-pa.txt top 20 words
# མི: 50
#
# མྱེད: 45
#
# ངང: 30
#
# ཚིག: 23
#
# བྱ་བ: 22
#
# ཡེ་ཤེས: 21
#
# སེམས: 20
#
# བསྟན་པ: 19
#
# དོན: 18
#
# གསལ: 17
#
# བསྒོམ: 15
#
# ཙམ: 15
#
# ཉིད: 14
#
# སེམས་ཉིད: 14
#
# ཡང་ན: 14
#
# བཤད: 13
#
# བོན: 12
#
# སྤྱོད་པ: 11
#
# དེ་ནས: 11
#
# མཚོན: 11
#
# 12-SMDG-lhug-par-bzhag-pa.txt top 20 bigrams
# བོན་ཉིད: 12
#
# ཡེ་ཤེས་ངང: 11
#
# མི་མཚོན: 9
#
# མི་བཤད: 9
#
# མི་བསྒོམ: 9
#
# ཡེ་ཤེས་གསལ: 8
#
# གསལ་བོན: 8
#
# མྱེད་པས: 8
#
# ཡེངས་པ་ཙམ: 7
#
# ཡང་ན་སེམས: 5
#
# མི་དམྱིགས: 3
#
# སེམས་ཡེ་ནས: 3
#
# མི་རྟོག: 3
#
# གསལ་བ་ཙམ: 3
#
# མན་ངག་ལྷུག: 2
#
# ཚད་མྱེད: 2
#
# མྱེད་འོད་ལྡན: 2
#
# དེ་ནས་ངང: 2
#
# དེ་ནས་མཚོན: 2
#
# དེ་ནས་བཤད: 2
#
# 13-ngang-thag_sems-smad-sde-dgu-TTN-v3.txt top 20 words
# བྱ: 74
#
# ལྔ: 68
#
# སེམས: 65
#
# ངང: 49
#
# མི: 46
#
# མྱེད: 43
#
# ཡེ་ཤེས: 40
#
# པོ: 39
#
# ལས: 38
#
# འི: 35
#
# ཀ: 33
#
# གཤེན་ལྷ: 31
#
# ཐག: 30
#
# རྩལ: 28
#
# འོད: 28
#
# རང: 28
#
# དུས: 27
#
# ཉིད: 26
#
# ཀུན: 25
#
# དུག: 25
#
# 13-ngang-thag_sems-smad-sde-dgu-TTN-v3.txt top 20 bigrams
# གཤེན་ལྷ་ཀ: 22
#
# བྱང་ཆུབ་སེམས: 18
#
# དུག་ལྔ: 14
#
# འོད་ལྔ: 12
#
# ངང་ཐག: 11
#
# ངང་ཉིད: 11
#
# ཐག་བཅད: 11
#
# རང་འབྱུང: 9
#
# ལྷ་ལྔ: 8
#
# མེ་ཆུ: 8
#
# ཆུ་ས: 8
#
# ཡེ་ཤེས་ལྔ: 8
#
# ཐེག་སྒོ: 7
#
# ལས་འདས: 7
#
# བོན་ཉིད: 7
#
# པོ་འི: 6
#
# གསང་སྒོ: 6
#
# རྩལ་གསུམ: 6
#
# ས་རླུང: 6
#
# སེམས་རང: 6
#
# 14-SMDG-thig-le-dbyings-kyi-ti-ka-v2.txt top 20 words
# ལས: 86
#
# བྱ: 82
#
# དོན: 73
#
# ཡེ་ཤེས: 65
#
# ལྷ: 64
#
# གནས: 45
#
# དབྱིངས: 41
#
# ལྔ: 41
#
# སྤྲུལ: 36
#
# བོན: 33
#
# མེད་པ: 32
#
# གསལ་བ: 31
#
# སྐུ: 31
#
# བྱ་བ: 29
#
# བཞི: 29
#
# རང: 28
#
# གསུམ: 28
#
# བདག: 28
#
# ཐམས་ཅད: 26
#
# གསའ: 26
#
# 14-SMDG-thig-le-dbyings-kyi-ti-ka-v2.txt top 20 bigrams
# སྤྲུལ་ལོ: 17
#
# བརྒྱུད་དེས: 17
#
# བཞི་བཅུ: 13
#
# བཅུ་རྩ: 10
#
# རྩ་ལྔ: 9
#
# རང་འབྱུང: 8
#
# དེ་ལྟ་བུ: 8
#
# ལྷ་མོ་ལས: 8
#
# ཐིག་ལེ་དབྱིངས: 7
#
# ཡོངས་སུ་རྫོགས་པ: 7
#
# ལས་འདས་པ: 7
#
# ཡེ་གཤེན་གཙུག་ཕུད: 7
#
# བོན་ཉིད: 7
#
# རུ་སྤྲུལ: 7
#
# གཡུང་དྲུང་ཡོངས་སུ: 6
#
# གསང་བ་འདུས་པ: 6
#
# ཁྲི་བཞི་ནམ: 6
#
# བཞི་ནམ་ཏིང: 6
#
# མཁའ་འགྱིང: 6
#
# ཐུགས་ཉིད: 5
#
# nyingma texts
# L1-rig-pa'i-khu-byug_p302-324.txt top 20 words
# མི: 79
#
# ཀུན: 54
#
# རྡོ་རྗེ: 52
#
# ཆེན་པོ: 40
#
# མེད: 39
#
# ལས: 38
#
# ཐམས་ཅད: 33
#
# བཅོམ་ལྡན་འདས: 30
#
# སྐུ: 29
#
# ཉིད: 27
#
# མཆོག: 26
#
# ཡེ་ཤེས: 25
#
# ཆོས: 24
#
# མེད་པ: 22
#
# ཡིན: 21
#
# སངས་རྒྱས: 21
#
# ཐེག་པ: 20
#
# ཕྱིར: 20
#
# ལམ: 20
#
# ཁྱོད: 20
#
# L1-rig-pa'i-khu-byug_p302-324.txt top 20 bigrams
# དེ་ནས་བཅོམ་ལྡན་འདས: 15
#
# ཕྱག་འཚལ: 13
#
# བཅོམ་ལྡན་འདས་དཔལ: 11
#
# དཔལ་ཀུན: 11
#
# རྡོ་རྗེ་ཐེག་པ: 11
#
# རྡོ་རྗེ་སེམས་དཔའ: 10
#
# དེ་བཞིན་གཤེགས་པ: 7
#
# ཆོས་ཐམས་ཅད: 6
#
# ལས་འདས: 6
#
# མི་རྟོག: 6
#
# བཀྲ་ཤིས་པ་རིག་པ: 6
#
# བཅོམ་ལྡན་འདས་ཆེན་པོ: 5
#
# ཐེག་པ་ཆེན་པོ: 5
#
# ལས་འདས་པ: 5
#
# རྒྱུད་ལས: 5
#
# དཀྱིལ་འཁོར་ཆེན་པོ: 5
#
# རྟག་ཕྱག: 5
#
# རྡོ་རྗེ་འཛིན་པ: 5
#
# ངོ་བོ་ཉིད: 4
#
# རྣམ་པར་དག་པ: 4
#
# L2-rtsal-chen_p436-447་.txt top 20 words
# མི: 41
#
# མེད: 41
#
# ཉིད: 30
#
# ཀུན: 29
#
# ལས: 27
#
# བཅོམ་ལྡན་འདས: 26
#
# ཆོས: 26
#
# དོན: 25
#
# བྱང་ཆུབ: 19
#
# སེམས: 19
#
# དེ་ནས: 18
#
# གཉིས: 18
#
# གནས: 18
#
# རྒྱུད: 17
#
# དཔལ: 17
#
# སངས་རྒྱས: 17
#
# ལམ: 17
#
# རྩལ: 16
#
# ཆེན: 16
#
# མེད་པ: 15
#
# L2-rtsal-chen_p436-447་.txt top 20 bigrams
# བཅོམ་ལྡན་འདས་དཔལ: 16
#
# དེ་ནས་བཅོམ་ལྡན་འདས: 14
#
# གཉིས་མེད: 14
#
# བྱང་ཆུབ་སེམས: 12
#
# རྩལ་ཆེན: 12
#
# དཔལ་ཀུན: 11
#
# སེམས་རྩལ: 10
#
# རྒྱུད་ལས: 9
#
# དཔལ་རྡོ་རྗེ: 5
#
# རྡོ་རྗེ་སེམས་དཔའ: 5
#
# བཅོམ་ལྡན་འདས་ཀུན: 5
#
# ཆེན་སྤྲུགས་པ: 5
#
# ཕྱག་འཚལ: 4
#
# རྣམ་པར་དག་པ: 4
#
# བཀའ་སྩལ: 4
#
# མི་གནས: 4
#
# རྣམ་པར་དག: 4
#
# ནོར་བུ་རིན་པོ་ཆེ: 3
#
# རྩལ་སྤྲུགས: 3
#
# སངས་རྒྱས་སེམས་ཅན: 3
#
# L3-khyung-chen_p447-468.txt top 20 words
# མི: 130
#
# མེད: 71
#
# ཉིད: 66
#
# གནས: 56
#
# ཀུན: 50
#
# ལམ: 45
#
# བྱང་ཆུབ: 39
#
# ཆོས: 31
#
# ཡིན: 31
#
# ལས: 31
#
# དོན: 26
#
# སངས་རྒྱས: 26
#
# སྙིང་པོ: 23
#
# མཆོག: 20
#
# རང་བཞིན: 20
#
# རྒྱུད: 20
#
# སེམས: 19
#
# དེ་བཞིན: 19
#
# གནས་པ: 19
#
# ཐམས་ཅད: 19
#
# L3-khyung-chen_p447-468.txt top 20 bigrams
# མི་གནས: 22
#
# མི་དགོས: 15
#
# བཅོམ་ལྡན་འདས་དཔལ: 13
#
# དཔལ་ཀུན: 11
#
# སེམས་ཁྱུང་ཆེན: 11
#
# དེ་ནས་བཅོམ་ལྡན་འདས: 10
#
# རྒྱུད་ལས: 10
#
# མི་རྙེད: 9
#
# མི་རྟོག: 7
#
# བཟང་པོ་ཉིད: 6
#
# མི་བྱེད: 6
#
# བྱང་ཆུབ་སེམས: 6
#
# མི་འགྱུར: 5
#
# ལྷུན་རྫོགས: 5
#
# རྡོ་རྗེ་སེམས་དཔའ: 4
#
# ལམ་མི: 4
#
# ཆོས་ལམ: 4
#
# རང་བཞིན་གནས་པ: 4
#
# བྱང་ཆུབ་སྙིང་པོ: 4
#
# གནས་མེད: 4
#
# L4_byang-sems-bsgom-rdo-la-gser-zhun-p416-425.txt top 20 words
# མི: 50
#
# མེད: 47
#
# ཀུན: 24
#
# ལམ: 23
#
# ཡིན: 22
#
# གནས: 20
#
# ཆོས: 18
#
# ཕྱིར: 18
#
# ལས: 17
#
# འགྱུར: 16
#
# སེམས: 15
#
# བྱང་ཆུབ: 13
#
# དེ་དག: 13
#
# ཤེས: 12
#
# ཤིང: 12
#
# ཉིད: 11
#
# རྟོག: 11
#
# ཞིང: 11
#
# གྱུར་པ: 9
#
# གང: 9
#
# L4_byang-sems-bsgom-rdo-la-gser-zhun-p416-425.txt top 20 bigrams
# མེད་ཕྱིར: 9
#
# མི་འགྱུར: 5
#
# མི་བྱེད: 5
#
# མི་གནས: 5
#
# བྱང་ཆུབ་སེམས: 4
#
# མི་རྟོག: 4
#
# རྒྱལ་བ་ཀུན: 3
#
# རྒྱལ་བས་གསུངས: 3
#
# སྣ་ཚོགས་དག: 3
#
# མཐའ་ཡ: 3
#
# སྒོམ་པ་རྡོ: 2
#
# གསེར་ཞུན: 2
#
# ཉིད་བདེ་གཤེགས: 2
#
# འཇམ་དཔལ་གཞོན་ནུ: 2
#
# ཕ་རོལ་ཕྱིན: 2
#
# རྡོ་རྗེ་རྩེ་མོ: 2
#
# བྱང་ཆུབ་སེམས་ཉིད: 2
#
# བྱང་ཆུབ་སེམས་དཔའ: 2
#
# མི་འབྱུང: 2
#
# ལམ་ཉིད: 2
#
# L5_nam-mkha'-che-rgyas-pa-yi-ge-med-pa_V8-p.468-473.txt top 20 words
# མེད་པ: 23
#
# ཡི་གེ: 22
#
# མཆོག: 12
#
# དེ་ནས: 11
#
# ལས: 11
#
# མེད: 11
#
# རྒྱུད: 8
#
# དོན: 8
#
# ཡི: 8
#
# བཀག: 8
#
# འཁོར: 7
#
# གཤེགས་པ: 7
#
# ལེའུ: 7
#
# ནམ་མཁའ: 6
#
# མཚན་མ: 6
#
# བདག་པོ: 6
#
# དོན་དམ: 6
#
# ཡེ་ཤེས: 6
#
# ལ་སོགས: 5
#
# ཞུས་པ: 5
#
# L5_nam-mkha'-che-rgyas-pa-yi-ge-med-pa_V8-p.468-473.txt top 20 bigrams
# ཡི་གེ་མེད་པ: 16
#
# མེད་པ་ལས: 4
#
# དེ་ནས་བདག་པོ: 4
#
# བཀའ་སྩལ: 4
#
# ཡི་གེ་མེད: 3
#
# སྔོན་མ་ཐོས་པ: 2
#
# དེ་ནས་འཁོར: 2
#
# དེ་བཞིན་གཤེགས་པ: 2
#
# གསོལ་ཡི་གེ: 2
#
# ཤིན་ཏུ་བཟློག: 2
#
# མགྲིན་གཅིག: 2
#
# གཤེགས་པ་ཡི་གེ: 2
#
# རིན་ཆེན་རིགས: 2
#
# ཡི་དོན: 2
#
# རྒྱུད་མཆོག: 2
#
# རང་བཞིན་གནས་པ: 2
#
# གང་ལྡན་པ: 2
#
# ཡི་གེ་མེད་པར: 2
#
# སེམས་དཔའ་དགྱེས་པ: 2
#
# དགྱེས་པ་ལ་སོགས: 2
#
# LL01_L14_rtse-mo-byung-rgyal_vol8-p480-491.txt top 20 words
# མེད: 33
#
# དབྱིངས: 30
#
# ཆོས: 22
#
# བྱང་ཆུབ: 22
#
# མི: 22
#
# ལས: 20
#
# ཀུན: 20
#
# དོན: 17
#
# སེམས: 15
#
# དཀྱིལ་འཁོར: 15
#
# རྣམ་པར: 15
#
# རྣམ་དག: 14
#
# ཆེན་པོ: 13
#
# ཡེ་ཤེས: 12
#
# སྐུ: 12
#
# བདག: 12
#
# རྣལ་འབྱོར: 12
#
# སངས་རྒྱས: 12
#
# འགྱུར: 12
#
# རྫོགས: 11
#
# LL01_L14_rtse-mo-byung-rgyal_vol8-p480-491.txt top 20 bigrams
# བྱང་ཆུབ་སེམས: 9
#
# བྱང་ཆུབ་སྙིང་པོ: 9
#
# གཉིས་མེད: 7
#
# རྣམ་པར་དག: 7
#
# ལྷུན་རྫོགས: 6
#
# དབྱིངས་ལས: 5
#
# སྐྱེ་མེད: 5
#
# བདེ་བ་ཆེན་པོ: 4
#
# ཕྱི་ནང: 4
#
# མི་རྟོག: 4
#
# རྣམ་དག་བྱང་ཆུབ: 3
#
# མཉམ་སྦྱོར: 3
#
# རྣམ་གྲངས: 3
#
# མི་གནས: 3
#
# རྡུལ་ཙམ: 3
#
# ཙམ་མེད: 3
#
# ཡེ་ནས་ལྷུན་གྲུབ: 3
#
# རྟོག་པ་མི: 3
#
# མེད་དོན: 3
#
# ཆོ་འཕྲུལ་སྣ་ཚོགས: 3
#
# LL02_་nam-mkha'-rgyal-po_vol8-v475-480.txt top 20 words
# མེད: 51
#
# མི: 25
#
# ནམ་མཁའ: 20
#
# ལས: 15
#
# བྲལ: 14
#
# ཀུན: 10
#
# ཡེ་ཤེས: 10
#
# སེམས: 10
#
# མེད་པ: 10
#
# སྒྱུ་མ: 10
#
# དབྱིངས: 9
#
# ཉིད: 8
#
# འདས་པ: 8
#
# མཐའ: 8
#
# བརྗོད: 7
#
# ཚིག: 7
#
# བྲལ་བ: 7
#
# མཚན་ཉིད: 6
#
# དེ་ཉིད: 6
#
# འདས: 6
#
# LL02_་nam-mkha'-rgyal-po_vol8-v475-480.txt top 20 bigrams
# ལས་འདས: 6
#
# ལས་འདས་པ: 5
#
# བརྗོད་མེད: 4
#
# མི་གནས: 4
#
# མེད་ལས: 3
#
# མི་ནུས: 3
#
# མཐའ་ཀུན: 3
#
# དབྱིངས་ལས: 3
#
# ནམ་མཁའ་ཆེ: 2
#
# མེད་ནམ་མཁའ: 2
#
# ནམ་མཁའ: 2
#
# དབུས་མཐའ: 2
#
# མེད་དབང་པོ: 2
#
# གཉིས་མེད: 2
#
# སེམས་མེད: 2
#
# ཞིང་རྟོགས་པ: 2
#
# ཀུན་མེད: 2
#
# མཐའ་ལས: 2
#
# མེད་དག: 2
#
# འཛིན་མེད: 2
#
# LL03_L16_bde-ba-phra-bkod_V8-p.495-498.txt top 20 words
# མེད: 28
#
# མེད་པ: 15
#
# ཕྲ: 11
#
# བཀོད་པ: 11
#
# མི: 11
#
# བདེ་བ: 10
#
# བྲལ: 8
#
# སྐྱེ: 8
#
# ཀློང: 8
#
# རང: 8
#
# ཀུན: 7
#
# སེམས: 6
#
# དོན: 6
#
# ལས: 6
#
# དབྱིངས: 6
#
# ཡིན: 6
#
# བྲལ་བ: 6
#
# ཡེ: 6
#
# ལྷུན: 5
#
# གྲུབ་པ: 5
#
# LL03_L16_bde-ba-phra-bkod_V8-p.495-498.txt top 20 bigrams
# ཕྲ་བཀོད་པ: 10
#
# མི་སྐྱེ: 4
#
# སྐྱེ་མེད: 3
#
# སྣང་བ་རང: 3
#
# བདེ་བ་ཕྲ: 2
#
# སྤང་ལེན: 2
#
# མྱ་ངན་འདས: 2
#
# བདེ་བ་རང: 2
#
# དབུས་མེད: 2
# དངོས་པོ་ཀུན: 2
#
# མེད་དབྱིངས: 2
#
# ལས་འདས: 2
#
# འཁོར་བ་མྱ་ངན: 2
#
# སྡུག་བསྔལ་བྲལ་བ: 2
#
# བྲལ་བ་ཡིན: 2
#
# ཡེ་བརྡལ: 2
#
# མེད་སྣང་བ: 2
#
# སྐྱེ་དབྱིངས: 2
#
# རིག་པ་རང: 2
#
# ཤར་དོན་དམ: 2
#
# LL04_byang-chub-sems-tig.txt top 20 words
# མེད: 6
#
# ཚོལ: 4
#
# ལས: 3
#
# བདེ་བ: 3
#
# སངས་རྒྱས: 3
#
# མི: 3
#
# བྱང་ཆུབ: 2
#
# ལུས: 2
#
# འདས་པ: 2
#
# ཀློང: 2
#
# དབྱེར: 2
#
# ཉམས: 2
#
# ཡེ་ནས: 2
#
# དག་པ: 2
#
# ཡིན: 2
#
# ཡེ: 2
#
# མེད་པ: 2
#
# ཚིག: 2
#
# བལྟ: 2
#
# དོན: 2
#
# LL04_byang-chub-sems-tig.txt top 20 bigrams
# དབྱེར་མེད: 2
#
# ཡེ་ནས་དག་པ: 2
#
# མེད་ཡེ: 2
#
# ཡེ་སངས་རྒྱས: 2
#
# མི་བལྟ: 2
#
# སེམས་ཏིག: 1
#
# ཏིག་ཆོས: 1
#
# ལུས་དབྱིངས: 1
#
# རྒྱུ་གཅིག་པ: 1
#
# འཁོར་བ་མྱ: 1
#
# མྱ་ངན: 1
#
# ངན་འདས་པ: 1
#
# འདས་པ་གཉིས: 1
#
# གཉིས་མེད: 1
#
# ཀློང་དབྱེར: 1
#
# མེད་ཀློང: 1
#
# ཀློང་ལས: 1
#
# ཉམས་བདེ་བ: 1
#
# སྐུ་སྣང་སྲིད: 1
#
# ལུས་ཡེ་ནས: 1
#
# LL05_spyi-bcings-spyi-chings_Liljenberg-p268ff.txt top 20 words
# མི: 17
#
# ལུང: 14
#
# ཆེན་པོ: 14
#
# རྟོག་པ: 12
#
# གསུམ: 10
#
# སྔགས: 9
#
# གཅིག: 9
#
# གསལ་བ: 8
#
# བདག: 8
#
# མེད་པ: 7
#
# ཉིད: 7
#
# ལས: 7
#
# ཡིན: 7
#
# མེད: 6
#
# ངང: 6
#
# དག: 6
#
# རྒྱུ: 6
#
# རྫོགས་པ: 5
#
# ཆེ: 5
#
# འགྱུར: 5
#
# LL05_spyi-bcings-spyi-chings_Liljenberg-p268ff.txt top 20 bigrams
# སྤྱི་བཅིངས: 2
#
# བཤད་དེ་བ: 2
#
# མི་རུང: 2
#
# རྣམ་པར་མི: 2
#
# མི་རྟོག་པ: 2
#
# ཉེན་ཆེ: 2
#
# རྫོགས་པ་ཆེན་པོ: 2
#
# རྟག་པ་ཆེན་པོ: 2
#
# ལུང་ཆེན་པོ: 2
#
# མི་བཏུབ: 2
#
# མི་ཁྱབ་པ: 2
#
# ཕྱི་ནང: 2
#
# ཚིག་གསུམ: 2
#
# དཔལ་ཀུན: 1
#
# ཕྱག་འཚལ: 1
#
# འཚལ་ལོ: 1
#
# ལོ་སྤྱི: 1
#
# བཅིངས་སྔགས: 1
#
# འདྲེས་གསལ་བ: 1
#
# བདག་ཉིད་༢༠༢༡: 1
#
# LL06_L15_bde-ba-rab-'byams_vol8-p.473-475-not-sure.txt top 20 words
# མེད་པ: 18
#
# དབྱིངས: 12
#
# མེད: 12
#
# ཐིག་ལེ: 12
#
# ཉིད: 11
#
# བདེ: 8
#
# རྫོགས: 6
#
# ཆེ: 6
#
# མི: 4
#
# ལྷུན: 4
#
# ཐམས་ཅད: 4
#
# ལས: 4
#
# བྱང་ཆུབ: 4
#
# ཀུན: 3
#
# བཙལ: 3
#
# དབྱེར: 3
#
# ཡེ་ཤེས: 3
#
# ཡེ་ནས: 3
#
# སྐུ: 3
#
# རྡོ་རྗེ: 3
#
# LL06_L15_bde-ba-rab-'byams_vol8-p.473-475-not-sure.txt top 20 bigrams
# ཐིག་ལེ་བདེ: 4
#
# དབྱེར་མེད: 3
#
# ལྷུན་རྫོགས: 3
#
# རྫོགས་ཐིག་ལེ: 3
#
# དབྱིངས་ཉིད: 3
#
# བྱང་ཆུབ་སྐུ: 3
#
# བདེ་འབྱམས: 2
#
# མེད་ལྷུན: 2
#
# ཉིད་ཆེ: 2
#
# བྱ་བ་མེད་པ: 2
#
# ཉིད་ལས: 2
#
# སྐུ་ཐིག་ལེ: 2
#
# ཐིག་ལེ་མེད་པ: 2
#
# ནུབ་པ་མེད: 2
#
# མེད་བསྒོམ་པ: 2
#
# འགྱུར་བ་མེད་པ: 2
#
# བལ་ནག: 2
#
# དེ་ནས་འཁོར: 1
#
# བསྒོམ་བསྒྲུབ: 1
#
# བསྒྲུབ་ཀུན: 1
#
# LL07_L10_srog-gi-'khor-lo_v8.p491-494.txt top 20 words
# མེད: 12
#
# མི: 10
#
# རང་བཞིན: 8
#
# ཆོས་དབྱིངས: 8
#
# དབྱིངས: 7
#
# འཁོར་ལོ: 6
#
# ངང: 6
#
# སྐུ་གསུང་ཐུགས: 6
#
# རྒྱལ་བ: 6
#
# ཡོངས: 6
#
# ཐུགས: 6
#
# རྫོགས: 6
#
# ཀུན: 5
#
# བྱང་ཆུབ: 5
#
# སྙིང་པོ: 5
#
# འདུས: 5
#
# རྒྱ་མཚོ: 5
#
# མེད་པ: 5
#
# སྲོག: 4
#
# ཐབས: 4
#
# LL07_L10_srog-gi-'khor-lo_v8.p491-494.txt top 20 bigrams
# བྱང་ཆུབ་སེམས: 3
#
# མི་ཟད་རྒྱན: 3
#
# རྣལ་འབྱོར་ཡོངས: 2
#
# རང་རིག་དབང་ཕྱུག: 2
#
# སྐྱེ་མེད: 2
#
# མྱ་ངན་འདས: 2
#
# ང་མེད: 2
#
# མེད་བདག: 2
#
# མེད་པ་ཡུམ: 2
#
# ཡེ་ཤེས་དབྱིངས: 2
#
# མཆོག་མི་ཟད: 2
#
# རྒྱུ་གཅིག: 2
#
# བསམ་མི: 2
#
# མི་ཁྱབ: 2
#
# འཁོར་ལོ་བཅོམ་ལྡན་འདས: 1
#
# བཅོམ་ལྡན་འདས་ཏེ་མ: 1
#
# ཏེ་མ་ལུས: 1
#
# ལུས་ཀུན: 1
#
# དཔལ་ཐུགས་རྗེ: 1
#
# ཐུགས་རྗེ་ཐབས: 1
#
# LL08_thig-le-drug-pa-NGB-vol33.txt top 20 words
# ཀུན: 16
#
# མེད: 15
#
# མི: 15
#
# གནས: 10
#
# ལམ: 10
#
# ལས: 6
#
# ཤིང: 6
#
# ཆོས: 6
#
# ཉིད: 6
#
# བྲལ: 6
#
# ཡུལ: 6
#
# སེམས: 5
#
# གཉིས: 5
#
# མཐའ: 5
#
# རང་བཞིན: 5
#
# ཆེན་པོ: 4
#
# བྱང་ཆུབ: 4
#
# རྒྱུད: 4
#
# རང: 4
#
# དག: 4
#
# LL08_thig-le-drug-pa-NGB-vol33.txt top 20 bigrams
# རྒྱུད་ལས: 3
#
# གཉིས་མེད: 3
#
# རྫོགས་པ་ཆེན་པོ: 2
#
# རྒྱ་མཚོ་གནས: 2
#
# སངས་རྒྱས་ཀུན: 2
#
# བྱང་ཆུབ་སེམས: 2
#
# མེད་སྔོན: 2
#
# མེད་ཡང་དག: 2
#
# མེད་འདྲེས: 2
#
# འདྲེས་ཤིང: 2
#
# མི་བྱེད: 2
#
# བྲལ་ཟིན་པ: 2
#
# ཆེན་པོ་ཆོས་ཉིད: 1
#
# ཆོས་ཉིད་བྱང་ཆུབ: 1
#
# སེམས་ཐིག་ལེ: 1
#
# ཐིག་ལེ་རྒྱ་མཚོ: 1
#
# ལས་ཞུས་པ: 1
#
# དེ་ནས་སངས་རྒྱས: 1
#
# བསྟོད་བྱས: 1
#
# བྱས་ཤིང: 1
#
# LL09_spyi-gcod_vol8_p.498.txt top 20 words
# མེད: 6
#
# བལྟ: 4
#
# བདེ་བ: 3
#
# སངས་རྒྱས: 3
#
# ཚོལ: 3
#
# དོན: 3
#
# མི: 3
#
# བྱང་ཆུབ: 2
#
# ལུས: 2
#
# འདས་པ: 2
#
# ཀློང: 2
#
# དབྱེར: 2
#
# ཉམས: 2
#
# ཡེ་ནས: 2
#
# དག་པ: 2
#
# ཡིན: 2
#
# ཡེ: 2
#
# མེད་པ: 2
#
# ཚིག: 2
#
# ལས: 2
#
# LL09_spyi-gcod_vol8_p.498.txt top 20 bigrams
# དབྱེར་མེད: 2
#
# ཡེ་ནས་དག་པ: 2
#
# མེད་ཡེ: 2
#
# ཡེ་སངས་རྒྱས: 2
#
# མི་བལྟ: 2
#
# བསྲུངས་ཕྲ: 1
#
# ཕྲ་བཀོད་པ: 1
#
# སེམས་རྫོགས་པ: 1
#
# རྫོགས་པ་སྤྱི: 1
#
# སྤྱི་གཅོད: 1
#
# ཟེར་ཏིག: 1
#
# ཏིག་ཆོས: 1
#
# ལུས་དབྱིངས: 1
#
# རྒྱུ་གཅིག་པ: 1
#
# འཁོར་བ་མྱ་ངན: 1
#
# མྱ་ངན་འདས་པ: 1
#
# འདས་པ་གཉིས: 1
#
# གཉིས་མེད: 1
#
# ཀློང་དབྱེར: 1
#
# མེད་ཀློང: 1
#
# LL10_yid-bzhin-nor-bu-431.txt top 20 words
# མེད: 3
#
# ལས: 2
#
# ཆེན་པོ: 2
#
# རྟག: 2
#
# སྤྱོད་ཡུལ: 2
#
# དེ་ནས: 1
#
# བཅོམ་ལྡན: 1
#
# བཀའ: 1
#
# སྩལ: 1
#
# ཁམས: 1
#
# གསུམ: 1
#
# འདས: 1
#
# རིན་ཆེན: 1
#
# དག: 1
#
# བགྲོད: 1
#
# རྣམ་གྲོལ: 1
#
# ལམ: 1
#
# སྟོན་པ: 1
#
# གཞན: 1
#
# རྙེད་པ: 1
#
# LL10_yid-bzhin-nor-bu-431.txt top 20 bigrams
# དེ་ནས་བཅོམ་ལྡན: 1
#
# བཅོམ་ལྡན་བཀའ: 1
#
# བཀའ་སྩལ: 1
#
# ཁམས་གསུམ: 1
#
# གསུམ་ལས: 1
#
# ལས་འདས: 1
#
# འདས་རིན་ཆེན: 1
#
# རིན་ཆེན་དག: 1
#
# དག་བགྲོད: 1
#
# བགྲོད་མེད: 1
#
# མེད་རྣམ་གྲོལ: 1
#
# རྣམ་གྲོལ་ལམ: 1
#
# ལམ་སྟོན་པ: 1
#
# སྟོན་པ་གཞན: 1
#
# མི་འགྱུར: 1
#
# ཐིག་ལེ་ཆེན་པོ: 1
#
# ཆེན་པོ་ཀུན་ཁྱབ: 1
#
# ཀུན་ཁྱབ་གནས: 1
#
# གནས་རང་བྱུང: 1
#
# བཅོས་ཡེ་ནས: 1
#
# LL11_kun-'dus-NGB-mtshams-brag-vol1-624-626་.txt top 20 words
# ཀུན: 6
#
# ཐམས་ཅད: 5
#
# ཡུལ: 4
#
# ལས: 4
#
# བྱང་ཆུབ: 4
#
# མེད: 4
#
# འདུས: 3
#
# ཡེ་ནས: 3
#
# དབྱིངས: 3
#
# དགུ: 3
#
# གམ: 3
#
# ལྷུན: 3
#
# ཀློང: 3
#
# གསལ: 3
#
# བདེ་བ: 2
#
# ངང: 2
#
# ཕྱིར: 2
#
# མཐའ: 2
#
# གཅིག: 2
#
# སྣང: 2
#
# LL11_kun-'dus-NGB-mtshams-brag-vol1-624-626་.txt top 20 bigrams
# ཀུན་འདུས: 2
#
# བྱང་ཆུབ་མཆོག: 2
#
# རྒྱ་གར་སྐད: 1
#
# ས་རྦ: 1
#
# རྦ་ཨ: 1
#
# ཨ་ཏ: 1
#
# ཏ་བོད་སྐད: 1
#
# འདུས་བཅོམ་ལྡན་འདས: 1
#
# བཅོམ་ལྡན་འདས་བྱ་བྲལ: 1
#
# བྱ་བྲལ་བདེ་བ: 1
#
# ཕྱག་འཚལ: 1
#
# འཚལ་ལོ: 1
#
# ལོ་ཆོས་སྐུ: 1
#
# ཆོས་སྐུ་ཡེ་ནས: 1
#
# ཡེ་ནས་རྣམ་པར: 1
#
# རྣམ་པར་རབ: 1
#
# རབ་དབེན་པ: 1
#
# རྣམ་རྟོག: 1
#
# རྟོག་བླ་དགས: 1
#
# བླ་དགས་ཡུལ: 1
#
# LL12_rje-btsan-dam-pa_NGB-vol34-p63-64.txt top 20 words
# ཀུན: 6
#
# དོན: 4
#
# ལུང: 4
#
# རྗེ་བཙན: 3
#
# རྣལ་འབྱོར: 3
#
# དམ་པ: 2
#
# ལྷ: 2
#
# ལས: 2
#
# མཆོག: 2
#
# འཕགས་པ: 2
#
# རྡོ་རྗེ: 2
#
# རྫོགས་པ: 2
#
# ཡིན: 2
#
# ངེས་པ: 2
#
# ཆེན: 2
#
# རྒྱ་གར: 1
#
# སྐད: 1
#
# ཙ་ར: 1
#
# ཤ: 1
#
# ཨ: 1
#
# LL12_rje-btsan-dam-pa_NGB-vol34-p63-64.txt top 20 bigrams
# རྗེ་བཙན་དམ་པ: 2
#
# རྒྱ་གར་སྐད: 1
#
# ཙ་ར་ཤ: 1
#
# ཤ་ཨ: 1
#
# ཐུ་བོད་སྐད: 1
#
# དམ་པ་བཅོམ་ལྡན་འདས: 1
#
# བཅོམ་ལྡན་འདས་དཔལ: 1
#
# དཔལ་ཀུན: 1
#
# ཕྱག་འཚལ: 1
#
# འཚལ་ལོ: 1
#
# ལོ་ཁྲེན: 1
#
# རྣལ་འབྱོར་ལྷ: 1
#
# ལྷ་ཡི: 1
#
# ཡི་ལྷ: 1
#
# ལྷ་རྣལ་འབྱོར: 1
#
# རྣལ་འབྱོར་ལས: 1
#
# རྣལ་འབྱོར་མཆོག: 1
#
# མཆོག་འཕགས་པ: 1
#
# འཕགས་པ་ལས: 1
#
# རྡོ་རྗེ་རྒྱལ་བ: 1
#
# LL13-sgom-pa-don-grubdocx.txt top 20 words
# སེམས: 6
#
# མེད: 5
#
# བྱང་ཆུབ: 4
#
# ཆོས: 4
#
# ཀུན: 3
#
# ཆེན་པོ: 3
#
# མི: 3
#
# བསྒོམ་པ: 3
#
# སྒོམ་པ: 2
#
# བྱ་བ: 2
#
# བདེ་བ: 2
#
# སེམས་ཅན: 2
#
# ཁྱབ: 2
#
# བྱ: 2
#
# ཆོས་ཉིད: 2
#
# རྟོགས་པ: 2
#
# གཉིས: 2
#
# རང་བཞིན: 2
#
# གཞན: 2
#
# ཅི་ཡང: 2
#
# LL13-sgom-pa-don-grubdocx.txt top 20 bigrams
# མེད་སེམས: 2
#
# བྱང་ཆུབ་སེམས: 2
#
# རྒྱ་གར་སྐད: 1
#
# བོ་དྷི་ཙི་ཏ: 1
#
# ཙི་ཏ་ས་མ་ཏི: 1
#
# ས་མ་ཏི་ཨ་མོ་གྷ: 1
#
# ཨ་མོ་གྷ་ཙ་ན: 1
#
# སེམས་སྒོམ་པ: 1
#
# སྒོམ་པ་དོན་གྲུབ: 1
#
# བྱ་བ་དཔལ: 1
#
# དཔལ་ཀུན: 1
#
# བཟང་པོ་བདེ་བ: 1
#
# བདེ་བ་ཆེན་པོ: 1
#
# ཕྱག་འཚལ: 1
#
# འཚལ་ཐུག: 1
#
# ཐུག་རྗེ: 1
#
# རྗེ་རྒྱ་མཚོ: 1
#
# རྒྱ་མཚོ་སེམས་ཅན: 1
#
# སེམས་ཅན་ཀུན: 1
#
# ཁྱབ་ལྷ: 1

# %%
print("bon large texts")
for i in range(len(bon_large_idx2fname)):
    words = Counter(bon_large_texts_f[i])
    bigrams = Counter(bon_large_bigrams_f[i])
    print("{} top {} words".format(bon_large_idx2fname[i], N))
    for k, v in words.most_common(N):
        print("{}: {}\n".format(k, v))
    print("{} top {} bigrams".format(bon_large_idx2fname[i], N))
    for k, v in bigrams.most_common(N):
        print("{}: {}\n".format(k, v))

print("nyingma large texts")       
for i in range(len(nyingma_large_idx2fname)):
    words = Counter(nyingma_large_texts_f[i])
    bigrams = Counter(nyingma_large_bigrams_f[i])
    print("{} top {} words".format(nyingma_large_idx2fname[i], N))
    for k, v in words.most_common(N):
        print("{}: {}\n".format(k, v))
    print("{} top {} bigrams".format(nyingma_large_idx2fname[i], N))
    for k, v in bigrams.most_common(N):
        print("{}: {}\n".format(k, v))
# Out:
# bon large texts
# Kanjur-172-gab-pa-dgu་_pp.1-565.txt top 20 words
# ལས: 1937
#
# སེམས: 1097
#
# མི: 992
#
# མེད་པ: 805
#
# དོན: 662
#
# མེད: 627
#
# བྱང་ཆུབ: 604
#
# ཉིད: 561
#
# བྱ: 518
#
# ཐམས་ཅད: 488
#
# ཡེ་ཤེས: 475
#
# བོན: 440
#
# ཆེན་པོ: 420
#
# རྟོགས་པ: 383
#
# གཉིས: 378
#
# ཡིན: 371
#
# ཡེ་ནས: 351
#
# གསལ་བ: 305
#
# འབྲུ: 299
#
# ནམ་མཁའ: 288
#
# Kanjur-172-gab-pa-dgu་_pp.1-565.txt top 20 bigrams
# བོན་ཉིད: 215
#
# བྱང་ཆུབ་སེམས: 210
#
# འབྲུ་ཏིག: 137
#
# གཉིས་མེད: 123
#
# དམར་ཐག: 114
#
# ཐ་རམ་སྔོན་པོ: 112
#
# བདེ་བ་ཆེན་པོ: 105
#
# སྒྲར་འབྲུ: 104
#
# ལུང་མནན: 101
#
# མི་འགལ: 94
#
# ངང་ལས: 92
#
# ངོས་གཟུངས: 92
#
# ལས་འདས་པ: 85
#
# མངོན་དུ་གྱུར་པ: 80
#
# དོན་ལས: 78
#
# གཤེན་ལྷ་འོད: 72
#
# འོད་དཀར: 71
#
# རྣམ་པར་ཤེས་པ: 71
#
# ལས་བཅའ: 68
#
# འབྲུ་ལས: 64
#
# kanjur-174-1_gser-gyi-rus-sbal.txt top 20 words
# མི: 123
#
# མེད: 103
#
# དོན: 92
#
# ཉིད: 81
#
# ལས: 69
#
# བསྟན: 64
#
# གཉིས: 63
#
# རྒྱུད: 61
#
# ལམ: 61
#
# བསྟན་པ: 58
#
# འགྱུར: 46
#
# དེ་བཞིན་ཉིད: 43
#
# མེད་པ: 42
#
# རྩ་བ: 41
#
# སྟོན་པ: 37
#
# ཐམས་ཅད: 37
#
# འཁོར: 36
#
# ཕྱག་རྒྱ: 35
#
# གནས: 34
#
# སྙིང་པོ: 34
#
# kanjur-174-1_gser-gyi-rus-sbal.txt top 20 bigrams
# དེ་ནས་སྟོན་པ: 29
#
# རྒྱུད་ལས: 28
#
# མན་ངག་རྩ་བ: 21
#
# གཉིས་མེད: 21
#
# མི་འགྱུར: 14
#
# ངག་རྩ་བ: 14
#
# མེ་ངག: 12
#
# རྒྱུད་ཉིད: 11
#
# ཉིད་བསྟན་པ: 11
#
# བྱ་གང་ཞིག: 11
#
# མི་རྟོག: 10
#
# ལས་འདས: 9
#
# ངོ་བོ་ཉིད: 9
#
# བསྟན་དེ་བཞིན་ཉིད: 9
#
# ཕྱག་རྒྱ་རྩ: 9
#
# མཐའ་རུ: 8
#
# ཡི་དོན: 8
#
# ལམ་མི: 8
#
# མཐའ་ལས: 8
#
# རང་འབྱུང: 8
#
# nyingma large texts
# gser-gyi-rus-sbal_vol8-p.520-558.txt top 20 words
# མི: 143
#
# མེད: 121
#
# དོན: 88
#
# ཉིད: 86
#
# བསྟན: 75
#
# ལས: 73
#
# ལམ: 68
#
# གཉིས: 67
#
# རྒྱུད: 61
#
# བསྟན་པ: 58
#
# ཐམས་ཅད: 43
#
# སངས་རྒྱས: 43
#
# འགྱུར: 42
#
# དེ་བཞིན་ཉིད: 40
#
# མེད་པ: 39
#
# རྩ་བ: 38
#
# རྫོགས་ཆེན: 37
#
# མཆོག: 35
#
# འཁོར: 34
#
# སྙིང་པོ: 33
#
# gser-gyi-rus-sbal_vol8-p.520-558.txt top 20 bigrams
# རྒྱུད་ལས: 29
#
# གཉིས་མེད: 28
#
# དེ་ནས་སྟོན་པ: 26
#
# མི་འགྱུར: 16
#
# ལས་འདས: 12
#
# རྒྱུད་ཉིད: 11
#
# ཉིད་བསྟན་པ: 10
#
# བྱ་གང་ཞིག: 10
#
# མི་རྟོག: 10
#
# ངོ་བོ་ཉིད: 10
#
# ཐིག་ལེ་གཅིག: 10
#
# དོན་ཉིད: 9
#
# སངས་རྒྱས་ལམ: 9
#
# མཐའ་ལས: 9
#
# མཐའ་རུ: 8
#
# ཁམས་གསུམ: 8
#
# རྩོལ་བསྒྲུབ: 8
#
# སངས་རྒྱས་ཉིད: 8
#
# བསྟན་དེ་བཞིན་ཉིད: 8
#
# ཉི་ཤུ་རྩ: 8
#
# kun-byed-rgyal-po_vol8_p.7-183.txt top 20 words
# ཀུན: 774
#
# ང: 650
#
# བྱེད: 550
#
# མི: 506
#
# མེད: 497
#
# སེམས: 483
#
# བྱང་ཆུབ: 466
#
# ཡི: 404
#
# རང་བཞིན: 392
#
# ཡིན: 386
#
# ལས: 359
#
# ཆོས: 341
#
# རང: 286
#
# གསུམ: 285
#
# སྟོན་པ: 257
#
# ཆེན་པོ: 256
#
# སེམས་དཔའ: 245
#
# ཡེ་ཤེས: 242
#
# བསྟན་པ: 238
#
# རྒྱལ་པོ: 235
#
# kun-byed-rgyal-po_vol8_p.7-183.txt top 20 bigrams
# ཀུན་བྱེད: 414
#
# ང་ཡི: 224
#
# བྱང་ཆུབ་སེམས: 219
#
# བྱེད་རྒྱལ་པོ: 214
#
# རང་འབྱུང: 159
#
# སེམས་དཔའ་ཆེན་པོ: 158
#
# ཀྱེ་སེམས་དཔའ: 156
#
# སེམས་ཀུན: 139
#
# ཡི་རང་བཞིན: 139
#
# འབྱུང་ཡེ་ཤེས: 116
#
# བྱེད་ང: 110
#
# ཉོན་ཅིག: 91
#
# མི་རྟོག: 78
#
# ཆེན་པོ་ཉོན: 76
#
# ང་ལས: 67
#
# དེ་ནས་བྱང་ཆུབ: 63
#
# མི་དགོས: 60
#
# ཁམས་གསུམ: 60
#
# མངོན་དུ་ཕྱུང་བ: 55
#
# ལས་བྱུང་བ: 50

# %%
N = 20

print("nyingma GN texts")       
for i in range(len(nyingma_GN_idx2fname)):
    words = Counter(nyingma_GN_texts_f[i])
    bigrams = Counter(nyingma_GN_bigrams_f[i])
    print("{}".format(nyingma_GN_idx2fname[i]))
    print("words")
    for k, v in words.most_common(N):
        print("{}: {}\n".format(k, v))
    print("bigrams")
    for k, v in bigrams.most_common(N):
        print("{}: {}\n".format(k, v))
# Out:
# nyingma GN texts
# L1_GN2-rig-pa-khu-byug.txt
# words
# རིག་པ: 3
#
# སེམས: 3
#
# ཁུ་བྱུག: 2
#
# དགོངས་པ: 2
#
# ཧ: 2
#
# ཀུན་གཞི: 2
#
# བཅོས: 2
#
# ཡེ་ཤེས: 2
#
# ལས: 2
#
# ཆོས་ཉིད: 2
#
# བྱང་ཆུབ: 2
#
# ཀློང་རྡོལ: 1
#
# གླུ: 1
#
# བསམ་གཏན: 1
#
# ཙནྡན: 1
#
# གོི: 1
#
# ཤ: 1
#
# ཚལ: 1
#
# ནམ: 1
#
# ཆ: 1
#
# bigrams
# བྱང་ཆུབ་སེམས: 2
#
# དགོངས་པ་རིག་པ: 1
#
# རིག་པ་ཀློང་རྡོལ: 1
#
# ཀློང་རྡོལ་གླུ: 1
#
# བསམ་གཏན་ཙནྡན: 1
#
# ཙནྡན་གོི: 1
#
# གོི་ཤ: 1
#
# ཆ་སྟོད: 1
#
# སྲས་ཐུ་པོ: 1
#
# ཐུ་པོ་རཱ་ཛ: 1
#
# རཱ་ཛ་ཧ: 1
#
# ཧ་སྟི: 1
#
# སྟི་འདི་སྐད: 1
#
# འདི་སྐད་ལོ: 1
#
# ལོ་ཧཱུྃ: 1
#
# ཧཱུྃ་ཀུན་གཞི: 1
#
# ཀུན་གཞི་ཡེ་ནས: 1
#
# བཅོས་དེ་བཞིན: 1
#
# དེ་བཞིན་ཆོས: 1
#
# དབྱིངས་རང་བྱུང: 1
#
# L2_G5-rtsal-chen.txt
# words
# མི: 9
#
# འགྱུར: 4
#
# ཆེན: 3
#
# ཉིད: 3
#
# རྩལ: 2
#
# གླིང: 2
#
# ཀུ: 2
#
# རྟོག: 2
#
# དབྱིངས: 2
#
# ལས: 2
#
# རིག་པ: 2
#
# ཡིན: 2
#
# ཞིང: 2
#
# མེད་པ: 2
#
# ཡེ་ཤེས: 2
#
# དགོངས་པ: 1
#
# བྱང་སེམས: 1
#
# ཀློང་རྡོལ: 1
#
# གླུ: 1
#
# བསམ་གཏན: 1
#
# bigrams
# མི་འགྱུར: 4
#
# རྩལ་ཆེན: 2
#
# མི་རྟོག: 2
#
# རིག་པ་མི: 2
#
# དགོངས་པ་བྱང་སེམས: 1
#
# བྱང་སེམས་ཀློང་རྡོལ: 1
#
# ཀློང་རྡོལ་གླུ: 1
#
# བསམ་གཏན་སྐྱ་རེངས: 1
#
# སྐྱ་རེངས་གཉིས: 1
#
# ཤར་ཙམ: 1
#
# རྒྱལ་པོ་ཀུ: 1
#
# ཀུ་ཀུ: 1
#
# ཀུ་རཱ: 1
#
# རཱ་ཛ: 1
#
# འདི་སྐད་ལོ: 1
#
# ལོ་ཡེ་ནས: 1
#
# ཡེ་ནས་ལྷུན་གྲུབ: 1
#
# ལྷུན་གྲུབ་ཀུན: 1
#
# རྟོག་སྤྲོས་བྲལ: 1
#
# སྤྲོས་བྲལ་བྱང་ཆུབ: 1
#
# L3_GN1-khyung-chen.txt
# words
# སེམས: 4
#
# དགོངས་པ: 3
#
# མེད་པ: 3
#
# བྱང་ཆུབ: 3
#
# མི: 3
#
# གླུ: 2
#
# ཁྱུང་ཆེན: 2
#
# ཆོས་ཉིད: 2
#
# རྒྱལ་པོ: 2
#
# ལས: 2
#
# མེད: 2
#
# རྟོག་པ: 2
#
# ཞིང: 2
#
# བསམ: 2
#
# ཡེངས: 2
#
# མེད་པར: 2
#
# སྒོམ: 2
#
# ཞོག: 2
#
# བླངས: 2
#
# སེམས་སྡེ: 1
#
# bigrams
# བྱང་ཆུབ་སེམས: 2
#
# སེམས་སྡེ་བཅོ་བརྒྱད: 1
#
# དགོངས་པ་རིག་འཛིན: 1
#
# བཞེངས་པ་བཞུགས: 1
#
# ན་མོ་གུ་རུ: 1
#
# གུ་རུ་བིདྱཱ: 1
#
# བིདྱཱ་དྷཱ: 1
#
# དྷཱ་རེ: 1
#
# རེ་བྷྱ: 1
#
# དགོངས་པ་ཆོས་ཉིད: 1
#
# ཆོས་ཉིད་ཀློང་རྡོལ: 1
#
# ཀློང་རྡོལ་གླུ: 1
#
# གླུ་ཡི: 1
#
# ཡི་བསམ་གཏན: 1
#
# བསམ་གཏན་ཙནྡན: 1
#
# རྒྱལ་པོ་དྷ: 1
#
# དྷ་ཧེ: 1
#
# ཏེ་ལོ་འདི་སྐད: 1
#
# འདི་སྐད་ལོ: 1
#
# ལོ་ཧཱུྃ: 1
#
# L4_GN6-sems-sgom.txt
# words
# དབྱིངས: 3
#
# མི: 3
#
# སེམས: 2
#
# སྒོམ: 2
#
# ཐམས་ཅད: 2
#
# ཡེ་ནས: 2
#
# རིག་པ: 2
#
# མེད་པ: 2
#
# འགྱུར: 2
#
# ཡེངས: 2
#
# ལས: 2
#
# ཆོས་ཉིད: 2
#
# དགོངས་པ: 1
#
# ཀློང་རྡོལ: 1
#
# གླུ: 1
#
# བསམ་གཏན: 1
#
# རྒྱན: 1
#
# ཆགས: 1
#
# དཔལ: 1
#
# རི: 1
#
# bigrams
# སེམས་སྒོམ: 2
#
# མི་འགྱུར: 2
#
# དགོངས་པ་དབྱིངས: 1
#
# དབྱིངས་ཀློང་རྡོལ: 1
#
# ཀློང་རྡོལ་གླུ: 1
#
# བསམ་གཏན་རྒྱན: 1
#
# རྒྱན་ཆགས: 1
#
# ཆགས་དཔལ: 1
#
# སྐྱ་རེངས་གསུམ: 1
#
# ཤར་ཙམ: 1
#
# ནཱ་གརྫུ: 1
#
# སྣང་བ་ཐམས་ཅད: 1
#
# ཐམས་ཅད་ཡེ་ནས: 1
#
# ཡེ་ནས་དབྱིངས: 1
#
# དབྱིངས་ཆེན: 1
#
# རིག་པ་འཕོ་འགྱུར: 1
#
# འཕོ་འགྱུར་མེད་པ: 1
#
# དུར་བཏབ: 1
#
# དབྱིངས་ཉིད: 1
#
# ཉིད་མི: 1
#
# L5_GN3-nam-mkha-che.txt
# words
# མེད: 3
#
# ནམ་མཁའ: 2
#
# ཆེ: 2
#
# དགོངས་པ: 2
#
# རང་བྱུང: 2
#
# ལས: 2
#
# ཐུགས: 2
#
# བདག: 2
#
# གཞན: 2
#
# ཡེ་ཤེས: 1
#
# ཀློང་རྡོལ: 1
#
# གླུ: 1
#
# བསམ་གཏན: 1
#
# མེ་ཏོག: 1
#
# ཨུ: 1
#
# དུམྦཱ: 1
#
# རའི: 1
#
# ཚལ: 1
#
# ནམ་སྨད: 1
#
# ཆ: 1
#
# bigrams
# ནམ་མཁའ་ཆེ: 2
#
# དགོངས་པ་ཡེ་ཤེས: 1
#
# ཡེ་ཤེས་ཀློང་རྡོལ: 1
#
# ཀློང་རྡོལ་གླུ: 1
#
# བསམ་གཏན་མེ་ཏོག: 1
#
# མེ་ཏོག་ཨུ: 1
#
# ཨུ་དུམྦཱ: 1
#
# དུམྦཱ་རའི: 1
#
# རའི་ཚལ: 1
#
# སྲས་མོ་སཱ་ར: 1
#
# འདི་སྐད་ལོ: 1
#
# ལོ་ཀུན་གཞི: 1
#
# བཅོས་ཡེ་ནས: 1
#
# ཡེ་ནས་ཆོས: 1
#
# དབྱིངས་རྒྱུ: 1
#
# བསྐྱེད་འཇིག: 1
#
# འཇིག་བྲལ: 1
#
# བྲལ་མེད: 1
#
# མེད་རང་བྱུང: 1
#
# རང་བྱུང་ལྷུན: 1
#
# LL01-GN-rtse-mo.txt
# words
# མེད: 6
#
# སངས་རྒྱས: 4
#
# རྩེ་མོ: 2
#
# བྱུང་རྒྱལ: 2
#
# དགོངས་པ: 2
#
# ཤར: 2
#
# བྱང་ཆུབ: 2
#
# སེམས: 2
#
# བཙལ: 2
#
# བཅོས: 2
#
# སེམས་ལས: 2
#
# ཡིན: 2
#
# གསལ་བ: 2
#
# ལས: 2
#
# བདག: 2
#
# རྩོལ: 1
#
# ཀློང་རྡོལ: 1
#
# གླུ: 1
#
# བསམ་གཏན: 1
#
# ཤིང: 1
#
# bigrams
# རྩེ་མོ་བྱུང་རྒྱལ: 2
#
# སེམས་ལས་སངས་རྒྱས: 2
#
# དགོངས་པ་རྩོལ: 1
#
# རྩོལ་མེད: 1
#
# མེད་ཀློང་རྡོལ: 1
#
# ཀློང་རྡོལ་གླུ: 1
#
# བསམ་གཏན་ཤིང: 1
#
# ཤིང་ནལ: 1
#
# ནལ་བྱིས: 1
#
# དམར་རེངས་གསུམ: 1
#
# ཤར་ཙམ: 1
#
# སྨད་འཚོང་མ་བུདྡྷ: 1
#
# བུདྡྷ་མ་ཏི: 1
#
# མ་ཏི་འདི་སྐད: 1
#
# འདི་སྐད་ལོ: 1
#
# ལོ་ཨེ་མ་ཧོ: 1
#
# ཨེ་མ་ཧོ་ཆོས་ཉིད: 1
#
# ཆོས་ཉིད་བྱང་ཆུབ: 1
#
# བྱང་ཆུབ་སེམས: 1
#
# སེམས་བརྟག: 1
#
# LL02-GN_namkha'i-rgyal-po.txt
# words
# ཀུན: 3
#
# ནམ་མཁའ: 2
#
# རྒྱལ་པོ: 2
#
# གྲོལ་བ: 2
#
# སེམས: 2
#
# ལས: 2
#
# རྟོགས: 2
#
# མེད: 2
#
# རིག་པ: 2
#
# དགོངས་པ: 1
#
# ཀློང་རྡོལ: 1
#
# གླུ: 1
#
# བསམ་གཏན: 1
#
# མེ་ཏོག: 1
#
# ཚལ: 1
#
# ནམ: 1
#
# ཆ: 1
#
# སྟོད: 1
#
# དྷརྨ་རཱ་ཛ: 1
#
# འདི་སྐད: 1
#
# bigrams
# ནམ་མཁའ་རྒྱལ་པོ: 2
#
# དགོངས་པ་གྲོལ་བ: 1
#
# གྲོལ་བ་ཀློང་རྡོལ: 1
#
# ཀློང་རྡོལ་གླུ: 1
#
# བསམ་གཏན་མེ་ཏོག: 1
#
# ཆ་སྟོད: 1
#
# དྷརྨ་རཱ་ཛ་འདི་སྐད: 1
#
# རང་བཞིན་ཡེ་ནས: 1
#
# ཡེ་ནས་མཛོད་ཆེན: 1
#
# མཛོད་ཆེན་ལས: 1
#
# ལས་གང་ལྟར: 1
#
# གང་ལྟར་རྟོགས: 1
#
# རྟོགས་ཤིང: 1
#
# ཤིང་ཇི་ལྟ: 1
#
# སྣང་བ་ཀུན: 1
#
# ཀུན་འབྱུང: 1
#
# འབྱུང་འཇུག: 1
#
# འཇུག་འབྱུང་བ: 1
#
# འབྱུང་བ་མེད: 1
#
# བཟང་གཉིས: 1
#
# LL03-GN-12_bde-ba-phra-bkod.txt
# words
# མི: 5
#
# ལས: 4
#
# བདེ་བ: 3
#
# སེམས་ཉིད: 3
#
# སངས་རྒྱས: 3
#
# རིག་པ: 3
#
# འགྱུར: 3
#
# གནས: 3
#
# འཕྲ: 2
#
# བཀོད: 2
#
# དགོངས་པ: 2
#
# ཡིན་པ: 2
#
# མེད: 2
#
# ཡེ་ནས: 2
#
# མེད་པ: 2
#
# ཟབ་མོ: 2
#
# ཆོས་དབྱིངས: 2
#
# ལྟར: 2
#
# ཆེན་པོ: 2
#
# དག་པ: 2
#
# bigrams
# རིག་པ་མི: 3
#
# མི་འགྱུར: 3
#
# བདེ་བ་འཕྲ: 2
#
# འཕྲ་བཀོད: 2
#
# སངས་རྒྱས་ཡིན་པ: 2
#
# ཡིན་པ་ལས: 2
#
# ལས་རིག་པ: 2
#
# དགོངས་པ་ཕྲིན་ལས: 1
#
# ཕྲིན་ལས་ཀློང་རྡོལ: 1
#
# ཀློང་རྡོལ་གླུ: 1
#
# བསམ་གཏན་རིན་པོ་ཆེ: 1
#
# ནམ་གུང་ཡོལ: 1
#
# མཁན་པོ་དྷ: 1
#
# དྷ་ཧེ: 1
#
# ཧེ་འདི་སྐད: 1
#
# འདི་སྐད་ལོ: 1
#
# ལོ་སེམས་ཉིད: 1
#
# སེམས་ཉིད་སངས་རྒྱས: 1
#
# ལས་སེམས་ལས: 1
#
# སེམས་ལས་སངས་རྒྱས: 1
#
# LL04-GN11_spyi-chings.txt
# words
# ནམ་མཁའ: 3
#
# ལས: 3
#
# སྤྱི་ཆིངས: 2
#
# དགོངས་པ: 2
#
# སེམས: 2
#
# ཀློང: 2
#
# གསལ: 2
#
# རྟོག་པ: 2
#
# མེད་པ: 2
#
# ཡེ་ཤེས: 2
#
# མེད: 2
#
# ཀློང་རྡོལ: 1
#
# གླུ: 1
#
# བསམ་གཏན: 1
#
# དཔག་བསམ: 1
#
# ཤིང་གི: 1
#
# གྲིབ་མ: 1
#
# ཐོ་རེངས: 1
#
# ཁར: 1
#
# ཨཱརྻ: 1
#
# bigrams
# དགོངས་པ་ནམ་མཁའ: 1
#
# ནམ་མཁའ་ཀློང་རྡོལ: 1
#
# ཀློང་རྡོལ་གླུ: 1
#
# བསམ་གཏན་དཔག་བསམ: 1
#
# དཔག་བསམ་ཤིང་གི: 1
#
# ཤིང་གི་གྲིབ་མ: 1
#
# ཐོ་རེངས་ཁར: 1
#
# ཁར་ཨཱརྻ: 1
#
# ཨཱརྻ་པ་ལོ: 1
#
# པ་ལོ་འདི་སྐད: 1
#
# འདི་སྐད་ལོ: 1
#
# ལོ་བྱང་ཆུབ: 1
#
# བྱང་ཆུབ་སེམས: 1
#
# ནམ་མཁའ་ལྟ་བུ: 1
#
# ཀློང་གསལ: 1
#
# རྟོག་པ་མེད་པ: 1
#
# ནང་མེད: 1
#
# མེད་ཀུན: 1
#
# སྣང་གདོད: 1
#
# དག་པ་ནམ་མཁའ: 1
#
# LL06_GN16-bde-ba-rab-'byams.txt
# words
# ལས: 3
#
# བདེ་བ: 2
#
# རབ་འབྱམས: 2
#
# དེ་བ: 2
#
# སྣང་སྲིད: 2
#
# གཞན: 2
#
# རྟོགས: 2
#
# ཡེ་ཤེས: 2
#
# ལྔ: 2
#
# དགོངས་པ: 1
#
# སྐུ་གསུམ: 1
#
# ཀློང་རྡོལ: 1
#
# གླུ: 1
#
# བསམ་གཏན: 1
#
# གྲོང་ཁྱེར: 1
#
# དཔལ་ཡོན: 1
#
# སྲོད: 1
#
# དུས: 1
#
# རྒྱལ་པོ: 1
#
# རཱ་ཛ: 1
#
# bigrams
# བདེ་བ་རབ་འབྱམས: 2
#
# དགོངས་པ་སྐུ་གསུམ: 1
#
# སྐུ་གསུམ་ཀློང་རྡོལ: 1
#
# ཀློང་རྡོལ་གླུ: 1
#
# བསམ་གཏན་གྲོང་ཁྱེར: 1
#
# གྲོང་ཁྱེར་དཔལ་ཡོན: 1
#
# རྒྱལ་པོ་དེ་བ: 1
#
# དེ་བ་རཱ་ཛ: 1
#
# རཱ་ཛ་འདི་སྐད: 1
#
# འདི་སྐད་ལོ: 1
#
# ལོ་སྣང་སྲིད: 1
#
# སྣང་སྲིད་ཆོས: 1
#
# མངོན་དུ་ལྟོས་པ: 1
#
# ཡང་དག་ཉིད: 1
#
# བྱ་སྣང་སྲིད: 1
#
# སྣང་སྲིད་ཐམས་ཅད: 1
#
# ཐམས་ཅད་ཡེ་ནས: 1
#
# ཡེ་ནས་ཀུན: 1
#
# ལས་གཞན: 1
#
# གཞན་མེད: 1
#
# LL07-GN13-srog-gi-'khor-lo.txt
# words
# མཁའ: 3
#
# ཡེ་ཤེས: 3
#
# ལས: 3
#
# སྲོག: 2
#
# འཁོར་ལོ: 2
#
# དགོངས་པ: 2
#
# ཤ: 2
#
# བཅོས: 2
#
# དག་པ: 2
#
# སེམས: 2
#
# མེད: 2
#
# དཀྱིལ་འཁོར: 2
#
# རིག་པ: 2
#
# རང་བྱུང: 1
#
# ཀློང་རྡོལ: 1
#
# གླུ: 1
#
# བསམ་གཏན: 1
#
# ནྱ: 1
#
# གྲོ: 1
#
# དྷའི: 1
#
# bigrams
# རིག་པ་ཡེ་ཤེས: 2
#
# དགོངས་པ་རང་བྱུང: 1
#
# རང་བྱུང་ཀློང་རྡོལ: 1
#
# ཀློང་རྡོལ་གླུ: 1
#
# བསམ་གཏན་ནྱ: 1
#
# ནྱ་གྲོ: 1
#
# གྲོ་དྷའི: 1
#
# དྷའི་དགོན་པ: 1
#
# ཤོག་ལྷེ་༡༧༨: 1
#
# ༡༧༨་དུས: 1
#
# དྲང་སྲོང་བྷི: 1
#
# བྷི་ཤ: 1
#
# ཤ་ཏི: 1
#
# ཏི་འདི་སྐད: 1
#
# འདི་སྐད་ལོ: 1
#
# བཅོས་མཁའ: 1
#
# གཟའ་སྐར་ཀུན: 1
#
# ཀུན་འཕྱོ་བ: 1
#
# མི་བརྗོད: 1
#
# བྱང་ཆུབ་སེམས: 1
#
# LL08_GN4-thig-le-drug.txt
# words
# ལས: 3
#
# ཆོས: 3
#
# རྣམ་པར: 3
#
# གཞན: 3
#
# ཐིག་ལེ: 2
#
# དྲུག: 2
#
# དགོངས་པ: 2
#
# ནམ་མཁའ: 2
#
# མེད: 2
#
# བཅོས: 2
#
# བཙལ: 2
#
# ཀློང་རྡོལ: 1
#
# གླུ: 1
#
# བསམ་གཏན: 1
#
# སྐྱ་རེངས: 1
#
# དང་པོ: 1
#
# ཤར: 1
#
# ཙམ: 1
#
# རྒྱ་མཚོ: 1
#
# གཏིང: 1
#
# bigrams
# ཐིག་ལེ་དྲུག: 2
#
# དགོངས་པ་ནམ་མཁའ: 1
#
# ནམ་མཁའ་ཀློང་རྡོལ: 1
#
# ཀློང་རྡོལ་གླུ: 1
#
# བསམ་གཏན་སྐྱ་རེངས: 1
#
# སྐྱ་རེངས་དང་པོ: 1
#
# དང་པོ་ཤར: 1
#
# ཤར་ཙམ: 1
#
# གཏིང་རུམ: 1
#
# རྒྱལ་པོས་འདི་སྐད: 1
#
# དབུས་མེད: 1
#
# མེད་ནམ་མཁའ: 1
#
# ནམ་མཁའ་ལྟ་བུ: 1
#
# སྨ་བསམ་ཡུལ: 1
#
# བསམ་ཡུལ་ལས: 1
#
# ལས་འདས་པ: 1
#
# འདས་པ་ཤོག་ལྷེ: 1
#
# ཤོག་ལྷེ་༡༧༣: 1
#
# ༡༧༣་ཆོས: 1
#
# སྐུ་སྲིད: 1
#
# LL09_GN10-spyi-gcod.txt
# words
# ལས: 4
#
# སྤྱི: 2
#
# གཅོད: 2
#
# ཕྱི་མ: 2
#
# ཀུན་གཞི: 2
#
# ཤར: 2
#
# ཤར་བ: 2
#
# ནུབ་པ: 2
#
# བཅོས: 2
#
# ཆོས་ཉིད: 2
#
# རིག་པ: 2
#
# ཡེ་ཤེས: 2
#
# མྱོང: 2
#
# དགོངས་པ: 1
#
# གསང་བ: 1
#
# ཀློང་རྡོལ: 1
#
# གླུ: 1
#
# བསམ་གཏན: 1
#
# ཤིང: 1
#
# ནྱ: 1
#
# bigrams
# སྤྱི་གཅོད: 2
#
# དགོངས་པ་གསང་བ: 1
#
# གསང་བ་ཀློང་རྡོལ: 1
#
# ཀློང་རྡོལ་གླུ: 1
#
# བསམ་གཏན་ཤིང: 1
#
# ཤིང་ནྱ: 1
#
# ནྱ་གྲོ: 1
#
# གྲོ་དྷཱའི: 1
#
# དྷཱའི་རྩ་བ: 1
#
# སྲོད་ཐུན: 1
#
# ཐུན་ལ་འཇམ: 1
#
# ལ་འཇམ་དཔལ: 1
#
# དཔལ་བཤེས་གཉེན: 1
#
# བཤེས་གཉེན་ཕྱི་མ: 1
#
# ཕྱི་མ་འདི་སྐད: 1
#
# འདི་སྐད་ལོ: 1
#
# ལོ་ཀུན་གཞི: 1
#
# ཀུན་གཞི་ཡངས་པ: 1
#
# ཉི་མ་ཤར: 1
#
# ཤར་ཤར་བ: 1
#
# LL10_GN8-yid-bzhin-nor-bu.txt
# words
# མེད: 4
#
# བྱང་ཆུབ: 3
#
# སེམས: 3
#
# རང་བཞིན: 3
#
# བདག: 3
#
# ཡིད་བཞིན: 2
#
# ནོར་བུ: 2
#
# ཤར: 2
#
# བཅོས: 2
#
# མི: 2
#
# དབྱིངས: 2
#
# ལས: 2
#
# དགོངས་པ: 1
#
# དངོས་གྲུབ: 1
#
# ཀློང་རྡོལ: 1
#
# གླུ: 1
#
# བསམ་གཏན: 1
#
# དམར་རེངས: 1
#
# གཉིས: 1
#
# ཙམ: 1
#
# bigrams
# ཡིད་བཞིན་ནོར་བུ: 2
#
# བྱང་ཆུབ་སེམས: 2
#
# དགོངས་པ་དངོས་གྲུབ: 1
#
# དངོས་གྲུབ་ཀློང་རྡོལ: 1
#
# ཀློང་རྡོལ་གླུ: 1
#
# བསམ་གཏན་དམར་རེངས: 1
#
# དམར་རེངས་གཉིས: 1
#
# ཤར་ཙམ: 1
#
# བྱང་ཆུབ་འདི་སྐད: 1
#
# འདི་སྐད་ལོ: 1
#
# ལོ་ཆོས་ཉིད: 1
#
# ཆོས་ཉིད་བྱང་ཆུབ: 1
#
# བླང་ཞིང: 1
#
# ཞིང་བལྟ: 1
#
# བལྟ་མེད: 1
#
# སྣང་ཅིས་ཀྱང: 1
#
# ཅིས་ཀྱང་བཅོས: 1
#
# མེད་སེམས: 1
#
# རང་བཞིན་ཅི་ཡང: 1
#
# ཅི་ཡང་མི: 1
#
# LL11-GN14-kun-'dus.txt
# words
# ཀུན: 4
#
# ཨ: 4
#
# བྱང་ཆུབ: 4
#
# ལས: 4
#
# ཉིད: 3
#
# སེམས: 3
#
# རིན་ཆེན: 2
#
# འདུས: 2
#
# དགོངས་པ: 2
#
# མེད: 2
#
# སངས་རྒྱས: 2
#
# ཡིན: 2
#
# ཨ་ཡི: 2
#
# ཡེ་ནས: 2
#
# མེད་པ: 2
#
# སྐྱེ: 1
#
# ཀློང་རྡོལ: 1
#
# གླུ: 1
#
# བསམ་གཏན: 1
#
# རྒྱས་པ: 1
#
# bigrams
# བྱང་ཆུབ་སེམས: 3
#
# རིན་ཆེན་ཀུན: 2
#
# ཀུན་འདུས: 2
#
# ཨ་ཡིན: 2
#
# དགོངས་པ་སྐྱེ: 1
#
# སྐྱེ་མེད: 1
#
# མེད་ཀློང་རྡོལ: 1
#
# ཀློང་རྡོལ་གླུ: 1
#
# བསམ་གཏན་རྒྱས་པ: 1
#
# སྲས་མོ་གོ་མ: 1
#
# གོ་མ་དེ་བཱི: 1
#
# དེ་བཱི་འདི་སྐད: 1
#
# འདི་སྐད་ལོ: 1
#
# ལོ་སངས་རྒྱས: 1
#
# སངས་རྒྱས་ཀུན: 1
#
# ཐུགས་ཉིད: 1
#
# ཉིད་ཡི་གེ: 1
#
# ཡི་གེ་ཨ: 1
#
# ཨ་ཡི་རང་བཞིན: 1
#
# རང་བཞིན་ཡེ་ནས: 1
#
# LL12-GN18-rje-btsan-dam-pa.txt
# words
# དམ་པ: 2
#
# བཅོས: 2
#
# ངང: 2
#
# བསླད: 2
#
# རྣམ་རྟོག: 2
#
# ལས: 2
#
# མེད་པར: 2
#
# རྗེ་བཙུན: 1
#
# དགོངས་པ: 1
#
# ཤེས་རབ: 1
#
# ཀློང་རྡོལ: 1
#
# གླུ: 1
#
# བསམ་གཏན: 1
#
# དབེན་པ: 1
#
# ཆེན་པོ: 1
#
# གནས: 1
#
# བུདྡྷ: 1
#
# གུཔྟ: 1
#
# འདི་སྐད: 1
#
# ལོ: 1
#
# bigrams
# རྗེ་བཙུན་དམ་པ: 1
#
# དགོངས་པ་ཤེས་རབ: 1
#
# ཤེས་རབ་ཀློང་རྡོལ: 1
#
# ཀློང་རྡོལ་གླུ: 1
#
# བསམ་གཏན་དབེན་པ: 1
#
# དབེན་པ་ཆེན་པོ: 1
#
# བུདྡྷ་གུཔྟ: 1
#
# གུཔྟ་འདི་སྐད: 1
#
# འདི་སྐད་ལོ: 1
#
# ལོ་ཆོས: 1
#
# བཅོས་ཀུན: 1
#
# མེད་པ་བྱང་སེམས: 1
#
# བྱང་སེམས་ངང: 1
#
# རྣམ་པར་རྟོག་པ: 1
#
# རྣམ་རྟོག་རང་བྱུང: 1
#
# རང་བྱུང་རང: 1
#
# རང་ཞི: 1
#
# གནས་པ་ལས: 1
#
# ལས་སྒོམ་པ: 1
#
# ལས་གུད: 1

# %% [markdown]
# ## Per text top words (unfiltered)

# %%
N = 100

print("bon texts")
for i in range(len(bon_idx2fname)):
    words = Counter(bon_texts[i])
    bigrams = Counter(bon_bigrams[i])
    print("{} top {} words".format(bon_idx2fname[i], N))
    for k, v in words.most_common(N):
        print("{}: {}\n".format(k, v))
    print("{} top {} bigrams".format(bon_idx2fname[i], N))
    for k, v in bigrams.most_common(N):
        print("{}: {}\n".format(k, v))

print("nyingma texts")       
for i in range(len(nyingma_idx2fname)):
    words = Counter(nyingma_texts[i])
    bigrams = Counter(nyingma_bigrams[i])
    print("{} top {} words".format(nyingma_idx2fname[i], N))
    for k, v in words.most_common(N):
        print("{}: {}\n".format(k, v))
    print("{} top {} bigrams".format(nyingma_idx2fname[i], N))
    for k, v in bigrams.most_common(N):
        print("{}: {}\n".format(k, v))
# Out:
# bon texts
# 01-SMDG-gser-lung-non-che.txt top 100 words
# ལ: 914
#
# གི: 780
#
# ནི: 338
#
# དང: 296
#
# གིས: 249
#
# ཀྱི: 248
#
# དེ: 209
#
# ཀྱང: 209
#
# གོ: 196
#
# ནས: 187
#
# སྟེ: 184
#
# དུ: 183
#
# ན: 171
#
# སེམས: 166
#
# པ: 163
#
# བདག: 157
#
# ལས: 156
#
# སུ: 146
#
# མི: 146
#
# ཏེ: 139
#
# མ: 133
#
# གྱི: 126
#
# ལུང: 111
#
# ཡིན: 95
#
# བརྣན: 86
#
# བསྒོམ: 84
#
# མེད་པ: 81
#
# མོ: 77
#
# སླུ་བ: 74
#
# དོན: 72
#
# ཉིད: 72
#
# ཅིང: 69
#
# ཡིད: 66
#
# ཏིང་ངེ་འཛིན: 65
#
# ཆེན་པོ: 62
#
# མེད: 61
#
# བ: 60
#
# བྱང་ཆུབ: 59
#
# གྱིས: 59
#
# གཉིས: 58
#
# བཞི: 58
#
# མཚན་མ: 58
#
# བྱེད: 57
#
# ཀྱིས: 56
#
# དུས: 56
#
# འདི: 53
#
# ཅེས: 51
#
# གསུམ: 51
#
# ཡེ་ཤེས: 50
#
# སྙམ: 50
#
# སྟོན་པ: 49
#
# བག་ཆགས: 49
#
# ཐམས་ཅད: 48
#
# བྱ: 47
#
# བྱ་བ: 43
#
# ཅི: 42
#
# སེམས་ཉིད: 41
#
# གསལ་བ: 40
#
# བྱུང: 40
#
# སྒོམ་པ: 40
#
# ལྷ: 40
#
# ཅིག: 39
#
# གནས: 39
#
# མེད་པར: 39
#
# ཉམས: 39
#
# སྤྲུལ་པ: 39
#
# ཅན: 37
#
# བས: 36
#
# འཇུག: 36
#
# ཞིང: 36
#
# གསལ: 35
#
# ལུས: 35
#
# པོ: 33
#
# གང་ཞེ་ན: 32
#
# ངང: 32
#
# རྣམ་པར: 32
#
# བྱེད་པ: 32
#
# འོང: 31
#
# དབྱིངས: 30
#
# ནམ་མཁའ: 30
#
# བོན: 30
#
# ཉོན་མོངས: 29
#
# བསྒོམ་པ: 29
#
# རུ: 29
#
# ཡེ་ནས: 28
#
# གཅིག: 28
#
# ཤེས་པ: 28
#
# འབྱུང: 28
#
# འདྲ: 28
#
# སྙོམས་པ: 28
#
# གཞན: 27
#
# ངག: 27
#
# ལྟར: 27
#
# ཞེན་པ: 27
#
# སྟོན: 26
#
# བདེ་བ: 26
#
# རྣམ་པ: 25
#
# སེམས་ཅན: 25
#
# བརྒྱད: 25
#
# རྟོགས་པ: 25
#
# 01-SMDG-gser-lung-non-che.txt top 100 bigrams
# ལུང་བརྣན: 80
#
# དེ་ནི: 73
#
# བདག་གི: 64
#
# དེ་ལ: 63
#
# ལ་བསྒོམ: 63
#
# བརྣན་ལ: 63
#
# བསྒོམ་མོ: 62
#
# པ་གི: 58
#
# བྱང་ཆུབ་ཀྱི: 52
#
# གི་དུས: 51
#
# ཀྱི་སེམས: 50
#
# ཡིན་ཏེ: 48
#
# གི་ཏིང་ངེ་འཛིན: 48
#
# དུས་སུ: 41
#
# བྱེད་ན: 41
#
# མེད་པ་གི: 40
#
# ལ་ཀྱང: 37
#
# གི་བྱང་ཆུབ: 36
#
# ན་དེ: 36
#
# གི་དོན: 35
#
# ཏིང་ངེ་འཛིན་ལ: 35
#
# སྙམ་བྱེད: 34
#
# གི་ལུང: 33
#
# གིས་སླུ་བ: 33
#
# གོ་དེ: 30
#
# སེམས་ཀྱི: 28
#
# ལ་འཇུག: 28
#
# ལ་སྙོམས་པ: 28
#
# སྙོམས་པ་ལ: 28
#
# སྒོམ་པ་གི: 26
#
# ནས་ཞེན་པ: 25
#
# ཞེན་པ་གིས: 25
#
# སླུ་བ་དང: 25
#
# གིས་ནི: 24
#
# ཏེ་བདག: 24
#
# བདག་སྒོམ་པ: 24
#
# འཇུག་ཅིང: 23
#
# ལ་བདག: 23
#
# སླུ་བ་ཡིན: 23
#
# ཉོན་མོངས་པ: 22
#
# དང་འདྲ: 22
#
# སེམས་ནི: 22
#
# ཀྱང་བདག: 22
#
# སྟེ་དེ: 21
#
# ཅེས་བྱ: 21
#
# བྱ་གོ: 21
#
# འདྲ་སྟེ: 21
#
# ཉམས་སོད: 21
#
# གི་ངང: 20
#
# གི་བག་ཆགས: 20
#
# མི་སྣང་བ་ལ: 20
#
# མོ་བདག: 20
#
# ཅེས་བྱ་བ: 19
#
# རྣམ་པར་ཤེས་པ: 19
#
# གི་ཡེ་ཤེས: 18
#
# ཏེ་དེ: 18
#
# མ་ཡིན: 18
#
# བསྒོམས་པ་གིས: 18
#
# འཕྲག་དོག: 18
#
# དང་ལྡན་པ: 17
#
# ཅན་གྱི: 17
#
# གི་དབྱིངས: 16
#
# བ་གི: 16
#
# མཚན་མ་གི: 16
#
# ཉམས་སུ: 16
#
# རུང་སྟེ: 16
#
# ཉིད་དུ: 16
#
# བྱུང་བ་གིས: 16
#
# ཀྱི་སྤྲུལ་པ: 16
#
# གསེར་གྱི: 15
#
# གསལ་བ་ལ: 15
#
# བོན་ཉིད: 15
#
# གི་སེམས: 15
#
# ལ་ལུང: 15
#
# ལ་བཙལ་བ: 15
#
# སླུ་བ་པོ: 15
#
# ཅི་ལ: 14
#
# ཆེན་པོ་གི: 14
#
# སྟོན་ཏེ: 14
#
# བསམ་གྱིས: 14
#
# གྱིས་མི: 14
#
# འདི་ནས: 13
#
# ནས་མར: 13
#
# མར་ནི: 13
#
# དང་གཉིས: 13
#
# བག་ཆགས་ཀྱི: 13
#
# པ་ཅན: 13
#
# གྱི་ཡིད: 13
#
# གནས་ཏེ: 13
#
# ལ་བྱེད་པ: 13
#
# མི་ཁྱབ་པ: 13
#
# གི་ཏན: 13
#
# ཆེ་ལ: 13
#
# ལྷ་གི: 13
#
# བསྒོམ་པ་གི: 13
#
# སེམས་སུ: 13
#
# བརྟགས་ལ: 13
#
# གི་དྲོད: 13
#
# མོ་ཀྱང: 13
#
# ཀྱིས་སླུ་བ: 13
#
# 02-SMDG-gser-lung-non-chung.txt top 100 words
# གི: 130
#
# ལ: 113
#
# པ: 57
#
# མཚན་མ: 54
#
# ཀྱི: 49
#
# མྱེད: 48
#
# དུ: 44
#
# དང: 40
#
# ཐམས་ཅད: 39
#
# སེམས: 38
#
# ཉིད: 34
#
# ནི: 32
#
# ལས: 31
#
# གིས: 29
#
# ལུང: 28
#
# ཏེ: 26
#
# སེམས་ཉིད: 26
#
# བརྣན: 25
#
# ཀྱང: 23
#
# དོན: 22
#
# མོ: 22
#
# གྱི: 21
#
# བསྒོམ: 21
#
# བག་ཆགས: 20
#
# འབྱུང: 19
#
# སྟེ: 19
#
# བྱ་བ: 18
#
# དེ: 16
#
# ཅེས: 16
#
# གཤེན་ལྷ: 15
#
# རང: 15
#
# དཀར་པོ: 15
#
# མ: 15
#
# ཞིང: 14
#
# མི: 14
#
# ཡེ་ཤེས: 13
#
# སུ: 13
#
# གསལ: 13
#
# འདི: 12
#
# ལྔ: 12
#
# སྙིང་པོ: 12
#
# གོ: 11
#
# པར: 11
#
# གཞོམ་པ: 11
#
# དེས: 11
#
# དེ་ནས: 11
#
# ནས: 10
#
# རྒོངས: 10
#
# ལྔས: 10
#
# བསྒོམས་པ: 10
#
# གསལ་བ: 10
#
# རྟོགས་པ: 10
#
# ཞི: 10
#
# ཡིན: 9
#
# རྟོག་པ: 9
#
# མི་སྣང་བ: 9
#
# གང་ཞེ་ན: 8
#
# མཐུ: 8
#
# ཏིང་ངེ་འཛིན: 8
#
# ཕུང་པོ: 8
#
# ཕྱིར: 8
#
# ཅི: 8
#
# གསེར: 7
#
# ཀྱིས: 7
#
# ལུས: 7
#
# གདོས་པ: 7
#
# ཅན: 7
#
# རྟས་པ: 7
#
# བ: 7
#
# ཡེ་ནས: 7
#
# འདུ་ཤེས: 7
#
# ཨ: 7
#
# ལྡན་པ: 7
#
# འབྱུང་བ: 7
#
# ངང: 7
#
# ལ་མ: 7
#
# གྱུར: 7
#
# ཆེན་པོ: 7
#
# སྐྱེ་བ: 7
#
# གཞོམ: 6
#
# རང་བཞིན: 6
#
# ཉོན་མོངས: 6
#
# རྣམ་པར: 6
#
# ཞེན་པ: 6
#
# གཉིས: 6
#
# ཧ: 6
#
# བརྗོད་པ: 6
#
# འདུ་བྱེད: 6
#
# ལས་མ: 6
#
# གཞན: 6
#
# གྱིས: 6
#
# ན: 6
#
# སྡུག་བསྔལ: 6
#
# འོད: 5
#
# དང་པོ: 5
#
# ཏུ: 5
#
# རྒྱུ: 5
#
# ཡིད: 5
#
# དེ་ལྟར: 5
#
# ཅིང: 5
#
# 02-SMDG-gser-lung-non-chung.txt top 100 bigrams
# མྱེད་པ: 26
#
# ལུང་བརྣན: 25
#
# ཉིད་དུ: 22
#
# བརྣན་ལ: 22
#
# མཚན་མ་ཐམས་ཅད: 21
#
# ལ་བསྒོམ: 21
#
# བསྒོམ་མོ: 21
#
# པ་གི: 17
#
# གི་མཚན་མ: 17
#
# པ་ཉིད: 16
#
# དུ་ལུང: 16
#
# སེམས་རང: 14
#
# རང་འབྱུང: 14
#
# འབྱུང་གི: 14
#
# གི་གཤེན་ལྷ: 14
#
# གཤེན་ལྷ་དཀར་པོ: 14
#
# གི་དོན: 12
#
# གི་བག་ཆགས: 11
#
# ཅེས་བྱ་བ: 11
#
# མོ་དེ་ནས: 11
#
# མཚན་མ་མྱེད: 10
#
# བསྒོམས་པ་གིས: 10
#
# ཐམས་ཅད་ཞི: 10
#
# ཞི་ཞིང: 10
#
# བག་ཆགས་ཀྱི: 9
#
# རྒོངས་པ: 9
#
# ཏེ་སེམས་ཉིད: 9
#
# ཞིང་མི་སྣང་བ: 9
#
# མི་སྣང་བ་ལ: 9
#
# སེམས་མཚན་མ: 8
#
# མྱེད་པར: 8
#
# གི་ཕྱིར: 8
#
# ནི་སེམས: 7
#
# ཀྱི་མཚན་མ: 7
#
# མཐུ་རྟས་པ: 7
#
# དེ་ནི: 7
#
# བྱ་བ་གི: 7
#
# གསལ་ལ: 7
#
# དང་ལྡན་པ: 7
#
# གྱུར་ཏེ: 7
#
# གསལ་བ་ལ: 7
#
# ཀྱང་མ: 7
#
# གདོས་པ་ཅན: 6
#
# ཉོན་མོངས་པ: 6
#
# མཚན་མ་གཞོམ་པ: 6
#
# ཀྱི་ཕུང་པོ: 6
#
# གི་སྙིང་པོ: 6
#
# ལས་མཚན་མ: 6
#
# མཚན་མ་ཅི: 6
#
# རྟོག་པ་མྱེད: 6
#
# དེས་ནི: 6
#
# ལ་གྱུར: 6
#
# ཡིན་ཏེ: 5
#
# རྟས་པ་ནི: 5
#
# འདི་གོ: 5
#
# ལ་ཀྱང: 5
#
# གཞོམ་པ་དང: 5
#
# ཕུང་པོ་གདོས་པ: 5
#
# ལ་བྱ་བ: 5
#
# དང་མཚན་མ: 5
#
# ལ་བསྒོམས་པ: 5
#
# ཅེས་བརྗོད་པ: 5
#
# བརྗོད་པ་དེ: 5
#
# སྙིང་པོ་དེས: 5
#
# ལྡན་པ་གི: 5
#
# ཞེན་པ་གི: 5
#
# གི་ཏིང་ངེ་འཛིན: 5
#
# ཏིང་ངེ་འཛིན་ཅེས: 5
#
# འདུ་བྱེད་ལས: 5
#
# འཇོམས་ཏེ: 5
#
# འབྱུང་པ: 5
#
# པ་ཅེས་བྱ་བ: 5
#
# ཅེས་བྱ་བ་སེམས: 5
#
# གི་ཡེ་ཤེས: 5
#
# ཡེ་ཤེས་ཅེས: 5
#
# གསེར་གྱི: 4
#
# གྱི་ལུང: 4
#
# རྣམ་པར་རྟོག་པ: 4
#
# ཉིད་ཀྱི: 4
#
# ཀྱི་རྒོངས: 4
#
# ལྔས་གཞོམ་པ: 4
#
# གཞོམ་པ་གང་ཞེ་ན: 4
#
# ལ་འགྱུར: 4
#
# བཅོམས་ནས: 4
#
# མོ་ཨ: 4
#
# སྭ་ཧ: 4
#
# ཧ་ཅེས: 4
#
# ལྔ་དང: 4
#
# སྙིང་པོ་ཡིན: 4
#
# ནས་སེམས: 4
#
# ལས་འདས་པ: 4
#
# མ་ཡིན: 4
#
# བ་གི: 4
#
# གི་ངང: 4
#
# གི་འདུ་བྱེད: 4
#
# བྱ་བ་སེམས: 4
#
# ལས་འབྱུང: 4
#
# ལ་རྟོགས་པ: 4
#
# གཡུང་དྲུང་གི: 4
#
# སུ་གིས: 4
#
# 03-SMDG-sems-phran-rig-pa-khu-byug-sa-gcod.txt top 100 words
# གི: 41
#
# ལ: 29
#
# སེམས: 17
#
# དང: 17
#
# ཀྱི: 15
#
# ཁུ་བྱུག: 14
#
# ནས: 13
#
# རིག་པ: 12
#
# པ: 12
#
# བྱང་ཆུབ: 11
#
# གིས: 11
#
# གོ: 9
#
# བསྟན་པ: 9
#
# གསུང: 8
#
# དོན: 8
#
# དུ: 8
#
# བྱ: 8
#
# མྱེད: 7
#
# ལས: 7
#
# གསུམ: 7
#
# ཡན་ལག: 7
#
# སྟོན་པ: 6
#
# གྱི: 6
#
# ཀྱང: 6
#
# ཅེས: 6
#
# མཚན: 6
#
# འདི: 5
#
# དགུ: 5
#
# ཐམས་ཅད: 4
#
# སྙིང་པོ: 4
#
# སེམས་ཅན: 4
#
# ནི: 4
#
# ཏེ: 4
#
# གཉིས: 4
#
# དཔེ: 4
#
# དེ: 4
#
# ལྔ: 4
#
# ཡིས: 4
#
# མེད་པ: 4
#
# ས: 3
#
# ཐུགས་རྗེ: 3
#
# དངོས: 3
#
# ཡི: 3
#
# ལྷ: 3
#
# ཞིང: 3
#
# ཅི: 3
#
# མི: 3
#
# སྟེ: 3
#
# བྱང: 3
#
# འཕུར: 3
#
# སྐྱེ་བ: 3
#
# སྤྲོ་བ: 3
#
# གྱིས: 3
#
# བདུན: 3
#
# གཅོད: 2
#
# ས་བཅད: 2
#
# གཤེན་ལྷ: 2
#
# འོད: 2
#
# དཀར: 2
#
# ཡེ་ཤེས: 2
#
# ལྡན་པ: 2
#
# ཆེན་པོ: 2
#
# ཀྱིས: 2
#
# ཐབས: 2
#
# མན་ངག: 2
#
# སྟོན: 2
#
# སྤྲུལ་པ: 2
#
# ཐོས་པ: 2
#
# སྙན: 2
#
# བཙལ་བ: 2
#
# ཕལ: 2
#
# ལྟར: 2
#
# རྣམ་པ: 2
#
# ཆགས: 2
#
# མཁའ: 2
#
# རྗེས: 2
#
# དང་པོ: 2
#
# གདགས: 2
#
# ལུགས: 2
#
# གང་ཞེ་ན: 2
#
# གསོལ་བ: 2
#
# བཏགས་པ: 2
#
# ཅིའི་ཕྱིར: 2
#
# ཅེ་ན: 2
#
# ལྷང་ལྷང: 2
#
# བསྒྲགས་པ: 2
#
# ཏུ: 2
#
# གཡུང་དྲུང: 2
#
# ཡེ་ནས: 2
#
# ཆིབ་པ: 2
#
# བཙལ: 2
#
# སྐྱབས: 2
#
# འོག: 2
#
# ལག: 2
#
# ཉི་ཤུ: 2
#
# རྩ: 2
#
# གཅིག: 2
#
# དབང: 2
#
# བྱེའུ: 2
#
# འཕར་མ: 2
#
# 03-SMDG-sems-phran-rig-pa-khu-byug-sa-gcod.txt top 100 bigrams
# གི་ཁུ་བྱུག: 10
#
# བསྟན་པ་དང: 8
#
# བྱང་ཆུབ་སེམས: 6
#
# སེམས་རིག་པ: 6
#
# རིག་པ་གི: 6
#
# ལ་བསྟན་པ: 6
#
# ཀྱི་སེམས: 5
#
# སེམས་ཀྱི: 4
#
# གི་སྙིང་པོ: 4
#
# བྱང་ཆུབ་ཀྱི: 4
#
# ལས་མཚན: 4
#
# མཚན་དུ: 4
#
# ཅེས་བྱ: 4
#
# པ་གི: 4
#
# དགུ་ཡིས: 4
#
# ཁུ་བྱུག་གི: 3
#
# དངོས་མྱེད: 3
#
# མྱེད་གསུང: 3
#
# གསུང་གི: 3
#
# ཁུ་བྱུག་འདི: 3
#
# གི་གསུང: 3
#
# གོ་དེ: 3
#
# བྱ་གོ: 3
#
# ཁུ་བྱུག་དགུ: 3
#
# རིག་པ་ཁུ་བྱུག: 2
#
# གི་ས: 2
#
# ས་གཅོད: 2
#
# གི་ས་བཅད: 2
#
# ལ་སྟོན་པ: 2
#
# སྟོན་པ་གཤེན་ལྷ: 2
#
# གཤེན་ལྷ་འོད: 2
#
# འོད་དཀར: 2
#
# དང་ལྡན་པ: 2
#
# ཐབས་ཀྱི: 2
#
# ཀྱི་གསུང: 2
#
# ཐོས་པ་ལ: 2
#
# རིག་པ་ལྷ: 2
#
# ལྷ་གི: 2
#
# ལ་བྱ: 2
#
# མཁའ་ལ: 2
#
# གོ་བྱང་ཆུབ: 2
#
# འདི་ལ: 2
#
# མཚན་གྱི: 2
#
# གྱི་གདགས: 2
#
# གདགས་ལུགས: 2
#
# དཔེ་ལས: 2
#
# དུ་གསོལ་བ: 2
#
# དོན་ལས: 2
#
# དུ་བཏགས་པ: 2
#
# ནི་བྱང་ཆུབ: 2
#
# དེ་ཅིའི་ཕྱིར: 2
#
# ཅིའི་ཕྱིར་ཅེ་ན: 2
#
# བསྒྲགས་པ་གིས: 2
#
# སེམས་ཅན་ཐམས་ཅད: 2
#
# གཡུང་དྲུང་གི: 2
#
# སེམས་སྤྲོ་བ: 2
#
# སྙིང་པོ་ཅེས: 2
#
# མྱེད་པ: 2
#
# སྟོན་པ་གིས: 2
#
# བཙལ་ནས: 2
#
# སྟོན་པ་གི: 2
#
# སྐྱབས་འོག: 2
#
# ཉི་ཤུ་རྩ: 2
#
# དང་གསུམ: 2
#
# མེད་པ་གི: 2
#
# གི་ཐིག་ལེ: 2
#
# སེམས་ཕྲན: 1
#
# ཕྲན་རིག་པ: 1
#
# གཅོད་བཞུགས་པ: 1
#
# བཞུགས་པ་ལགས་སོ: 1
#
# ལགས་སོ་བྱང་ཆུབ: 1
#
# ས་བཅད་ལ: 1
#
# དཀར་ཐམས་ཅད: 1
#
# ཐམས་ཅད་མཁྱེན་པ: 1
#
# མཁྱེན་པ་གི: 1
#
# གི་ཡེ་ཤེས: 1
#
# ཡེ་ཤེས་དང: 1
#
# ལྡན་པ་དེས: 1
#
# དེས་ཐུགས་རྗེ: 1
#
# ཐུགས་རྗེ་ཆེན་པོ: 1
#
# ཆེན་པོ་གི: 1
#
# གི་བྱིན: 1
#
# བྱིན་གྱི: 1
#
# གྱི་རླབས: 1
#
# རླབས་ཀྱིས: 1
#
# ཀྱིས་བཤད: 1
#
# བཤད་ནས: 1
#
# ནས་རིག་པ: 1
#
# རིག་པ་ཐབས: 1
#
# ཀྱི་རྒྱུད་པ: 1
#
# རྒྱུད་པ་གི: 1
#
# གི་མདོ: 1
#
# མདོ་བྱང་ཆུབ: 1
#
# ཀྱི་བདེན་པ: 1
#
# བདེན་པ་དངོས: 1
#
# སྙིང་པོ་མན་ངག: 1
#
# མན་ངག་དོན: 1
#
# དོན་གྱི: 1
#
# གྱི་ཀྱང: 1
#
# ཀྱང་བཅུད: 1
#
# 04-SMDG-rig-pa-khu-byug-gzhung.txt top 100 words
# གི: 101
#
# ལ: 92
#
# ཁུ་བྱུག: 62
#
# མི: 52
#
# སྟེ: 36
#
# ཡེ་ཤེས: 30
#
# ན: 28
#
# དང: 27
#
# ནི: 26
#
# ཀྱང: 25
#
# མེད: 25
#
# ཀྱི: 24
#
# རེ: 21
#
# སྤྲོ: 21
#
# སྒྲོགས: 20
#
# ཉིད: 19
#
# ཙམ: 19
#
# གྱི: 19
#
# དམིགས: 19
#
# གིས: 17
#
# མ: 17
#
# ཇི: 17
#
# པ: 16
#
# ངང: 16
#
# བོན: 15
#
# རང་བཞིན: 15
#
# དཔེ: 15
#
# རྟགས: 15
#
# སྤྲུལ་པ: 14
#
# ཀུན: 14
#
# མཚན་མ: 14
#
# རིག་པ: 13
#
# ཆེ: 13
#
# བཅོས: 12
#
# དོན: 11
#
# སེམས་ཉིད: 11
#
# ནམ་མཁའ: 11
#
# ནས: 10
#
# ཐིག: 10
#
# གསུང: 9
#
# དབྱིངས: 9
#
# ལྷ: 9
#
# མཁའ: 9
#
# བྱ: 9
#
# ཅན: 9
#
# ཏེ: 9
#
# ཐིག་ལེ: 8
#
# ཅི: 8
#
# རྣམ་ཤེས: 8
#
# མཐའ: 8
#
# ཕྱིར་ཡང: 8
#
# མཚོན་པ: 8
#
# མྱ་ངན: 8
#
# འདས: 8
#
# གཅིག: 7
#
# སྐུ: 7
#
# འབྱུང: 7
#
# འདེབས: 7
#
# སྐྱེ: 7
#
# དངོས་པོ: 6
#
# འདི: 6
#
# འགྱུར: 6
#
# གནས: 6
#
# གཤེན: 6
#
# ནམ་མཁར: 6
#
# གསལ: 6
#
# སྣང: 6
#
# གཉིས: 6
#
# གསུམ: 6
#
# ལས: 5
#
# ཐིམ: 5
#
# སྙན: 5
#
# གོ: 5
#
# འཕུར: 5
#
# དུ: 5
#
# རྒྱུ: 5
#
# ཁྱབ: 5
#
# སེམས: 5
#
# སྙིང་པོ: 5
#
# བྱུང: 4
#
# ཏུ: 4
#
# བུ: 4
#
# ཡིད: 4
#
# ཕྱིན: 4
#
# ཐོས: 4
#
# འཇིག་རྟེན: 4
#
# སྟོན: 4
#
# ཤིང: 4
#
# མེད་པ: 4
#
# མཉམ: 4
#
# སྟོན་པ: 3
#
# འོད: 3
#
# རྔོ: 3
#
# མྱེད: 3
#
# གསང: 3
#
# རུ: 3
#
# སླ: 3
#
# བྲན: 3
#
# སྲས: 3
#
# བུ་མོ: 3
#
# 04-SMDG-rig-pa-khu-byug-gzhung.txt top 100 bigrams
# གི་ཁུ་བྱུག: 31
#
# ལ་མི: 24
#
# རེ་སྤྲོ: 21
#
# དང་རེ: 20
#
# ཙམ་ན: 18
#
# མི་དམིགས: 18
#
# ཇི་ལ: 16
#
# པ་གི: 13
#
# བོན་ཉིད: 12
#
# མ་བཅོས: 12
#
# སྤྲུལ་པ་གི: 11
#
# མེད་སྟེ: 11
#
# སྒྲོགས་པ: 10
#
# མཚན་མ་མེད: 10
#
# ཁུ་བྱུག་ཀྱང: 9
#
# སྟེ་ཇི: 9
#
# ཀུན་ཀྱང: 8
#
# དཔེ་གི: 8
#
# དམིགས་ཡེ་ཤེས: 8
#
# དོན་གྱི: 8
#
# གྱི་ཁུ་བྱུག: 8
#
# ཁུ་བྱུག་བོན: 8
#
# ཀྱི་ཁུ་བྱུག: 8
#
# ནམ་མཁའ་གི: 8
#
# གི་ཕྱིར་ཡང: 8
#
# རིག་པ་ཆེ: 8
#
# མཚོན་པ་མྱ་ངན: 8
#
# མྱ་ངན་འདས: 8
#
# མཁའ་ལ: 7
#
# རྟགས་ཅན: 7
#
# རྟགས་ཀྱི: 7
#
# ཁུ་བྱུག་སེམས་ཉིད: 7
#
# བཅོས་ངང: 7
#
# ངང་དོན: 7
#
# ཕྱིར་ཡང་ཁུ་བྱུག: 7
#
# ཁུ་བྱུག་སྟེ: 7
#
# ཐིག་འདེབས: 7
#
# འདེབས་རིག་པ: 7
#
# འདས་སྤྲུལ་པ: 7
#
# རང་བཞིན་སྟེ: 6
#
# སྟེ་དཔེ: 6
#
# ཁུ་བྱུག་ནམ་མཁར: 6
#
# ཅི་ལ: 6
#
# ཀྱི་རང་བཞིན: 6
#
# ཅན་སྟེ: 6
#
# སྟེ་རྟགས: 6
#
# ལྷ་གི: 5
#
# ནི་མ: 5
#
# གི་ངང: 5
#
# མི་སྐྱེ: 5
#
# ཐིག་ལེ་གཅིག: 4
#
# གཅིག་ལ: 4
#
# ལ་ཐིམ: 4
#
# གི་རྣམ་ཤེས: 4
#
# གི་རང་བཞིན: 4
#
# གཉིས་མཐའ: 4
#
# མཐའ་ལ: 4
#
# མི་འབྱུང: 4
#
# མེད་པ་གི: 4
#
# སྐྱེ་མི: 4
#
# མི་འགྱུར: 4
#
# གི་ཡེ་ཤེས: 3
#
# ཁུ་བྱུག་ནི: 3
#
# རྔོ་གིས: 3
#
# དབྱིངས་ཀྱི: 3
#
# ཀྱི་ཐིག་ལེ: 3
#
# གི་གསུང: 3
#
# ཀྱང་དང: 3
#
# ན་ལྷ: 3
#
# བུ་མོ་དང: 3
#
# པ་ཡེ་ཤེས: 3
#
# ཡེ་ཤེས་སྙན: 3
#
# ཡེ་ཤེས་ཤངས: 3
#
# ཀྱི་རྟགས: 3
#
# ཡེ་ཤེས་ལྗགས: 3
#
# འཇིག་རྟེན་དཔེ: 3
#
# ཡེ་ཤེས་སྐུ: 3
#
# ཆེ་ཡེ་ཤེས: 3
#
# ལ་མ: 3
#
# ཁྱབ་བདལ: 3
#
# སེམས་ཀྱི: 3
#
# དབྱིངས་ནས: 3
#
# ནས་ཁུ་བྱུག: 3
#
# ཁུ་བྱུག་སྒྲོགས: 3
#
# སྒྲོགས་སྙིང་པོ: 3
#
# སྙིང་པོ་ཡེ་ཤེས: 3
#
# ངང་ལ: 3
#
# གསུང་གི: 3
#
# གི་ཐིག: 3
#
# ནི་མི: 3
#
# མི་འགག་པ: 3
#
# འགག་པ་གིས: 3
#
# ལ་སྒྲོགས: 3
#
# ལ་མཚན་མ: 3
#
# ལ་ཀྱང: 3
#
# ཁུ་བྱུག་གི: 2
#
# དངོས་པོ་ལ: 2
#
# རིག་པ་ལྷ: 2
#
# གོ་བ་ལ: 2
#
# ལ་སླ: 2
#
# 05-SMDG-rig-pa-khu-byug-grel.txt top 100 words
# གི: 964
#
# ལ: 779
#
# དང: 383
#
# ནི: 352
#
# ཀྱི: 290
#
# ཀྱང: 282
#
# གིས: 272
#
# གོ: 261
#
# དེ: 244
#
# ན: 243
#
# ནས: 209
#
# སེམས: 207
#
# པ: 193
#
# དུ: 176
#
# མི: 173
#
# ཏེ: 165
#
# ཁུ་བྱུག: 143
#
# སྟེ: 139
#
# འདི: 126
#
# བོན: 126
#
# ཉིད: 123
#
# ལས: 122
#
# གྱི: 121
#
# ཅེས་པ: 113
#
# བྱ: 112
#
# ཐམས་ཅད: 108
#
# རིག་པ: 105
#
# མེད་པ: 105
#
# ཆེན་པོ: 101
#
# སུ: 100
#
# རྟོགས: 99
#
# དོན: 96
#
# གསལ་བ: 92
#
# ཀྱིས: 90
#
# ནམ་མཁའ: 89
#
# བྱང་ཆུབ: 88
#
# མ: 85
#
# ཞིང: 84
#
# ཅེས: 76
#
# ཡེ་ཤེས: 75
#
# སྐྱེ་བ: 75
#
# ཡིན: 70
#
# རང: 65
#
# གྱིས: 63
#
# རྣམ་པར: 63
#
# གཤེན: 62
#
# རྒྱལ་པོ: 62
#
# དུས: 62
#
# བ: 60
#
# མེད: 60
#
# ཙམ: 60
#
# ཏུ: 58
#
# པར: 55
#
# ཅི: 55
#
# སྤྲུལ་པ: 55
#
# གཉིས: 54
#
# དེས: 53
#
# དཔེར་ན: 53
#
# ཤེས་པ: 52
#
# མཚན་མ: 51
#
# འདྲ: 50
#
# ལྟར: 49
#
# ངང: 49
#
# བཤད: 48
#
# ཤེས་རིག: 48
#
# ཐབས: 47
#
# སྤྲོ: 47
#
# སྟོན་པ: 46
#
# དོན་དམ: 46
#
# བྱ་བ: 46
#
# ཅིག: 46
#
# རྟོགས་པ: 45
#
# གསུམ: 44
#
# འགྱུར་བ: 44
#
# དྭང: 44
#
# འོད: 43
#
# སེམས་ཅན: 43
#
# བདེ་བ: 43
#
# བྱུང: 42
#
# དངོས་པོ: 40
#
# དབྱིངས: 39
#
# རྣམས: 39
#
# འབྱུང: 39
#
# བསྒོམ་པ: 39
#
# རང་བཞིན: 38
#
# གནས: 38
#
# སྒྲོགས: 38
#
# འབྱུང་བ: 37
#
# གམ: 37
#
# གཤེན་ལྷ: 36
#
# འདྲ་བ: 36
#
# འདོད་པ: 35
#
# ལྷ: 34
#
# ཅན: 34
#
# གསུང: 34
#
# ཀུན་གཞི: 34
#
# བསྟན་པ: 34
#
# ཡིན་པ: 33
#
# ཐུགས་རྗེ: 33
#
# གནས་པ: 33
#
# 05-SMDG-rig-pa-khu-byug-grel.txt top 100 bigrams
# གི་ཁུ་བྱུག: 90
#
# པ་གི: 68
#
# བྱང་ཆུབ་ཀྱི: 67
#
# ཀྱི་སེམས: 66
#
# ལ་ཀྱང: 64
#
# རིག་པ་གི: 61
#
# བོན་ཉིད: 61
#
# གསལ་བ་ལ: 56
#
# གི་རྒྱལ་པོ: 51
#
# དང་འདྲ: 50
#
# གི་དོན: 49
#
# རྟོགས་ན: 49
#
# གིས་ནི: 47
#
# རང་ཤེས་རིག: 47
#
# བྱ་གོ: 47
#
# དེ་ལ: 46
#
# འདྲ་སྟེ: 46
#
# སྤྲོ་ཞིང: 46
#
# ཤེས་རིག་གི: 45
#
# དེ་ནི: 43
#
# སྐྱེ་བ་ལ: 42
#
# ཞིང་དྭང: 42
#
# དྭང་བ: 42
#
# མེད་པ་གི: 40
#
# ཙམ་ན: 40
#
# བ་སྐྱེ་བ: 40
#
# ཅེས་པ་དཔེར་ན: 40
#
# སེམས་རིག་པ: 39
#
# གི་དུས: 39
#
# སྤྲུལ་པ་གི: 38
#
# རྣམ་པར་ཤེས་པ: 38
#
# ཀྱང་མི: 37
#
# ཅི་ལ: 36
#
# ལ་རྟོགས: 35
#
# བསྒོམ་པ་གི: 35
#
# ཡིན་ཏེ: 34
#
# དོན་དམ་པར: 34
#
# ནམ་མཁའ་གི: 34
#
# བདེ་བ་ཆེན་པོ: 34
#
# སེམས་ཀྱི: 32
#
# རྟོགས་ཙམ: 32
#
# དང་འདྲ་བ: 31
#
# ལ་འགྱུར་བ: 31
#
# ན་རང: 31
#
# དེ་གི: 30
#
# གི་ངང: 30
#
# གཤེན་ལྷ་འོད: 29
#
# ཏེ་དེ: 29
#
# འདོད་པ་གི: 29
#
# འོད་དཀར: 28
#
# ཅེས་བྱ་བ: 28
#
# ཡིན་པ་གིས: 27
#
# ཅེས་བྱ: 27
#
# འདི་གིས: 27
#
# ཁུ་བྱུག་འདི: 27
#
# འགྱུར་བ་གོ: 27
#
# ནམ་མཁའ་ལ: 27
#
# དང་ལྡན་པ: 26
#
# གི་ཡེ་ཤེས: 26
#
# སེམས་ཀྱིས: 26
#
# གི་རིགས་ཅན: 26
#
# རྟོགས་པ་གི: 25
#
# ཉིད་བདེ་བ: 25
#
# ནི་སེམས: 24
#
# དུས་ན: 24
#
# ལ་བྱ: 24
#
# ན་སེམས: 23
#
# སྟོན་ཏེ: 22
#
# ནི་ནམ་མཁའ: 22
#
# སེམས་ཅན་ཐམས་ཅད: 22
#
# རྣམས་ནི: 22
#
# འདྲ་བ་ལ: 22
#
# གི་ཐབས: 22
#
# ཉིད་ཀྱི: 21
#
# ཡེ་ཤེས་ཀྱི: 21
#
# རྒྱལ་པོ་བྱང་ཆུབ: 21
#
# ཆེན་པོ་གི: 21
#
# ཀུན་གཞི་བྱང་ཆུབ: 20
#
# ལ་བཤད: 20
#
# ཐབས་ཀྱིས: 20
#
# གཤེན་ཕྲན: 20
#
# ན་སྤྲོ: 20
#
# གི་ནང: 19
#
# གཉིས་སུ: 19
#
# བཤད་དེ: 19
#
# རིག་པ་ཐབས: 19
#
# ཀྱིས་བརྒྱུད: 19
#
# དཔེར་ན་ནམ་མཁའ: 19
#
# བྱང་ཆུབ་སེམས: 18
#
# ནང་ནས: 18
#
# རྒྱལ་པོ་ཀུན་གཞི: 18
#
# གིས་ཀྱང: 18
#
# དེ་རིག་པ: 18
#
# ཀྱིས་སེམས: 18
#
# འཁོར་གཤེན: 18
#
# ལ་ན: 18
#
# རྡུལ་ཀྱང: 18
#
# གོ་དེ: 17
#
# གི་རྒྱུ: 17
#
# བརྒྱུད་དེས: 17
#
# 06-SMDG-cog-bzhag-sa-gcod.txt top 100 words
# གི: 8
#
# ལ: 7
#
# ཀྱི: 6
#
# ཅོག: 5
#
# བཞག: 5
#
# དང: 5
#
# སྟོན་པ: 4
#
# སེམས: 4
#
# ནས: 4
#
# དུ: 4
#
# མ: 4
#
# པ: 4
#
# དོན: 4
#
# མྱེད: 3
#
# སྟོན: 3
#
# གསུམ: 3
#
# ཏེ: 3
#
# ས: 2
#
# གཅོད: 2
#
# གོ: 2
#
# ནང: 2
#
# ན: 2
#
# གསལ: 2
#
# གསལ་བ: 2
#
# གྱི: 2
#
# གྱིས: 2
#
# འདི: 2
#
# མན་ངག: 2
#
# དཀྱིལ: 2
#
# ཀྱང: 2
#
# ཀླད: 2
#
# རྒྱངས: 2
#
# བསྟན: 2
#
# མདོ: 2
#
# ཡིས: 2
#
# མདོའ: 2
#
# གིས: 2
#
# བཞུགས་པ: 1
#
# ལགས་སོ: 1
#
# ཨེ་མ་ཧོ: 1
#
# སྤུངས: 1
#
# སྨར: 1
#
# རོ: 1
#
# བར་སྣང: 1
#
# མཁའ: 1
#
# ཟླ: 1
#
# ཤར་པ: 1
#
# རྒྱ་མཚོ: 1
#
# ཆུ: 1
#
# བྲན: 1
#
# རྡོ: 1
#
# ཤིང: 1
#
# ས་ལ: 1
#
# ཐུགས་ལས: 1
#
# འོད: 1
#
# ཤར་བ: 1
#
# ལས་འཕྲོ: 1
#
# ཅན: 1
#
# བྱིང་རྨུགས: 1
#
# བློ: 1
#
# གོ་བ: 1
#
# རྟོགས་པ: 1
#
# ཡིད་གཞུངས: 1
#
# བསྒོམ: 1
#
# བྱས: 1
#
# སངས་རྒྱས: 1
#
# གཞན: 1
#
# བཙལ: 1
#
# ཐུགས: 1
#
# ཕོག་པ: 1
#
# ཚིག: 1
#
# བདུན: 1
#
# ནི: 1
#
# ཞལ: 1
#
# གསུངས་པ: 1
#
# ཡིན: 1
#
# ཅེས: 1
#
# བྱ: 1
#
# སྟེ: 1
#
# བདེན་པ: 1
#
# ད: 1
#
# བྱང་ཆུབ: 1
#
# ཟབ་མོ: 1
#
# རྣམ་པ: 1
#
# དང་པོ: 1
#
# ཕྱག: 1
#
# བཙལ་བ: 1
#
# ཉིད: 1
#
# སྐུ: 1
#
# བསྟོད་པ: 1
#
# བག་ཆགས: 1
#
# འབྱོངས་པ: 1
#
# གཅིགགཉིས: 1
#
# འདྲེས་པ: 1
#
# དགུ: 1
#
# བསྡུ་བ: 1
#
# གཉིས: 1
#
# རྟག་ཆད: 1
#
# མཐའ: 1
#
# བསལ: 1
#
# 06-SMDG-cog-bzhag-sa-gcod.txt top 100 bigrams
# ཅོག་བཞག: 4
#
# སེམས་ཀྱི: 3
#
# བཞག་མ: 3
#
# གི་ས: 2
#
# ས་གཅོད: 2
#
# གསལ་བ་མྱེད: 2
#
# སྟོན་པ་གི: 2
#
# ལ་སྟོན: 2
#
# ཀྱི་དཀྱིལ: 2
#
# དཀྱིལ་དུ: 2
#
# ནས་ཀྱང: 2
#
# ཀླད་རྒྱངས: 2
#
# མ་གི: 2
#
# གི་མདོ: 2
#
# ཏེ་ཅོག: 2
#
# བཞག་གི: 1
#
# གཅོད་བཞུགས་པ: 1
#
# བཞུགས་པ་ལགས་སོ: 1
#
# ལགས་སོ་ཨེ་མ་ཧོ: 1
#
# ཨེ་མ་ཧོ་སྤུངས: 1
#
# སྤུངས་གོ: 1
#
# གོ་སྨར: 1
#
# སྨར་རོ: 1
#
# རོ་བར་སྣང: 1
#
# བར་སྣང་མཁའ: 1
#
# མཁའ་ལ: 1
#
# ལ་ཟླ: 1
#
# ཟླ་ཤར་པ: 1
#
# ཤར་པ་རྒྱ་མཚོ: 1
#
# རྒྱ་མཚོ་ཆུ: 1
#
# ཆུ་བྲན: 1
#
# བྲན་ནང: 1
#
# ནང་ན: 1
#
# ན་གསལ: 1
#
# གསལ་རྡོ: 1
#
# རྡོ་ཤིང: 1
#
# ཤིང་ས་ལ: 1
#
# ས་ལ་གསལ་བ: 1
#
# མྱེད་སྟོན་པ: 1
#
# གི་ཐུགས་ལས: 1
#
# ཐུགས་ལས་འོད: 1
#
# འོད་ཤར་བ: 1
#
# ཤར་བ་ལས་འཕྲོ: 1
#
# ལས་འཕྲོ་ཅན: 1
#
# ཅན་གྱི: 1
#
# གྱི་སེམས: 1
#
# སེམས་ལ: 1
#
# ལ་གསལ: 1
#
# གསལ་བྱིང་རྨུགས: 1
#
# བྱིང་རྨུགས་བློ: 1
#
# བློ་ལ: 1
#
# ལ་གསལ་བ: 1
#
# མྱེད་གོ་བ: 1
#
# གོ་བ་ལ: 1
#
# སྟོན་གྱིས: 1
#
# གྱིས་རྟོགས་པ: 1
#
# རྟོགས་པ་ལ: 1
#
# ལ་གྱིས: 1
#
# གྱིས་འདི: 1
#
# འདི་ལ: 1
#
# ལ་ཡིད་གཞུངས: 1
#
# ཡིད་གཞུངས་བསྒོམ: 1
#
# བསྒོམ་བྱས: 1
#
# བྱས་ན: 1
#
# ན་སངས་རྒྱས: 1
#
# སངས་རྒྱས་གཞན: 1
#
# གཞན་ནས: 1
#
# ནས་བཙལ: 1
#
# བཙལ་དུ: 1
#
# དུ་མྱེད: 1
#
# མྱེད་མན་ངག: 1
#
# མན་ངག་སེམས: 1
#
# ཀྱི་ཅོག: 1
#
# མ་ཐུགས: 1
#
# ཐུགས་ཀྱི: 1
#
# དུ་བཞག: 1
#
# བཞག་ནས: 1
# ཀྱང་སེམས: 1
#
# དུ་ཕོག་པ: 1
#
# ཕོག་པ་ལ: 1
#
# སྟོན་ཚིག: 1
#
# ཚིག་བདུན: 1
#
# བདུན་པ: 1
#
# པ་དང: 1
#
# དང་ཀླད: 1
#
# རྒྱངས་ནི: 1
#
# ནི་སྟོན་པ: 1
#
# གི་ཞལ: 1
#
# ཞལ་ནས: 1
#
# ནས་གསུངས་པ: 1
#
# གསུངས་པ་ཡིན: 1
#
# ཡིན་ཅེས: 1
#
# ཅེས་བྱ: 1
#
# བྱ་སྟེ: 1
#
# སྟེ་དོན: 1
#
# དོན་གྱི: 1
#
# གྱི་བདེན་པ: 1
#
# བདེན་པ་ཅོག: 1
#
# གི་ཀླད: 1
#
# རྒྱངས་བསྟན: 1
#
# 07-SMDG-cog-bzhag-gzhung.txt top 100 words
# ལ: 16
#
# ནི: 14
#
# རྣམ་པ: 9
#
# གསུམ་པོ: 9
#
# འདྲ: 9
#
# ཅོག: 5
#
# གི: 5
#
# གོ: 5
#
# བཞག: 4
#
# ཀྱང: 4
#
# མི: 4
#
# མྱེད: 3
#
# གིས: 3
#
# སྟངས: 3
#
# ཐབས: 3
#
# སྟོན་པ: 2
#
# གསུམ: 2
#
# དགུ: 2
#
# ཕྱེ: 2
#
# སྟེ: 2
#
# བཞག་པ: 2
#
# སུ: 2
#
# གསལ་བ: 2
#
# མཁའ: 2
#
# མ: 2
#
# ཀྱི: 2
#
# མན་ངག: 2
#
# ངང: 2
#
# གཞུང: 1
#
# བཞུགས: 1
#
# ཀུན: 1
#
# ཏུ: 1
#
# བཟང་པོ: 1
#
# གཤེན་ལྷ: 1
#
# འོད: 1
#
# དཀར: 1
#
# ལོ་ཕྱག: 1
#
# འཚལ: 1
#
# ལོ: 1
#
# ཚད: 1
#
# བཞི: 1
#
# ལྡན་པ: 1
#
# རུ: 1
#
# བསྟན: 1
#
# ཤེས: 1
#
# དོན: 1
#
# ཤེས་ལྡན: 1
#
# དག: 1
#
# བཟོ: 1
#
# གཏད: 1
#
# བརྟགས: 1
#
# སོ་པ: 1
#
# ཀ: 1
#
# བལྟ: 1
#
# ན: 1
#
# ཆུང: 1
#
# མེ་ལོང: 1
#
# ལྟ་བ: 1
#
# བསྡུ: 1
#
# གསེར: 1
#
# ལུས: 1
#
# བཞུ་བ: 1
#
# བསྙེན: 1
#
# འབུབ: 1
#
# དབྱེལ: 1
#
# ཚེམས: 1
#
# ཀྱིས: 1
#
# བསྡམས་པ: 1
#
# དཔག: 1
#
# སེང: 1
#
# ཆེན: 1
#
# གངས: 1
#
# མཆོངས་པ: 1
#
# བསྒྲུབ: 1
#
# ཁྱུང་ཆེན: 1
#
# ནམ་འཕང: 1
#
# གཅོད་པ: 1
#
# བར་སྣང: 1
#
# ཉི་ཤར: 1
#
# དམྱིགས: 1
#
# མེད: 1
#
# གཞའ་ཚོན: 1
#
# བྲིས་པ: 1
#
# སྐོར: 1
#
# བསྟན་པ: 1
#
# རྟག་ཆད: 1
#
# གཉིས: 1
#
# མཐའ: 1
#
# བསལ: 1
#
# ཡོད་པ: 1
#
# ལྟ: 1
#
# སྟོང་པ: 1
#
# སྨོན: 1
#
# རྟག་པ: 1
#
# གཟུང: 1
#
# པར: 1
#
# གཅོད: 1
#
# དེ: 1
#
# སེམས: 1
#
# བསྒོམ: 1
#
# 07-SMDG-cog-bzhag-gzhung.txt top 100 bigrams
# རྣམ་པ་གསུམ་པོ: 9
#
# གསུམ་པོ་ནི: 9
#
# ཅོག་བཞག: 4
#
# ཀྱང་ནི: 4
#
# ནི་མི: 4
#
# སྟངས་རྣམ་པ: 3
#
# ཐབས་རྣམ་པ: 3
#
# མཁའ་ལ: 2
#
# བཞག་མ: 2
#
# མ་གི: 2
#
# ལ་ཀྱང: 2
#
# བཞག་གི: 1
#
# གི་གཞུང: 1
#
# གཞུང་བཞུགས: 1
#
# བཞུགས་གོ: 1
#
# གོ་སྟོན་པ: 1
#
# སྟོན་པ་ཀུན: 1
#
# ཀུན་ཏུ: 1
#
# ཏུ་བཟང་པོ: 1
#
# བཟང་པོ་གཤེན་ལྷ: 1
#
# གཤེན་ལྷ་འོད: 1
#
# འོད་དཀར: 1
#
# དཀར་ལོ་ཕྱག: 1
#
# ལོ་ཕྱག་འཚལ: 1
#
# འཚལ་ལོ: 1
#
# ལོ་སྟོན་པ: 1
#
# སྟོན་པ་ཚད: 1
#
# ཚད་མྱེད: 1
#
# མྱེད་བཞི: 1
#
# བཞི་ལ: 1
#
# ལ་ལྡན་པ: 1
#
# ལྡན་པ་གིས: 1
#
# གིས་གསུམ: 1
#
# གསུམ་གསུམ: 1
#
# གསུམ་དགུ: 1
#
# དགུ་རུ: 1
#
# རུ་ཕྱེ: 1
#
# ཕྱེ་སྟེ: 1
#
# སྟེ་བསྟན: 1
#
# བསྟན་ཤེས: 1
#
# ཤེས་དོན: 1
#
# དོན་རྣམ་པ: 1
#
# ནི་ཤེས་ལྡན: 1
#
# ཤེས་ལྡན་དག: 1
#
# དག་ལ: 1
#
# ལ་བཟོ: 1
#
# བཟོ་གཏད: 1
#
# གཏད་འདྲ: 1
#
# འདྲ་བརྟགས: 1
#
# བརྟགས་སྟངས: 1
#
# ནི་སོ་པ: 1
#
# སོ་པ་ལ: 1
#
# ལ་ཀ: 1
#
# ཀ་ལ: 1
#
# ལ་བཞག་པ: 1
#
# བཞག་པ་འདྲ: 1
#
# འདྲ་བལྟ: 1
#
# བལྟ་སྟངས: 1
#
# ནི་ན: 1
#
# ན་ཆུང: 1
#
# ཆུང་མེ་ལོང: 1
#
# མེ་ལོང་ལྟ་བ: 1
#
# ལྟ་བ་འདྲ: 1
#
# འདྲ་བསྡུ: 1
#
# བསྡུ་ཐབས: 1
#
# ནི་གསེར: 1
#
# གསེར་ཕྱེ: 1
#
# ཕྱེ་ལུས: 1
#
# ལུས་སུ: 1
#
# སུ་བཞུ་བ: 1
#
# བཞུ་བ་འདྲ: 1
#
# འདྲ་བསྙེན: 1
#
# བསྙེན་ཐབས: 1
#
# ནི་འབུབ: 1
#
# འབུབ་དབྱེལ: 1
#
# དབྱེལ་ཚེམས: 1
#
# ཚེམས་ཀྱིས: 1
#
# ཀྱིས་བསྡམས་པ: 1
#
# བསྡམས་པ་འདྲ: 1
#
# འདྲ་དཔག: 1
#
# དཔག་སྟངས: 1
#
# ནི་སེང: 1
#
# སེང་ཆེན: 1
#
# ཆེན་གངས: 1
#
# གངས་ལ: 1
#
# ལ་མཆོངས་པ: 1
#
# མཆོངས་པ་འདྲ: 1
#
# འདྲ་བསྒྲུབ: 1
#
# བསྒྲུབ་ཐབས: 1
#
# ནི་ཁྱུང་ཆེན: 1
#
# ཁྱུང་ཆེན་ནམ་འཕང: 1
#
# ནམ་འཕང་གཅོད་པ: 1
#
# གཅོད་པ་འདྲ: 1
#
# འདྲ་གསལ་བ: 1
#
# གསལ་བ་རྣམ་པ: 1
#
# ནི་བར་སྣང: 1
#
# བར་སྣང་མཁའ: 1
#
# ལ་ཉི་ཤར: 1
#
# ཉི་ཤར་འདྲ: 1
#
# འདྲ་དམྱིགས: 1
#
# 08-SMDG-cog-bzhag-grel.txt top 100 words
# ལ: 240
#
# གི: 167
#
# དང: 95
#
# མྱེད: 95
#
# པ: 92
#
# ཀྱང: 85
#
# གིས: 80
#
# ན: 73
#
# མི: 60
#
# ནི: 53
#
# གོ: 50
#
# དུ: 50
#
# དེ: 38
#
# སྟེ: 38
#
# སུ: 38
#
# ཀྱི: 36
#
# ཉིད: 36
#
# པར: 34
#
# དོན: 32
#
# འདི: 32
#
# ནས: 30
#
# གསུམ: 30
#
# བྱ: 29
#
# ངང: 28
#
# སེམས: 27
#
# གཉིས: 25
#
# ལས: 24
#
# རྣམ་པ: 23
#
# གཞག: 23
#
# ཏེ: 22
#
# གསལ: 22
#
# ཅོག: 21
#
# ཅེས་པ: 21
#
# པས: 20
#
# ཤེས་པ: 20
#
# བསྒོམ: 20
#
# མ: 19
#
# ཆེན་པོ: 19
#
# བོན: 19
#
# འབྲས་བུ: 19
#
# མན་ངག: 19
#
# གསལ་བ: 18
#
# དེ་ལྟར: 18
#
# ལྡན་པ: 16
#
# ཨེ་མ་ཧོ: 16
#
# ངེས་པ: 15
#
# བྱང་ཆུབ: 15
#
# སྟོན་པ: 14
#
# ཅེས: 14
#
# རྒྱུན: 14
#
# ལྟར: 14
#
# ཏུ: 13
#
# གྱི: 13
#
# གང་ཞེ་ན: 13
#
# ལས་འཕྲོ: 13
#
# ཀྱིས: 12
#
# ཙམ: 12
#
# ཉམ: 12
#
# བསྒོམས: 12
#
# བསྟན་པ: 12
#
# མཚན་མ: 12
#
# ཀུན: 11
#
# ཐམས་ཅད: 11
#
# ཚད: 11
#
# སེམས་ཉིད: 11
#
# ང: 11
#
# དམྱིགས: 11
#
# དབྱིངས: 10
#
# སྐུ: 10
#
# མོ: 10
#
# བར: 10
#
# རིག་པ: 10
#
# ཏིང་ངེ་འཛིན: 10
#
# མཐའ: 10
#
# འོད: 9
#
# ཕྱག: 9
#
# གཤེན་རབ: 9
#
# འདྲ་བ: 9
#
# བྱ་བ: 9
#
# གཅིག: 9
#
# དཔེར་ན: 9
#
# དག་པ: 9
#
# ཐོབ: 9
#
# བསྒྲུབ: 9
#
# བདག: 9
#
# ལྟ་བ: 9
#
# རྡུལ: 9
#
# ཡིན: 9
#
# བཞག: 8
#
# ལོ: 8
#
# པོ: 8
#
# རྟོགས་པ: 8
#
# གནས: 8
#
# ཅིག: 8
#
# མེད་པ: 8
#
# དགུ: 8
#
# སྒོམ: 8
#
# ཅི: 8
#
# བསྒོམ་པ: 8
#
# དཀར: 7
#
# 08-SMDG-cog-bzhag-grel.txt top 100 bigrams
# མྱེད་པ: 43
#
# པ་གི: 39
#
# མྱེད་པར: 23
#
# གི་དོན: 21
#
# པ་དང: 18
#
# ཅོག་གིས: 18
#
# གི་ངང: 17
#
# ལ་བྱ: 17
#
# ལ་ཀྱང: 16
#
# སུ་མྱེད: 16
#
# ཅེས་པ་ཨེ་མ་ཧོ: 15
#
# རྣམ་པ་གསུམ: 15
#
# ཀྱང་མི: 15
#
# བོན་ཉིད: 14
#
# གིས་གཞག: 14
#
# ངང་ལ: 13
#
# མྱེད་པས: 13
#
# གཞག་པ: 13
#
# དེ་ལ: 12
#
# ཤེས་པ་ལ: 12
#
# དང་གཉིས: 11
#
# ལ་ཅོག: 11
#
# ཉམ་མི: 11
#
# མི་ང: 11
#
# མན་ངག་འདི: 11
#
# བསྒོམས་ན: 10
#
# ལ་བསྟན་པ: 10
#
# དང་ལྡན་པ: 9
#
# དང་གསུམ: 9
#
# གསུམ་མོ: 9
#
# མོ་དེ་ལྟར: 9
#
# ཙམ་ཉིད: 9
#
# ཉིད་ན: 9
#
# བྱ་ལ: 9
#
# ལ་བསྒོམས: 9
#
# བསྟན་པ་གོ: 9
#
# བྱ་སྟེ: 9
#
# སྟེ་གང་ཞེ་ན: 9
#
# བྱ་གོ: 8
#
# ང་བར: 8
#
# དང་འདྲ་བ: 8
#
# འདྲ་བ་ལ: 8
#
# ལ་ན: 8
#
# ལས་འཕྲོ་དག་པ: 8
#
# དག་པ་གི: 8
#
# གི་གཤེན་རབ: 8
#
# གཤེན་རབ་ཀྱིས: 8
#
# ཀྱིས་ཀྱང: 8
#
# ཀྱང་མན་ངག: 8
#
# ན་འབྲས་བུ: 8
#
# འབྲས་བུ་ཐོབ: 8
#
# ཐོབ་ངེས་པ: 8
#
# ངེས་པ་ལ: 8
#
# གཉིས་སུ: 8
#
# དོན་ལ: 8
#
# གསལ་བ་ལ: 8
#
# བྱང་ཆུབ་སེམས: 8
#
# བདེ་བ་ཆེན་པོ: 7
#
# ན་ལས་འཕྲོ: 7
#
# གསུམ་ཅེས་པ: 7
#
# རྡུལ་ཀྱང: 7
#
# ཀྱང་མྱེད: 7
#
# ཉིད་ཀྱི: 7
#
# འདི་ལ: 7
#
# གི་ཉམ: 7
#
# གསལ་ལ: 7
#
# བྱང་ཆུབ་ཀྱི: 7
#
# ཀྱི་སེམས: 7
#
# སྟོན་པ་གིས: 6
#
# ཅེས་བྱ: 6
#
# དོན་དུ: 6
#
# ཚད་མྱེད: 6
#
# ལ་ལྡན་པ: 6
#
# གིས་ཀྱང: 6
#
# རྣམ་པ་གསུམ་པོ: 6
#
# ཨེ་མ་ཧོ་གང་ཞིག: 6
#
# གི་འབྲས་བུ: 6
#
# སྒྲུབ་ན: 6
#
# ན་དཔེར་ན: 6
#
# ལྟ་བ་གི: 6
#
# འདི་གི: 6
#
# ཨེ་མ་ཧོ་བསྒྲུབ: 6
#
# བསྒྲུབ་ན: 6
#
# དང་བྲལ་བ: 6
#
# ལ་བསྒོམ: 6
#
# བསྒོམ་དུ: 6
#
# ཡེངས་སུ: 6
#
# པར་ཀྱང: 6
#
# ལ་སེམས་ཉིད: 6
#
# གིས་ནི: 5
#
# གི་ཕྱིར: 5
#
# ཀྱང་དེ: 5
#
# གང་ཞིག་སྐྱེས་བུ: 5
#
# དག་ལས་འཕྲོ: 5
#
# ལས་འཕྲོ་དང: 5
#
# དང་སྐལ་བ: 5
#
# སྐལ་བ་ལ: 5
#
# སྟངས་རྣམ་པ: 5
#
# ལྡན་པ་ཞིག: 5
#
# ཞིག་གིས: 5
#
# 09-SMDG-rgyun-thag-sa-gcod-gzhung-grel.txt top 100 words
# གི: 267
#
# ལ: 227
#
# མྱེད: 149
#
# སེམས: 118
#
# པ: 107
#
# ཀྱི: 103
#
# དང: 98
#
# དུ: 88
#
# གོ: 80
#
# ནི: 79
#
# གིས: 78
#
# མ: 74
#
# དོན: 72
#
# ཀྱང: 70
#
# ཐམས་ཅད: 60
#
# བྱང་ཆུབ: 51
#
# པས: 51
#
# ནས: 49
#
# བྱ: 49
#
# ཅེས: 48
#
# ཡེ་ནས: 48
#
# ཀུན: 40
#
# མི: 39
#
# པར: 39
#
# བོན: 39
#
# དེ: 36
#
# མཚན་མ: 36
#
# དབྱིངས: 35
#
# ན: 35
#
# ཡིན: 33
#
# བརྗོད: 32
#
# ཏེ: 29
#
# རང་བཞིན: 29
#
# རིག་པ: 28
#
# ཏུ: 28
#
# ཉིད: 27
#
# ཡེ་ཤེས: 26
#
# བསྟན་པ: 26
#
# སུ: 26
#
# ཅིང: 25
#
# གྱི: 24
#
# ཀྱིས: 23
#
# བཟང་པོ: 22
#
# ལུང: 21
#
# ཀུན་གཞི: 21
#
# ཇི: 21
#
# ཡིད་ཆེས: 21
#
# གསུམ: 20
#
# འདི: 20
#
# སྐྱེ་འཆི: 20
#
# ལས: 20
#
# ཅེས་པ: 20
#
# སྐྱེ་བ: 20
#
# ཚིག: 19
#
# སྟེ: 19
#
# བཤད: 19
#
# རྒྱུན: 17
#
# འཆི་བ: 17
#
# ཐག: 16
#
# མན་ངག: 16
#
# ནམ་མཁའ: 16
#
# ཕོ་བྲང: 16
#
# བཅོས: 16
#
# གནས: 16
#
# རྣམ་པར: 15
#
# དག་པ: 15
#
# འདུ: 15
#
# འབྲལ: 15
#
# གཏེར: 15
#
# གཤེན་རབ: 15
#
# ཤར: 15
#
# སྣང་སྲིད: 15
#
# ཆོ་འཕྲུལ: 15
#
# མངོན: 15
#
# དེ་ལྟར: 15
#
# མཚོན: 14
#
# འོད: 14
#
# བསྒོམ: 14
#
# སྟོན་པ: 13
#
# ཆེན་པོ: 13
#
# རྣམས: 13
#
# ཡིན་པ: 13
#
# སྙིང་པོ: 13
#
# གསལ་བ: 13
#
# ནོར: 13
#
# གཤེན་ལྷ: 13
#
# གསལ: 12
#
# ཞལ་ཆེམས: 12
#
# བསྟན: 11
#
# འིས: 11
#
# རྩིས: 11
#
# སངས་རྒྱས: 11
#
# གསུངས: 11
#
# རྒྱུ: 11
#
# རྒྱུད: 10
#
# གང: 10
#
# དེ་ལྟ: 10
#
# བུ: 10
#
# མངོན་དུ: 10
#
# གྱུར་པ: 10
#
# 09-SMDG-rgyun-thag-sa-gcod-gzhung-grel.txt top 100 bigrams
# པ་གི: 60
#
# མྱེད་པ: 53
#
# སེམས་ཀྱི: 50
#
# བྱང་ཆུབ་སེམས: 43
#
# བྱ་གོ: 39
#
# ཅེས་བྱ: 38
#
# མྱེད་པར: 35
#
# གི་དོན: 30
#
# དུ་མྱེད: 30
#
# མྱེད་པས: 26
#
# ལ་ཀྱང: 24
#
# ཀུན་ཏུ: 23
#
# སེམས་ལ: 22
#
# བསྟན་པ་དང: 18
#
# དང་དོན: 18
#
# ཏུ་བཟང་པོ: 17
#
# བརྗོད་དུ: 17
#
# ཡིད་ཆེས་པས: 17
#
# མཚན་མ་མྱེད: 16
#
# དེ་ལ: 15
#
# གི་དབྱིངས: 15
#
# འདུ་འབྲལ: 15
#
# དབྱིངས་ནས: 15
#
# བོན་ཐམས་ཅད: 15
#
# པར་ཡིད་ཆེས: 15
#
# རྒྱུན་ཐག: 14
#
# རང་བཞིན་དུ: 14
#
# བོན་ཉིད: 14
#
# གི་ཡེ་ཤེས: 13
#
# དག་པ་གི: 13
#
# ཀྱི་རང་བཞིན: 13
#
# མ་བཅོས: 13
#
# ཇི་ལ: 13
#
# གཤེན་ལྷ་འོད: 13
#
# གི་བྱང་ཆུབ: 12
#
# མ་ནོར: 12
#
# ཕོ་བྲང་ཡིན: 12
#
# སྐྱེ་བ་མྱེད: 12
#
# འབྲལ་མྱེད: 11
#
# བཟང་པོ་གཤེན་ལྷ: 11
#
# ཀུན་གཞི་བྱང་ཆུབ: 11
#
# གི་རྒྱུ: 11
#
# མཚན་མ་གི: 11
#
# དང་འདུ: 10
#
# དོན་ལ: 10
#
# སྣང་སྲིད་ཐམས་ཅད: 10
#
# གི་ཆོ་འཕྲུལ: 10
#
# ཆེན་པོ་གི: 10
#
# འོད་དཀར: 10
#
# ཀྱི་དོན: 9
#
# རིག་པ་ཀུན: 9
#
# སྐྱེ་འཆི་མྱེད: 9
#
# གི་ཀློང: 9
#
# སྐྱེ་འཆི་དང: 9
#
# ཚིག་དང: 9
#
# ཡིན་པ་ལ: 9
#
# མཚོན་དུ: 9
#
# ལུང་གི: 9
#
# གི་ཞལ་ཆེམས: 9
#
# གི་རང་བཞིན: 9
#
# གསུམ་གྱི: 9
#
# ཀྱང་མ: 9
#
# པས་ནི: 9
#
# རྣམ་པར་དག་པ: 8
#
# ལ་མ: 8
#
# དེ་ལྟ་བུ: 8
#
# ཉིད་ལ: 8
#
# ལ་བསྟན་པ: 8
#
# གི་སྙིང་པོ: 8
#
# ཡེ་ནས་སངས་རྒྱས: 8
#
# ཐམས་ཅད་སེམས: 8
#
# ལ་བཤད: 8
#
# ལ་བོར: 8
#
# མི་མངོན: 8
#
# དུས་ན: 8
#
# སུ་མྱེད: 8
#
# འཆི་བ་གི: 8
#
# པས་བོན: 8
#
# ཐམས་ཅད་མཁྱེན་པ: 7
#
# མཁྱེན་པ་གི: 7
#
# མངོན་དུ་གྱུར་པ: 7
#
# ཀྱི་རྒྱུན: 7
#
# ཅི་ལ: 7
#
# ཀྱི་ཕོ་བྲང: 7
#
# ཀྱང་མི: 7
#
# སེམས་ཡེ་ནས: 7
#
# གོ་དེ་ལྟར: 7
#
# ཅིང་མཚོན: 7
#
# གི་དུས: 7
#
# ཐམས་ཅད་ཀྱི: 6
#
# དོན་ནི: 6
#
# པ་ནི: 6
#
# ལ་མི: 6
#
# སངས་རྒྱས་པ: 6
#
# ཀྱི་རྩིས: 6
#
# མཉམ་པ་གི: 6
#
# གཏེར་ལྡན: 6
#
# མི་བསྒོམ: 6
#
# གི་བཀའ: 6
#
# པ་མྱེད: 6
#
# 10-SMDG-sems-lung-rgyun-thag.txt top 100 words
# ལ: 16
#
# གི: 14
#
# གོ: 9
#
# མི: 9
#
# མྱེད: 7
#
# ན: 6
#
# མ: 6
#
# བཅོས: 6
#
# པ: 5
#
# དོན: 5
#
# དམྱིགས: 5
#
# ཉིད: 5
#
# ཀྱང: 4
#
# སེམས: 3
#
# རྒྱུན: 3
#
# འབྲས་བུ: 3
#
# དག་པ: 3
#
# སུ: 3
#
# ནས: 3
#
# ཤེས: 3
#
# རྟོགས: 3
#
# གཡོས: 3
#
# ངང: 3
#
# འདས: 3
#
# དུ: 3
#
# ལུང: 2
#
# ཐག: 2
#
# སྟོན་པ: 2
#
# གྱི: 2
#
# ཐུགས: 2
#
# ལས: 2
#
# ཤེས་པ: 2
#
# བྱ: 2
#
# ཚད: 2
#
# གཉིས: 2
#
# དབྱིངས: 2
#
# གཡོ: 2
#
# གསལ: 2
#
# རྒོངས: 2
#
# དེ་བཞིན་ཉིད: 2
#
# སྤྱི: 2
#
# རིག་པ: 2
#
# ནམ་མཁའ: 2
#
# ཡེ་ནས: 2
#
# རང་བཞིན: 2
#
# ནམ་ཀ: 2
#
# སྤྱོད: 2
#
# བོན: 2
#
# ཐིག་ལེ: 2
#
# བཞུགས་པ: 1
#
# དབུ: 1
#
# ཕྱོགས: 1
#
# ལགས་སོ: 1
#
# གཤེན་ལྷ: 1
#
# འོད: 1
#
# དཀར: 1
#
# ཡང་དག: 1
#
# བརྣག: 1
#
# ངེས་པ: 1
#
# ཕྱིས: 1
#
# བྱོན་པ: 1
#
# རྣམས: 1
#
# སྟོན: 1
#
# ཏེ: 1
#
# ཨེ་མ་ཧོ: 1
#
# གང: 1
#
# དགསེམས: 1
#
# མི་འགྱུར་བ: 1
#
# གཡུང་དྲུང: 1
#
# འདི: 1
#
# བསྒོམ་པ: 1
#
# འདོད: 1
#
# འདི་ལྟར: 1
#
# ཅེས: 1
#
# ཐུགས་རྗེས: 1
#
# བྱིན: 1
#
# གྱིས: 1
#
# བརླབས: 1
#
# ཀྱིས: 1
#
# གཤེན: 1
#
# མེད: 1
#
# འོད་ལྡན: 1
#
# བསྟན: 1
#
# ལྟ་སྤྱོད: 1
#
# དམ་ཚིག: 1
#
# འཕྲིན་ལས: 1
#
# དགསྒོམ: 1
#
# དག: 1
#
# ཏུ: 1
#
# གཡོས་མ: 1
#
# རང: 1
#
# འཆར: 1
#
# དྲོད: 1
#
# མྱོང: 1
#
# འབྲསབུ: 1
#
# གདོན: 1
#
# ཟ: 1
#
# འགྱུར: 1
#
# དགོངས་པ: 1
#
# དེ་བཞིན: 1
#
# 10-SMDG-sems-lung-rgyun-thag.txt top 100 bigrams
# མི་དམྱིགས: 5
#
# གི་རྒྱུན: 3
#
# སུ་མྱེད: 3
#
# ཤེས་ན: 3
#
# ལ་ཀྱང: 3
#
# མ་གཡོས: 3
#
# སེམས་ལུང: 2
#
# ལུང་གི: 2
#
# རྒྱུན་ཐག: 2
#
# པ་གི: 2
#
# གི་དོན: 2
#
# ལས་དག་པ: 2
#
# ཤེས་པ་ལ: 2
#
# ལ་བྱ: 2
#
# མ་བཅོས: 2
#
# མི་གཡོ: 2
#
# རྒོངས་པ: 2
#
# བཅོས་སུ: 2
#
# སྤྱི་ལ: 2
#
# ལ་རིག་པ: 2
#
# ཉིད་ནམ་མཁའ: 2
#
# སྤྱོད་འདས: 2
#
# བོན་ཉིད: 2
#
# ཐག་བཞུགས་པ: 1
#
# བཞུགས་པ་གི: 1
#
# གི་དབུ: 1
#
# དབུ་ཕྱོགས: 1
#
# ཕྱོགས་ལགས་སོ: 1
#
# ལགས་སོ་སྟོན་པ: 1
#
# སྟོན་པ་གཤེན་ལྷ: 1
#
# གཤེན་ལྷ་འོད: 1
#
# འོད་དཀར: 1
#
# དཀར་གྱི: 1
#
# གྱི་ཐུགས: 1
#
# ཐུགས་ཡང་དག: 1
#
# ཡང་དག་པ: 1
#
# གི་བརྣག: 1
#
# བརྣག་པ: 1
#
# པ་འབྲས་བུ: 1
#
# འབྲས་བུ་ངེས་པ: 1
#
# ངེས་པ་ལ: 1
#
# ལ་སྟོན་པ: 1
#
# སྟོན་པ་གི: 1
#
# དོན་ཕྱིས: 1
#
# ཕྱིས་བྱོན་པ: 1
#
# བྱོན་པ་གི: 1
#
# གི་ལས: 1
#
# དག་པ་རྣམས: 1
#
# རྣམས་ལ: 1
#
# ལ་སྟོན: 1
#
# སྟོན་ཏེ: 1
#
# ཏེ་ཨེ་མ་ཧོ: 1
#
# ཨེ་མ་ཧོ་གང: 1
#
# གང་ལས: 1
#
# དག་པ་དགསེམས: 1
#
# དགསེམས་མི་འགྱུར་བ: 1
#
# མི་འགྱུར་བ་གི: 1
#
# གི་གཡུང་དྲུང: 1
#
# གཡུང་དྲུང་འདི: 1
#
# འདི་བསྒོམ་པ: 1
#
# བསྒོམ་པ་ལ: 1
#
# ལ་འདོད: 1
#
# འདོད་ན: 1
#
# ན་འདི་ལྟར: 1
#
# འདི་ལྟར་ཤེས་པ: 1
#
# བྱ་གོ: 1
#
# གོ་ཅེས: 1
#
# ཅེས་ཐུགས་རྗེས: 1
#
# ཐུགས་རྗེས་བྱིན: 1
#
# བྱིན་གྱིས: 1
#
# གྱིས་བརླབས: 1
#
# བརླབས་ཀྱིས: 1
#
# ཀྱིས་གཤེན: 1
#
# གཤེན་ཚད: 1
#
# ཚད་མེད: 1
#
# མེད་འོད་ལྡན: 1
#
# འོད་ལྡན་ལ: 1
#
# ལ་བསྟན: 1
#
# བསྟན་གོ: 1
#
# གོ་ལྟ་སྤྱོད: 1
#
# ལྟ་སྤྱོད་དམ་ཚིག: 1
#
# དམ་ཚིག་འཕྲིན་ལས: 1
#
# འཕྲིན་ལས་དགསྒོམ: 1
#
# དགསྒོམ་པ: 1
#
# པ་དག: 1
#
# དག་ཏུ: 1
#
# ཏུ་ཤེས་པ: 1
#
# བྱ་མ: 1
#
# མ་གཡོས་མ: 1
#
# གཡོས་མ་བཅོས: 1
#
# བཅོས་གཉིས: 1
#
# གཉིས་སུ: 1
#
# མྱེད་རང: 1
#
# རང་ལ: 1
#
# ལ་འཆར: 1
#
# འཆར་གྱི: 1
#
# གྱི་དྲོད: 1
#
# དྲོད་མྱོང: 1
#
# མྱོང་ནས: 1
#
# ནས་འབྲསབུ: 1
#
# 11-SMDG-sems-lung-rgyun-thag-'grel.txt top 100 words
# ལ: 65
#
# གི: 61
#
# ནི: 45
#
# གོ: 44
#
# ཀྱང: 33
#
# ཉིད: 30
#
# དེ: 28
#
# པ: 24
#
# སེམས: 23
#
# བྱ: 22
#
# ཀྱི: 21
#
# དུ: 20
#
# ཡིན: 20
#
# ངང: 19
#
# སུ: 18
#
# ཅེས་པ: 18
#
# ཅེས: 18
#
# སྟེ: 16
#
# ན: 16
#
# ལས: 15
#
# མྱེད: 15
#
# ནམ་མཁའ: 14
#
# མ: 14
#
# དོན: 14
#
# མི: 14
#
# བོན: 13
#
# ཡེ་ཤེས: 13
#
# བྱང་ཆུབ: 12
#
# ཀྱིས: 11
#
# ནས: 11
#
# གསལ་བ: 11
#
# དམྱིགས: 11
#
# གིས: 10
#
# དང: 10
#
# རང་བཞིན: 9
#
# བཅོས: 9
#
# གཅིག: 8
#
# རྟོགས་པ: 8
#
# གནས་པ: 8
#
# དེ་ལྟར: 8
#
# རྟོགས: 8
#
# ཆེན་པོ: 8
#
# གྱིས: 7
#
# དབྱིངས: 7
#
# རྒོངས: 7
#
# གཡོས་པ: 7
#
# ཡེ་ནས: 7
#
# ཙམ: 7
#
# བ: 6
#
# ཐམས་ཅད: 6
#
# གསལ: 6
#
# སྒོམ་པ: 6
#
# མ་བཅོས་པ: 6
#
# གཉིས: 6
#
# ཤེས: 6
#
# ལྟར: 6
#
# བདེ་བ: 6
#
# འདས་པ: 5
#
# ལས་མི: 5
#
# སལ: 5
#
# རིག་པ: 5
#
# ཅི: 5
#
# ལུང: 4
#
# གྱི: 4
#
# ཐུགས: 4
#
# སྣང: 4
#
# ཞིང: 4
#
# ཤེས་པ: 4
#
# ནང: 4
#
# སེམས་ཉིད: 4
#
# དེ་བཞིན་ཉིད: 4
#
# སྤྱི: 4
#
# བཅོས་པ: 4
#
# ཀུན་གཞི: 4
#
# དོན་དམ: 4
#
# འདས: 4
#
# མཚོན: 4
#
# རྒྱུན: 3
#
# བཤད: 3
#
# ཚད: 3
#
# མེད: 3
#
# གསན: 3
#
# དེ་ནས: 3
#
# ཏུ: 3
#
# ཆད: 3
#
# ཏིང་ངེ་འཛིན: 3
#
# ཉམས: 3
#
# དཀྱུས: 3
#
# འདུས་པ: 3
#
# ཕྱིར: 3
#
# དམ་ཚིག: 3
#
# ཕྱི: 3
#
# གམ: 3
#
# མྱ་ངན: 3
#
# ལྟ་བ: 3
#
# དེ་ལྟ: 3
#
# པས: 3
#
# རྟོག་པ: 3
#
# མེད་པ: 3
#
# འབྲས་བུ: 3
#
# 11-SMDG-sems-lung-rgyun-thag-'grel.txt top 100 bigrams
# བྱ་གོ: 16
#
# གི་ངང: 13
#
# བོན་ཉིད: 11
#
# བྱང་ཆུབ་སེམས: 10
#
# ཅེས་བྱ: 10
#
# ལ་བྱ: 9
#
# དེ་ནི: 9
#
# གི་དོན: 9
#
# མི་དམྱིགས: 9
#
# ལ་ཀྱང: 8
#
# རྒོངས་པ: 7
#
# སེམས་ཀྱི: 7
#
# ངང་ལ: 7
#
# སུ་མྱེད: 7
#
# མ་གཡོས་པ: 6
#
# པ་གི: 6
#
# ཀྱང་མི: 6
#
# བདེ་བ་གི: 6
#
# ལས་འདས་པ: 5
#
# སལ་ཀྱིས: 5
#
# གཉིས་སུ: 5
#
# མྱེད་པ: 5
#
# ཤེས་ན: 5
#
# བཅོས་སུ: 5
#
# ཡིན་ལ: 5
#
# ནམ་མཁའ་ལྟར: 5
#
# ཡེ་ཤེས་ཆེན་པོ: 5
#
# ཡིན་དེ: 5
#
# གི་དབྱིངས: 4
#
# ཤེས་པ་ལ: 4
#
# ཅེས་པ་དེ: 4
#
# དོན་ལ: 4
#
# ལ་གནས་པ: 4
#
# གོ་དེ: 4
#
# ཉིད་ཀྱི: 4
#
# གོ་དེ་ལྟར: 4
#
# གཡོས་པ་ནི: 4
#
# སྤྱི་ལ: 4
#
# ལ་རིག་པ: 4
#
# ངང་ཉིད: 4
#
# ཉིད་ནམ་མཁའ: 4
#
# ཅི་ལ: 4
#
# དེ་གི: 4
#
# གསལ་བ་གི: 4
#
# མཚོན་དུ: 4
#
# དུ་མྱེད: 4
#
# ནི་སེམས: 4
#
# ཅེས་ཀྱང: 4
#
# གི་རྒྱུན: 3
#
# གསན་ནས: 3
#
# ཉམས་སུ: 3
#
# གི་ཕྱིར: 3
#
# ཕྱི་ནང: 3
#
# མྱ་ངན་ལས: 3
#
# འདས་པ་གི: 3
#
# ཀྱི་རང་བཞིན: 3
#
# ཀྱི་ངང: 3
#
# ལས་ཀྱང: 3
#
# གསལ་ལ: 3
#
# གོ་མ: 3
#
# མ་བཅོས་པ་ནི: 3
#
# དེ་ཡེ་ནས: 3
#
# གོ་ཅེས: 3
#
# དམྱིགས་པ: 3
#
# ཅེས་པ་བྱང་ཆུབ: 3
#
# མ་བཅོས: 3
# ལ་མ་ཡེངས་པ: 3
#
# སེམས་ནམ་མཁའ: 3
#
# ལྟར་ཡེ་ཤེས: 3
#
# ཁྱབ་བདལ: 3
#
# ལ་རང་བཞིན: 3
#
# རང་བཞིན་མྱེད: 3
#
# ན་ཅེས་པ: 3
#
# གཅིག་དུ: 3
#
# གི་བྱང་ཆུབ: 3
#
# སེམས་ཅེས: 3
#
# ཀྱིས་རྟོགས: 3
#
# ཙམ་ཉིད: 3
#
# ཉིད་ན: 3
#
# ནི་བོན: 3
#
# ཀྱང་བྱ: 3
#
# ལུང་གི: 2
#
# རྒྱུན་ཐག: 2
#
# ཐག་གི: 2
#
# གཤེན་ལྷ་འོད: 2
#
# འོད་དཀར: 2
#
# ཐུགས་ཀྱི: 2
#
# ཀྱི་བརྣག: 2
#
# བརྣག་པ: 2
#
# པ་འདི: 2
#
# དབྱིངས་ནས: 2
#
# ནས་བསྒོམ: 2
#
# གཙུག་ཕུད་ཀྱིས: 2
#
# དེ་ཡན་ཆད: 2
#
# ཆད་ནི: 2
#
# ནི་གཅིག: 2
#
# བཀྲལ་ཞིང: 2
#
# ཞིང་ངོས་བཟུང: 2
#
# ངོས་བཟུང་ནས: 2
#
# ནས་བཤད་པ: 2
#
# 12-SMDG-lhug-par-bzhag-pa.txt top 100 words
# ལ: 106
#
# གི: 92
#
# མི: 50
#
# མྱེད: 45
#
# གོ: 43
#
# པ: 35
#
# དང: 35
#
# གིས: 34
#
# ངང: 30
#
# མོ: 25
#
# ཅེས: 25
#
# ཀྱང: 24
#
# ཚིག: 23
#
# དུ: 23
#
# བྱ་བ: 22
#
# ཡེ་ཤེས: 21
#
# ན: 21
#
# སེམས: 20
#
# ནི: 19
#
# བསྟན་པ: 19
#
# དོན: 18
#
# མ: 17
#
# གསལ: 17
#
# ཀྱི: 16
#
# བསྒོམ: 15
#
# ཙམ: 15
#
# ཉིད: 14
#
# སེམས་ཉིད: 14
#
# ཡང་ན: 14
#
# བཤད: 13
#
# བོན: 12
#
# སྤྱོད་པ: 11
#
# དེ་ནས: 11
#
# མཚོན: 11
#
# གཤེན་རབ: 11
#
# མན་ངག: 10
#
# ལྡན: 10
#
# ལས: 9
#
# སུ: 9
#
# གནས: 9
#
# པས: 9
#
# པར: 8
#
# འདི: 8
#
# གསལ་བ: 8
#
# ཅི: 8
#
# ཡེངས་པ: 8
#
# ནས: 7
#
# དམྱིགས: 7
#
# བསྟན: 7
#
# བཅོས: 7
#
# སྟེ: 7
#
# བསྒོམ་པ: 7
#
# ཏེ: 6
#
# དགུ: 6
#
# མ་བཅོས་པ: 6
#
# ཡོད: 6
#
# གནས་པ: 5
#
# དེ: 5
#
# ཆེན་པོ: 5
#
# བྱ: 5
#
# རྟོག་པ: 5
#
# སྣང: 4
#
# འབྲས་བུ: 4
#
# ལགས: 4
#
# ཏུ: 4
#
# རྟོག: 4
#
# ཐིག་ལེ: 4
#
# དེ་བཞིན་ཉིད: 4
#
# མཚན་མ: 4
#
# བྲལ་བ: 4
#
# ཡེངས: 4
#
# ཡེ་ནས: 4
#
# སངས་རྒྱས: 4
#
# བློ: 4
#
# བློ་རིག: 4
#
# ལྷུག: 3
#
# ངེས་ཚིག: 3
#
# བ: 3
#
# མེད་པ: 3
#
# རྒུ: 3
#
# བགྲོད: 3
#
# གྱིས: 3
#
# འདས་པ: 3
#
# འཁྲུལ: 3
#
# སྐུ: 3
#
# གསུང: 3
#
# དགོངས་པ: 3
#
# སྤྱོད་ཡུལ: 3
#
# ནོར: 3
#
# ལགས་སོ: 2
#
# སྟོན་པ: 2
#
# ཐུགས: 2
#
# ཞུགས: 2
#
# གཞན: 2
#
# ཚད: 2
#
# འོད་ལྡན: 2
#
# སྟོན: 2
#
# གདམ་ངག: 2
#
# དཀྱུས: 2
#
# བཀའ: 2
#
# 12-SMDG-lhug-par-bzhag-pa.txt top 100 bigrams
# ངང་ལ: 25
#
# པ་གི: 21
#
# ཅེས་བྱ་བ: 19
#
# གི་ཚིག: 18
#
# ཚིག་གིས: 18
#
# གིས་མི: 18
#
# བྱ་བ་གི: 18
#
# མྱེད་པ: 17
#
# གི་དོན: 14
#
# གི་ངང: 14
#
# ཙམ་མོ: 14
#
# དུ་མྱེད: 12
#
# བོན་ཉིད: 12
#
# དོན་ལ: 11
#
# གཤེན་རབ་ཀྱི: 11
#
# ཡེ་ཤེས་ངང: 11
#
# ཀྱི་སྤྱོད་པ: 10
#
# སྤྱོད་པ་དང: 10
#
# དང་ཀྱང: 10
#
# ཀྱང་ལྡན: 10
#
# བཤད་གོ: 10
#
# བསྒོམ་མོ: 10
#
# མོ་ཡང་ན: 10
#
# བསྟན་པ་དང: 9
#
# གི་ཡེ་ཤེས: 9
#
# ལ་སེམས་ཉིད: 9
#
# མི་མཚོན: 9
#
# མཚོན་གོ: 9
#
# མི་བཤད: 9
#
# མི་བསྒོམ: 9
#
# སེམས་ལ: 9
#
# བསྟན་པ་ནི: 8
#
# ཡེ་ཤེས་གསལ: 8
#
# གསལ་བོན: 8
#
# ལ་གནས: 8
#
# མྱེད་གོ: 8
#
# གོ་ཡེ་ཤེས: 8
#
# མྱེད་པས: 8
#
# ལ་ཀྱང: 7
#
# གོ་དེ་ནས: 7
#
# མ་ཡེངས་པ: 7
#
# བསྟན་གོ: 7
#
# མོ་སེམས: 7
#
# ཡེངས་པ་ཙམ: 7
#
# གིས་བསྟན: 6
#
# ཡོད་ཅེས: 6
#
# ཀྱང་མི: 6
#
# དགུ་གིས: 5
#
# ལ་གནས་པ: 5
#
# ཅི་ལ: 5
#
# ཆེན་པོ་གི: 5
#
# གསལ་ལ: 5
#
# ཡང་ན་སེམས: 5
#
# མྱེད་པར: 4
#
# བསྒོམ་དུ: 4
#
# དང་དགུ: 4
#
# སུ་མྱེད: 4
#
# མ་བཅོས་པ་གི: 4
#
# དང་བྲལ་བ: 4
#
# བྱ་བ་དང: 4
#
# ལ་མི: 4
#
# ལ་བློ་རིག: 4
#
# བློ་རིག་པ: 4
#
# ལགས་ཏེ: 3
#
# པར་བསྟན་པ: 3
#
# གི་ངེས་ཚིག: 3
#
# དུ་བསྟན་པ: 3
#
# གོ་མན་ངག: 3
#
# པ་གཤེན་རབ: 3
#
# མེད་པ་གི: 3
#
# སེམས་ཉིད་ལ: 3
#
# ཏུ་མྱེད: 3
#
# དང་རྒུ: 3
#
# ཅེས་བྱ: 3
#
# བཅོས་ན: 3
#
# གི་སྤྱོད་ཡུལ: 3
#
# ལ་བསྒོམ་པ: 3
#
# མི་དམྱིགས: 3
#
# སེམས་ཡེ་ནས: 3
#
# སངས་རྒྱས་པ: 3
#
# ལས་ཀྱང: 3
#
# ཉིད་ཀྱི: 3
#
# མི་རྟོག: 3
#
# གསལ་བ་ཙམ: 3
#
# ལ་མ: 3
#
# བསྒོམ་པ་ལ: 3
#
# པ་མ: 3
#
# བྲལ་བ་ལ: 3
#
# མན་ངག་ལྷུག: 2
#
# ལྷུག་པ: 2
#
# འདི་ནི: 2
#
# ནི་ཚིག: 2
#
# ལ་ཞུགས: 2
#
# ཚད་མྱེད: 2
#
# མྱེད་འོད་ལྡན: 2
#
# འདི་གི: 2
#
# སྟོན་ཏེ: 2
#
# གསལ་བ་གི: 2
#
# དེ་ནས་ངང: 2
#
# གནས་པ་ལ: 2
#
# 13-ngang-thag_sems-smad-sde-dgu-TTN-v3.txt top 100 words
# ལ: 264
#
# གི: 225
#
# གོ: 120
#
# སྟེ: 109
#
# དུ: 104
#
# ཀྱི: 99
#
# གིས: 93
#
# དེ: 90
#
# དང: 88
#
# ན: 79
#
# བྱ: 74
#
# ལྔ: 68
#
# སེམས: 65
#
# ཅེས་པ: 63
#
# པ: 59
#
# ཅེས: 54
#
# མ: 51
#
# ཀྱང: 50
#
# ངང: 49
#
# མི: 46
#
# མྱེད: 43
#
# གྱི: 42
#
# ཡེ་ཤེས: 40
#
# ནི: 40
#
# པོ: 39
#
# སུ: 39
#
# ལས: 38
#
# འི: 35
#
# ནས: 34
#
# ཀ: 33
#
# གཤེན་ལྷ: 31
#
# ཐག: 30
#
# ཅིང: 30
#
# རྩལ: 28
#
# འོད: 28
#
# རང: 28
#
# དུས: 27
#
# འདི: 26
#
# ཉིད: 26
#
# ཀུན: 25
#
# དུག: 25
#
# བྱང་ཆུབ: 23
#
# ཀྱིས: 23
#
# གསལ: 23
#
# སྒོ: 23
#
# གསུམ: 23
#
# ལྷ: 22
#
# ཡུལ: 22
#
# ས: 21
#
# བ: 20
#
# ཡིན: 19
#
# མཚོན: 19
#
# སྐུ: 19
#
# ནང: 19
#
# དེ་ཡང: 19
#
# གྱིས: 18
#
# ལུས: 18
#
# ཐེག་པ: 17
#
# མཐོང: 17
#
# དཔེ: 17
#
# གཉིས: 17
#
# རྟོགས: 16
#
# བཞིན: 16
#
# རྫོགས: 16
#
# སྣང: 16
#
# བག་ཆགས: 16
#
# མེ: 16
#
# སྣང་བ: 16
#
# སྤྱོད: 15
#
# ཆུ: 15
#
# འཁོར་བ: 14
#
# བོན: 14
#
# འབྱུང: 14
#
# དེ་ལྟར: 14
#
# བར་དོ: 13
#
# འགྱུར: 13
#
# འབྲས་བུ: 13
#
# ཅི: 13
#
# ནམ་མཁའ: 13
#
# རྒྱུ: 13
#
# སྤྱོད་པ: 13
#
# དགོངས་པ: 13
#
# ཉམས: 13
#
# བཅད: 13
#
# དབྱིངས: 13
#
# རླུང: 13
#
# ཤེས་པ: 13
#
# མེད: 12
#
# རུ: 12
#
# མཐའ: 11
#
# རིག་པ: 11
#
# དོན: 11
#
# སྲུང: 11
#
# ཞིང: 11
#
# སངས་རྒྱས: 11
#
# ཐམས་ཅད: 11
#
# དཔེར་ན: 11
#
# མ་ཡིན་པ: 11
#
# རང་བཞིན: 11
#
# གསའ: 10
#
# 13-ngang-thag_sems-smad-sde-dgu-TTN-v3.txt top 100 bigrams
# བྱ་གོ: 52
#
# ཅེས་བྱ: 34
#
# ཀ་ལ: 31
#
# ལ་པོ: 23
#
# གཤེན་ལྷ་ཀ: 22
#
# ལ་བྱ: 21
#
# སེམས་ཀྱི: 20
#
# ངང་དུ: 19
#
# བྱང་ཆུབ་སེམས: 18
#
# ཀྱི་ངང: 17
#
# པ་གི: 16
#
# དཔེ་གིས: 16
#
# གི་དུས: 16
#
# གིས་མཚོན: 15
#
# མཚོན་ཅིང: 15
#
# དེ་ལ: 15
#
# དུག་ལྔ: 14
#
# གོ་དེ: 14
#
# གི་ངང: 13
#
# ཉིད་དུ: 12
#
# འོད་ལྔ: 12
#
# ངང་ཐག: 11
#
# ལ་ཀྱང: 11
#
# ངང་ཉིད: 11
#
# ཐག་བཅད: 11
#
# གསའ་གིས: 10
#
# གི་དཔེ: 10
#
# ལྔ་གི: 10
#
# དུས་ན: 10
#
# གི་སྐུ: 9
#
# རང་འབྱུང: 9
#
# ནང་དུ: 9
#
# མ་ཡིན: 8
#
# བར་དོ་ལ: 8
#
# ལྷ་ལྔ: 8
#
# མེ་ཆུ: 8
#
# ཆུ་ས: 8
#
# སྲོད་ལ: 8
#
# ཡེ་ཤེས་ལྔ: 8
#
# ཤེས་པ་ལ: 8
#
# ཅེས་པ་དེ་ལྟར: 8
#
# བྱ་སྟེ: 8
#
# ཀྱང་མ: 7
#
# ཆོད་ན: 7
#
# ཐེག་སྒོ: 7
#
# ཉིན་མོ: 7
#
# གུང་ལ: 7
#
# འདི་ཅེས: 7
#
# ལས་འདས: 7
#
# ལྔ་ལ: 7
#
# དེ་བཞིན་དུ: 7
#
# བོན་ཉིད: 7
#
# སྟེ་དེ་ཡང: 7
#
# གོ་དེ་ཡང: 7
#
# པོ་འི: 6
#
# ལ་ཡེ་ཤེས: 6
#
# ཅི་ལ: 6
#
# གི་མཆོག: 6
#
# ལ་སྣང: 6
#
# གསང་སྒོ: 6
#
# རྩལ་གསུམ: 6
#
# ས་རླུང: 6
#
# ལ་བག་ཆགས: 6
#
# ཀུན་ཏུ: 6
#
# ཏུ་བཟང་པོ: 6
#
# ཅེས་པ་འདི: 6
#
# འདི་གིས: 6
#
# དང་འདྲ: 6
#
# བཞིན་དུ: 6
#
# ལ་མ: 6
#
# སེམས་རང: 6
#
# འབྱུང་གི: 6
#
# གི་གཤེན་ལྷ: 6
#
# སྟེ་དཔེར་ན: 6
#
# ཅེས་པ་སེམས: 6
#
# དུས་སུ: 6
#
# གི་ཡེ་ཤེས: 5
#
# སྐལ་པ: 5
#
# རྔོ་གིས: 5
#
# གི་བར་དོ: 5
#
# འཁོར་བ་གི: 5
#
# བྱ་རྩལ: 5
#
# གི་དོན: 5
#
# དུ་དུག: 5
#
# ཡིན་སྟེ: 5
#
# གི་སྒོ: 5
#
# སེམས་སུ: 5
#
# དང་བྲལ: 5
#
# ཀུན་གཞིའ: 5
#
# ཅིང་ཅེས་པ: 5
#
# ཅེས་བྱ་བ: 5
#
# སྡུག་བསྔལ་དང: 5
#
# དང་བཅས: 5
#
# བཅས་སྟེ: 5
#
# སྟེ་དེ: 5
#
# མྱེད་དེ: 5
#
# མཆོག་ཅེས: 5
#
# བསྡུ་སྟེ: 5
#
# སེམས་ཅེས་པ: 5
#
# ཅིག་ཤེས་པ: 5
#
# 14-SMDG-thig-le-dbyings-kyi-ti-ka-v2.txt top 100 words
# གི: 358
#
# ལ: 320
#
# དང: 210
#
# ཀྱི: 153
#
# གོ: 143
#
# གིས: 143
#
# དུ: 122
#
# ཅེས: 118
#
# ལས: 86
#
# གྱི: 85
#
# བྱ: 82
#
# པ: 76
#
# ནི: 74
#
# དོན: 73
#
# དེ: 72
#
# ཡེ་ཤེས: 65
#
# ལྷ: 64
#
# སུ: 57
#
# སྟེ: 57
#
# ཏེ: 56
#
# ཀྱང: 56
#
# གནས: 45
#
# དབྱིངས: 41
#
# ལྔ: 41
#
# ནས: 40
#
# སྤྲུལ: 36
#
# བོན: 33
#
# མེད་པ: 32
#
# གསལ་བ: 31
#
# སྐུ: 31
#
# གྱིས: 30
#
# བྱ་བ: 29
#
# བཞི: 29
#
# རང: 28
#
# ཏུ: 28
#
# མ: 28
#
# གསུམ: 28
#
# བདག: 28
#
# ཐམས་ཅད: 26
#
# གསའ: 26
#
# རུ: 25
#
# གནས་པ: 25
#
# ཀྱིས: 25
#
# ཀུན: 24
#
# མི: 24
#
# ཅེས་པ: 23
#
# དེས: 23
#
# ཕྱག་རྒྱ: 23
#
# ཉིད: 22
#
# སེམས: 22
#
# སྤྲུལ་པ: 22
#
# མེད: 22
#
# ལོ: 22
#
# རང་བཞིན: 21
#
# རྩ: 21
#
# བསྟན་པ: 21
#
# ཐིག་ལེ: 19
#
# ཅིང: 19
#
# སེམས་ཅན: 19
#
# རྣམས: 19
#
# གཤེན: 19
#
# བྱིན: 19
#
# ཡུམ: 19
#
# རིན་པོ་ཆེ: 19
#
# ལྷ་མོ: 19
#
# གཡུང་དྲུང: 18
#
# གཉིས: 18
#
# ཡིན: 18
#
# བ: 18
#
# ཐིག: 18
#
# བརྒྱུད: 18
#
# རྫོགས་པ: 17
#
# ཐུགས: 17
#
# དཀྱིལ་འཁོར: 17
#
# ཐུགས་རྗེ: 17
#
# ལུས: 17
#
# རྫུ་འཕྲུལ: 16
#
# སྟོན: 16
#
# སྣང: 16
#
# ཅན: 16
#
# ཕྱག: 16
#
# ན: 16
#
# མཐའ: 15
#
# ངང: 15
#
# མཚན: 15
#
# རྒྱུ: 15
#
# ཡོངས་སུ: 14
#
# ཡི: 14
#
# པར: 14
#
# ནམ་མཁའ: 14
#
# མཁར: 14
#
# མཁའ: 14
#
# བརླབ: 14
#
# བཅུ: 14
#
# སྟོན་པ: 13
#
# གསལ: 13
#
# བྱུང: 13
#
# ཡེ: 13
#
# མཚན་མ: 13
#
# ཆགས: 13
#
# 14-SMDG-thig-le-dbyings-kyi-ti-ka-v2.txt top 100 bigrams
# ཅེས་བྱ: 52
#
# བྱ་གོ: 43
#
# ཅེས་པ: 34
#
# གསའ་གིས: 26
#
# གི་དོན: 23
#
# བྱིན་གྱིས: 18
#
# སྤྲུལ་ལོ: 17
#
# ལ་བརྒྱུད: 17
#
# བརྒྱུད་དེས: 17
#
# གི་ཡེ་ཤེས: 15
#
# གོ་དེ: 15
#
# དེ་གི: 15
#
# གིས་མཁར: 14
#
# ཀུན་ཏུ: 13
#
# བྱ་སྟེ: 13
#
# ཡེ་ཤེས་ཀྱི: 13
#
# ཅེས་ཀྱང: 13
#
# བཞི་བཅུ: 13
#
# པ་གི: 12
#
# ཀྱང་བྱ: 12
#
# གྱིས་བརླབ: 12
#
# དུ་སྤྲུལ: 12
#
# ལྔ་གི: 11
#
# ཀྱི་དོན: 11
#
# གི་ཕྱིར: 11
#
# ལྷ་གི: 11
#
# དབྱིངས་སུ: 11
#
# དབྱིངས་ཀྱི: 10
#
# ཀྱི་ཡེ་ཤེས: 10
#
# གསལ་བ་ལ: 10
#
# ཡིན་ལ: 10
#
# གི་དབྱིངས: 10
#
# ཐམས་ཅད་ཀྱི: 10
#
# ཅེས་བྱ་བ: 10
#
# བཅུ་རྩ: 10
#
# ཏུ་བཟང་པོ: 9
#
# བོན་གྱི: 9
#
# དུ་གནས་པ: 9
#
# ངང་དུ: 9
#
# དོན་དམ་པར: 9
#
# དེ་ལ: 9
#
# མེད་པ་གི: 9
#
# གི་ལྷ་མོ: 9
#
# གི་ངང: 9
#
# རྩ་ལྔ: 9
#
# བདག་གི: 9
#
# དོན་གྱི: 8
#
# རང་འབྱུང: 8
#
# གོ་དེ་ཡང: 8
#
# གནས་པ་ལ: 8
#
# རྫོགས་པ་གི: 8
#
# བདག་དང: 8
#
# གྱི་དོན: 8
#
# དེ་ལྟ་བུ: 8
#
# ནམ་མཁའ་གི: 8
#
# ཀྱི་ལྷ: 8
#
# དོན་དང: 8
#
# དང་བཅས་པ: 8
#
# བྱ་ལ: 8
#
# ལ་གནས: 8
#
# གནས་གོ: 8
#
# ལ་སྤྲུལ: 8
#
# ལྷ་མོ་ལས: 8
#
# ཐིག་ལེ་དབྱིངས: 7
#
# ཡོངས་སུ་རྫོགས་པ: 7
#
# སུ་མེད་པ: 7
#
# བྱུང་སྟེ: 7
#
# སྣང་ལ: 7
#
# ལ་ཆགས: 7
#
# གི་སྐུ: 7
#
# གཉིས་སུ: 7
#
# མེད་པ་གིས: 7
#
# ལས་འདས་པ: 7
#
# དང་ལྡན་པ: 7
#
# གི་ཏིང་ངེ་འཛིན: 7
#
# མཐའ་ལ: 7
#
# ཡེ་གཤེན་གཙུག་ཕུད: 7
#
# བོན་ཉིད: 7
#
# ལ་གནས་པ: 7
#
# ལ་མི: 7
#
# ཆགས་གོ: 7
#
# མཚན་དང: 7
#
# བསྟན་པ་གི: 7
#
# གི་གནས: 7
#
# ལ་དེ: 7
#
# ལ་བྱ: 7
#
# གཟུགས་ཀྱི: 7
#
# རུ་སྤྲུལ: 7
#
# གཡུང་དྲུང་ཡོངས་སུ: 6
#
# ཡེ་ཤེས་དང: 6
#
# གསལ་བ་གི: 6
#
# རིགས་ཀྱི: 6
#
# རང་བཞིན་དུ: 6
#
# སྤྲུལ་པ་གི: 6
#
# ནི་ཡེ་ཤེས: 6
#
# ལྡན་པ་གི: 6
#
# ཀུན་ལ: 6
#
# སྐུ་གསུང་ཐུགས་ཀྱི: 6
#
# ཐུགས་རྗེ་གི: 6
#
# ལ་རང་བཞིན: 6
#
# nyingma texts
# L1-rig-pa'i-khu-byug_p302-324.txt top 100 words
# གི: 241
#
# ལ: 204
#
# དང: 90
#
# གིས: 87
#
# མི: 79
#
# ཀྱི: 57
#
# ཀུན: 54
#
# རྡོ་རྗེ: 52
#
# དུ: 48
#
# ནི: 45
#
# ཀྱང: 43
#
# ནས: 42
#
# པ: 42
#
# ཆེན་པོ: 40
#
# མེད: 39
#
# མ: 38
#
# ལས: 38
#
# གོ: 37
#
# ཏུ: 34
#
# ཐམས་ཅད: 33
#
# དེ: 32
#
# བཅོམ་ལྡན་འདས: 30
#
# ན: 29
#
# སྐུ: 29
#
# གྱི: 27
#
# ཉིད: 27
#
# འདི: 27
#
# མཆོག: 26
#
# ཡེ་ཤེས: 25
#
# ཆོས: 24
#
# མེད་པ: 22
#
# ཡིན: 21
#
# སངས་རྒྱས: 21
#
# ཐེག་པ: 20
#
# ཕྱིར: 20
#
# ལམ: 20
#
# ཁྱོད: 20
#
# དེ་བཞིན: 19
#
# གཉིས: 19
#
# རང་བཞིན: 19
#
# སྟེ: 19
#
# དེ་ནས: 19
#
# གཅིག: 18
#
# དག་པ: 18
#
# རྒྱུད: 18
#
# གང: 17
#
# དཔལ: 16
#
# ཕྱག: 16
#
# སྙིང་པོ: 16
#
# ཅེས: 16
#
# གནས: 15
#
# རྣམ་པར: 15
#
# གཞན: 15
#
# ལྔ: 15
#
# དཀྱིལ་འཁོར: 15
#
# འཚལ: 14
#
# ཡི: 14
#
# རྣམས: 14
#
# བྱང་ཆུབ: 14
#
# བསྟན་པ: 14
#
# རྫོགས: 14
#
# བྱ: 13
#
# ཏེ: 13
#
# གནས་པ: 13
#
# རྒྱལ་བ: 13
#
# མེད་པར: 12
#
# གྱུར: 12
#
# དེ་བཞིན་ཉིད: 12
#
# གསུམ: 12
#
# སེམས་དཔའ: 12
#
# རྒྱལ་པོ: 12
#
# བདག: 11
#
# ཐུགས: 11
#
# ཅིང: 11
#
# སེམས: 11
#
# སུ: 11
#
# བཞིན: 11
#
# འདས: 11
#
# འགྱུར: 11
#
# ཕྱག་རྒྱ: 11
#
# ཁུ་བྱུག: 10
#
# ལྟར: 10
#
# བདེ་བ: 10
#
# རྟག་པ: 10
#
# མིན: 10
#
# དབྱིངས: 10
#
# བརྗོད: 10
#
# འབྲས་བུ: 10
#
# རྟག: 10
#
# བཀྲ་ཤིས་པ: 9
#
# རིག་པ: 9
#
# གཤེགས་པ: 9
#
# གྱུར་པ: 9
#
# ཤིང: 9
#
# ལྡན་པ: 9
#
# བྱ་བ: 9
#
# འཛིན་པ: 9
#
# ལྡན: 9
#
# དོན: 9
#
# གསུང: 9
#
# L1-rig-pa'i-khu-byug_p302-324.txt top 100 bigrams
# ཀུན་ཏུ: 18
#
# དེ་ནས་བཅོམ་ལྡན་འདས: 15
#
# ཕྱག་འཚལ: 13
#
# ལ་མི: 13
#
# ཆེན་པོ་གི: 12
#
# ཀུན་གྱི: 12
#
# བཅོམ་ལྡན་འདས་དཔལ: 11
#
# དཔལ་ཀུན: 11
#
# རྡོ་རྗེ་ཐེག་པ: 11
#
# གི་ཕྱིར: 10
#
# དེ་ནི: 10
#
# དེ་ལ: 10
#
# རྡོ་རྗེ་སེམས་དཔའ: 10
#
# གོ་དེ་ནས: 10
#
# ལ་ཀྱང: 10
#
# ཐེག་པ་གི: 10
#
# ཁྱོད་ལ: 10
#
# མེད་པ་གི: 9
#
# ཆོས་ཀྱི: 9
#
# གི་སྐུ: 9
#
# ཐམས་ཅད་ཀྱི: 8
#
# པ་གི: 8
#
# གི་མཆོག: 8
#
# ཆེད་དུ: 8
#
# ཏུ་བཟང་པོས: 8
#
# རིག་པ་གི: 7
#
# གི་ཁུ་བྱུག: 7
#
# དེ་བཞིན་གཤེགས་པ: 7
#
# མ་ཡིན: 7
#
# མེད་པ་གིས: 7
#
# གི་ལེའུ: 7
#
# ལེའུ་སྟེ: 7
#
# ཇི་ལྟ་ལ: 7
#
# གི་ལམ: 7
#
# དག་པ་གི: 7
#
# གི་རྒྱུད: 7
#
# ཆོས་ཐམས་ཅད: 6
#
# ཀྱི་སྐུ: 6
#
# ལས་འདས: 6
#
# མི་རྟོག: 6
#
# གནས་པ་གི: 6
#
# བཀྲ་ཤིས་པ་རིག་པ: 6
#
# རྒྱུད་ཀྱི: 6
#
# བཅོམ་ལྡན་འདས་ཆེན་པོ: 5
#
# ཐེག་པ་ཆེན་པོ: 5
#
# ཀྱི་དེ་བཞིན་ཉིད: 5
#
# ལས་འདས་པ: 5
#
# འདས་པ་གི: 5
#
# གི་ཆོས: 5
#
# ལ་བྱ་བ: 5
#
# རྫོགས་པ་གི: 5
#
# སེམས་དཔའ་གིས: 5
#
# ཉིད་དུ: 5
#
# ལ་གནས: 5
#
# གང་ལ: 5
#
# པ་དང: 5
#
# གནས་པ་གིས: 5
#
# ལ་གནས་པ: 5
#
# གཞན་ལ: 5
#
# ལ་སྙོམས་པ: 5
#
# སྙོམས་པ་ལ: 5
#
# པ་གོ: 5
#
# གི་ཏིང་ངེ་འཛིན: 5
#
# གདོད་ནས: 5
#
# རྟག་ཏུ: 5
#
# ཁུ་བྱུག་གི: 5
#
# རྒྱུད་ལས: 5
#
# དཀྱིལ་འཁོར་ཆེན་པོ: 5
#
# ཁྱོད་ནི: 5
#
# རྟག་ཕྱག: 5
#
# ཀྱང་རྟག: 5
#
# རྡོ་རྗེ་འཛིན་པ: 5
#
# ཏུ་བཟང་པོ: 4
#
# གི་དུས: 4
#
# ངོ་བོ་ཉིད: 4
#
# རྣམ་པར་དག་པ: 4
#
# རྟག་པ་ལ: 4
#
# གསལ་བ་ལ: 4
#
# གྱུར་ན: 4
#
# ཀུན་ལ: 4
#
# ཅེས་བྱ་བ: 4
#
# གི་ངང: 4
#
# གཉིས་མེད: 4
#
# གི་འབྲས་བུ: 4
#
# རྒྱལ་བ་གི: 4
#
# ཏིང་ངེ་འཛིན་ལ: 4
#
# ལ་ཞུགས: 4
#
# ཞུགས་ནས: 4
#
# མེད་དེ: 4
#
# དང་མ: 4
#
# གིས་ན: 4
#
# འདུས་པ་གི: 4
#
# བྱ་བ་གི: 4
#
# ལ་གྱུར: 4
#
# སྙིང་པོ་གི: 4
#
# བསྟན་པ་གི: 4
#
# སངས་རྒྱས་ཀུན: 4
#
# ལ་བསྟོད་པ: 4
#
# ཀྱི་རྒྱལ་པོ: 4
#
# ལེགས་གོ: 4
#
# L2-rtsal-chen_p436-447་.txt top 100 words
# གི: 122
#
# ལ: 104
#
# གིས: 41
#
# མི: 41
#
# མེད: 41
#
# པ: 36
#
# གོ: 32
#
# ཀྱང: 31
#
# ཉིད: 30
#
# ཀུན: 29
#
# ཏུ: 29
#
# ལས: 27
#
# བཅོམ་ལྡན་འདས: 26
#
# ཆོས: 26
#
# དོན: 25
#
# དུ: 24
#
# དང: 24
#
# མ: 21
#
# བྱང་ཆུབ: 19
#
# སེམས: 19
#
# ཀྱི: 19
#
# དེ: 19
#
# ནི: 19
#
# ཀྱིས: 18
#
# དེ་ནས: 18
#
# གཉིས: 18
#
# གནས: 18
#
# རྒྱུད: 17
#
# དཔལ: 17
#
# སངས་རྒྱས: 17
#
# ལམ: 17
#
# རྩལ: 16
#
# ཆེན: 16
#
# གྱི: 15
#
# ན: 15
#
# མེད་པ: 15
#
# ནས: 15
#
# རང་བཞིན: 14
#
# སྙིང་པོ: 14
#
# སྟེ: 14
#
# བརྗོད་པ: 14
#
# ཐམས་ཅད: 11
#
# རྣམས: 11
#
# འདི: 11
#
# བཟང་པོ: 10
#
# དེ་བཞིན: 10
#
# ཆེན་པོ: 10
#
# དག་པ: 10
#
# བཞིན: 10
#
# མཆོག: 10
#
# བྱ་བ: 10
#
# ལེའུ: 10
#
# ཡིན: 9
#
# བཟང་པོས: 9
#
# ཡི: 9
#
# དག: 9
#
# ཕྱག: 8
#
# འཚལ: 8
#
# རྣམ་པར: 8
#
# ཏེ: 8
#
# སྤྱོད་པ: 8
#
# སུ: 8
#
# བྱ: 8
#
# ལྷུན: 7
#
# གྱིས: 7
#
# རྡོ་རྗེ: 7
#
# སྐུ: 7
#
# འཁྲུལ: 7
#
# གཞན: 7
#
# གསུམ: 6
#
# མེད་པར: 6
#
# རྫོགས: 6
#
# གྱུར: 6
#
# སྤྲུགས་པ: 6
#
# བྲལ: 6
#
# ཚིག: 6
#
# བདག: 5
#
# འཛིན: 5
#
# སེམས་དཔའ: 5
#
# ལ་སོགས: 5
#
# ཕྱིར: 5
#
# ཅེས: 5
#
# བདག་མེད: 5
#
# དབྱིངས: 5
#
# ཤེས: 5
#
# ཆེད: 5
#
# བདག་གཞན: 5
#
# ཏིང་འཛིན: 5
#
# འདྲ: 5
#
# མཐོང: 5
#
# དུས: 4
#
# རྫོགས་པ: 4
#
# བཞུགས་པ: 4
#
# ཁོ་ན་ཉིད: 4
#
# རིན་པོ་ཆེ: 4
#
# རབ་ཏུ: 4
#
# གསོལ: 4
#
# སྤྲུགས: 4
#
# བཅོས: 4
#
# བཤད: 4
#
# L2-rtsal-chen_p436-447་.txt top 100 bigrams
# ཀུན་ཏུ: 20
#
# གོ་དེ་ནས: 16
#
# བཅོམ་ལྡན་འདས་དཔལ: 16
#
# དེ་ནས་བཅོམ་ལྡན་འདས: 14
#
# གཉིས་མེད: 14
#
# བྱང་ཆུབ་སེམས: 12
#
# རྩལ་ཆེན: 12
#
# དཔལ་ཀུན: 11
#
# སེམས་རྩལ: 10
#
# གི་དོན: 9
#
# ཏུ་བཟང་པོས: 9
#
# རྒྱུད་ལས: 9
#
# གི་ལེའུ: 9
#
# ལེའུ་སྟེ: 9
#
# ཏུ་བཟང་པོ: 8
#
# གི་ལམ: 8
#
# པ་གི: 8
#
# དག་པ་གི: 7
#
# གི་ཆོས: 7
#
# གི་རྒྱུད: 7
#
# གྱི་རྒྱུད: 6
#
# མ་ཡིན: 6
#
# མེད་པ་གི: 6
#
# ཆོས་ཀྱི: 6
#
# ཉིད་ཀྱིས: 6
#
# ལ་བྱ་བ: 6
#
# སྤྲུགས་པ་གི: 6
#
# པ་གོ: 6
#
# ཆེན་གྱི: 5
#
# ཀུན་གྱི: 5
#
# གི་མཆོག: 5
#
# དཔལ་རྡོ་རྗེ: 5
#
# རྡོ་རྗེ་སེམས་དཔའ: 5
#
# ལ་བྱ: 5
#
# བཅོམ་ལྡན་འདས་ཀུན: 5
#
# ཆེད་དུ: 5
#
# དུ་བརྗོད་པ: 5
#
# བརྗོད་པ་ལ: 5
#
# ཆེན་སྤྲུགས་པ: 5
#
# དོན་ལ: 5
#
# ཉིད་ལ: 5
#
# ཕྱག་འཚལ: 4
#
# གི་དུས: 4
#
# ཆེན་པོ་གི: 4
#
# ཉིད་ཀྱི: 4
#
# རྣམ་པར་དག་པ: 4
#
# ལ་སོགས་པ: 4
#
# གི་རང་བཞིན: 4
#
# བཀའ་སྩལ: 4
#
# སྩལ་པ: 4
#
# བསྟན་པ་གི: 4
#
# དེ་ལ: 4
#
# ཕྱག་ཀྱང: 4
#
# མེད་པ་གིས: 4
# ལ་གནས: 4
#
# མི་གནས: 4
#
# རྣམ་པར་དག: 4
#
# ལ་ཀྱང: 4
#
# གི་སྙིང་པོ: 4
#
# གོ་བྱང་ཆུབ: 4
#
# ལ་ཕྱག: 3
#
# ཐམས་ཅད་ཀྱི: 3
#
# དེ་ཁོ་ན་ཉིད: 3
#
# ལྷུན་གྱིས: 3
#
# ནོར་བུ་རིན་པོ་ཆེ: 3
#
# རྣམས་ཀྱིས: 3
#
# ནས་བཅོམ་ལྡན་འདས: 3
#
# གི་ཕྱིར: 3
#
# རྩལ་སྤྲུགས: 3
#
# བཤད་དུ: 3
#
# བྱ་བ་གི: 3
#
# ཀྱི་དབྱིངས: 3
#
# སངས་རྒྱས་སེམས་ཅན: 3
#
# ཡོངས་ཀྱིས: 3
#
# ལྷུན་རྫོགས: 3
#
# བཟང་པོ་ཉིད: 3
#
# ཡེ་ནས་རྣམ་པར: 3
#
# གིས་བཅོམ་ལྡན་འདས: 3
#
# གི་ཡུལ: 3
#
# ཡུལ་ལ: 3
#
# ཡོད་མ: 3
#
# འཁྲུལ་པ: 3
#
# ལ་མི: 3
#
# མི་དམིགས: 3
#
# ཆོས་ལ: 3
#
# སྟོན་པ་གིས: 3
#
# ཇི་ལྟ་ལ: 3
#
# ཀྱང་འཚལ: 3
#
# བཟང་པོ་ལ: 2
#
# དེ་བཞིན་གཤེགས་པ: 2
#
# རྫོགས་པ་གི: 2
#
# ངོ་བོ་ཉིད: 2
#
# ཀྱི་དེ: 2
#
# པ་ཀུན: 2
#
# གྱི་རང་བཞིན: 2
#
# གྲུབ་པ་གི: 2
#
# རྟག་པ་ལ: 2
#
# དེ་བཞིན་གོ: 2
#
# རིན་པོ་ཆེ་གི: 2
#
# བཟང་པོ་གི: 2
#
# L3-khyung-chen_p447-468.txt top 100 words
# གི: 206
#
# ལ: 193
#
# མི: 130
#
# གིས: 89
#
# མེད: 71
#
# ཉིད: 66
#
# འདི: 60
#
# གནས: 56
#
# ཀྱང: 51
#
# ཀུན: 50
#
# ཀྱི: 50
#
# དང: 46
#
# ལམ: 45
#
# དུ: 44
#
# མ: 42
#
# བྱང་ཆུབ: 39
#
# ཏུ: 37
#
# པ: 36
#
# དེ: 34
#
# ཆོས: 31
#
# ཡིན: 31
#
# ལས: 31
#
# ནས: 27
#
# ནི: 27
#
# གྱི: 27
#
# དོན: 26
#
# སངས་རྒྱས: 26
#
# ཀྱིས: 23
#
# སྙིང་པོ: 23
#
# ན: 23
#
# རྣམས: 20
#
# སྟེ: 20
#
# མཆོག: 20
#
# རང་བཞིན: 20
#
# རྒྱུད: 20
#
# སེམས: 19
#
# དེ་བཞིན: 19
#
# གནས་པ: 19
#
# ཐམས་ཅད: 19
#
# གཞན: 19
#
# ཆེན་པོ: 19
#
# ཡི: 19
#
# གོ: 18
#
# གྱིས: 18
#
# དེ་བཞིན་ཉིད: 18
#
# གསུམ: 18
#
# བཅོམ་ལྡན་འདས: 17
#
# ཁྱུང་ཆེན: 17
#
# དགོས: 17
#
# ཡེ་ཤེས: 16
#
# མེད་པ: 16
#
# རྫོགས: 16
#
# དཔལ: 15
#
# ལྷུན: 15
#
# ཡེ་ནས: 15
#
# འགྱུར: 14
#
# གང: 14
#
# བྱ: 14
#
# དཀྱིལ་འཁོར: 14
#
# ཕྱག་རྒྱ: 14
#
# ངང: 13
#
# མཐའ: 13
#
# བཞིན: 13
#
# སྐུ: 13
#
# དེ་ནས: 12
#
# བཟང་པོ: 12
#
# རྙེད: 12
#
# མིན: 12
#
# དག་པ: 12
#
# ཡང་དག: 12
#
# བསྟན་པ: 12
#
# རྟོག: 11
#
# པས: 11
#
# ལུས: 11
#
# བྱེད: 11
#
# གཉིས: 11
#
# གཅིག: 11
#
# ཏེ: 10
#
# ཇི་བཞིན: 10
#
# ཡུལ: 10
#
# སུ: 10
#
# ཞིང: 10
#
# ཆགས: 10
#
# དབྱིངས: 10
#
# ལེའུ: 10
#
# འདས: 10
#
# ས: 10
#
# ཡུལ་མེད: 9
#
# གཉེན་པོ: 9
#
# ཅིང: 9
#
# འཁྲུལ: 9
#
# ཚུལ: 9
#
# རྡོ་རྗེ: 8
#
# ཕྱག: 8
#
# འཚལ: 8
#
# རྣམ་པར: 8
#
# བརྗོད་པ: 8
#
# ཐིག་ལེ: 8
#
# བསྒོམ: 8
#
# འབྱུང་བ: 8
#
# L3-khyung-chen_p447-468.txt top 100 bigrams
# མི་གནས: 22
#
# ཀུན་ཏུ: 19
#
# ཉིད་ལ: 17
#
# ལ་མི: 16
#
# གི་ལམ: 15
#
# མི་དགོས: 15
#
# བཅོམ་ལྡན་འདས་དཔལ: 13
#
# འདི་ལ: 13
#
# པ་གི: 12
#
# མ་ཡིན: 12
#
# དཔལ་ཀུན: 11
#
# ཏུ་བཟང་པོ: 11
#
# ཉིད་ཀྱིས: 11
#
# སེམས་ཁྱུང་ཆེན: 11
#
# ཁྱུང་ཆེན་གྱི: 11
#
# གྱི་རྒྱུད: 11
#
# མེད་པ་གི: 11
#
# དེ་ནས་བཅོམ་ལྡན་འདས: 10
#
# བྱང་ཆུབ་ཀྱི: 10
#
# ཀྱི་སེམས: 10
#
# རྒྱུད་ལས: 10
#
# ཀྱང་མི: 10
#
# གོ་དེ་ནས: 9
#
# མི་རྙེད: 9
#
# གི་ལེའུ: 9
#
# ལེའུ་སྟེ: 9
#
# ལ་ཀྱང: 9
#
# གི་ཡུལ་མེད: 8
#
# ལ་གནས: 8
#
# མ་ལུས: 8
#
# གི་ཆོས: 8
#
# འདི་ནི: 8
#
# ཚུལ་དུ: 8
#
# ལྷུན་གྱིས: 8
#
# ཀུན་གྱི: 8
#
# མི་རྟོག: 7
#
# འདི་ཡི: 7
#
# པ་གོ: 7
#
# སྙིང་པོ་འདི: 7
#
# གི་དཀྱིལ་འཁོར: 7
#
# གནས་པ་གི: 7
#
# དག་པ་གི: 7
#
# བཟང་པོ་ཉིད: 6
#
# ཀྱིས་ཉིད: 6
#
# ཆོས་ཀྱི: 6
#
# ཉིད་ཀྱི: 6
#
# གི་དོན: 6
#
# གིས་ཀྱང: 6
#
# གནས་པ་གིས: 6
#
# འཁྲུལ་པ: 6
#
# ལ་ཉིད: 6
#
# གི་ངང: 6
#
# མི་བྱེད: 6
#
# གྱིས་གྲུབ་པ: 6
#
# མཐའ་ལ: 6
#
# དེ་ལ: 6
#
# བྱང་ཆུབ་སེམས: 6
#
# ཆེ་བ་གི: 5
#
# ཆོས་རྣམས: 5
#
# མཆོག་ཏུ: 5
#
# མི་འགྱུར: 5
#
# གཞན་ནས: 5
#
# གི་གནས: 5
#
# ཀྱང་མ: 5
#
# ཕྱག་རྒྱ་གི: 5
#
# གི་ཚུལ: 5
#
# ལྷུན་རྫོགས: 5
#
# འདི་ལས: 5
#
# གདོད་ནས: 5
#
# གི་སྐལ་ལྡན: 5
#
# རྒྱུད་ཀྱི: 5
#
# རྡོ་རྗེ་སེམས་དཔའ: 4
#
# རྣམས་ཀྱིས: 4
#
# ལམ་ལ: 4
#
# ལམ་མི: 4
#
# ཡུལ་ལ: 4
#
# ཆོས་ལམ: 4
#
# གིས་འདི: 4
#
# གི་མཐའ: 4
#
# རང་བཞིན་གནས་པ: 4
#
# བྱང་ཆུབ་སྙིང་པོ: 4
#
# ཀྱང་མེད: 4
#
# འདོད་པ་གིས: 4
#
# གནས་མེད: 4
#
# རྟག་ཏུ: 4
#
# གི་རྒྱལ་པོ: 4
#
# གང་ལ: 4
#
# ཀུན་དང: 4
#
# དང་བྲལ: 4
#
# ལས་འདས: 4
#
# ལམ་མེད: 4
#
# བྱ་མི: 4
#
# ལ་འགྱུར: 4
#
# འདི་མི: 4
#
# ཡེ་ཤེས་སྙིང་པོ: 4
#
# མི་དམིགས: 4
#
# མི་བྱ: 4
#
# དུ་མི: 4
#
# བསྟན་པ་གི: 4
#
# དོན་མི: 4
#
# L4_byang-sems-bsgom-rdo-la-gser-zhun-p416-425.txt top 100 words
# ལ: 89
#
# གི: 71
#
# མི: 50
#
# དེ: 47
#
# མེད: 47
#
# གིས: 45
#
# དང: 44
#
# ཀྱང: 39
#
# ཀྱི: 28
#
# དུ: 24
#
# ཀུན: 24
#
# ལམ: 23
#
# ནི: 22
#
# ཡིན: 22
#
# མ: 21
#
# གནས: 20
#
# ཆོས: 18
#
# ཕྱིར: 18
#
# ཏེ: 17
#
# ལས: 17
#
# འདི: 16
#
# འགྱུར: 16
#
# སེམས: 15
#
# ན: 14
#
# རྣམས: 14
#
# བྱང་ཆུབ: 13
#
# དེ་དག: 13
#
# ཤེས: 12
#
# ཤིང: 12
#
# གོ: 11
#
# ཉིད: 11
#
# རྟོག: 11
#
# ཞིང: 11
#
# ཏུ: 11
#
# ཅེས: 11
#
# ཅིང: 11
#
# པ: 11
#
# གྱི: 10
#
# ནས: 10
#
# གྱུར་པ: 9
#
# གང: 9
#
# སྣང: 9
#
# སུ: 8
#
# རབ: 8
#
# དེ་ཕྱིར: 8
#
# བྲལ: 8
#
# རྟོག་པ: 8
#
# མཐའ: 8
#
# དག: 8
#
# བག་ཆགས: 8
#
# སྐྱེ: 8
#
# མེད་པ: 8
#
# ལ་སོགས: 7
#
# གྱིས: 7
#
# གསུངས: 7
#
# དེ་ཉིད: 7
#
# འབྱུང: 7
#
# གཞན: 7
#
# དོན: 7
#
# བྱེད: 7
#
# སྐྱེ་བོ: 7
#
# འཁྲུལ: 7
#
# བཞིན: 7
#
# སྣ་ཚོགས: 7
#
# བདུད: 7
#
# རང་བཞིན: 6
#
# ལུས: 6
#
# སྤྱོད་པ: 6
#
# རྒྱལ་བས: 6
#
# དེ་ཡང: 6
#
# འཕགས་པ: 6
#
# ཡི: 6
#
# བསྒོམ་པ: 6
#
# འདས: 6
#
# འདིར: 6
#
# རྒྱུ: 6
#
# བདག: 6
#
# གསུམ: 5
#
# གཉིས: 5
#
# དབང: 5
#
# ཡིད: 5
#
# རབ་ཏུ: 5
#
# འཇིག་རྟེན: 5
#
# རྡོ་རྗེ: 5
#
# སེམས་ཉིད: 5
#
# པར: 5
#
# ཐ་སྙད: 5
#
# སྤྱོད་ཡུལ: 5
#
# དངོས་པོ: 5
#
# རྒྱུན: 5
#
# ཚད་མ: 5
#
# བརྟགས་པ: 5
#
# རྐྱེན: 5
#
# མཐུ: 5
#
# ཡུལ: 5
#
# དམིགས: 5
#
# སྐྱེས: 5
#
# སྐད་ཅིག: 5
#
# ཡོད: 5
#
# ཕྱོགས: 5
#
# L4_byang-sems-bsgom-rdo-la-gser-zhun-p416-425.txt top 100 bigrams
# དེ་ལ: 12
#
# ལ་ཀྱང: 11
#
# མེད་ཕྱིར: 9
#
# སེམས་ཀྱི: 7
#
# གི་ལམ: 7
#
# མ་ཡིན: 7
#
# ཀུན་གྱི: 6
#
# ཀུན་ཏུ: 6
#
# གང་ལ: 6
#
# ལ་མི: 6
#
# བདུད་ཀྱི: 6
#
# ཆོས་ཀྱི: 5
#
# ཅེས་རྒྱལ་བས: 5
#
# ལ་འགྱུར: 5
#
# མི་འགྱུར: 5
#
# མེད་དེ: 5
#
# མི་བྱེད: 5
#
# མི་གནས: 5
#
# བྱང་ཆུབ་སེམས: 4
#
# མི་རྟོག: 4
#
# དེ་ནི: 4
#
# གྱུར་པ་གིས: 4
#
# འཕགས་པ་གི: 4
#
# རྟོག་པ་གི: 4
#
# རང་གི: 4
#
# རྟོག་པ་གིས: 4
#
# གི་གནས: 4
#
# པ་གི: 4
#
# དང་མི: 4
#
# བསྒོམས་པ་གིས: 4
#
# རྡོ་ལ: 3
#
# ལ་གསེར: 3
#
# དག་པ་གི: 3
#
# རྒྱལ་བ་ཀུན: 3
#
# ལ་གྱུར་པ: 3
#
# རྒྱལ་བས་གསུངས: 3
#
# ཀྱང་བྱང་ཆུབ: 3
#
# ལམ་འདི: 3
#
# བརྟག་པར: 3
#
# རྣམས་ཀྱི: 3
#
# གི་རྒྱུན: 3
#
# ཚད་མ་ལ: 3
#
# གི་ཆོས: 3
#
# འདི་ནི: 3
#
# ཇི་ལྟ་ལ: 3
#
# འདྲ་བ་ལ: 3
#
# ལམ་དེ: 3
#
# སྣ་ཚོགས་དག: 3
#
# དག་གིས: 3
#
# འདྲ་ལ: 3
#
# བཞིན་དུ: 3
#
# དུ་སྣང: 3
#
# ཡིད་ལ: 3
#
# གིས་བདག: 3
#
# དང་ཆོས: 3
#
# ཆོས་རྣམས: 3
#
# མཐའ་ཡ: 3
#
# ཡ་གིས: 3
#
# ཆོས་ནི: 3
#
# མེད་པ་གིས: 3
#
# གི་ལུས: 3
#
# སྐྱེ་དང: 3
#
# མེད་ཅིང: 3
#
# ཀྱི་དབྱིངས: 3
#
# ཡིན་ཏེ: 3
#
# ཀྱང་མེད: 3
#
# ཀུན་ཀྱང: 3
#
# ཀྱང་མི: 3
#
# ཀྱི་ལས: 3
#
# དུ་མི: 3
#
# ཀྱང་བདུད: 3
#
# བསྒོམ་པ་གི: 3
#
# གི་སྤྱོད་པ: 3
#
# སྒོམ་པ་རྡོ: 2
#
# གསེར་ཞུན: 2
#
# ཉིད་བདེ་གཤེགས: 2
#
# གིས་གནས: 2
#
# མཚུངས་པ་ལ: 2
#
# ལ་རབ: 2
#
# ཆོས་ལ: 2
#
# འཇམ་དཔལ་གཞོན་ནུ: 2
#
# ཕ་རོལ་ཕྱིན: 2
#
# གིས་ན: 2
#
# ན་དེ: 2
#
# རྡོ་རྗེ་རྩེ་མོ: 2
#
# ཆོས་སུ: 2
#
# བྱང་ཆུབ་སེམས་ཉིད: 2
#
# དེ་ཡི: 2
#
# བྱང་ཆུབ་སེམས་དཔའ: 2
#
# དེ་མེད: 2
#
# མི་འབྱུང: 2
#
# ལམ་ཉིད: 2
#
# དེ་ན: 2
#
# རྡོ་རྗེ་སེམས་དཔའ: 2
#
# རྟོག་ལས: 2
#
# ལས་འདས: 2
#
# གི་ཐ་སྙད: 2
#
# གིས་མི: 2
#
# མ་ཡིན་ཡང: 2
#
# དོན་འདིར: 2
#
# L5_nam-mkha'-che-rgyas-pa-yi-ge-med-pa_V8-p.468-473.txt top 100 words
# གི: 39
#
# ལ: 28
#
# མེད་པ: 23
#
# ཡི་གེ: 22
#
# པ: 21
#
# གོ: 21
#
# ནི: 17
#
# དང: 16
#
# དེ: 16
#
# སྟེ: 14
#
# དུ: 12
#
# མཆོག: 12
#
# དེ་ནས: 11
#
# ལས: 11
#
# ཀྱང: 11
#
# མེད: 11
#
# རྣམས: 10
#
# གིས: 10
#
# ཀྱི: 9
#
# མ: 9
#
# རྒྱུད: 8
#
# འདི: 8
#
# ན: 8
#
# དོན: 8
#
# ཡི: 8
#
# བཀག: 8
#
# འཁོར: 7
#
# གཤེགས་པ: 7
#
# ལེའུ: 7
#
# ནས: 7
#
# ནམ་མཁའ: 6
#
# གྱི: 6
#
# ཀྱིས: 6
#
# མཚན་མ: 6
#
# བདག་པོ: 6
#
# དོན་དམ: 6
#
# ཡེ་ཤེས: 6
#
# ལ་སོགས: 5
#
# ཞུས་པ: 5
#
# བཤད: 5
#
# བདེ་བ: 5
#
# བཀའ: 5
#
# སེམས་དཔའ: 4
#
# གསུངས་པ: 4
#
# མི: 4
#
# ཏེ: 4
#
# ཆེན་པོ: 4
#
# གསོལ: 4
#
# དང་པོ: 4
#
# རྣམ་པར: 4
#
# མཐོང་བ: 4
#
# ཤེས་རབ: 4
#
# སྩལ: 4
#
# རང་བཞིན: 4
#
# ཆེ: 3
#
# རྒྱལ་པོ: 3
#
# ཐོས་པ: 3
#
# དམ་པ: 3
#
# ཉག་གཅིག: 3
#
# ཐབས: 3
#
# མཛད: 3
#
# ཐུགས་ཆུད: 3
#
# རིགས: 3
#
# ཤིན་ཏུ: 3
#
# དཀའ: 3
#
# ཀུན: 3
#
# པར: 3
#
# ཚུལ: 3
#
# གྱིས: 3
#
# གཅིག: 3
#
# ཏུ: 3
#
# བློ: 3
#
# རིག་པ: 3
#
# ཡིན: 3
#
# ཆོས་དབྱིངས: 3
#
# ཆོས: 3
#
# བྱང་ཆུབ: 3
#
# དམིགས་པ: 3
#
# ཁྱད་པར: 3
#
# མེད་པར: 3
#
# ཡིས: 3
#
# གང: 3
#
# ལྡན་པ: 3
#
# རྡོ་རྗེ: 2
#
# ཉིད: 2
#
# སྔོན་མ: 2
#
# བཅོམ་ལྡན་འདས: 2
#
# དཔལ: 2
#
# དཔེར་ན: 2
#
# གནས: 2
#
# ཞུ་བ: 2
#
# དེ་བཞིན: 2
#
# ཐུགས: 2
#
# སུ: 2
#
# སྣང: 2
#
# ཁྱོད: 2
#
# ལེགས་པ: 2
#
# འདོད: 2
#
# བྲལ་བ: 2
#
# བཟློག: 2
#
# L5_nam-mkha'-che-rgyas-pa-yi-ge-med-pa_V8-p.468-473.txt top 100 bigrams
# ཡི་གེ་མེད་པ: 16
#
# མེད་པ་གི: 10
#
# པ་གོ: 8
#
# གོ་དེ་ནས: 7
#
# གི་ལེའུ: 6
#
# ལེའུ་སྟེ: 6
#
# གི་རྒྱུད: 5
#
# ལ་སོགས་པ: 5
#
# བདེ་བ་ལ: 5
#
# ལ་གཤེགས་པ: 5
#
# བཤད་དུ: 4
#
# དུ་གསོལ: 4
#
# མེད་པ་ལས: 4
#
# དེ་ནས་བདག་པོ: 4
#
# གི་མཆོག: 4
#
# བཀའ་སྩལ: 4
#
# པ་གི: 4
#
# པ་དང: 3
#
# འཁོར་རྣམས: 3
#
# གི་དོན: 3
#
# བདག་པོ་གི: 3
#
# གཤེགས་པ་གི: 3
#
# ཡི་གེ་མེད: 3
#
# སྩལ་པ: 3
#
# བཀག་པ: 3
#
# སྔོན་མ་ཐོས་པ: 2
#
# ཐོས་པ་གིས: 2
#
# དེ་ནས་འཁོར: 2
#
# རྣམས་ཀྱིས: 2
#
# དེ་བཞིན་གཤེགས་པ: 2
#
# གསོལ་ཡི་གེ: 2
#
# འཁོར་གྱི: 2
#
# ཐུགས་ཆུད་ནས: 2
#
# ལེགས་པ་ལ: 2
#
# འདོད་ན: 2
#
# ཤིན་ཏུ་བཟློག: 2
#
# བཟློག་པར: 2
#
# མགྲིན་གཅིག: 2
#
# གཅིག་ཏུ: 2
#
# གཤེགས་པ་ཡི་གེ: 2
#
# ནི་མ: 2
#
# གོ་དོན་དམ: 2
#
# རིན་ཆེན་རིགས: 2
#
# མ་བསྐྱེད: 2
#
# ནི་དེ: 2
#
# དེ་ལ: 2
#
# ཀྱང་མ: 2
#
# མཆོག་ལ: 2
#
# གི་འཁོར: 2
#
# གི་གཙོ: 2
#
# མེད་པ་ནི: 2
#
# ཡི་དོན: 2
#
# གི་ཤེས་རབ: 2
#
# ཀྱི་རང་བཞིན: 2
#
# རྒྱུད་མཆོག: 2
#
# རང་བཞིན་གནས་པ: 2
#
# གནས་པ་གི: 2
#
# གོ་ཆོས: 2
#
# ཆོས་ཀྱི: 2
#
# གོ་ཡི་གེ: 2
#
# གང་ལྡན་པ: 2
#
# ན་ཡི་གེ: 2
#
# ཡི་གེ་མེད་པར: 2
#
# འདི་ཡི: 2
#
# སེམས་དཔའ་དགྱེས་པ: 2
#
# དགྱེས་པ་ལ་སོགས: 2
#
# ནམ་མཁའ་དེ: 2
#
# ནི་བཀག: 2
#
# པ་མེད་པ: 2
#
# རྡོ་རྗེ་སེམས་དཔའ: 1
#
# སེམས་དཔའ་ནམ་མཁའ: 1
#
# ནམ་མཁའ་ཆེ: 1
#
# ཆེ་རྒྱས་པ: 1
#
# རྒྱས་པ་ཡི་གེ: 1
#
# རྒྱུད་རྒྱལ་པོ: 1
#
# རྒྱལ་པོ་གི: 1
#
# རྒྱུད་དུ: 1
#
# དུ་གསུངས་པ: 1
#
# གསུངས་པ་ཡི་གེ: 1
#
# མེད་པ་འདི: 1
#
# འདི་གསུངས་པ: 1
#
# གསུངས་པ་གི: 1
#
# གི་ཚེ: 1
#
# ཚེ་ན: 1
#
# ན་ཉིད: 1
#
# ཉིད་དང: 1
#
# དང་ཐ: 1
#
# ཐ་མི: 1
#
# མི་དད་པ: 1
#
# དད་པ་རྣམས: 1
#
# རྣམས་སྔོན་མ: 1
#
# ཐོས་པ་འདི: 1
#
# འདི་ཐོས་པ: 1
#
# གིས་སྐྲག་པ: 1
#
# སྐྲག་པ་ལ: 1
#
# ལ་གྱུར: 1
#
# གྱུར་ཏེ: 1
#
# ཏེ་དེ་ནས: 1
#
# དེ་ནས་རྡོ་རྗེ: 1
#
# རྡོ་རྗེ་འཛིན་པ: 1
#
# LL01_L14_rtse-mo-byung-rgyal_vol8-p480-491.txt top 100 words
# གི: 126
#
# ལ: 77
#
# མེད: 33
#
# ཀྱི: 32
#
# དང: 31
#
# དབྱིངས: 30
#
# གིས: 25
#
# རྣམས: 24
#
# དུ: 23
#
# ཆོས: 22
#
# བྱང་ཆུབ: 22
#
# མི: 22
#
# ཀྱང: 21
#
# ལས: 20
#
# ཀུན: 20
#
# ནས: 18
#
# དོན: 17
#
# ན: 16
#
# སེམས: 15
#
# དཀྱིལ་འཁོར: 15
#
# རྣམ་པར: 15
#
# རྣམ་དག: 14
#
# མ: 14
#
# ཆེན་པོ: 13
#
# པ: 12
#
# ཡེ་ཤེས: 12
#
# སྐུ: 12
#
# བདག: 12
#
# རྣལ་འབྱོར: 12
#
# ནི: 12
#
# སངས་རྒྱས: 12
#
# འགྱུར: 12
#
# རྫོགས: 11
#
# ཡིན: 11
#
# ཉིད: 11
#
# བཞིན: 11
#
# ཡེ་ནས: 11
#
# སྙིང་པོ: 11
#
# མེད་པ: 10
#
# ཏུ: 10
#
# སྣ་ཚོགས: 10
#
# གྱི: 10
#
# རྒྱལ་བ: 10
#
# རྒྱ་མཚོ: 9
#
# གཞན: 9
#
# ཐམས་ཅད: 8
#
# ཐུགས: 8
#
# མཐའ: 8
#
# ཐུགས་རྗེ: 8
#
# མཉམ: 8
#
# ལྷུན: 8
#
# གནས: 8
#
# ཕྱིར: 8
#
# གཉིས: 8
#
# ཏེ: 7
#
# རྡོ་རྗེ: 7
#
# འཁྲུལ: 7
#
# གང: 7
#
# ལྷུན་གྲུབ: 7
#
# ཅན: 7
#
# རྒྱལ་པོ: 7
#
# རྫོགས་པ: 7
#
# དེ་བཞིན: 7
#
# ཆོ་འཕྲུལ: 7
#
# རྟོག: 7
#
# དག: 7
#
# སྒྱུ་མ: 7
#
# བཟང་པོ: 6
#
# ཁམས: 6
#
# འགྲོ་དོན: 6
#
# འདི: 6
#
# ལྡན: 6
#
# དབང: 6
#
# སྐྱེ: 6
#
# ཐབས: 6
#
# མཆོག: 6
#
# སྐྱེས: 6
#
# གྱིས: 6
#
# རང་བཞིན: 6
#
# སྤྱོད་པ: 6
#
# ཚོགས: 6
#
# གསལ: 6
#
# ཀྱིས: 5
#
# འཁོར: 5
#
# རྒྱུད: 5
#
# གསུང: 5
#
# ལམ: 5
#
# རྒྱན: 5
#
# གྱུར: 5
#
# རང་བྱུང: 5
#
# གཅིག: 5
#
# སེམས་ཅན: 5
#
# བ: 5
#
# རྟོགས: 5
#
# ཅི: 5
#
# ཙམ: 5
#
# རྟོག་པ: 5
#
# སྟེ: 5
#
# ཕྱི: 5
#
# ནང: 5
#
# LL01_L14_rtse-mo-byung-rgyal_vol8-p480-491.txt top 100 bigrams
# ཆོས་ཀྱི: 16
#
# ཀྱི་དབྱིངས: 14
#
# བྱང་ཆུབ་སེམས: 9
#
# གི་དཀྱིལ་འཁོར: 9
#
# བྱང་ཆུབ་སྙིང་པོ: 9
#
# ཀུན་ཏུ: 8
#
# གི་ཕྱིར: 7
#
# རྒྱལ་བ་གི: 7
#
# གཉིས་མེད: 7
#
# རྣམ་པར་དག: 7
#
# ཏུ་བཟང་པོ: 6
#
# ལྷུན་རྫོགས: 6
#
# ཀྱི་སྐུ: 6
#
# བདག་དང: 6
#
# དབྱིངས་ལས: 5
#
# མེད་པ་གི: 5
#
# གི་དོན: 5
#
# སྐྱེ་མེད: 5
#
# ཆོས་རྣམས: 5
#
# གི་རྒྱལ་པོ: 5
#
# གི་ཆོ་འཕྲུལ: 5
#
# ལ་ཀྱང: 5
#
# མ་ཡིན: 5
#
# པ་གི: 4
#
# བདེ་བ་ཆེན་པོ: 4
#
# ཆེན་པོ་གི: 4
#
# གི་མཐའ: 4
#
# ཀུན་གྱི: 4
#
# ནམ་མཁའ་གི: 4
#
# སྙིང་པོ་ལ: 4
#
# གྲུབ་པ་གི: 4
#
# སྐྱེ་བ་གི: 4
#
# ཉིད་ལ: 4
#
# ཕྱི་ནང: 4
#
# དང་མི: 4
#
# མི་རྟོག: 4
#
# མེད་པ་གིས: 3
#
# གི་བློ་ལྡན: 3
#
# དབྱིངས་དང: 3
#
# གི་སྐུ: 3
#
# རྣམ་དག་བྱང་ཆུབ: 3
#
# འདས་པ་གི: 3
#
# ཐུགས་རྗེ་གི: 3
#
# དོན་དུ: 3
#
# ཀྱི་དཀྱིལ་འཁོར: 3
#
# མཉམ་སྦྱོར: 3
#
# གི་རྣམ: 3
#
# རྣམ་གྲངས: 3
#
# རྫོགས་པ་གི: 3
#
# གི་དབྱིངས: 3
#
# ཀྱི་ཕྱག་རྒྱ: 3
#
# ལ་གནས: 3
#
# མ་སྐྱེས: 3
#
# མི་གནས: 3
#
# བཞིན་དུ: 3
#
# རྒྱལ་པོ་གི: 3
#
# དང་གཞན་དོན: 3
#
# རྡུལ་ཙམ: 3
#
# ཙམ་མེད: 3
#
# དབྱིངས་ནས: 3
#
# བ་གི: 3
#
# ཡེ་ནས་ལྷུན་གྲུབ: 3
#
# དང་གཞན: 3
#
# གཞན་དུ: 3
#
# རྟོག་པ་མི: 3
#
# མེད་དོན: 3
#
# འཁྲུལ་པ: 3
#
# ཚིག་གི: 3
#
# སྙིང་པོ་ནི: 3
#
# ཆོ་འཕྲུལ་སྣ་ཚོགས: 3
#
# སངས་རྒྱས་མངོན་སུམ: 3
#
# མཉམ་པ་གི: 3
#
# ལ་འགྱུར: 3
#
# དོན་ལས: 3
#
# རང་གི: 3
#
# སྒྱུ་མ་གི: 3
#
# ཅི་ལ: 3
#
# མི་ཟད་རྒྱན: 3
#
# རྒྱན་གྱི: 3
#
# གྱི་འཁོར་ལོ: 3
#
# རྣམས་ཀྱིས: 2
#
# གི་ཡེ་ཤེས: 2
#
# ཆེན་པོ་ལ: 2
#
# གོ་བར: 2
#
# བར་འདིར: 2
#
# རྩེ་མོ་བྱུང་རྒྱལ: 2
#
# ལ་ཕྱག: 2
#
# ཕྱག་འཚལ: 2
#
# འཚལ་ལོ: 2
#
# གི་ཐུགས: 2
#
# སྣ་ཚོགས་ཀུན: 2
#
# དང་ཡེ་ཤེས: 2
#
# སེམས་ལ: 2
#
# འཁྲུལ་འཁོར: 2
#
# ཁམས་གསུམ: 2
#
# འགྲོ་དོན་དུ: 2
#
# དོན་ལ: 2
#
# པ་རྣལ་འབྱོར: 2
#
# རྣལ་འབྱོར་དོན: 2
#
# དོན་ལྷུན་གྲུབ: 2
#
# LL02_་nam-mkha'-rgyal-po_vol8-v475-480.txt top 100 words
# མེད: 51
#
# གི: 37
#
# ལ: 32
#
# གིས: 26
#
# མི: 25
#
# དང: 24
#
# ཀྱང: 22
#
# ནམ་མཁའ: 20
#
# དེ: 15
#
# ལས: 15
#
# ན: 15
#
# བྲལ: 14
#
# མ: 12
#
# ཀྱི: 11
#
# དུ: 11
#
# ཀུན: 10
#
# ཡེ་ཤེས: 10
#
# སེམས: 10
#
# མེད་པ: 10
#
# སྒྱུ་མ: 10
#
# དབྱིངས: 9
#
# ཉིད: 8
#
# འདས་པ: 8
#
# མཐའ: 8
#
# ནི: 7
#
# བརྗོད: 7
#
# གོ: 7
#
# ཚིག: 7
#
# བྲལ་བ: 7
#
# མཚན་ཉིད: 6
#
# དེ་ཉིད: 6
#
# འདས: 6
#
# གནས: 6
#
# འདི: 6
#
# ཡིན: 6
#
# ཏེ: 6
#
# ཆོས: 6
#
# ཏུ: 5
#
# ...
#
# གསལ: 2
#
# གནས: 2
#
# འདས: 2
#
# དག: 2
#
# ང: 2
#
# བདག: 2
#
# བྲལ་བ: 2
#
# ནམ་མཁའ: 2
#
# ཁམས: 2
#
# བརྟགས: 2
#
# སྣང: 2
#
# ཡུམ: 2
#
# ཆོ་འཕྲུལ: 2
#
# ཡེ་ཤེས: 2
#
# དོན་དམ: 2
#
# རྫོགས་པ: 2
#
# ཆེ: 2
#
# ཏེ: 2
#
# དབྱེར: 2
#
# ཆེན་པོ: 2
#
# གཞན: 2
#
# ནས: 2
#
# རྒྱུ: 2
#
# མཉམ: 2
#
# སྲིད: 2
#
# ཤེས་རབ: 2
#
# བསམ: 2
#
# ཁྱབ: 2
#
# གཉིས: 2
#
# བཅོམ་ལྡན་འདས: 1
#
# ཏེ་མ: 1
#
# ལུས: 1
#
# དཔལ: 1
#
# མཐའ: 1
#
# ཕྱིན་པ: 1
#
# བདེ་བ: 1
#
# མཁྱེན་པ: 1
#
# ཉིད: 1
#
# LL07_L10_srog-gi-'khor-lo_v8.p491-494.txt top 100 bigrams
# རྒྱལ་བ་གི: 5
#
# ཀུན་གྱི: 4
#
# ཡོངས་ཀྱི: 4
#
# སྲོག་གི: 3
#
# གི་འཁོར་ལོ: 3
#
# ཀྱི་རང་བཞིན: 3
#
# བྱང་ཆུབ་སེམས: 3
#
# གི་སྙིང་པོ: 3
#
# ངང་དུ: 3
#
# མི་ཟད་རྒྱན: 3
#
# ལ་རྫོགས: 3
#
# ཐབས་ཀྱི: 2
#
# སྐུ་གསུང་ཐུགས་ཀྱི: 2
#
# ཆོས་ཀྱི: 2
#
# ཀྱི་སྲོག: 2
#
# འཁོར་ལོ་འདི: 2
#
# རྣལ་འབྱོར་ཡོངས: 2
#
# ཀྱི་གཏེར་ཆེན: 2
#
# ཐུགས་ཀྱི: 2
#
# རང་རིག་དབང་ཕྱུག: 2
#
# སྐྱེ་མེད: 2
#
# མྱ་ངན་འདས: 2
#
# ང་མེད: 2
#
# མེད་བདག: 2
#
# བདག་དང: 2
#
# དང་བྲལ་བ: 2
#
# གི་ཐུགས: 2
#
# ནམ་མཁའ་གི: 2
#
# དེ་ལ: 2
#
# མེད་པ་ཡུམ: 2
#
# ཡུམ་གྱི: 2
#
# གྱི་ངང: 2
#
# ཡེ་ཤེས་དབྱིངས: 2
#
# ཡོངས་ལ: 2
#
# མཆོག་མི་ཟད: 2
#
# རྒྱན་གྱི: 2
#
# གྱི་འཁོར་ལོ: 2
#
# འཁོར་ལོ་ལ: 2
#
# མེད་པ་གི: 2
#
# འབྱུང་བ་གི: 2
#
# གཞན་ནས: 2
#
# རྒྱུ་གཅིག: 2
#
# ཐབས་དང: 2
#
# དང་ཤེས་རབ: 2
#
# བསམ་མི: 2
#
# མི་ཁྱབ: 2
#
# འཁོར་ལོ་བཅོམ་ལྡན་འདས: 1
#
# བཅོམ་ལྡན་འདས་ཏེ་མ: 1
#
# ཏེ་མ་ལུས: 1
#
# ལུས་ཀུན: 1
#
# གྱི་དཔལ: 1
#
# དཔལ་ཐུགས་རྗེ: 1
#
# ཐུགས་རྗེ་ཐབས: 1
#
# ཀྱི་འགྲོ་དོན: 1
#
# འགྲོ་དོན་མཐའ: 1
#
# མཐའ་ལ: 1
#
# ལ་ཕྱིན་པ: 1
#
# ཕྱིན་པ་བདེ་བ: 1
#
# བདེ་བ་ཐམས་ཅད: 1
#
# ཐམས་ཅད་མཁྱེན་པ: 1
#
# མཁྱེན་པ་ཉིད: 1
#
# ཉིད་ཀྱི: 1
#
# ཀྱི་ངང: 1
#
# ངང་སྐུ་གསུང་ཐུགས: 1
#
# རང་བཞིན་ཆོས: 1
#
# ཀྱི་དབྱིངས: 1
#
# དབྱིངས་བྱང་ཆུབ: 1
#
# སེམས་ཀྱི: 1
#
# འདི་མཉམ་ཉིད: 1
#
# མཉམ་ཉིད་འདུས་པ: 1
#
# འདུས་པ་གི: 1
#
# གི་གཏེར: 1
#
# གཏེར་ལ: 1
#
# ལ་ཕྱག: 1
#
# ཕྱག་འཚལ: 1
#
# འཚལ་ལོ: 1
#
# ལོ་ལུས་ངག: 1
#
# ལུས་ངག་ཡིད: 1
#
# ཡིད་གསུམ: 1
#
# གསུམ་སྐུ་གསུང་ཐུགས: 1
#
# སྐུ་གསུང་ཐུགས་སྦྱོར་བ: 1
#
# སྦྱོར་བ་རྒྱལ་བ: 1
#
# རྒྱལ་བ་རྣམས: 1
#
# རྣམས་ཀྱི: 1
#
# ཀྱི་གསང: 1
#
# གསང་ཆེན: 1
#
# ཆེན་འཁོར: 1
#
# འཁོར་བཟློག: 1
#
# བཟློག་པ: 1
#
# པ་མྱ་ངན: 1
#
# མྱ་ངན་འདས་པ: 1
#
# འདས་པ་གི: 1
#
# གི་དམ་ཚིག: 1
#
# དམ་ཚིག་ལུ་གུ་རྒྱུད: 1
#
# ལུ་གུ་རྒྱུད་ཆོས་དབྱིངས: 1
#
# ཆོས་དབྱིངས་རྣལ་འབྱོར: 1
#
# གཏེར་ཆེན་པས: 1
#
# པས་རྣ: 1
#
# རྣ་བརྒྱུད: 1
#
# བརྒྱུད་ཐུགས: 1
#
# LL08_thig-le-drug-pa-NGB-vol33.txt top 100 words
# གི: 43
#
# ལ: 19
#
# ཀུན: 16
#
# མེད: 15
#
# མི: 15
#
# དང: 12
#
# ཀྱི: 10
#
# གནས: 10
#
# དེ: 10
#
# ལམ: 10
#
# རྣམས: 9
#
# དུ: 8
#
# གིས: 7
#
# ལས: 6
#
# ཤིང: 6
#
# ཆོས: 6
#
# ཉིད: 6
#
# བྲལ: 6
#
# ཡུལ: 6
#
# སེམས: 5
#
# གཉིས: 5
#
# མཐའ: 5
#
# ཏུ: 5
#
# རང་བཞིན: 5
#
# གྱི: 5
#
# ཆེན་པོ: 4
#
# བྱང་ཆུབ: 4
#
# རྒྱུད: 4
#
# གྱིས: 4
#
# རང: 4
#
# དག: 4
#
# ནི: 4
#
# ཀྱང: 4
#
# རྟོག: 4
#
# ཚིག: 4
#
# མ: 4
#
# ཡེ་ཤེས: 4
#
# རྒྱ་མཚོ: 3
#
# འཇུག་པ: 3
#
# སྟེ: 3
#
# པ: 3
#
# གོ: 3
#
# སྟོན: 3
#
# ཚུལ: 3
#
# གྱུར་པ: 3
#
# རྣམ་དག: 3
#
# བྱ་བྲལ: 3
#
# འདས: 3
#
# དེ་ཉིད: 3
#
# རྒྱལ་པོ: 3
#
# བྱེད: 3
#
# དོན: 3
#
# ཚོགས: 3
#
# རྫོགས་པ: 2
#
# ཐིག་ལེ: 2
#
# ལེའུ: 2
#
# སངས་རྒྱས: 2
#
# ཕྱོགས: 2
#
# མཆོག: 2
#
# དགོངས: 2
#
# ན: 2
#
# མེད་པ: 2
#
# སྟོན་པ: 2
#
# སྙིང་པོ: 2
#
# བདེ་བ: 2
#
# བཅོས: 2
#
# ཇི་བཞིན: 2
#
# ལ་སོགས: 2
#
# དེ་ཕྱིར: 2
#
# ཞིང: 2
#
# དཀའ: 2
#
# བསམ: 2
#
# དབང་པོ: 2
#
# བརྗོད: 2
#
# ཙམ: 2
#
# སྔོན: 2
#
# དྲང་སྲོང: 2
#
# རྩོལ་བ: 2
#
# ལུང: 2
#
# ཡང་དག: 2
#
# འཁྲུལ: 2
#
# འདྲེས: 2
#
# མཚུངས: 2
#
# སྤང་བླང: 2
#
# རྣམ་པ: 2
#
# གསལ་བ: 2
#
# གཡོ: 2
#
# ཏིང་འཛིན: 2
#
# ཐམས་ཅད: 2
#
# ཅེས: 2
#
# ཏེ: 2
#
# མཉམ་པ: 2
#
# བརྟགས: 2
#
# ཀྱིས: 2
#
# ལྔ: 2
#
# གསུམ: 2
#
# ལྷུན: 2
#
# ཟིན་པ: 2
#
# མཚན་མ: 2
#
# རྣམ: 2
#
# LL08_thig-le-drug-pa-NGB-vol33.txt top 100 bigrams
# ཀུན་ཏུ: 5
#
# རང་གི: 4
#
# དང་བྲལ: 4
#
# ཀུན་དང: 4
#
# གི་ཆོས: 4
#
# རྒྱུད་ལས: 3
#
# གཉིས་མེད: 3
#
# ལམ་དུ: 3
#
# གི་ལམ: 3
#
# ལ་གནས: 3
#
# གི་ཡུལ: 3
#
# རྫོགས་པ་ཆེན་པོ: 2
#
# བྱང་ཆུབ་ཀྱི: 2
#
# ཀྱི་སེམས: 2
#
# རྒྱ་མཚོ་གནས: 2
#
# གནས་ལ: 2
#
# ལ་འཇུག་པ: 2
#
# འཇུག་པ་གི: 2
#
# གི་རྒྱུད: 2
#
# གི་ལེའུ: 2
#
# ལེའུ་སྟེ: 2
#
# པ་གོ: 2
#
# སངས་རྒྱས་ཀུན: 2
#
# ཀུན་གྱིས: 2
#
# ཕྱོགས་རྣམས: 2
#
# མཆོག་གི: 2
#
# རྣམས་ཀུན: 2
#
# མེད་པ་གི: 2
#
# གི་ཚུལ: 2
#
# ལ་གྱུར་པ: 2
#
# ལ་ཆོས: 2
#
# བྱང་ཆུབ་སེམས: 2
#
# སེམས་ཀྱི: 2
#
# ཀྱི་རང་བཞིན: 2
#
# བདེ་བ་གི: 2
#
# ཀུན་གྱི: 2
#
# ཚིག་གིས: 2
#
# མེད་སྔོན: 2
#
# སྔོན་གྱི: 2
#
# གྱི་དྲང་སྲོང: 2
#
# དྲང་སྲོང་རྣམས: 2
#
# རྣམས་ཀྱི: 2
#
# ཀྱི་ལམ: 2
#
# དུ་མེད: 2
#
# རྩོལ་བ་གི: 2
#
# མེད་ཡང་དག: 2
#
# མེད་འདྲེས: 2
#
# འདྲེས་ཤིང: 2
#
# ལ་ཀྱང: 2
#
# ཀྱང་མི: 2
#
# རྒྱལ་པོ་ལ: 2
#
# དེ་ལ: 2
#
# མཉམ་པ་གི: 2
#
# གི་རྒྱལ་པོ: 2
#
# ཆོས་རྣམས: 2
#
# མི་བྱེད: 2
#
# ཡུལ་ལ: 2
#
# བྲལ་ཟིན་པ: 2
#
# ཟིན་པ་གི: 2
#
# མཚན་མ་གི: 2
#
# ཆེན་པོ་ཆོས་ཉིད: 1
#
# ཆོས་ཉིད་བྱང་ཆུབ: 1
#
# སེམས་ཐིག་ལེ: 1
#
# ཐིག་ལེ་རྒྱ་མཚོ: 1
#
# ལས་ཞུས་པ: 1
#
# ཞུས་པ་གི: 1
#
# སྟེ་གཉིས: 1
#
# གཉིས་པ: 1
#
# གོ་དེ་ནས: 1
#
# དེ་ནས་སངས་རྒྱས: 1
#
# གྱིས་བསྟོད: 1
#
# བསྟོད་བྱས: 1
#
# བྱས་ཤིང: 1
#
# ཤིང་ཕྱོགས: 1
#
# རྣམས་དབང: 1
#
# དབང་བསྐུར: 1
#
# བསྐུར་རང: 1
#
# གི་གསང་སྔགས: 1
#
# གསང་སྔགས་སྟོན: 1
#
# སྟོན་ཞིང་ཁམས: 1
#
# ཞིང་ཁམས་མཐའ: 1
#
# མཐའ་ཀླས: 1
#
# ཀླས་མཆོག: 1
#
# གི་དཀྱིལ་འཁོར: 1
#
# དཀྱིལ་འཁོར་སྦྱོར: 1
#
# སྦྱོར་མྱ་ངན: 1
#
# མྱ་ངན་རྦ་ཀློང: 1
#
# རྦ་ཀློང་རྣམ་རྟོག: 1
#
# རྣམ་རྟོག་དྲ: 1
#
# དྲ་བ: 1
#
# བ་སེལ: 1
#
# སེལ་ཀུན: 1
#
# ཏུ་བཟང་པོ: 1
#
# བཟང་པོ་རིགས: 1
#
# རིགས་ཀྱི: 1
#
# ཀྱི་འཁོར་ལོ: 1
#
# འཁོར་ལོ་དག: 1
#
# དག་ཕྱོགས: 1
#
# ཏུ་གཟིགས: 1
#
# གཟིགས་ཤིང: 1
#
# LL09_spyi-gcod_vol8_p.498.txt top 100 words
# གིས: 6
#
# མེད: 6
#
# གི: 6
#
# བལྟ: 4
#
# གོ: 3
#
# ལ: 3
#
# བདེ་བ: 3
#
# སངས་རྒྱས: 3
#
# ཚོལ: 3
#
# དོན: 3
#
# མི: 3
#
# བྱང་ཆུབ: 2
#
# མ: 2
#
# ལུས: 2
#
# སུ: 2
#
# འདས་པ: 2
#
# དེ: 2
#
# པ: 2
#
# ཀློང: 2
#
# དབྱེར: 2
#
# ཉམས: 2
#
# ཡེ་ནས: 2
#
# དག་པ: 2
#
# ཡིན: 2
#
# ཡེ: 2
#
# མེད་པ: 2
#
# ཚིག: 2
#
# ལས: 2
#
# རྣལ་འབྱོར: 2
#
# བ: 2
#
# འཁྲུལ: 2
#
# བསྲུངས: 1
#
# ཕྲ: 1
#
# བཀོད་པ: 1
#
# ཀྱི: 1
#
# སེམས: 1
#
# རྫོགས་པ: 1
#
# སྤྱི: 1
#
# གཅོད: 1
#
# ཀྱང: 1
#
# ཟེར: 1
#
# ཏིག: 1
#
# ཆོས: 1
#
# རྣམས: 1
#
# དབྱིངས: 1
#
# རྒྱུ: 1
#
# གཅིག་པ: 1
#
# འཁོར་བ: 1
#
# མྱ་ངན: 1
#
# གཉིས: 1
#
# ཇི་ལྟ: 1
#
# བལྟས: 1
#
# ཀུན: 1
#
# ཏུ: 1
#
# བཟང་པོ: 1
#
# ལས་མ: 1
#
# སྐུ: 1
#
# སྣང་སྲིད: 1
#
# ན: 1
#
# སེམས་ཅན: 1
#
# སེམས་ཉིད: 1
#
# རྒྱལ་བ: 1
#
# རྡོ་རྗེ: 1
#
# སེམས་དཔའ: 1
#
# ཆོས་སྐུ: 1
#
# མཆོག: 1
#
# བཙལ: 1
#
# དུ: 1
#
# བསྒོམ་པ: 1
#
# དང: 1
#
# བྲལ: 1
#
# བརྗོད་པ: 1
#
# ཐ་སྙད: 1
#
# པས: 1
#
# བལྟ་བ: 1
#
# དམིགས་མེད: 1
#
# སྙིང་པོ: 1
#
# དགོངས: 1
#
# དམིགས: 1
#
# དེ་ཉིད: 1
#
# ཡིན་པ: 1
#
# ཆེན་པོ: 1
#
# གང་ཞིག: 1
#
# སྟོང: 1
#
# བསྒོམ: 1
#
# ལྕགས: 1
#
# ནས: 1
#
# བཀྲོལ་བ: 1
#
# རྫོགས: 1
#
# བར: 1
#
# འདིར: 1
#
# ཁམས: 1
#
# གསུམ: 1
#
# སྒྲོན་མ: 1
#
# འཛུད: 1
#
# LL09_spyi-gcod_vol8_p.498.txt top 100 bigrams
# མ་ལུས: 2
#
# དབྱེར་མེད: 2
#
# བདེ་བ་གི: 2
#
# ཡེ་ནས་དག་པ: 2
#
# དག་པ་གིས: 2
#
# མེད་ཡེ: 2
#
# ཡེ་སངས་རྒྱས: 2
#
# ཚོལ་བ: 2
#
# མི་བལྟ: 2
#
# བསྲུངས་ཕྲ: 1
#
# ཕྲ་བཀོད་པ: 1
#
# བཀོད་པ་གོ: 1
#
# གོ་བྱང་ཆུབ: 1
#
# བྱང་ཆུབ་ཀྱི: 1
#
# ཀྱི་སེམས: 1
#
# སེམས་རྫོགས་པ: 1
#
# རྫོགས་པ་སྤྱི: 1
#
# སྤྱི་གཅོད: 1
#
# གཅོད་ཀྱང: 1
#
# ཀྱང་ཟེར: 1
#
# ཟེར་ཏིག: 1
#
# ཏིག་ཆོས: 1
#
# ཆོས་རྣམས: 1
#
# རྣམས་མ: 1
#
# ལུས་དབྱིངས: 1
#
# དབྱིངས་སུ: 1
#
# སུ་རྒྱུ: 1
#
# རྒྱུ་གཅིག་པ: 1
#
# གཅིག་པ་གིས: 1
#
# གིས་འཁོར་བ: 1
#
# འཁོར་བ་མྱ་ངན: 1
#
# མྱ་ངན་འདས་པ: 1
#
# འདས་པ་གཉིས: 1
#
# གཉིས་མེད: 1
#
# མེད་དེ: 1
#
# དེ་ཇི་ལྟ: 1
#
# ཇི་ལྟ་ལ: 1
#
# ལ་བལྟས: 1
#
# བལྟས་པ: 1
#
# པ་ཀུན: 1
#
# ཀུན་ཏུ: 1
#
# ཏུ་བཟང་པོ: 1
#
# བཟང་པོ་གི: 1
#
# གི་ཀློང: 1
#
# ཀློང་དབྱེར: 1
#
# མེད་ཀློང: 1
#
# ཀློང་ལས་མ: 1
#
# ལས་མ་ཉམས: 1
#
# ཉམས་བདེ་བ: 1
#
# གི་སྐུ: 1
#
# སྐུ་སྣང་སྲིད: 1
#
# སྣང་སྲིད་མ: 1
#
# ལུས་ཡེ་ནས: 1
#
# གིས་ན: 1
#
# ན་སེམས་ཅན: 1
#
# སེམས་ཅན་སེམས་ཉིད: 1
#
# སེམས་ཉིད་རྒྱལ་བ: 1
#
# རྒྱལ་བ་སངས་རྒྱས: 1
#
# སངས་རྒྱས་ཡིན: 1
#
# ཡིན་རྡོ་རྗེ: 1
#
# རྡོ་རྗེ་སེམས་དཔའ: 1
#
# སེམས་དཔའ་དབྱེར: 1
#
# སངས་རྒྱས་ཡེ་ནས: 1
#
# གིས་ཆོས་སྐུ: 1
#
# ཆོས་སྐུ་བདེ་བ: 1
#
# གི་མཆོག: 1
#
# མཆོག་བཙལ: 1
#
# བཙལ་དུ: 1
#
# དུ་མེད་པ: 1
#
# མེད་པ་གིས: 1
#
# གིས་བསྒོམ་པ: 1
#
# བསྒོམ་པ་གི: 1
#
# གི་ཚིག: 1
#
# ཚིག་དང: 1
#
# དང་བྲལ: 1
#
# བྲལ་ཚིག: 1
#
# ཚིག་ལས: 1
#
# ལས་འདས་པ: 1
#
# འདས་པ་གིས: 1
#
# གིས་བརྗོད་པ: 1
#
# བརྗོད་པ་གི: 1
#
# གི་ཐ་སྙད: 1
#
# ཐ་སྙད་མེད: 1
#
# སངས་རྒྱས་པས: 1
#
# པས་བལྟ་བ: 1
#
# བལྟ་བ་གི: 1
#
# གི་དམིགས་མེད: 1
#
# དམིགས་མེད་དེ: 1
#
# དེ་སྙིང་པོ: 1
#
# སྙིང་པོ་བྱང་ཆུབ: 1
#
# བྱང་ཆུབ་དགོངས: 1
#
# དགོངས་སུ: 1
#
# སུ་མེད་པ: 1
#
# མེད་པ་གོ: 1
#
# གོ་རྣལ་འབྱོར: 1
#
# རྣལ་འབྱོར་བལྟ: 1
#
# བལྟ་དམིགས: 1
#
# དམིགས་ཚོལ: 1
#
# བ་དོན: 1
#
# དོན་ལས: 1
#
# LL10_yid-bzhin-nor-bu-431.txt top 100 words
# ལ: 4
#
# མེད: 3
#
# གི: 3
#
# པ: 2
#
# ལས: 2
#
# ཏེ: 2
#
# ཆེན་པོ: 2
#
# རྟག: 2
#
# ནི: 2
#
# སྤྱོད་ཡུལ: 2
#
# དེ་ནས: 1
#
# བཅོམ་ལྡན: 1
#
# བཀའ: 1
#
# སྩལ: 1
#
# ཁམས: 1
#
# གསུམ: 1
#
# འདས: 1
#
# རིན་ཆེན: 1
#
# དག: 1
#
# བགྲོད: 1
#
# རྣམ་གྲོལ: 1
#
# ལམ: 1
#
# སྟོན་པ: 1
#
# གཞན: 1
#
# ནས: 1
#
# རྙེད་པ: 1
#
# མི: 1
#
# འགྱུར: 1
#
# ཐིག་ལེ: 1
#
# ཀུན་ཁྱབ: 1
#
# གནས: 1
#
# རང་བྱུང: 1
#
# མ: 1
#
# བཅོས: 1
#
# ཡེ་ནས: 1
#
# གསལ: 1
#
# རྩོལ་བ: 1
#
# གིས: 1
#
# བཙལ: 1
# སྙིང་པོ: 1
#
# དོན: 1
#
# རྣམ་སྣང: 1
#
# རྟག་པ: 1
#
# ཀུན: 1
#
# ཏུ: 1
#
# བཟང: 1
#
# གཉིས: 1
#
# བདེ་མཆོག: 1
#
# ལྷུན: 1
#
# གྱིས: 1
#
# གྲུབ: 1
#
# ཆེན: 1
#
# བདེ: 1
#
# སྤྱོད་པ: 1
#
# བདེ་ཆེན: 1
#
# ལོངས་སྤྱོད: 1
#
# རྫོགས་པ: 1
#
# འདི: 1
#
# ཤེས: 1
#
# རྣལ་འབྱོར: 1
#
# དྲང་སྲོང: 1
#
# རྣམས: 1
#
# ཀྱི: 1
#
# ཡིན: 1
#
# ཅེས: 1
#
# ངེས་པ: 1
#
# གསུངས: 1
#
# རིན་པོ་ཆེ: 1
#
# དང: 1
#
# མཉམ་པ: 1
#
# སྐྱེ་བ: 1
#
# མེད་པ: 1
#
# རྒྱུད: 1
#
# ཡིད་བཞིན: 1
#
# ནོར་བུ: 1
#
# ལེའུ: 1
#
# སྟེ: 1
#
# བཅུ: 1
#
# གོ: 1
#
# LL10_yid-bzhin-nor-bu-431.txt top 100 bigrams
# དེ་ནས་བཅོམ་ལྡན: 1
#
# བཅོམ་ལྡན་བཀའ: 1
#
# བཀའ་སྩལ: 1
#
# སྩལ་པ: 1
#
# པ་ཁམས: 1
#
# ཁམས་གསུམ: 1
#
# གསུམ་ལས: 1
#
# ལས་འདས: 1
#
# འདས་རིན་ཆེན: 1
#
# རིན་ཆེན་དག: 1
#
# དག་བགྲོད: 1
#
# བགྲོད་མེད: 1
#
# མེད་རྣམ་གྲོལ: 1
#
# རྣམ་གྲོལ་ལམ: 1
#
# ལམ་སྟོན་པ: 1
#
# སྟོན་པ་གཞན: 1
#
# གཞན་ནས: 1
#
# ནས་རྙེད་པ: 1
#
# རྙེད་པ་ལ: 1
#
# ལ་མི: 1
#
# མི་འགྱུར: 1
#
# འགྱུར་ཏེ: 1
#
# ཏེ་ཐིག་ལེ: 1
#
# ཐིག་ལེ་ཆེན་པོ: 1
#
# ཆེན་པོ་ཀུན་ཁྱབ: 1
#
# ཀུན་ཁྱབ་གནས: 1
#
# གནས་རང་བྱུང: 1
#
# རང་བྱུང་མ: 1
#
# མ་བཅོས: 1
#
# བཅོས་ཡེ་ནས: 1
#
# ཡེ་ནས་གསལ: 1
#
# གསལ་རྩོལ་བ: 1
#
# རྩོལ་བ་གིས: 1
#
# གིས་བཙལ: 1
#
# བཙལ་མེད: 1
#
# མེད་སྙིང་པོ: 1
#
# སྙིང་པོ་གི: 1
#
# གི་དོན: 1
#
# དོན་རྣམ་སྣང: 1
#
# རྣམ་སྣང་རྟག་པ: 1
#
# རྟག་པ་ལ: 1
#
# ལ་ཀུན: 1
#
# ཀུན་ཏུ: 1
#
# ཏུ་བཟང: 1
#
# བཟང་གཉིས: 1
#
# གཉིས་མེད: 1
#
# མེད་བདེ་མཆོག: 1
#
# བདེ་མཆོག་ལྷུན: 1
#
# ལྷུན་གྱིས: 1
#
# གྱིས་གྲུབ: 1
#
# གྲུབ་རྟག: 1
#
# རྟག་ཆེན: 1
#
# ཆེན་བདེ: 1
#
# བདེ་ལ: 1
#
# ལ་རྟག: 1
#
# རྟག་སྤྱོད་པ: 1
#
# སྤྱོད་པ་བདེ་ཆེན: 1
#
# བདེ་ཆེན་ལོངས་སྤྱོད: 1
#
# ལོངས་སྤྱོད་རྫོགས་པ: 1
#
# རྫོགས་པ་ནི: 1
#
# ནི་འདི: 1
#
# འདི་ཤེས: 1
#
# ཤེས་རྣལ་འབྱོར: 1
#
# རྣལ་འབྱོར་སྤྱོད་ཡུལ: 1
#
# སྤྱོད་ཡུལ་ཏེ: 1
#
# ཏེ་དྲང་སྲོང: 1
#
# དྲང་སྲོང་ཆེན་པོ: 1
#
# ཆེན་པོ་རྣམས: 1
#
# རྣམས་ཀྱི: 1
#
# ཀྱི་ནི: 1
#
# ནི་སྤྱོད་ཡུལ: 1
#
# སྤྱོད་ཡུལ་ཡིན: 1
#
# ཡིན་ཅེས: 1
#
# ཅེས་ངེས་པ: 1
#
# ངེས་པ་ལ: 1
#
# ལ་གསུངས: 1
#
# གསུངས་རིན་པོ་ཆེ: 1
#
# རིན་པོ་ཆེ་དང: 1
#
# དང་མཉམ་པ: 1
#
# མཉམ་པ་སྐྱེ་བ: 1
#
# སྐྱེ་བ་མེད་པ: 1
#
# མེད་པ་གི: 1
#
# གི་རྒྱུད: 1
#
# རྒྱུད་ལས: 1
#
# ལས་ཡིད་བཞིན: 1
#
# ཡིད་བཞིན་ནོར་བུ: 1
#
# ནོར་བུ་གི: 1
#
# གི་ལེའུ: 1
#
# ལེའུ་སྟེ: 1
#
# སྟེ་བཅུ: 1
#
# བཅུ་པ: 1
#
# པ་གོ: 1
#
# LL11_kun-'dus-NGB-mtshams-brag-vol1-624-626་.txt top 100 words
# གི: 24
#
# ལ: 18
#
# དུ: 7
#
# ཀུན: 6
#
# ནི: 6
#
# ཐམས་ཅད: 5
#
# ཀྱང: 5
#
# མ: 5
#
# གིས: 5
#
# ཡུལ: 4
#
# ལས: 4
#
# བྱང་ཆུབ: 4
#
# མེད: 4
#
# གྱིས: 4
#
# འདུས: 3
#
# ཡེ་ནས: 3
#
# དབྱིངས: 3
#
# དགུ: 3
#
# ཀྱི: 3
#
# གམ: 3
#
# ན: 3
#
# ལྷུན: 3
#
# ཀློང: 3
#
# གསལ: 3
#
# བདེ་བ: 2
#
# ངང: 2
#
# ཕྱིར: 2
#
# མཐའ: 2
#
# གཅིག: 2
#
# སྣང: 2
#
# འདོད: 2
#
# སེམས: 2
#
# སྡུག་བསྔལ: 2
#
# ཆེན་པོ: 2
#
# མཁའ: 2
#
# ཐབས: 2
#
# རྣམས: 2
#
# ཐ་སྙད: 2
#
# མཆོག: 2
#
# ལམ: 2
#
# ཏུ: 2
#
# ཙམ: 2
#
# བཅས་པ: 2
#
# སྐྱོན་མེད: 2
#
# ནམ་མཁའ: 2
#
# གྲུབ་པ: 2
#
# ཡེ་ཤེས: 2
#
# ཤར་བ: 2
#
# འདི: 2
#
# རང: 2
#
# བསྒོམ་པ: 2
#
# གནས: 2
#
# རྫོགས: 2
#
# དེ: 2
#
# ནས: 2
#
# འགྱུར: 2
#
# འཁྲུལ: 2
#
# རྒྱ་གར: 1
#
# སྐད: 1
#
# ས: 1
#
# རྦ: 1
#
# ཨ: 1
#
# ཏ: 1
#
# བོད་སྐད: 1
#
# བཅོམ་ལྡན་འདས: 1
#
# བྱ་བྲལ: 1
#
# ཕྱག: 1
#
# འཚལ: 1
#
# ལོ: 1
#
# ཆོས་སྐུ: 1
#
# རྣམ་པར: 1
#
# རབ: 1
#
# དབེན་པ: 1
#
# རྣམ: 1
#
# རྟོག: 1
#
# བླ་དགས: 1
#
# འདས་པ: 1
#
# ཡོད་མེད: 1
#
# སྟོང་པ: 1
#
# སུ: 1
#
# ཉིད: 1
#
# ལྟ་བ: 1
#
# ཁྱད་པར: 1
#
# སྟེ: 1
#
# རྩོལ་བ: 1
#
# ནད: 1
#
# ཆོས་ཉིད: 1
#
# གནས་པ: 1
#
# རང་བཞིན: 1
#
# ཐུགས་རྗེ: 1
#
# ལྟར: 1
#
# ཁྱབ་པ: 1
#
# ཀྱིས: 1
#
# རོལ: 1
#
# པས: 1
#
# འདོད་དགུ: 1
#
# བསྒྱུར་བ: 1
#
# དཔལ: 1
#
# ཆོས: 1
#
# སྣ་ཚོགས: 1
#
# LL11_kun-'dus-NGB-mtshams-brag-vol1-624-626་.txt top 100 bigrams
# གི་ཡུལ: 3
#
# གམ་དུ: 3
#
# ལྷུན་གྱིས: 3
#
# ཀུན་འདུས: 2
#
# གི་ཕྱིར: 2
#
# དགུ་ལ: 2
#
# བྱང་ཆུབ་མཆོག: 2
#
# དུ་བཅས་པ: 2
#
# བཅས་པ་གི: 2
#
# ཀྱང་སྐྱོན་མེད: 2
#
# གྱིས་གྲུབ་པ: 2
#
# ཤར་བ་གི: 2
#
# འདི་ནི: 2
#
# རང་ལ: 2
#
# བསྒོམ་པ་གི: 2
#
# གི་གནས: 2
#
# རྒྱ་གར་སྐད: 1
#
# སྐད་དུ: 1
#
# དུ་ས: 1
#
# ས་རྦ: 1
#
# རྦ་ཨ: 1
#
# ཨ་ཏ: 1
#
# ཏ་བོད་སྐད: 1
#
# བོད་སྐད་དུ: 1
#
# དུ་ཀུན: 1
#
# འདུས་བཅོམ་ལྡན་འདས: 1
#
# བཅོམ་ལྡན་འདས་བྱ་བྲལ: 1
#
# བྱ་བྲལ་བདེ་བ: 1
#
# བདེ་བ་གི: 1
#
# གི་ངང: 1
#
# ངང་ལ: 1
#
# ལ་ཕྱག: 1
#
# ཕྱག་འཚལ: 1
#
# འཚལ་ལོ: 1
#
# ལོ་ཆོས་སྐུ: 1
#
# ཆོས་སྐུ་ཡེ་ནས: 1
#
# ཡེ་ནས་རྣམ་པར: 1
#
# རྣམ་པར་རབ: 1
#
# རབ་དབེན་པ: 1
#
# དབེན་པ་གི: 1
#
# གི་རྣམ: 1
#
# རྣམ་རྟོག: 1
#
# རྟོག་བླ་དགས: 1
#
# བླ་དགས་ཡུལ: 1
#
# ཡུལ་ལས: 1
#
# ལས་འདས་པ: 1
#
# འདས་པ་གི: 1
#
# ཕྱིར་ཡོད་མེད: 1
#
# ཡོད་མེད་སྟོང་པ: 1
#
# སྟོང་པ་གི: 1
#
# གི་མཐའ: 1
#
# མཐའ་ནི: 1
#
# ནི་དབྱིངས: 1
#
# དབྱིངས་སུ: 1
#
# སུ་གཅིག: 1
#
# གཅིག་དབྱིངས: 1
#
# དབྱིངས་ཉིད: 1
#
# ཉིད་གཅིག: 1
#
# གཅིག་ལ: 1
#
# ལ་ལྟ་བ: 1
#
# ལྟ་བ་གི: 1
#
# གི་ཁྱད་པར: 1
#
# ཁྱད་པར་དགུ: 1
#
# ལ་སྣང: 1
#
# སྣང་སྟེ: 1
#
# སྟེ་སྣང: 1
#
# སྣང་འདོད: 1
#
# འདོད་རྩོལ་བ: 1
#
# རྩོལ་བ་གི: 1
#
# གི་སེམས: 1
#
# སེམས་ནི: 1
#
# ནི་སྡུག་བསྔལ: 1
#
# སྡུག་བསྔལ་ནད: 1
#
# ནད་ཆོས་ཉིད: 1
#
# ཆོས་ཉིད་ངང: 1
#
# ངང་གི: 1
#
# གི་གནས་པ: 1
#
# གནས་པ་གི: 1
#
# གི་རང་བཞིན: 1
#
# རང་བཞིན་ལས: 1
#
# ལས་ཐུགས་རྗེ: 1
#
# ཐུགས་རྗེ་ཆེན་པོ: 1
#
# ཆེན་པོ་གི: 1
#
# གི་མཁའ: 1
#
# མཁའ་ལྟར: 1
#
# ལྟར་ཁྱབ་པ: 1
#
# ཁྱབ་པ་ནི: 1
#
# ནི་ཐབས: 1
#
# ཐབས་ཀྱིས: 1
#
# ཀྱིས་རོལ: 1
#
# རོལ་པས: 1
#
# པས་འདོད་དགུ: 1
#
# འདོད་དགུ་ལ: 1
#
# ལ་བསྒྱུར་བ: 1
#
# བསྒྱུར་བ་གི: 1
#
# གི་དཔལ: 1
#
# དཔལ་ཆོས: 1
#
# ཆོས་རྣམས: 1
#
# རྣམས་སྣ་ཚོགས: 1
#
# སྣ་ཚོགས་ཇི་བཞིན: 1
#
# LL12_rje-btsan-dam-pa_NGB-vol34-p63-64.txt top 100 words
# གི: 10
#
# ལ: 8
#
# ཀུན: 6
#
# ཏུ: 4
#
# ཀྱང: 4
#
# གོ: 4
#
# ཡིས: 4
#
# དོན: 4
#
# ལུང: 4
#
# རྗེ་བཙན: 3
#
# རྣལ་འབྱོར: 3
#
# པ: 3
#
# དུ: 2
#
# དམ་པ: 2
#
# ལྷ: 2
#
# ལས: 2
#
# མཆོག: 2
#
# འཕགས་པ: 2
#
# ནི: 2
#
# རྡོ་རྗེ: 2
#
# གྱི: 2
#
# གིས: 2
#
# རྫོགས་པ: 2
#
# ཡིན: 2
#
# ངེས་པ: 2
#
# ཆེན: 2
#
# ནས: 2
#
# དང: 2
#
# རྒྱ་གར: 1
#
# སྐད: 1
#
# ཙ་ར: 1
#
# ཤ: 1
#
# ཨ: 1
#
# ཐུ: 1
#
# བོད་སྐད: 1
#
# བཅོམ་ལྡན་འདས: 1
#
# དཔལ: 1
#
# བཟང་པོ: 1
#
# ཕྱག: 1
#
# འཚལ: 1
#
# ལོ: 1
#
# ཁྲེན: 1
#
# ཡི: 1
#
# རྒྱལ་བ: 1
#
# མེས: 1
#
# བཟང: 1
#
# འཆང: 1
#
# རྒྱལ: 1
#
# འཇིགས: 1
#
# སྐྱབས: 1
#
# ཉམས་པ: 1
#
# ཆད: 1
#
# བྱུང་བ: 1
#
# མགོན: 1
#
# བཙུན: 1
#
# དེ་ལས: 1
#
# གཞན: 1
#
# མེད: 1
#
# དེར: 1
#
# གཞོལ་བ: 1
#
# མཆོད་པ: 1
#
# སྤྲིན: 1
#
# གནས་པ: 1
#
# སྒྲུབ་ཐབས: 1
#
# སོངང: 1
#
# མི: 1
#
# ལྡོག: 1
#
# དངོས་གྲུབ: 1
#
# པས: 1
#
# ཕྱག་རྒྱ: 1
#
# བདེ་ཆེན: 1
#
# ལྷུན: 1
#
# གྱིས: 1
#
# འདི་དག: 1
#
# བླ་མ: 1
#
# སྟེ: 1
#
# མངོན་སུམ: 1
#
# སངས་རྒྱས: 1
#
# ཡིན་པ: 1
#
# ན: 1
#
# འདྲ་བ: 1
#
# དང་བ: 1
#
# བསྐྱེད: 1
#
# སྟོན: 1
#
# དཔའ་བོ: 1
#
# དེ་དག: 1
#
# བསྟན: 1
#
# མཁས་པ: 1
#
# བཞིན: 1
#
# རྒྱུད་པ: 1
#
# སྣུམ་པ: 1
#
# དམ་ཚིག: 1
#
# བསྐང་བ: 1
#
# ཐུགས་རྗེ: 1
#
# ཐབས: 1
#
# ལྡན་པ: 1
#
# ཕན་པ: 1
#
# བཞེད་པ: 1
#
# སྐྱེ་བོ: 1
#
# ཆ་ཤས: 1
#
# LL12_rje-btsan-dam-pa_NGB-vol34-p63-64.txt top 100 bigrams
# ཀུན་ཏུ: 3
#
# རྗེ་བཙན་དམ་པ: 2
#
# ལས་ཀྱང: 2
#
# ཀུན་གྱི: 2
#
# ངེས་པ་གི: 2
#
# གི་དོན: 2
#
# རྒྱ་གར་སྐད: 1
#
# སྐད་དུ: 1
#
# དུ་ཙ་ར: 1
#
# ཙ་ར་ཤ: 1
#
# ཤ་ཨ: 1
#
# ཨ་ལ: 1
#
# ལ་ཐུ: 1
#
# ཐུ་བོད་སྐད: 1
#
# བོད་སྐད་དུ: 1
#
# དུ་རྗེ་བཙན: 1
#
# དམ་པ་བཅོམ་ལྡན་འདས: 1
#
# བཅོམ་ལྡན་འདས་དཔལ: 1
#
# དཔལ་ཀུན: 1
#
# ཏུ་བཟང་པོ: 1
#
# བཟང་པོ་ལ: 1
#
# ལ་ཕྱག: 1
#
# ཕྱག་འཚལ: 1
#
# འཚལ་ལོ: 1
#
# ལོ་ཁྲེན: 1
#
# ཁྲེན་ཏུ: 1
#
# ཏུ་རྣལ་འབྱོར: 1
#
# རྣལ་འབྱོར་ལྷ: 1
#
# ལྷ་ཡི: 1
#
# ཡི་ལྷ: 1
#
# ལྷ་རྣལ་འབྱོར: 1
#
# རྣལ་འབྱོར་ལས: 1
#
# ཀྱང་རྣལ་འབྱོར: 1
#
# རྣལ་འབྱོར་མཆོག: 1
#
# མཆོག་འཕགས་པ: 1
#
# འཕགས་པ་ལས: 1
#
# ཀྱང་འཕགས་པ: 1
#
# འཕགས་པ་ནི: 1
#
# ནི་རྡོ་རྗེ: 1
#
# རྡོ་རྗེ་རྒྱལ་བ: 1
#
# རྒྱལ་བ་ཀུན: 1
#
# གྱི་མེས: 1
#
# མེས་རྗེ་བཙན: 1
#
# དམ་པ་ཀུན: 1
#
# ཏུ་བཟང: 1
#
# བཟང་རྡོ་རྗེ: 1
#
# རྡོ་རྗེ་འཆང: 1
#
# འཆང་རྒྱལ: 1
#
# རྒྱལ་འཇིགས: 1
#
# འཇིགས་པ: 1
#
# པ་གི: 1
#
# གི་སྐྱབས: 1
#
# སྐྱབས་ཉམས་པ: 1
#
# ཉམས་པ་གི: 1
#
# གི་ཆད: 1
#
# ཆད་པ: 1
#
# པ་བྱུང་བ: 1
#
# བྱུང་བ་ལ: 1
#
# ལ་མགོན: 1
#
# མགོན་བཙུན: 1
#
# བཙུན་དེ་ལས: 1
#
# དེ་ལས་གཞན: 1
#
# གཞན་མེད: 1
#
# མེད་གོ: 1
#
# གོ་དེར: 1
#
# དེར་གཞོལ་བ: 1
#
# གཞོལ་བ་ནི: 1
#
# ནི་མཆོད་པ: 1
#
# མཆོད་པ་གི: 1
#
# གི་སྤྲིན: 1
#
# སྤྲིན་ཀུན: 1
#
# ཏུ་གནས་པ: 1
#
# གནས་པ་གིས: 1
#
# གིས་སྒྲུབ་ཐབས: 1
#
# སྒྲུབ་ཐབས་སོངང: 1
#
# སོངང་ཡིས: 1
#
# ཡིས་མི: 1
#
# མི་ལྡོག: 1
#
# ལྡོག་དངོས་གྲུབ: 1
#
# དངོས་གྲུབ་པས: 1
#
# པས་དོན: 1
#
# དོན་ཀུན: 1
#
# ཀུན་ཕྱག་རྒྱ: 1
#
# ཕྱག་རྒྱ་རྫོགས་པ: 1
#
# རྫོགས་པ་ཡིན: 1
#
# ཡིན་བདེ་ཆེན: 1
#
# བདེ་ཆེན་ལྷུན: 1
#
# ལྷུན་གྱིས: 1
#
# གྱིས་རྫོགས་པ: 1
#
# རྫོགས་པ་ཀྱང: 1
#
# ཀྱང་འདི་དག: 1
#
# འདི་དག་ཀུན: 1
#
# གྱི་བླ་མ: 1
#
# བླ་མ་སྟེ: 1
#
# སྟེ་མངོན་སུམ: 1
#
# མངོན་སུམ་སངས་རྒྱས: 1
#
# སངས་རྒྱས་ཡིན་པ: 1
#
# ཡིན་པ་ན: 1
#
# ན་འདྲ་བ: 1
#
# འདྲ་བ་ལ: 1
#
# LL13-sgom-pa-don-grubdocx.txt top 100 words
# ལ: 13
#
# ཀྱི: 7
#
# ནི: 7
#
# སེམས: 6
#
# ན: 6
#
# གི: 5
#
# མེད: 5
#
# དུ: 4
#
# བྱང་ཆུབ: 4
#
# ཀྱང: 4
#
# གིས: 4
#
# ཆོས: 4
#
# ཅེས: 3
#
# ཀུན: 3
#
# ཆེན་པོ: 3
#
# དང: 3
#
# མི: 3
#
# བསྒོམ་པ: 3
#
# མ: 2
#
# སྒོམ་པ: 2
#
# པ: 2
#
# བྱ་བ: 2
#
# ཏུ: 2
#
# བདེ་བ: 2
#
# སེམས་ཅན: 2
#
# ཁྱབ: 2
#
# བྱ: 2
#
# ཆོས་ཉིད: 2
#
# རྟོགས་པ: 2
#
# འདི: 2
#
# རྣམས: 2
#
# གཉིས: 2
#
# སུ: 2
#
# རང་བཞིན: 2
#
# གཞན: 2
#
# ཅི་ཡང: 2
#
# བསྒོམ: 2
#
# རྟོག་པ: 2
#
# ཡིན: 2
#
# དེ: 2
#
# རྒྱ་གར: 1
#
# སྐད: 1
#
# བོ་དྷི: 1
#
# ཙི་ཏ: 1
#
# ས་མ་ཏི: 1
#
# ཨ་མོ་གྷ: 1
#
# ཙ་ན: 1
#
# བོད་སྐད: 1
#
# དོན་གྲུབ: 1
#
# དཔལ: 1
#
# བཟང་པོ: 1
#
# ཕྱག: 1
#
# འཚལ: 1
#
# ཐུག: 1
#
# རྗེ: 1
#
# རྒྱ་མཚོ: 1
#
# ལྷ: 1
#
# ཀླུ: 1
#
# བདེན་པ: 1
#
# བཀའ: 1
#
# ཉན: 1
#
# ཏེ: 1
#
# དཀོན་མཆོག: 1
#
# གསུམ: 1
#
# ནམ་ཡང: 1
#
# བསྐུར: 1
#
# རྟོགས: 1
#
# བདེ: 1
#
# བ: 1
#
# གྲུབ: 1
#
# སྐྱེས་བུ: 1
#
# རང: 1
#
# རིག: 1
#
# ནས: 1
#
# སྐལ་ལྡན: 1
#
# བློ: 1
#
# གོ་བ: 1
#
# གྱིས: 1
#
# དང་སེམས: 1
#
# ཡེ་ནས: 1
#
# བཙལ: 1
#
# རྙེད: 1
#
# འདི་འདྲ: 1
#
# བསྟན: 1
#
# མ་ཡིན་པ: 1
#
# ཚེ: 1
#
# མོ: 1
#
# རྣམ་པར: 1
#
# མཚན་མ: 1
#
# ཅི: 1
#
# བྱུང: 1
#
# དེ་ཉིད: 1
#
# ཤེས: 1
#
# དབྱིངས: 1
#
# དུབསྒོམ: 1
#
# དགོས: 1
#
# གཉེན་པོ: 1
#
# བཅོས: 1
#
# ཤིང: 1
#
# དགག: 1
#
# LL13-sgom-pa-don-grubdocx.txt top 100 bigrams
# བྱང་ཆུབ་ཀྱི: 2
#
# ཀྱི་སེམས: 2
#
# ཆེན་པོ་ལ: 2
#
# ཀུན་ལ: 2
#
# ལ་ཁྱབ: 2
#
# མེད་སེམས: 2
#
# སེམས་ཀྱི: 2
#
# ཆོས་ཀྱི: 2
#
# དེ་ལ: 2
#
# བྱང་ཆུབ་སེམས: 2
#
# རྒྱ་གར་སྐད: 1
#
# སྐད་དུ: 1
#
# དུ་བོ་དྷི: 1
#
# བོ་དྷི་ཙི་ཏ: 1
#
# ཙི་ཏ་ས་མ་ཏི: 1
#
# ས་མ་ཏི་ཨ་མོ་གྷ: 1
#
# ཨ་མོ་གྷ་ཙ་ན: 1
#
# ཙ་ན་མ: 1
#
# མ་བོད་སྐད: 1
#
# བོད་སྐད་དུ: 1
#
# དུ་བྱང་ཆུབ: 1
#
# སེམས་སྒོམ་པ: 1
#
# སྒོམ་པ་དོན་གྲུབ: 1
#
# དོན་གྲུབ་པ: 1
#
# པ་ཅེས: 1
#
# ཅེས་བྱ་བ: 1
#
# བྱ་བ་དཔལ: 1
#
# དཔལ་ཀུན: 1
#
# ཀུན་ཏུ: 1
#
# ཏུ་བཟང་པོ: 1
#
# བཟང་པོ་བདེ་བ: 1
#
# བདེ་བ་ཆེན་པོ: 1
#
# ལ་ཕྱག: 1
#
# ཕྱག་འཚལ: 1
#
# འཚལ་ཐུག: 1
#
# ཐུག་རྗེ: 1
#
# རྗེ་རྒྱ་མཚོ: 1
#
# རྒྱ་མཚོ་སེམས་ཅན: 1
#
# སེམས་ཅན་ཀུན: 1
#
# ཁྱབ་ལྷ: 1
#
# ལྷ་དང: 1
#
# དང་ཀླུ: 1
#
# ཀླུ་ཀྱང: 1
#
# ཀྱང་བདེན་པ: 1
#
# བདེན་པ་གི: 1
#
# གི་བཀའ: 1
#
# བཀའ་ཉན: 1
#
# ཉན་ཏེ: 1
#
# ཏེ་དཀོན་མཆོག: 1
#
# དཀོན་མཆོག་གསུམ: 1
#
# གསུམ་ནི: 1
#
# ནི་ནམ་ཡང: 1
#
# ནམ་ཡང་བསྐུར: 1
#
# བསྐུར་མི: 1
#
# མི་བྱ: 1
#
# བྱ་ཆོས་ཉིད: 1
#
# ཆོས་ཉིད་རྟོགས: 1
#
# རྟོགས་བདེ: 1
#
# བདེ་བ: 1
#
# བ་ཆེན་པོ: 1
#
# ལ་གྲུབ: 1
#
# གྲུབ་སྐྱེས་བུ: 1
#
# སྐྱེས་བུ་ཆེན་པོ: 1
#
# ཆེན་པོ་རང: 1
#
# རང་གིས: 1
#
# གིས་རིག: 1
#
# རིག་ནས: 1
#
# ནས་རྟོགས་པ: 1
#
# རྟོགས་པ་འདི: 1
#
# འདི་སྐལ་ལྡན: 1
#
# སྐལ་ལྡན་རྣམས: 1
#
# རྣམས་ཀྱི: 1
#
# ཀྱི་བློ: 1
#
# བློ་ལ: 1
#
# ལ་གོ་བ: 1
#
# གོ་བ་ལ: 1
#
# ལ་གྱིས: 1
#
# གྱིས་ཆོས: 1
#
# ཆོས་དང་སེམས: 1
#
# དང་སེམས་ནི: 1
#
# ནི་ཡེ་ནས: 1
#
# ཡེ་ནས་གཉིས: 1
#
# གཉིས་སུ: 1
#
# སུ་མེད: 1
#
# ཀྱི་རང་བཞིན: 1
#
# རང་བཞིན་བཙལ: 1
#
# བཙལ་ཀྱང: 1
#
# ཀྱང་མ: 1
#
# མ་རྙེད: 1
#
# རྙེད་ན: 1
#
# ན་གཞན: 1
#
# གཞན་ལ: 1
#
# ལ་འདི་འདྲ: 1
#
# འདི་འདྲ་ཅེས: 1
#
# ཅེས་ནི: 1
#
# ནི་བསྟན: 1
#
# བསྟན་དུ: 1
#
# དུ་མེད: 1
#
# སེམས་དང: 1
#
# དང་ཆོས: 1

# %%
N = 100

print("nyingma GN texts")       
for i in range(len(nyingma_GN_idx2fname)):
    words = Counter(nyingma_GN_texts[i])
    bigrams = Counter(nyingma_GN_bigrams[i])
    print("{}".format(nyingma_GN_idx2fname[i]))
    print("words")
    for k, v in words.most_common(N):
        print("{}: {}\n".format(k, v))
    print("bigrams")
    for k, v in bigrams.most_common(N):
        print("{}: {}\n".format(k, v))
# Out:
# nyingma GN texts
# L1_GN2-rig-pa-khu-byug.txt
# words
# གི: 10
#
# ལ: 4
#
# རིག་པ: 3
#
# དུ: 3
#
# དང: 3
#
# སེམས: 3
#
# ཅེས: 3
#
# ཁུ་བྱུག: 2
#
# དགོངས་པ: 2
#
# ཧ: 2
#
# ཀུན་གཞི: 2
#
# མ: 2
#
# བཅོས: 2
#
# ཀྱི: 2
#
# ཡེ་ཤེས: 2
#
# པ: 2
#
# ལས: 2
#
# ཆོས་ཉིད: 2
#
# ན: 2
#
# གིས: 2
#
# ཀྱང: 2
#
# བྱང་ཆུབ: 2
#
# གོ: 2
#
# ཀློང་རྡོལ: 1
#
# གླུ: 1
#
# བསམ་གཏན: 1
#
# ཙནྡན: 1
#
# གོི: 1
#
# ཤ: 1
#
# ཚལ: 1
#
# ནམ: 1
#
# གྱི: 1
#
# ཆ: 1
#
# སྟོད: 1
#
# སྲས: 1
#
# ཐུ་པོ: 1
#
# རཱ་ཛ: 1
#
# སྟི: 1
#
# འདི་སྐད: 1
#
# ལོ: 1
#
# ཧཱུྃ: 1
#
# ཡེ་ནས: 1
#
# དེ་བཞིན: 1
#
# ཆོས: 1
#
# དབྱིངས: 1
#
# རང་བྱུང: 1
#
# མཁའ: 1
#
# འདྲ་མཉམ: 1
#
# ཆེན་པོ: 1
#
# ཤོག་ལྷེ: 1
#
# ༡༧༢: 1
#
# ཚིག: 1
#
# ཡི་གེ: 1
#
# སྒྲ: 1
#
# འདས་པ: 1
#
# ཀུན: 1
#
# ཏུ: 1
#
# བཟང: 1
#
# མཉམ: 1
#
# ཞིང: 1
#
# དབྱེར: 1
#
# མེད: 1
#
# ལུས་ངག: 1
#
# ཡིད: 1
#
# གསུམ: 1
#
# མཚན་མ: 1
#
# ཅི: 1
#
# སླད: 1
#
# འགྱུར་མེད: 1
#
# དེ: 1
#
# རྣམ་རྟོག: 1
#
# སྐྱོན: 1
#
# སྤངས: 1
#
# ངང: 1
#
# བཞག་པ: 1
#
# སྒོམ: 1
#
# གུད: 1
#
# མེད་པར: 1
#
# འཁུམས: 1
#
# སྒྱུ་མ: 1
#
# ཕུང་པོ: 1
#
# ད་ལྟ: 1
#
# བསྙིལ་བ: 1
#
# ཕྱིར: 1
#
# ཀུན་བཟང: 1
#
# ཐུགས: 1
#
# འོད་ཟེར: 1
#
# ང: 1
#
# ཤར: 1
#
# གྷི: 1
#
# ཏ་མ: 1
#
# ཀོ་ལ: 1
#
# ས་མ: 1
#
# ཧོ: 1
#
# གསུང: 1
#
# གཞན: 1
#
# ཤྲཱི: 1
#
# སེང: 1
#
# སྣ་ཚོགས: 1
#
# རང: 1
#
# bigrams
# རིག་པ་གི: 2
#
# གི་ཁུ་བྱུག: 2
#
# ཁུ་བྱུག་གི: 2
#
# གི་དགོངས་པ: 2
#
# མ་བཅོས: 2
#
# བྱང་ཆུབ་སེམས: 2
#
# དགོངས་པ་རིག་པ: 1
#
# རིག་པ་ཀློང་རྡོལ: 1
#
# ཀློང་རྡོལ་གླུ: 1
#
# གླུ་གི: 1
#
# གི་བསམ་གཏན: 1
#
# བསམ་གཏན་ཙནྡན: 1
#
# ཙནྡན་གོི: 1
#
# གོི་ཤ: 1
#
# ཤ་གི: 1
#
# གི་ཚལ: 1
#
# ཚལ་དུ: 1
#
# དུ་ནམ: 1
#
# ནམ་གྱི: 1
#
# གྱི་ཆ: 1
#
# ཆ་སྟོད: 1
#
# སྟོད་ལ: 1
#
# ལ་སྲས: 1
#
# སྲས་ཐུ་པོ: 1
#
# ཐུ་པོ་རཱ་ཛ: 1
#
# རཱ་ཛ་ཧ: 1
#
# ཧ་སྟི: 1
#
# སྟི་འདི་སྐད: 1
#
# འདི་སྐད་ལོ: 1
#
# ལོ་ཧཱུྃ: 1
#
# ཧཱུྃ་ཀུན་གཞི: 1
#
# ཀུན་གཞི་ཡེ་ནས: 1
#
# ཡེ་ནས་མ: 1
#
# བཅོས་དེ་བཞིན: 1
#
# དེ་བཞིན་ཆོས: 1
#
# ཆོས་ཀྱི: 1
#
# ཀྱི་དབྱིངས: 1
#
# དབྱིངས་རང་བྱུང: 1
#
# རང་བྱུང་ཡེ་ཤེས: 1
#
# ཡེ་ཤེས་མཁའ: 1
#
# མཁའ་འདྲ་མཉམ: 1
#
# འདྲ་མཉམ་པ: 1
#
# པ་ཆེན་པོ: 1
#
# ཆེན་པོ་གི: 1
#
# གི་ཤོག་ལྷེ: 1
#
# ཤོག་ལྷེ་༡༧༢: 1
#
# ༡༧༢་དང: 1
#
# དང་ཚིག: 1
#
# ཚིག་དང: 1
#
# དང་ཡི་གེ: 1
#
# ཡི་གེ་གི: 1
#
# གི་སྒྲ: 1
#
# སྒྲ་ལས: 1
#
# ལས་འདས་པ: 1
#
# འདས་པ་ཀུན: 1
#
# ཀུན་ཏུ: 1
#
# ཏུ་བཟང: 1
#
# བཟང་སེམས: 1
#
# སེམས་དང: 1
#
# དང་ཆོས་ཉིད: 1
#
# ཆོས་ཉིད་མཉམ: 1
#
# མཉམ་ཞིང: 1
#
# ཞིང་དབྱེར: 1
#
# དབྱེར་མེད: 1
#
# མེད་ན: 1
#
# ན་ལུས་ངག: 1
#
# ལུས་ངག་ཡིད: 1
#
# ཡིད་གསུམ: 1
#
# གསུམ་མཚན་མ: 1
#
# མཚན་མ་ཅི: 1
#
# ཅི་གིས: 1
#
# གིས་སླད: 1
#
# སླད་ཀྱང: 1
#
# ཀྱང་ཆོས་ཉིད: 1
#
# ཆོས་ཉིད་བྱང་ཆུབ: 1
#
# སེམས་ལ: 1
#
# ལ་འགྱུར་མེད: 1
#
# འགྱུར་མེད་དེ: 1
#
# དེ་རྣམ་རྟོག: 1
#
# རྣམ་རྟོག་སྐྱོན: 1
#
# སྐྱོན་སྤངས: 1
#
# སྤངས་ཀུན་གཞི: 1
#
# ཀུན་གཞི་བྱང་ཆུབ: 1
#
# སེམས་མ: 1
#
# བཅོས་ངང: 1
#
# ངང་དུ: 1
#
# དུ་བཞག་པ: 1
#
# བཞག་པ་ལས: 1
#
# ལས་སྒོམ: 1
#
# སྒོམ་ཅེས: 1
#
# ཅེས་གུད: 1
#
# གུད་ན: 1
#
# ན་མེད་པར: 1
#
# མེད་པར་འཁུམས: 1
#
# འཁུམས་སྒྱུ་མ: 1
#
# སྒྱུ་མ་གི: 1
#
# གི་ཕུང་པོ: 1
#
# ཕུང་པོ་ད་ལྟ: 1
#
# ད་ལྟ་བསྙིལ་བ: 1
#
# བསྙིལ་བ་གི: 1
#
# L2_G5-rtsal-chen.txt
# words
# མི: 9
#
# གིས: 6
#
# ལ: 5
#
# གི: 4
#
# འགྱུར: 4
#
# མ: 4
#
# ཆེན: 3
#
# ཉིད: 3
#
# ཀྱང: 3
#
# གོ: 3
#
# རྩལ: 2
#
# གྱི: 2
#
# པ: 2
#
# ན: 2
#
# གླིང: 2
#
# ཀུ: 2
#
# ཏུ: 2
#
# རྟོག: 2
#
# དབྱིངས: 2
#
# ལས: 2
#
# རིག་པ: 2
#
# ཏེ: 2
#
# འདི: 2
#
# ཡིན: 2
#
# ཞིང: 2
#
# མེད་པ: 2
#
# ཅེས: 2
#
# ཡེ་ཤེས: 2
#
# དགོངས་པ: 1
#
# བྱང་སེམས: 1
#
# ཀློང་རྡོལ: 1
#
# གླུ: 1
#
# བསམ་གཏན: 1
#
# སྐྱ་རེངས: 1
#
# གཉིས: 1
#
# ཤར: 1
#
# ཙམ: 1
#
# རྒྱ་མཚོ: 1
#
# དུ: 1
#
# ཁྱི: 1
#
# རྒྱལ་པོ: 1
#
# རཱ: 1
#
# ཛ: 1
#
# འདི་སྐད: 1
#
# ལོ: 1
#
# ཡེ་ནས: 1
#
# ལྷུན་གྲུབ: 1
#
# ཀུན: 1
#
# བཟང་པོ: 1
#
# དང: 1
#
# གསལ: 1
#
# སྤྲོས་བྲལ: 1
#
# བྱང་ཆུབ: 1
#
# སེམས: 1
#
# དམིགས: 1
#
# ཆོས: 1
#
# ཀྱི: 1
#
# བསླད: 1
#
# མཉམ་བཞག: 1
#
# རྩི: 1
#
# གང: 1
#
# བསམས: 1
#
# མཆོག: 1
#
# གསང་བ: 1
#
# རྨད་བྱུང: 1
#
# སེམས་ཉིད: 1
#
# རྣ་བ: 1
#
# ཉན་པ: 1
#
# ལ་སོགས: 1
#
# སྤྱོད་ཡུལ: 1
#
# ཡོད: 1
#
# ཀུན་གཞི: 1
#
# ཡེངས: 1
#
# བཞག: 1
#
# སྒོམ་པ: 1
#
# མེད་པར: 1
#
# འཁུམས: 1
#
# ཁམས: 1
#
# གསུམ: 1
#
# རང: 1
#
# སར: 1
#
# གྲོལ་བ: 1
#
# བཙལ: 1
#
# སྒྲུབ: 1
#
# དགོས: 1
#
# རེ: 1
#
# དོགས་པ: 1
#
# བདག་ཉིད: 1
#
# སངས་རྒྱས: 1
#
# གྷི: 1
#
# ཏི: 1
#
# ཀོ་ལ: 1
#
# ཧོ: 1
#
# གསུངས: 1
#
# གཞན: 1
#
# ཨཱ: 1
#
# དེ་བ: 1
#
# བཟང་ངན: 1
#
# བླང་དོར: 1
#
# ཟང་ཐལ: 1
#
# bigrams
# མི་འགྱུར: 4
#
# རྩལ་ཆེན: 2
#
# ཆེན་གྱི: 2
#
# མི་རྟོག: 2
#
# རིག་པ་མི: 2
#
# འགྱུར་མ: 2
#
# ལ་ཀྱང: 2
#
# ཀྱང་མི: 2
#
# མེད་པ་གིས: 2
#
# གྱི་དགོངས་པ: 1
#
# དགོངས་པ་བྱང་སེམས: 1
#
# བྱང་སེམས་ཀློང་རྡོལ: 1
#
# ཀློང་རྡོལ་གླུ: 1
#
# གླུ་གི: 1
#
# གི་བསམ་གཏན: 1
#
# བསམ་གཏན་སྐྱ་རེངས: 1
#
# སྐྱ་རེངས་གཉིས: 1
#
# གཉིས་པ: 1
#
# པ་ཤར: 1
#
# ཤར་ཙམ: 1
#
# ཙམ་ན: 1
#
# ན་རྒྱ་མཚོ: 1
#
# རྒྱ་མཚོ་གི: 1
#
# གི་གླིང: 1
#
# གླིང་དུ: 1
#
# དུ་ཁྱི: 1
#
# ཁྱི་གི: 1
#
# གི་རྒྱལ་པོ: 1
#
# རྒྱལ་པོ་ཀུ: 1
#
# ཀུ་ཀུ: 1
#
# ཀུ་རཱ: 1
#
# རཱ་ཛ: 1
#
# ཛ་གིས: 1
#
# གིས་འདི་སྐད: 1
#
# འདི་སྐད་ལོ: 1
#
# ལོ་ཡེ་ནས: 1
#
# ཡེ་ནས་ལྷུན་གྲུབ: 1
#
# ལྷུན་གྲུབ་ཀུན: 1
#
# ཀུན་ཏུ: 1
#
# ཏུ་བཟང་པོ: 1
#
# བཟང་པོ་དང: 1
#
# དང་གསལ: 1
#
# གསལ་ལ: 1
#
# ལ་མི: 1
#
# རྟོག་སྤྲོས་བྲལ: 1
#
# སྤྲོས་བྲལ་བྱང་ཆུབ: 1
#
# བྱང་ཆུབ་སེམས: 1
#
# སེམས་མི: 1
#
# འགྱུར་མི: 1
#
# མི་དམིགས: 1
#
# དམིགས་ཆོས: 1
#
# ཆོས་ཀྱི: 1
#
# ཀྱི་དབྱིངས: 1
#
# དབྱིངས་ཉིད: 1
#
# ཉིད་ལས: 1
#
# ལས་རིག་པ: 1
#
# མ་བསླད: 1
#
# བསླད་མཉམ་བཞག: 1
#
# མཉམ་བཞག་ན: 1
#
# ན་རྩི: 1
#
# རྩི་ལ: 1
#
# རྟོག་གང: 1
#
# གང་ལ: 1
#
# མི་བསམས: 1
#
# བསམས་ཏེ: 1
#
# ཏེ་མཆོག: 1
#
# མཆོག་ཏུ: 1
#
# ཏུ་གསང་བ: 1
#
# གསང་བ་གི: 1
#
# གི་རྨད་བྱུང: 1
#
# རྨད་བྱུང་སེམས་ཉིད: 1
#
# སེམས་ཉིད་འདི: 1
#
# འདི་རྣ་བ: 1
#
# རྣ་བ་གིས: 1
#
# གིས་ཉན་པ: 1
#
# ཉན་པ་ལ་སོགས: 1
#
# ལ་སོགས་སྤྱོད་ཡུལ: 1
#
# སྤྱོད་ཡུལ་ཡོད: 1
#
# ཡོད་མ: 1
#
# མ་ཡིན: 1
#
# ཡིན་ཀུན་གཞི: 1
#
# ཀུན་གཞི་མི: 1
#
# འགྱུར་དབྱིངས: 1
#
# དབྱིངས་ཆེན: 1
#
# ཆེན་ལ: 1
#
# ལ་རིག་པ: 1
#
# མ་ཡེངས: 1
#
# ཡེངས་བཞག: 1
#
# བཞག་སྒོམ་པ: 1
#
# སྒོམ་པ་འདི: 1
#
# འདི་ལས: 1
#
# ལས་མེད་པར: 1
#
# མེད་པར་འཁུམས: 1
#
# འཁུམས་ཁམས: 1
#
# ཁམས་གསུམ: 1
#
# གསུམ་རང: 1
#
# རང་སར: 1
#
# སར་གྲོལ་བ: 1
#
# གྲོལ་བ་གིས: 1
#
# གིས་བཙལ: 1
#
# L3_GN1-khyung-chen.txt
# words
# ལ: 11
#
# གི: 8
#
# དེ: 5
#
# གོ: 4
#
# གྱི: 4
#
# དུ: 4
#
# མ: 4
#
# སེམས: 4
#
# དགོངས་པ: 3
#
# མེད་པ: 3
#
# བྱང་ཆུབ: 3
#
# ཀྱང: 3
#
# མི: 3
#
# ཀྱི: 2
#
# གླུ: 2
#
# ཁྱུང་ཆེན: 2
#
# ཆོས་ཉིད: 2
#
# རྒྱལ་པོ: 2
#
# ནི: 2
#
# ལས: 2
#
# མེད: 2
#
# ཅི: 2
#
# རྟོག་པ: 2
#
# ཞིང: 2
#
# བསམ: 2
#
# ཡེངས: 2
#
# མེད་པར: 2
#
# སྒོམ: 2
#
# ཞོག: 2
#
# བླངས: 2
#
# ཅེས: 2
#
# སེམས་སྡེ: 1
#
# བཅོ་བརྒྱད: 1
#
# རིག་འཛིན: 1
#
# རྣམས: 1
#
# ཀྱིས: 1
#
# རྡོ་རྗེ: 1
#
# བཞེངས་པ: 1
#
# བཞུགས: 1
#
# ན་མོ: 1
#
# གུ་རུ: 1
#
# བིདྱཱ: 1
#
# དྷཱ: 1
#
# རེ: 1
#
# བྷྱ: 1
#
# ཀློང་རྡོལ: 1
#
# ཡི: 1
#
# བསམ་གཏན: 1
#
# ཙནྡན: 1
#
# ནགས་ཚལ: 1
#
# ནམ: 1
#
# གུང: 1
#
# དྷ: 1
#
# ཧེ: 1
#
# ན: 1
#
# ཏེ་ལོ: 1
#
# འདི་སྐད: 1
#
# ལོ: 1
#
# ཧཱུྃ: 1
#
# འགྱུར་བ: 1
#
# ཀུན་གཞི: 1
#
# བཅོས: 1
#
# གཟུང་འཛིན: 1
#
# རྣམ་རྟོག: 1
#
# ཡུལ: 1
#
# འདས: 1
#
# སྣང་བ: 1
#
# གཟུགས: 1
#
# སྤྱད: 1
#
# གིས: 1
#
# བཟུང: 1
#
# སེམས་ཉིད: 1
#
# རང་བཞིན: 1
#
# མཁའ: 1
#
# འདྲ: 1
#
# བསླད: 1
#
# བཅོས་པ: 1
#
# བཞག: 1
#
# ཆོས་དབྱིངས: 1
#
# ཆེན་པོ: 1
#
# རིག་པ: 1
#
# རྒྱུ: 1
#
# རྡུལ: 1
#
# ཙམ: 1
#
# འཁུམས: 1
#
# སྐྱེ་བ: 1
#
# བརྒྱུད: 1
#
# ནས: 1
#
# བདག་སྐྱེས: 1
#
# ཏེ: 1
#
# དོ་ཧ: 1
#
# ང་རྒྱལ: 1
#
# བཅག་པ: 1
#
# སྔོན་ཆད: 1
#
# མཆོག: 1
#
# ཏུ: 1
#
# སེམས་བསྐྱེད: 1
#
# ཅིང: 1
#
# དང: 1
#
# ཆོས: 1
#
# bigrams
# མེད་པ་གི: 3
#
# དེ་ལ: 2
#
# ཁྱུང་ཆེན་གྱི: 2
#
# གྱི་དགོངས་པ: 2
#
# བྱང་ཆུབ་སེམས: 2
#
# ཅི་ལ: 2
#
# ལ་ཀྱང: 2
#
# ཀྱང་མི: 2
#
# མ་ཡེངས: 2
#
# དུ་མེད་པ: 2
#
# ཅེས་གོ: 2
#
# སེམས་སྡེ་བཅོ་བརྒྱད: 1
#
# བཅོ་བརྒྱད་ཀྱི: 1
#
# ཀྱི་དགོངས་པ: 1
#
# དགོངས་པ་རིག་འཛིན: 1
#
# རིག་འཛིན་རྣམས: 1
#
# རྣམས་ཀྱིས: 1
#
# ཀྱིས་རྡོ་རྗེ: 1
#
# རྡོ་རྗེ་གི: 1
#
# གི་གླུ: 1
#
# གླུ་ལ: 1
#
# ལ་བཞེངས་པ: 1
#
# བཞེངས་པ་བཞུགས: 1
#
# བཞུགས་གོ: 1
#
# གོ་ན་མོ: 1
#
# ན་མོ་གུ་རུ: 1
#
# གུ་རུ་བིདྱཱ: 1
#
# བིདྱཱ་དྷཱ: 1
#
# དྷཱ་རེ: 1
#
# རེ་བྷྱ: 1
#
# བྷྱ་དེ: 1
#
# ལ་ཁྱུང་ཆེན: 1
#
# དགོངས་པ་ཆོས་ཉིད: 1
#
# ཆོས་ཉིད་ཀློང་རྡོལ: 1
#
# ཀློང་རྡོལ་གླུ: 1
#
# གླུ་ཡི: 1
#
# ཡི་བསམ་གཏན: 1
#
# བསམ་གཏན་ཙནྡན: 1
#
# ཙནྡན་གྱི: 1
#
# གྱི་ནགས་ཚལ: 1
#
# ནགས་ཚལ་དུ: 1
#
# དུ་ནམ: 1
#
# ནམ་གྱི: 1
#
# གྱི་གུང: 1
#
# གུང་ལ: 1
#
# ལ་རྒྱལ་པོ: 1
#
# རྒྱལ་པོ་དྷ: 1
#
# དྷ་ཧེ: 1
#
# ཧེ་ན: 1
#
# ན་ཏེ་ལོ: 1
#
# ཏེ་ལོ་འདི་སྐད: 1
#
# འདི་སྐད་ལོ: 1
#
# ལོ་ཧཱུྃ: 1
#
# ཧཱུྃ་འགྱུར་བ: 1
#
# འགྱུར་བ་མེད་པ: 1
#
# གི་ཆོས་ཉིད: 1
#
# ཆོས་ཉིད་ནི: 1
#
# ནི་ཀུན་གཞི: 1
#
# ཀུན་གཞི་མ: 1
#
# མ་བཅོས: 1
#
# བཅོས་བྱང་ཆུབ: 1
#
# སེམས་གཟུང་འཛིན: 1
#
# གཟུང་འཛིན་རྣམ་རྟོག: 1
#
# རྣམ་རྟོག་ཡུལ: 1
#
# ཡུལ་ལས: 1
#
# ལས་འདས: 1
#
# འདས་སྣང་བ: 1
#
# སྣང་བ་གི: 1
#
# གི་གཟུགས: 1
#
# གཟུགས་མེད: 1
#
# མེད་བྱང་ཆུབ: 1
#
# སེམས་ཅི: 1
#
# མི་སྤྱད: 1
#
# སྤྱད་རྟོག་པ: 1
#
# རྟོག་པ་གིས: 1
#
# གིས་མི: 1
#
# མི་བཟུང: 1
#
# བཟུང་ཞིང: 1
#
# ཞིང་སེམས་ཉིད: 1
#
# སེམས་ཉིད་རང་བཞིན: 1
#
# རང་བཞིན་བསམ: 1
#
# བསམ་མེད: 1
#
# མེད་མཁའ: 1
#
# མཁའ་འདྲ: 1
#
# འདྲ་ལ: 1
#
# ལ་མ: 1
#
# ཡེངས་མ: 1
#
# མ་བསླད: 1
#
# བསླད་བཅོས་པ: 1
#
# བཅོས་པ་མེད་པར: 1
#
# མེད་པར་བཞག: 1
#
# བཞག་སྒོམ: 1
#
# སྒོམ་དུ: 1
#
# གི་ཆོས་དབྱིངས: 1
#
# ཆོས་དབྱིངས་ཆེན་པོ: 1
#
# ཆེན་པོ་ལ: 1
#
# ལ་བསམ: 1
#
# བསམ་དུ: 1
#
# གི་རིག་པ: 1
#
# རིག་པ་མ: 1
#
# L4_GN6-sems-sgom.txt
# words
# གི: 6
#
# གྱི: 3
#
# དབྱིངས: 3
#
# གོ: 3
#
# ལ: 3
#
# མི: 3
#
# དེ: 3
#
# མ: 3
#
# ཅེས: 3
#
# སེམས: 2
#
# སྒོམ: 2
#
# པ: 2
#
# ན: 2
#
# ནས: 2
#
# ཐམས་ཅད: 2
#
# ཡེ་ནས: 2
#
# རིག་པ: 2
#
# མེད་པ: 2
#
# འགྱུར: 2
#
# ཡེངས: 2
#
# ལས: 2
#
# ཆོས་ཉིད: 2
#
# དགོངས་པ: 1
#
# ཀློང་རྡོལ: 1
#
# གླུ: 1
#
# བསམ་གཏན: 1
#
# རྒྱན: 1
#
# ཆགས: 1
#
# དཔལ: 1
#
# རི: 1
#
# ནགས: 1
#
# སུ: 1
#
# སྐྱ་རེངས: 1
#
# གསུམ: 1
#
# ཤར: 1
#
# ཙམ: 1
#
# ནཱ: 1
#
# གརྫུ: 1
#
# འདི་སྐད: 1
#
# སྣང་བ: 1
#
# ཆེན: 1
#
# འཕོ་འགྱུར: 1
#
# དུར: 1
#
# བཏབ: 1
#
# ཉིད: 1
#
# བསླད: 1
#
# མཁའ: 1
#
# ལྟར: 1
#
# དག་པ: 1
#
# བཅོས: 1
#
# ཡོངས: 1
#
# ཀྱི: 1
#
# འོད་གསལ: 1
#
# སྒོམ་པ: 1
#
# མིང: 1
#
# དུ: 1
#
# བཏགས་པ: 1
#
# གུད: 1
#
# མེད་པར: 1
#
# འཁུམས: 1
#
# བདག: 1
#
# ཕུང་པོ: 1
#
# གདོས་བཅས: 1
#
# འདི: 1
#
# གིས: 1
#
# དབྱེ་བ: 1
#
# ས་ལ: 1
#
# མཆི: 1
#
# གྷི: 1
#
# ཏ་མ: 1
#
# ཀོ་ལ: 1
#
# ས: 1
#
# ཧོ: 1
#
# གསུངས: 1
#
# གཞན: 1
#
# ཀྱང: 1
#
# ཤེལ: 1
#
# ཕྲེང: 1
#
# དཀར་པོ: 1
#
# བྱ་བ: 1
#
# མན་ངག: 1
#
# སྣང་སྲིད: 1
#
# ཡིན: 1
#
# དེས་ན: 1
#
# དེ་ཉིད: 1
#
# སྤྱོད: 1
#
# དགོངས: 1
#
# བཅུད: 1
#
# དྲུག: 1
#
# bigrams
# སེམས་སྒོམ: 2
#
# སྒོམ་གྱི: 2
#
# མེད་པ་གི: 2
#
# མི་འགྱུར: 2
#
# མ་ཡེངས: 2
#
# གྱི་དགོངས་པ: 1
#
# དགོངས་པ་དབྱིངས: 1
#
# དབྱིངས་ཀློང་རྡོལ: 1
#
# ཀློང་རྡོལ་གླུ: 1
#
# གླུ་གི: 1
#
# གི་བསམ་གཏན: 1
#
# བསམ་གཏན་རྒྱན: 1
#
# རྒྱན་ཆགས: 1
#
# ཆགས་དཔལ: 1
#
# དཔལ་གྱི: 1
#
# གྱི་རི: 1
#
# རི་གི: 1
#
# གི་ནགས: 1
#
# ནགས་སུ: 1
#
# སུ་སྐྱ་རེངས: 1
#
# སྐྱ་རེངས་གསུམ: 1
#
# གསུམ་པ: 1
#
# པ་ཤར: 1
#
# ཤར་ཙམ: 1
#
# ཙམ་ན: 1
#
# ན་ནཱ: 1
#
# ནཱ་གརྫུ: 1
#
# གརྫུ་ནས: 1
#
# ནས་འདི་སྐད: 1
#
# འདི་སྐད་གོ: 1
#
# གོ་སྣང་བ: 1
#
# སྣང་བ་ཐམས་ཅད: 1
#
# ཐམས་ཅད་ཡེ་ནས: 1
#
# ཡེ་ནས་དབྱིངས: 1
#
# དབྱིངས་ཆེན: 1
#
# ཆེན་ལ: 1
#
# ལ་རིག་པ: 1
#
# རིག་པ་འཕོ་འགྱུར: 1
#
# འཕོ་འགྱུར་མེད་པ: 1
#
# གི་དུར: 1
#
# དུར་བཏབ: 1
#
# བཏབ་ནས: 1
#
# ནས་དབྱིངས: 1
#
# དབྱིངས་ཉིད: 1
#
# ཉིད་མི: 1
#
# འགྱུར་རིག་པ: 1
#
# རིག་པ་མི: 1
#
# མི་བསླད: 1
#
# བསླད་དེ: 1
#
# དེ་མ: 1
#
# ཡེངས་མི: 1
#
# འགྱུར་མཁའ: 1
#
# མཁའ་ལྟར: 1
#
# ལྟར་དག་པ: 1
#
# དག་པ་ལ: 1
#
# ལ་མ: 1
#
# ཡེངས་མ: 1
#
# མ་བཅོས: 1
#
# བཅོས་ཡོངས: 1
# ཡོངས་ཀྱི: 1
#
# ཀྱི་འོད་གསལ: 1
#
# འོད་གསལ་ལས: 1
#
# ལས་སྒོམ་པ: 1
#
# སྒོམ་པ་མིང: 1
#
# མིང་དུ: 1
#
# དུ་བཏགས་པ: 1
#
# བཏགས་པ་གུད: 1
#
# གུད་ན: 1
#
# ན་མེད་པར: 1
#
# མེད་པར་འཁུམས: 1
#
# འཁུམས་བདག: 1
#
# བདག་གི: 1
#
# གི་ཕུང་པོ: 1
#
# ཕུང་པོ་གདོས་བཅས: 1
#
# གདོས་བཅས་འདི: 1
#
# འདི་གིས: 1
#
# གིས་དབྱེ་བ: 1
#
# དབྱེ་བ་མེད་པ: 1
#
# གི་ས་ལ: 1
#
# ས་ལ་མཆི: 1
#
# མཆི་གྷི: 1
#
# གྷི་ཏ་མ: 1
#
# ཏ་མ་ཀོ་ལ: 1
#
# ཀོ་ལ་ས: 1
#
# ས་ཧོ: 1
#
# ཧོ་ཅེས: 1
#
# ཅེས་གསུངས: 1
#
# གསུངས་གཞན: 1
#
# གཞན་ཀྱང: 1
#
# ཀྱང་ཤེལ: 1
#
# ཤེལ་ཕྲེང: 1
#
# ཕྲེང་དཀར་པོ: 1
#
# དཀར་པོ་ཅེས: 1
#
# ཅེས་བྱ་བ: 1
#
# བྱ་བ་གི: 1
#
# གི་མན་ངག: 1
#
# མན་ངག་ལས: 1
#
# ལས་སྣང་སྲིད: 1
#
# སྣང་སྲིད་ཐམས་ཅད: 1
#
# ཐམས་ཅད་ཆོས་ཉིད: 1
#
# L5_GN3-nam-mkha-che.txt
# words
# གི: 7
#
# ཀྱི: 3
#
# ལ: 3
#
# མེད: 3
#
# ནམ་མཁའ: 2
#
# ཆེ: 2
#
# དགོངས་པ: 2
#
# གིས: 2
#
# མ: 2
#
# གྱིས: 2
#
# རང་བྱུང: 2
#
# ལས: 2
#
# ཐུགས: 2
#
# བདག: 2
#
# ཅེས: 2
#
# གཞན: 2
#
# གོ: 2
#
# ཡེ་ཤེས: 1
#
# ཀློང་རྡོལ: 1
#
# གླུ: 1
#
# བསམ་གཏན: 1
#
# མེ་ཏོག: 1
#
# ཨུ: 1
#
# དུམྦཱ: 1
#
# རའི: 1
#
# ཚལ: 1
#
# དུ: 1
#
# ནམ་སྨད: 1
#
# ཆ: 1
#
# སྲས་མོ: 1
#
# སཱ་ར: 1
#
# ནི: 1
#
# འདི་སྐད: 1
#
# ལོ: 1
#
# ཀུན་གཞི: 1
#
# བཅོས: 1
#
# ཡེ་ནས: 1
#
# ཆོས: 1
#
# དབྱིངས: 1
#
# རྒྱུ: 1
#
# དང: 1
#
# རྐྱེན: 1
#
# བསྐྱེད: 1
#
# འཇིག: 1
#
# བྲལ: 1
#
# ལྷུན: 1
#
# གྲུབ་པ: 1
#
# བཅོམ་ལྡན་འདས: 1
#
# ཡུལ: 1
#
# འདས་པ: 1
#
# རྡོ་རྗེ: 1
#
# སེམས་དཔའ: 1
#
# འདི: 1
#
# མེད་པར: 1
#
# འཁུམས: 1
#
# སྒྱུ་མ: 1
#
# ཕུང་པོ: 1
#
# ད་ལྟ: 1
#
# བསྙིལ་བ: 1
#
# ཕྱིར: 1
#
# ཀུན་བཟང: 1
#
# གཏེར་ཆེན: 1
#
# བབས: 1
#
# གྷི: 1
#
# ཏ་མ: 1
#
# ཀོ་ལ: 1
#
# ཧོ: 1
#
# གསུངས: 1
#
# ཀྱང: 1
#
# འཕགས་པ: 1
#
# ལྷ: 1
#
# རིག་པ: 1
#
# དེ་ཉིད: 1
#
# དངོས: 1
#
# ངེས: 1
#
# ན: 1
#
# རྟོག: 1
#
# གསལ་བ: 1
#
# བཞག: 1
#
# དགོངས: 1
#
# བཅུད: 1
#
# དེ: 1
#
# གསུམ: 1
#
# པ: 1
#
# bigrams
# ནམ་མཁའ་ཆེ: 2
#
# ཆེ་གི: 2
#
# གི་དགོངས་པ: 2
#
# དགོངས་པ་ཡེ་ཤེས: 1
#
# ཡེ་ཤེས་ཀློང་རྡོལ: 1
#
# ཀློང་རྡོལ་གླུ: 1
#
# གླུ་གི: 1
#
# གི་བསམ་གཏན: 1
#
# བསམ་གཏན་མེ་ཏོག: 1
#
# མེ་ཏོག་ཨུ: 1
#
# ཨུ་དུམྦཱ: 1
#
# དུམྦཱ་རའི: 1
#
# རའི་ཚལ: 1
#
# ཚལ་དུ: 1
#
# དུ་ནམ་སྨད: 1
#
# ནམ་སྨད་ཀྱི: 1
#
# ཀྱི་ཆ: 1
#
# ཆ་ལ: 1
#
# ལ་སྲས་མོ: 1
#
# སྲས་མོ་སཱ་ར: 1
#
# སཱ་ར་ནི: 1
#
# ནི་གིས: 1
#
# གིས་འདི་སྐད: 1
#
# འདི་སྐད་ལོ: 1
#
# ལོ་ཀུན་གཞི: 1
#
# ཀུན་གཞི་མ: 1
#
# མ་བཅོས: 1
#
# བཅོས་ཡེ་ནས: 1
#
# ཡེ་ནས་ཆོས: 1
#
# ཆོས་ཀྱི: 1
#
# ཀྱི་དབྱིངས: 1
#
# དབྱིངས་རྒྱུ: 1
#
# རྒྱུ་དང: 1
#
# དང་རྐྱེན: 1
#
# རྐྱེན་གྱིས: 1
#
# གྱིས་མ: 1
#
# མ་བསྐྱེད: 1
#
# བསྐྱེད་འཇིག: 1
#
# འཇིག་བྲལ: 1
#
# བྲལ་མེད: 1
#
# མེད་རང་བྱུང: 1
#
# རང་བྱུང་ལྷུན: 1
#
# ལྷུན་གྱིས: 1
#
# གྱིས་གྲུབ་པ: 1
#
# གྲུབ་པ་བཅོམ་ལྡན་འདས: 1
#
# བཅོམ་ལྡན་འདས་རང་བྱུང: 1
#
# རང་བྱུང་ཡུལ: 1
#
# ཡུལ་ལས: 1
#
# ལས་འདས་པ: 1
#
# འདས་པ་རྡོ་རྗེ: 1
#
# རྡོ་རྗེ་སེམས་དཔའ: 1
#
# སེམས་དཔའ་གི: 1
#
# གི་ཐུགས: 1
#
# ཐུགས་བདག: 1
#
# བདག་གི: 1
#
# དགོངས་པ་འདི: 1
#
# འདི་ལས: 1
#
# ལས་མེད་པར: 1
#
# མེད་པར་འཁུམས: 1
#
# འཁུམས་སྒྱུ་མ: 1
#
# སྒྱུ་མ་གི: 1
#
# གི་ཕུང་པོ: 1
#
# ཕུང་པོ་ད་ལྟ: 1
#
# ད་ལྟ་བསྙིལ་བ: 1
#
# བསྙིལ་བ་གི: 1
#
# གི་ཕྱིར: 1
#
# ཕྱིར་ཀུན་བཟང: 1
#
# ཀུན་བཟང་ཐུགས: 1
#
# ཐུགས་ཀྱི: 1
#
# ཀྱི་གཏེར་ཆེན: 1
#
# གཏེར་ཆེན་བདག: 1
#
# བདག་ལ: 1
#
# ལ་བབས: 1
#
# བབས་གྷི: 1
#
# གྷི་ཏ་མ: 1
#
# ཏ་མ་ཀོ་ལ: 1
#
# ཀོ་ལ་ཧོ: 1
#
# ཧོ་ཅེས: 1
#
# ཅེས་གསུངས: 1
#
# གསུངས་གཞན: 1
#
# གཞན་ཀྱང: 1
#
# ཀྱང་འཕགས་པ: 1
#
# འཕགས་པ་ལྷ: 1
#
# ལྷ་གིས: 1
#
# གིས་རིག་པ: 1
#
# རིག་པ་དེ་ཉིད: 1
#
# དེ་ཉིད་དངོས: 1
#
# དངོས་གཞན: 1
#
# གཞན་མེད: 1
#
# མེད་ངེས: 1
#
# ངེས་ན: 1
#
# ན་རྟོག: 1
#
# རྟོག་མེད: 1
#
# མེད་གསལ་བ: 1
#
# གསལ་བ་ལ: 1
#
# ལ་བཞག: 1
#
# བཞག་ཅེས: 1
#
# ཅེས་གོ: 1
#
# གོ་ནམ་མཁའ: 1
#
# གི་དགོངས: 1
#
# LL01-GN-rtse-mo.txt
# words
# མེད: 6
#
# གིས: 6
#
# གི: 4
#
# ལ: 4
#
# སངས་རྒྱས: 4
#
# མ: 3
#
# གོ: 3
#
# རྩེ་མོ: 2
#
# བྱུང་རྒྱལ: 2
#
# གྱི: 2
#
# དགོངས་པ: 2
#
# ཤར: 2
#
# ན: 2
#
# བྱང་ཆུབ: 2
#
# སེམས: 2
#
# དེ: 2
#
# བཙལ: 2
#
# བཅོས: 2
#
# སེམས་ལས: 2
#
# ཀྱི: 2
#
# ཡིན: 2
#
# ནས: 2
#
# གསལ་བ: 2
#
# ལས: 2
#
# འདི: 2
#
# བདག: 2
#
# ཅེས: 2
#
# རྩོལ: 1
#
# ཀློང་རྡོལ: 1
#
# གླུ: 1
#
# བསམ་གཏན: 1
#
# ཤིང: 1
#
# ནལ: 1
#
# བྱིས: 1
#
# རྩ: 1
#
# དམར་རེངས: 1
#
# གསུམ: 1
#
# པ: 1
#
# ཙམ: 1
#
# སྨད་འཚོང་མ: 1
#
# བུདྡྷ: 1
#
# མ་ཏི: 1
#
# འདི་སྐད: 1
#
# ལོ: 1
#
# ཨེ་མ་ཧོ: 1
#
# ཆོས་ཉིད: 1
#
# བརྟག: 1
#
# ཏུ: 1
#
# དཔྱད: 1
#
# དུ: 1
#
# ཞིང: 1
#
# གཉེན་པོ: 1
#
# སུ: 1
#
# ལོགས: 1
#
# བཙལ་བ: 1
#
# མི: 1
#
# རྙེད: 1
#
# རང་བཞིན: 1
#
# གདོད: 1
#
# སྙིང་པོ: 1
#
# ཏིང་འཛིན: 1
#
# ཤོག་ལྷེ: 1
#
# ༡༧༦: 1
#
# ལྷད: 1
#
# ངང: 1
#
# མེད་པར: 1
#
# འཁུམས: 1
#
# ཕུང་པོ: 1
#
# གདོས་བཅས: 1
#
# བསྙིལ: 1
#
# ཀུན་བཟང: 1
#
# ཐུགས: 1
#
# འོད་ཟེར: 1
#
# གྷི: 1
#
# ཏ: 1
#
# ཀོ་ལ: 1
#
# ཨ: 1
#
# ཧོ: 1
#
# གསུངས: 1
#
# གཞན: 1
#
# ཀྱང: 1
#
# གུ་རུ: 1
#
# ཆེན་པོ: 1
#
# ཐམས་ཅད: 1
#
# ཡེ་ཤེས: 1
#
# རྐྱན: 1
#
# དེ་ལྟར: 1
#
# རྟོགས་པ: 1
#
# དག་པ: 1
#
# དགོངས: 1
#
# བཅུད: 1
#
# དགུ་པ: 1
#
# bigrams
# རྩེ་མོ་བྱུང་རྒྱལ: 2
#
# བྱུང་རྒྱལ་གྱི: 2
#
# སེམས་ལས་སངས་རྒྱས: 2
#
# གྱི་དགོངས་པ: 1
#
# དགོངས་པ་རྩོལ: 1
#
# རྩོལ་མེད: 1
#
# མེད་ཀློང་རྡོལ: 1
#
# ཀློང་རྡོལ་གླུ: 1
#
# གླུ་གི: 1
#
# གི་བསམ་གཏན: 1
#
# བསམ་གཏན་ཤིང: 1
#
# ཤིང་ནལ: 1
#
# ནལ་བྱིས: 1
#
# བྱིས་ལ: 1
#
# ལ་གི: 1
#
# གི་རྩ: 1
#
# རྩ་ལ: 1
#
# ལ་དམར་རེངས: 1
#
# དམར་རེངས་གསུམ: 1
#
# གསུམ་པ: 1
#
# པ་ཤར: 1
#
# ཤར་ཙམ: 1
#
# ཙམ་ན: 1
#
# ན་སྨད་འཚོང་མ: 1
#
# སྨད་འཚོང་མ་བུདྡྷ: 1
#
# བུདྡྷ་མ་ཏི: 1
#
# མ་ཏི་འདི་སྐད: 1
#
# འདི་སྐད་ལོ: 1
#
# ལོ་ཨེ་མ་ཧོ: 1
#
# ཨེ་མ་ཧོ་ཆོས་ཉིད: 1
#
# ཆོས་ཉིད་བྱང་ཆུབ: 1
#
# བྱང་ཆུབ་སེམས: 1
#
# སེམས་བརྟག: 1
#
# བརྟག་ཏུ: 1
#
# ཏུ་མེད: 1
#
# མེད་དེ: 1
#
# དེ་དཔྱད: 1
#
# དཔྱད་དུ: 1
#
# དུ་མེད: 1
#
# མེད་བཙལ: 1
#
# བཙལ་ཞིང: 1
#
# ཞིང་གཉེན་པོ: 1
#
# གཉེན་པོ་གིས: 1
#
# གིས་བཅོས: 1
#
# བཅོས་སུ: 1
#
# སུ་མེད: 1
#
# མེད་སེམས་ལས: 1
#
# སངས་རྒྱས་ལོགས: 1
#
# ལོགས་ན: 1
#
# ན་མེད: 1
#
# མེད་བཙལ་བ: 1
#
# བཙལ་བ་གིས: 1
#
# གིས་མི: 1
#
# མི་རྙེད: 1
#
# རྙེད་སེམས་ལས: 1
#
# སངས་རྒྱས་མེད: 1
#
# མེད་སེམས: 1
#
# སེམས་ཀྱི: 1
#
# ཀྱི་རང་བཞིན: 1
#
# རང་བཞིན་མ: 1
#
# མ་བཅོས: 1
#
# བཅོས་སངས་རྒྱས: 1
#
# སངས་རྒྱས་ཡིན: 1
#
# ཡིན་གདོད: 1
#
# གདོད་ནས: 1
#
# ནས་མ: 1
#
# མ་བཙལ: 1
#
# བཙལ་བྱང་ཆུབ: 1
#
# བྱང་ཆུབ་སྙིང་པོ: 1
#
# སྙིང་པོ་ལ: 1
#
# ལ་ཏིང་འཛིན: 1
#
# ཏིང་འཛིན་ཤོག་ལྷེ: 1
#
# ཤོག་ལྷེ་༡༧༦: 1
#
# ༡༧༦་མ: 1
#
# མ་ལྷད: 1
#
# ལྷད་ངང: 1
#
# ངང་གིས: 1
#
# གིས་གསལ་བ: 1
#
# གསལ་བ་ལས: 1
#
# ལས་སངས་རྒྱས: 1
#
# སངས་རྒྱས་དགོངས་པ: 1
#
# དགོངས་པ་འདི: 1
#
# འདི་ལས: 1
#
# ལས་མེད་པར: 1
#
# མེད་པར་འཁུམས: 1
#
# འཁུམས་བདག: 1
#
# བདག་གི: 1
#
# གི་ཕུང་པོ: 1
#
# ཕུང་པོ་གདོས་བཅས: 1
#
# གདོས་བཅས་འདི: 1
#
# འདི་བསྙིལ: 1
#
# བསྙིལ་ནས: 1
#
# ནས་ཀུན་བཟང: 1
#
# ཀུན་བཟང་ཐུགས: 1
#
# ཐུགས་ཀྱི: 1
#
# ཀྱི་འོད་ཟེར: 1
#
# འོད་ཟེར་བདག: 1
#
# བདག་ལ: 1
#
# ལ་ཤར: 1
#
# ཤར་གྷི: 1
#
# LL02-GN_namkha'i-rgyal-po.txt
# words
# གི: 8
#
# ལ: 5
#
# གོ: 4
#
# ཀུན: 3
#
# ནམ་མཁའ: 2
#
# རྒྱལ་པོ: 2
#
# གྲོལ་བ: 2
#
# སེམས: 2
#
# ལས: 2
#
# རྟོགས: 2
#
# མེད: 2
#
# ཏུ: 2
#
# རིག་པ: 2
#
# དེ: 2
#
# མ: 2
#
# པ: 2
#
# ཅེས: 2
#
# དགོངས་པ: 1
#
# ཀློང་རྡོལ: 1
#
# གླུ: 1
#
# བསམ་གཏན: 1
#
# མེ་ཏོག: 1
#
# ཚལ: 1
#
# དུ: 1
#
# ནམ: 1
#
# གྱི: 1
#
# ཆ: 1
#
# སྟོད: 1
#
# དྷརྨ་རཱ་ཛ: 1
#
# འདི་སྐད: 1
#
# ཀྱི: 1
#
# རང་བཞིན: 1
#
# ཡེ་ནས: 1
#
# མཛོད་ཆེན: 1
#
# གང་ལྟར: 1
#
# ཤིང: 1
#
# ཇི་ལྟ: 1
#
# སྣང་བ: 1
#
# འབྱུང: 1
#
# འཇུག: 1
#
# འབྱུང་བ: 1
#
# ན: 1
#
# བཟང: 1
#
# གཉིས: 1
#
# སུ: 1
#
# མེད་པ: 1
#
# བཟང་པོ: 1
#
# གནས: 1
#
# དབྱིངས: 1
#
# ལས་མ: 1
#
# བསླད་པ: 1
#
# གིས: 1
#
# སྒོམ: 1
#
# ཞིང: 1
#
# གནས་པ: 1
#
# འདི: 1
#
# ཀྱེ་མ: 1
#
# སྙིང: 1
#
# རེ: 1
#
# རྗེ: 1
#
# བདག་ཉིད: 1
#
# རང: 1
#
# སར: 1
#
# ཨ་ལ: 1
#
# དྷོ: 1
#
# ཧ: 1
#
# ཀོ: 1
#
# ཤ: 1
#
# ཨ: 1
#
# ཧོ: 1
#
# གསུངས: 1
#
# གཞན: 1
#
# ཀྱང: 1
#
# འཕགས་པ: 1
#
# དྲང་སྲོང: 1
#
# མིག: 1
#
# མན་ངག: 1
#
# ཡེངས: 1
#
# རྩེ་གཅིག: 1
#
# བསམ: 1
#
# དང: 1
#
# བྲལ: 1
#
# དེས་ན: 1
#
# ཡེ་ཤེས: 1
#
# ཟང་ཐལ: 1
#
# ཡིན: 1
#
# དགོངས: 1
#
# བཅུད: 1
#
# བཅུ་བདུན: 1
#
# bigrams
# ནམ་མཁའ་རྒྱལ་པོ: 2
#
# རྒྱལ་པོ་གི: 2
#
# ཀུན་ཏུ: 2
#
# གི་དགོངས་པ: 1
#
# དགོངས་པ་གྲོལ་བ: 1
#
# གྲོལ་བ་ཀློང་རྡོལ: 1
#
# ཀློང་རྡོལ་གླུ: 1
#
# གླུ་གི: 1
#
# གི་བསམ་གཏན: 1
#
# བསམ་གཏན་མེ་ཏོག: 1
#
# མེ་ཏོག་གི: 1
#
# གི་ཚལ: 1
#
# ཚལ་དུ: 1
#
# དུ་ནམ: 1
#
# ནམ་གྱི: 1
#
# གྱི་ཆ: 1
#
# ཆ་སྟོད: 1
#
# སྟོད་ལ: 1
#
# ལ་དྷརྨ་རཱ་ཛ: 1
#
# དྷརྨ་རཱ་ཛ་འདི་སྐད: 1
#
# འདི་སྐད་གོ: 1
#
# གོ་སེམས: 1
#
# སེམས་ཀྱི: 1
#
# ཀྱི་རང་བཞིན: 1
#
# རང་བཞིན་ཡེ་ནས: 1
#
# ཡེ་ནས་མཛོད་ཆེན: 1
#
# མཛོད་ཆེན་ལས: 1
#
# ལས་གང་ལྟར: 1
#
# གང་ལྟར་རྟོགས: 1
#
# རྟོགས་ཤིང: 1
#
# ཤིང་ཇི་ལྟ: 1
#
# ཇི་ལྟ་ལ: 1
#
# ལ་སྣང་བ: 1
#
# སྣང་བ་ཀུན: 1
#
# ཀུན་འབྱུང: 1
#
# འབྱུང་འཇུག: 1
#
# འཇུག་འབྱུང་བ: 1
#
# འབྱུང་བ་མེད: 1
#
# མེད་ན: 1
#
# ན་ཀུན: 1
#
# ཏུ་བཟང: 1
#
# བཟང་གཉིས: 1
#
# གཉིས་སུ: 1
#
# སུ་མེད་པ: 1
#
# མེད་པ་གི: 1
#
# གི་རིག་པ: 1
#
# རིག་པ་དེ: 1
#
# དེ་ཀུན: 1
#
# ཏུ་བཟང་པོ: 1
#
# བཟང་པོ་གི: 1
#
# གི་སེམས: 1
#
# སེམས་ལ: 1
#
# ལ་གནས: 1
#
# གནས་རིག་པ: 1
#
# རིག་པ་གི: 1
#
# གི་དབྱིངས: 1
#
# དབྱིངས་ལས་མ: 1
#
# ལས་མ་བསླད་པ: 1
#
# བསླད་པ་གིས: 1
#
# གིས་སྒོམ: 1
#
# སྒོམ་ཞིང: 1
#
# ཞིང་གནས་པ: 1
#
# གནས་པ་འདི: 1
#
# འདི་ལ: 1
#
# ལ་མེད: 1
#
# མེད་ཀྱེ་མ: 1
#
# ཀྱེ་མ་མ: 1
#
# མ་རྟོགས: 1
#
# རྟོགས་སྙིང: 1
#
# སྙིང་རེ: 1
#
# རེ་རྗེ: 1
#
# རྗེ་བདག་ཉིད: 1
#
# བདག་ཉིད་རང: 1
#
# རང་སར: 1
#
# སར་གྲོལ་བ: 1
#
# གྲོལ་བ་ཨ་ལ: 1
#
# ཨ་ལ་ལ: 1
#
# ལ་དྷོ: 1
#
# དྷོ་ཧ: 1
#
# ཧ་ཀོ: 1
#
# ཀོ་པ: 1
#
# པ་ཤ: 1
#
# ཤ་ཨ: 1
#
# ཨ་ཧོ: 1
#
# ཧོ་ཅེས: 1
#
# ཅེས་གསུངས: 1
#
# གསུངས་གོ: 1
#
# གོ་གཞན: 1
#
# གཞན་ཀྱང: 1
#
# ཀྱང་འཕགས་པ: 1
#
# འཕགས་པ་དྲང་སྲོང: 1
#
# དྲང་སྲོང་མིག: 1
#
# མིག་གི: 1
#
# གི་མན་ངག: 1
#
# མན་ངག་ལས: 1
#
# ལས་མ: 1
#
# མ་ཡེངས: 1
#
# ཡེངས་རྩེ་གཅིག: 1
#
# རྩེ་གཅིག་བསམ: 1
#
# བསམ་དང: 1
#
# LL03-GN-12_bde-ba-phra-bkod.txt
# words
# ལ: 8
#
# གི: 6
#
# མི: 5
#
# དུ: 4
#
# ལས: 4
#
# གིས: 4
#
# བདེ་བ: 3
#
# སེམས་ཉིད: 3
#
# སངས་རྒྱས: 3
#
# རིག་པ: 3
#
# འགྱུར: 3
#
# ནས: 3
#
# གནས: 3
#
# གོ: 3
#
# འཕྲ: 2
#
# བཀོད: 2
#
# ཀྱི: 2
#
# དགོངས་པ: 2
#
# ཡིན་པ: 2
#
# མེད: 2
#
# ཡེ་ནས: 2
#
# མེད་པ: 2
#
# འདི: 2
#
# ཟབ་མོ: 2
#
# ཆོས་དབྱིངས: 2
#
# ལྟར: 2
#
# ཆེན་པོ: 2
#
# དག་པ: 2
#
# ཆོས་ཉིད: 2
#
# གསལ་བ: 2
#
# མ: 2
#
# ནམ་མཁའ: 2
#
# ཅེས: 2
#
# རྟོག: 2
#
# ངང: 2
#
# ཕྲིན་ལས: 1
#
# ཀློང་རྡོལ: 1
#
# གླུ: 1
#
# བསམ་གཏན: 1
#
# རིན་པོ་ཆེ: 1
#
# གླིང: 1
#
# ནམ་གུང: 1
#
# ཡོལ: 1
#
# ཨོ་རྒྱན: 1
#
# གྱི: 1
#
# མཁན་པོ: 1
#
# དྷ: 1
#
# ཧེ: 1
#
# འདི་སྐད: 1
#
# ལོ: 1
#
# སེམས་ལས: 1
#
# ལོགས: 1
#
# ན: 1
#
# རང་བཞིན: 1
#
# བརྗོད་དོན: 1
#
# གམ: 1
#
# གསལ: 1
#
# རྒྱ་མཚོ: 1
#
# ཆེ: 1
#
# བཟོད: 1
#
# ཅིང: 1
#
# ནང: 1
#
# འཆར: 1
#
# ཀུན་གཞི: 1
#
# གཏན: 1
#
# སྦྱོང་བ: 1
#
# ཉི: 1
#
# མཁའ: 1
#
# ཡོངས: 1
#
# ཁྱབ་པ: 1
#
# བརྡལ: 1
#
# སྤྱད: 1
#
# གདོད: 1
#
# ཕྱིན: 1
#
# ཅི: 1
#
# ལོག: 1
#
# ལྷད: 1
#
# གཤེགས་པ: 1
#
# མེད་པར: 1
#
# མཇལ: 1
#
# རྣལ་འབྱོར: 1
#
# ཁྱུང་ཆེན: 1
#
# གཤོག་པ: 1
#
# ལྡིང: 1
#
# ཀརྨ: 1
#
# ཀོ་ལ: 1
#
# ཤ: 1
#
# ཨ་ཧོ: 1
#
# གསུངས: 1
#
# གཞན: 1
#
# ཀྱང: 1
#
# རྒྱ: 1
#
# ལུང: 1
#
# ཆེན: 1
#
# མོ་ལ: 1
#
# དེས་ན: 1
#
# བཅོས: 1
#
# ཤར: 1
#
# དགོངས: 1
#
# བཅུད: 1
#
# bigrams
# རིག་པ་མི: 3
#
# མི་འགྱུར: 3
#
# བདེ་བ་འཕྲ: 2
#
# འཕྲ་བཀོད: 2
#
# བཀོད་ཀྱི: 2
#
# སངས་རྒྱས་ཡིན་པ: 2
#
# ཡིན་པ་ལས: 2
#
# ལས་རིག་པ: 2
#
# དག་པ་གིས: 2
#
# གསལ་བ་ལ: 2
#
# ལ་གནས: 2
#
# ངང་དུ: 2
#
# ཀྱི་དགོངས་པ: 1
#
# དགོངས་པ་ཕྲིན་ལས: 1
#
# ཕྲིན་ལས་ཀློང་རྡོལ: 1
#
# ཀློང་རྡོལ་གླུ: 1
#
# གླུ་གི: 1
#
# གི་བསམ་གཏན: 1
#
# བསམ་གཏན་རིན་པོ་ཆེ: 1
#
# རིན་པོ་ཆེ་གི: 1
#
# གི་གླིང: 1
#
# གླིང་དུ: 1
#
# དུ་ནམ་གུང: 1
#
# ནམ་གུང་ཡོལ: 1
#
# ཡོལ་ལ: 1
#
# ལ་ཨོ་རྒྱན: 1
#
# ཨོ་རྒྱན་གྱི: 1
#
# གྱི་མཁན་པོ: 1
#
# མཁན་པོ་དྷ: 1
#
# དྷ་ཧེ: 1
#
# ཧེ་འདི་སྐད: 1
#
# འདི་སྐད་ལོ: 1
#
# ལོ་སེམས་ཉིད: 1
#
# སེམས་ཉིད་སངས་རྒྱས: 1
#
# ལས་སེམས་ལས: 1
#
# སེམས་ལས་སངས་རྒྱས: 1
#
# སངས་རྒྱས་ལོགས: 1
#
# ལོགས་ན: 1
#
# ན་མེད: 1
#
# མེད་སེམས་ཉིད: 1
#
# སེམས་ཉིད་ཡེ་ནས: 1
#
# ཡེ་ནས་སངས་རྒྱས: 1
#
# འགྱུར་རང་བཞིན: 1
#
# རང་བཞིན་མེད་པ: 1
#
# མེད་པ་འདི: 1
#
# འདི་ཟབ་མོ: 1
#
# ཟབ་མོ་གི: 1
#
# གི་ཆོས་དབྱིངས: 1
#
# ཆོས་དབྱིངས་མི: 1
#
# མི་བརྗོད་དོན: 1
#
# བརྗོད་དོན་གམ: 1
#
# གམ་གསལ: 1
#
# གསལ་རྒྱ་མཚོ: 1
#
# རྒྱ་མཚོ་ཆེ: 1
#
# ཆེ་ལྟར: 1
#
# ལྟར་ཆོས་དབྱིངས: 1
#
# ཆོས་དབྱིངས་ཟབ་མོ: 1
#
# ཟབ་མོ་ལས: 1
#
# འགྱུར་བཟོད: 1
#
# བཟོད་ཅིང: 1
#
# ཅིང་ནང: 1
#
# ནང་ནས: 1
#
# ནས་འཆར: 1
#
# འཆར་ཀུན་གཞི: 1
#
# ཀུན་གཞི་གཏན: 1
#
# གཏན་ནས: 1
#
# ནས་སྦྱོང་བ: 1
#
# སྦྱོང་བ་གི: 1
#
# གི་ཉི: 1
#
# ཉི་ཆེན་པོ: 1
#
# ཆེན་པོ་མཁའ: 1
#
# མཁའ་ལྟར: 1
#
# ལྟར་དག་པ: 1
#
# གིས་ཡོངས: 1
#
# ཡོངས་ལ: 1
#
# ལ་ཁྱབ་པ: 1
#
# ཁྱབ་པ་ལ: 1
#
# ལ་བརྡལ: 1
#
# བརྡལ་ཆོས་ཉིད: 1
#
# ཆོས་ཉིད་ཡེ་ནས: 1
#
# ཡེ་ནས་དག་པ: 1
#
# གིས་སྤྱད: 1
#
# སྤྱད་དུ: 1
#
# དུ་མེད་པ: 1
#
# མེད་པ་ལ: 1
#
# ལ་རིག་པ: 1
#
# འགྱུར་གདོད: 1
#
# གདོད་ནས: 1
#
# ནས་གསལ་བ: 1
#
# གནས་ཕྱིན: 1
#
# ཕྱིན་ཅི: 1
#
# ཅི་ལོག: 1
#
# ལོག་གིས: 1
#
# གིས་མ: 1
#
# མ་ལྷད: 1
#
# ལྷད་གསལ་བ: 1
#
# གནས་བདེ་བ: 1
#
# བདེ་བ་ལ: 1
#
# ལ་གཤེགས་པ: 1
#
# གཤེགས་པ་གི: 1
#
# LL04-GN11_spyi-chings.txt
# words
# གི: 6
#
# ལ: 5
#
# ཀྱི: 3
#
# ནམ་མཁའ: 3
#
# ལས: 3
#
# གོ: 3
#
# སྤྱི་ཆིངས: 2
#
# དགོངས་པ: 2
#
# སེམས: 2
#
# ནི: 2
#
# ཀློང: 2
#
# གསལ: 2
#
# རྟོག་པ: 2
#
# མེད་པ: 2
#
# ཡེ་ཤེས: 2
#
# མེད: 2
#
# གིས: 2
#
# ན: 2
#
# ཅེས: 2
#
# ཀློང་རྡོལ: 1
#
# གླུ: 1
#
# བསམ་གཏན: 1
#
# དཔག་བསམ: 1
#
# ཤིང་གི: 1
#
# གྲིབ་མ: 1
#
# ཐོ་རེངས: 1
#
# ཁར: 1
#
# ཨཱརྻ: 1
#
# པ་ལོ: 1
#
# འདི་སྐད: 1
#
# ལོ: 1
#
# བྱང་ཆུབ: 1
#
# ལྟ་བུ: 1
#
# ཕྱི: 1
#
# དང: 1
#
# ནང: 1
#
# ཀུན: 1
#
# གསལ་བ: 1
#
# སྣང: 1
#
# གདོད: 1
#
# ནས: 1
#
# དག་པ: 1
#
# འདྲ: 1
#
# རྣམ་རྟོག: 1
#
# བསྲེག་པ: 1
#
# མངོན: 1
#
# ཤར་བ: 1
#
# སྐྱེ་འགག: 1
#
# ཡངས: 1
#
# དོགས: 1
#
# རང་གཞན: 1
#
# ཤོག་ལྷེ: 1
#
# ༡༧༧: 1
#
# སངས་རྒྱས: 1
#
# འདི: 1
#
# མེད་པར: 1
#
# མཇལ: 1
#
# ཟ: 1
#
# སེམས་ཉིད: 1
#
# བདུད་རྩི: 1
#
# ཟོ: 1
#
# གོན: 1
#
# ཆོས་ཉིད: 1
#
# གོས: 1
#
# སུ: 1
#
# གྱོན: 1
#
# ཨེ་མ: 1
#
# ཀོ་ལ: 1
#
# ཤ: 1
#
# ཨ: 1
#
# ཧོ: 1
#
# གསུངས: 1
#
# གཞན: 1
#
# ཀྱང: 1
#
# ལུང: 1
#
# རྒྱལ་པོ: 1
#
# དེ་ཉིད: 1
#
# མ: 1
#
# བཅོས: 1
#
# དེ་ལྟར: 1
#
# ཡིན་པ: 1
#
# དགོངས: 1
#
# བཅུད: 1
#
# དེ: 1
#
# བཅུ་གཅིག: 1
#
# པ: 1
#
# bigrams
# སྤྱི་ཆིངས་ཀྱི: 2
#
# གི་ཀློང: 2
#
# གི་ཡེ་ཤེས: 2
#
# ཀྱི་དགོངས་པ: 1
#
# དགོངས་པ་ནམ་མཁའ: 1
#
# ནམ་མཁའ་ཀློང་རྡོལ: 1
#
# ཀློང་རྡོལ་གླུ: 1
#
# གླུ་གི: 1
#
# གི་བསམ་གཏན: 1
#
# བསམ་གཏན་དཔག་བསམ: 1
#
# དཔག་བསམ་ཤིང་གི: 1
#
# ཤིང་གི་གྲིབ་མ: 1
#
# གྲིབ་མ་ལ: 1
#
# ལ་ཐོ་རེངས: 1
#
# ཐོ་རེངས་ཁར: 1
#
# ཁར་ཨཱརྻ: 1
#
# ཨཱརྻ་པ་ལོ: 1
#
# པ་ལོ་འདི་སྐད: 1
#
# འདི་སྐད་ལོ: 1
#
# ལོ་བྱང་ཆུབ: 1
#
# བྱང་ཆུབ་སེམས: 1
#
# སེམས་ནི: 1
#
# ནི་ནམ་མཁའ: 1
#
# ནམ་མཁའ་ལྟ་བུ: 1
#
# ལྟ་བུ་གི: 1
#
# ཀློང་གསལ: 1
#
# གསལ་ལ: 1
#
# ལ་རྟོག་པ: 1
#
# རྟོག་པ་མེད་པ: 1
#
# མེད་པ་གི: 1
#
# ཡེ་ཤེས་ནི: 1
#
# ནི་ཕྱི: 1
#
# ཕྱི་དང: 1
#
# དང་ནང: 1
#
# ནང་མེད: 1
#
# མེད་ཀུན: 1
#
# ཀུན་ལ: 1
#
# ལ་གསལ་བ: 1
#
# གསལ་བ་ལ: 1
#
# ལ་སྣང: 1
#
# སྣང་གདོད: 1
#
# གདོད་ནས: 1
#
# ནས་དག་པ: 1
#
# དག་པ་ནམ་མཁའ: 1
#
# ནམ་མཁའ་གི: 1
#
# ཀློང་འདྲ: 1
#
# འདྲ་ལ: 1
#
# ལ་རྣམ་རྟོག: 1
#
# རྣམ་རྟོག་བསྲེག་པ: 1
#
# བསྲེག་པ་གི: 1
#
# ཡེ་ཤེས་མངོན: 1
#
# མངོན་ཤར་བ: 1
#
# ཤར་བ་གིས: 1
#
# གིས་སྐྱེ་འགག: 1
#
# སྐྱེ་འགག་ཡངས: 1
#
# ཡངས་དོགས: 1
#
# དོགས་རང་གཞན: 1
#
# རང་གཞན་མེད་པ: 1
#
# མེད་པ་ཤོག་ལྷེ: 1
#
# ཤོག་ལྷེ་༡༧༧: 1
#
# ༡༧༧་ལས: 1
#
# ལས་སངས་རྒྱས: 1
#
# སངས་རྒྱས་དགོངས་པ: 1
#
# དགོངས་པ་འདི: 1
#
# འདི་ལས: 1
#
# ལས་མེད་པར: 1
#
# མེད་པར་མཇལ: 1
#
# མཇལ་ཟ: 1
#
# ཟ་ན: 1
#
# ན་སེམས་ཉིད: 1
#
# སེམས་ཉིད་བདུད་རྩི: 1
#
# བདུད་རྩི་ཟོ: 1
#
# ཟོ་གོན: 1
#
# གོན་ན: 1
#
# ན་ཆོས་ཉིད: 1
#
# ཆོས་ཉིད་གོས: 1
#
# གོས་སུ: 1
#
# སུ་གྱོན: 1
#
# གྱོན་ཨེ་མ: 1
#
# ཨེ་མ་ཀོ་ལ: 1
#
# ཀོ་ལ་ཤ: 1
#
# ཤ་ཨ: 1
#
# ཨ་ཧོ: 1
#
# ཧོ་ཅེས: 1
#
# ཅེས་གསུངས: 1
#
# གསུངས་གོ: 1
#
# གོ་གཞན: 1
#
# གཞན་ཀྱང: 1
#
# ཀྱང་ལུང: 1
#
# ལུང་གི: 1
#
# གི་རྒྱལ་པོ: 1
#
# རྒྱལ་པོ་ལས: 1
#
# ལས་སེམས: 1
#
# སེམས་ཀྱི: 1
#
# ཀྱི་དེ་ཉིད: 1
#
# དེ་ཉིད་མ: 1
#
# མ་བཅོས: 1
#
# བཅོས་གསལ: 1
#
# གསལ་དེ་ལྟར: 1
#
# དེ་ལྟར་ཡིན་པ: 1
#
# LL06_GN16-bde-ba-rab-'byams.txt
# words
# ཀྱི: 3
#
# གི: 3
#
# ལ: 3
#
# ལས: 3
#
# གོ: 3
#
# བདེ་བ: 2
#
# རབ་འབྱམས: 2
#
# དུ: 2
#
# དེ་བ: 2
#
# སྣང་སྲིད: 2
#
# རྣམས: 2
#
# འདི: 2
#
# གཞན: 2
#
# རྟོགས: 2
#
# ནི: 2
#
# ཡེ་ཤེས: 2
#
# ཅེས: 2
#
# ལྔ: 2
#
# དགོངས་པ: 1
#
# སྐུ་གསུམ: 1
#
# ཀློང་རྡོལ: 1
#
# གླུ: 1
#
# བསམ་གཏན: 1
#
# གྲོང་ཁྱེར: 1
#
# དཔལ་ཡོན: 1
#
# སྲོད: 1
#
# དུས: 1
#
# སུ: 1
#
# རྒྱལ་པོ: 1
#
# རཱ་ཛ: 1
#
# འདི་སྐད: 1
#
# ལོ: 1
#
# ཆོས: 1
#
# མངོན་དུ: 1
#
# ལྟོས་པ: 1
#
# ཡང་དག: 1
#
# ཉིད: 1
#
# བཅོམ་པ: 1
#
# བྱ: 1
#
# ཐམས་ཅད: 1
#
# ཡེ་ནས: 1
#
# ཀུན: 1
#
# ཏུ: 1
#
# བཟང་པོ: 1
#
# དང: 1
#
# མེད: 1
#
# མ: 1
#
# ཡེངས: 1
#
# མཉམ་བཞག: 1
#
# པས: 1
#
# བསྒོམ་པ: 1
#
# བྱ་བ: 1
#
# མེད་པར: 1
#
# ལུས: 1
#
# སྒྱུ་མ: 1
#
# ཕུང་པོ: 1
#
# མིང་ཙམ: 1
#
# སྟེ: 1
#
# སེམས: 1
#
# ཆེན་པོ: 1
#
# སོན: 1
#
# ཙནྡྲ: 1
#
# ཀོ་ས་ལ: 1
#
# ཨ: 1
#
# ཧོ: 1
#
# གསུངས: 1
#
# ཀྱང: 1
#
# དྲི་མེད: 1
#
# བཤེས་གཉེན: 1
#
# གྱི: 1
#
# མན་ངག: 1
#
# དུག: 1
#
# རུ: 1
#
# གསལ: 1
#
# དེ་ལྟར: 1
#
# ན: 1
#
# རིག: 1
#
# མཆོག: 1
#
# ཡིན: 1
#
# དགོངས: 1
#
# བཅུད: 1
#
# དེ: 1
#
# བཅུ་དྲུག: 1
#
# པ: 1
#
# ཤོག་ལྷེ: 1
#
# ༡༨༠: 1
#
# bigrams
# བདེ་བ་རབ་འབྱམས: 2
#
# རབ་འབྱམས་ཀྱི: 2
#
# འདི་ལས: 2
#
# ཀྱི་དགོངས་པ: 1
#
# དགོངས་པ་སྐུ་གསུམ: 1
#
# སྐུ་གསུམ་ཀློང་རྡོལ: 1
#
# ཀློང་རྡོལ་གླུ: 1
#
# གླུ་གི: 1
#
# གི་བསམ་གཏན: 1
#
# བསམ་གཏན་གྲོང་ཁྱེར: 1
#
# གྲོང་ཁྱེར་དཔལ་ཡོན: 1
#
# དཔལ་ཡོན་དུ: 1
#
# དུ་སྲོད: 1
#
# སྲོད་ཀྱི: 1
#
# ཀྱི་དུས: 1
#
# དུས་སུ: 1
#
# སུ་རྒྱལ་པོ: 1
#
# རྒྱལ་པོ་དེ་བ: 1
#
# དེ་བ་རཱ་ཛ: 1
#
# རཱ་ཛ་འདི་སྐད: 1
#
# འདི་སྐད་ལོ: 1
#
# ལོ་སྣང་སྲིད: 1
#
# སྣང་སྲིད་ཆོས: 1
#
# ཆོས་རྣམས: 1
#
# རྣམས་མངོན་དུ: 1
#
# མངོན་དུ་ལྟོས་པ: 1
#
# ལྟོས་པ་རྣམས: 1
#
# རྣམས་ཡང་དག: 1
#
# ཡང་དག་ཉིད: 1
#
# ཉིད་དུ: 1
#
# དུ་བཅོམ་པ: 1
#
# བཅོམ་པ་ལ: 1
#
# ལ་བྱ: 1
#
# བྱ་སྣང་སྲིད: 1
#
# སྣང་སྲིད་ཐམས་ཅད: 1
#
# ཐམས་ཅད་ཡེ་ནས: 1
#
# ཡེ་ནས་ཀུན: 1
#
# ཀུན་ཏུ: 1
#
# ཏུ་བཟང་པོ: 1
#
# བཟང་པོ་གི: 1
#
# གི་དང: 1
#
# དང་འདི: 1
#
# ལས་གཞན: 1
#
# གཞན་མེད: 1
#
# མེད་མ: 1
#
# མ་ཡེངས: 1
#
# ཡེངས་མཉམ་བཞག: 1
#
# མཉམ་བཞག་པས: 1
#
# པས་བསྒོམ་པ: 1
#
# བསྒོམ་པ་ལ: 1
#
# ལ་བྱ་བ: 1
#
# བྱ་བ་འདི: 1
#
# ལས་མེད་པར: 1
#
# མེད་པར་རྟོགས: 1
#
# རྟོགས་ལུས: 1
#
# ལུས་ནི: 1
#
# ནི་སྒྱུ་མ: 1
#
# སྒྱུ་མ་གི: 1
#
# གི་ཕུང་པོ: 1
#
# ཕུང་པོ་མིང་ཙམ: 1
#
# མིང་ཙམ་སྟེ: 1
#
# སྟེ་སེམས: 1
#
# སེམས་ནི: 1
#
# ནི་ཡེ་ཤེས: 1
#
# ཡེ་ཤེས་ཆེན་པོ: 1
#
# ཆེན་པོ་ལ: 1
#
# ལ་སོན: 1
#
# སོན་ཙནྡྲ: 1
#
# ཙནྡྲ་དེ་བ: 1
#
# དེ་བ་ཀོ་ས་ལ: 1
#
# ཀོ་ས་ལ་ཨ: 1
#
# ཨ་ཧོ: 1
#
# ཧོ་ཅེས: 1
#
# ཅེས་གསུངས: 1
#
# གསུངས་གོ: 1
#
# གོ་གཞན: 1
#
# གཞན་ཀྱང: 1
#
# ཀྱང་དྲི་མེད: 1
#
# དྲི་མེད་བཤེས་གཉེན: 1
#
# བཤེས་གཉེན་གྱི: 1
#
# གྱི་མན་ངག: 1
#
# མན་ངག་ལས: 1
#
# ལས་དུག: 1
#
# དུག་ལྔ: 1
#
# ལྔ་ཡེ་ཤེས: 1
#
# ཡེ་ཤེས་ལྔ: 1
#
# ལྔ་རུ: 1
#
# རུ་གསལ: 1
#
# གསལ་དེ་ལྟར: 1
#
# དེ་ལྟར་རྟོགས: 1
#
# རྟོགས་ན: 1
#
# ན་རིག: 1
#
# རིག་མཆོག: 1
#
# མཆོག་ཡིན: 1
#
# ཡིན་ཅེས: 1
#
# ཅེས་གོ: 1
#
# གོ་བདེ་བ: 1
#
# ཀྱི་དགོངས: 1
#
# དགོངས་བཅུད: 1
#
# བཅུད་དེ: 1
#
# LL07-GN13-srog-gi-'khor-lo.txt
# words
# གི: 10
#
# ལ: 8
#
# གིས: 4
#
# མཁའ: 3
#
# ནི: 3
#
# དེ: 3
#
# ཡེ་ཤེས: 3
#
# ལས: 3
#
# ཅེས: 3
#
# གོ: 3
#
# སྲོག: 2
#
# འཁོར་ལོ: 2
#
# དགོངས་པ: 2
#
# ཤ: 2
#
# མ: 2
#
# བཅོས: 2
#
# དག་པ: 2
#
# སེམས: 2
#
# ཀྱང: 2
#
# མེད: 2
#
# དཀྱིལ་འཁོར: 2
#
# རིག་པ: 2
#
# པ: 2
#
# ཀྱི: 2
#
# རང་བྱུང: 1
#
# ཀློང་རྡོལ: 1
#
# གླུ: 1
#
# བསམ་གཏན: 1
#
# ནྱ: 1
#
# གྲོ: 1
#
# དྷའི: 1
#
# དགོན་པ: 1
#
# སྲོད་ཡོལ: 1
#
# གྱི: 1
#
# ཤོག་ལྷེ: 1
#
# ༡༧༨: 1
#
# དུས: 1
#
# སུ: 1
#
# དྲང་སྲོང: 1
#
# བྷི: 1
#
# ཏི: 1
#
# འདི་སྐད: 1
#
# ལོ: 1
#
# གཟའ་སྐར: 1
#
# ཀུན: 1
#
# འཕྱོ་བ: 1
#
# གདོད: 1
#
# ནས: 1
#
# མི: 1
#
# བརྗོད: 1
#
# བྱང་ཆུབ: 1
#
# ལྟར: 1
#
# མཚན་མ: 1
#
# རྣམ་རྟོག: 1
#
# སྒྱུ་མ: 1
#
# ཅི: 1
#
# བསླད: 1
#
# རྣལ་འབྱོར: 1
#
# སེམས་ཉིད: 1
#
# དབྱིངས: 1
#
# འཕོ་འགྱུར: 1
#
# ཆོས་དབྱིངས: 1
#
# བརྡལ་བ: 1
#
# ཆེན་པོ: 1
#
# དུ་མ: 1
#
# བཏབ་པ: 1
#
# གསང: 1
#
# འོད: 1
#
# གསལ་བ: 1
#
# འཆར: 1
#
# ཤར་བ: 1
#
# ཉིད: 1
#
# དོན: 1
#
# ཡེངས: 1
#
# སངས་རྒྱས: 1
#
# རྣམས: 1
#
# འདི: 1
#
# རླུང: 1
#
# ཆེན: 1
#
# གྱིས: 1
#
# རྣམ་པར: 1
#
# རྟོག་པ: 1
#
# མུན་པ: 1
#
# གཡེངས: 1
#
# ཨ་ཀ: 1
#
# ཀོ་ལ: 1
#
# མ་དྷ: 1
#
# ཨ: 1
#
# ཧོ: 1
#
# གསུངས: 1
#
# གཞན: 1
#
# ཀློང་ཆེན: 1
#
# འཁྱིལ: 1
#
# བ: 1
#
# བྱ་བ: 1
#
# མན་ངག: 1
#
# ཐམས་ཅད: 1
#
# རྫོགས་པ: 1
#
# ལྷུན་གྲུབ: 1
#
# སྟེ: 1
#
# bigrams
# སྲོག་གི: 2
#
# གི་འཁོར་ལོ: 2
#
# འཁོར་ལོ་གི: 2
#
# རིག་པ་ཡེ་ཤེས: 2
#
# གི་དགོངས་པ: 1
#
# དགོངས་པ་རང་བྱུང: 1
#
# རང་བྱུང་ཀློང་རྡོལ: 1
#
# ཀློང་རྡོལ་གླུ: 1
#
# གླུ་གི: 1
#
# གི་བསམ་གཏན: 1
#
# བསམ་གཏན་ནྱ: 1
#
# ནྱ་གྲོ: 1
#
# གྲོ་དྷའི: 1
#
# དྷའི་དགོན་པ: 1
#
# དགོན་པ་ལ: 1
#
# ལ་སྲོད་ཡོལ: 1
#
# སྲོད་ཡོལ་གྱི: 1
#
# གྱི་ཤོག་ལྷེ: 1
#
# ཤོག་ལྷེ་༡༧༨: 1
#
# ༡༧༨་དུས: 1
#
# དུས་སུ: 1
#
# སུ་དྲང་སྲོང: 1
#
# དྲང་སྲོང་བྷི: 1
#
# བྷི་ཤ: 1
#
# ཤ་ཏི: 1
#
# ཏི་འདི་སྐད: 1
#
# འདི་སྐད་ལོ: 1
#
# ལོ་མ: 1
#
# མ་བཅོས: 1
#
# བཅོས་མཁའ: 1
#
# མཁའ་ལ: 1
#
# ལ་གཟའ་སྐར: 1
#
# གཟའ་སྐར་ཀུན: 1
#
# ཀུན་འཕྱོ་བ: 1
#
# འཕྱོ་བ་གིས: 1
#
# གིས་གདོད: 1
#
# གདོད་ནས: 1
#
# ནས་དག་པ: 1
#
# དག་པ་གིས: 1
#
# གིས་མཁའ: 1
#
# མཁའ་ནི: 1
#
# ནི་མི: 1
#
# མི་བརྗོད: 1
#
# བརྗོད་དེ: 1
#
# དེ་བྱང་ཆུབ: 1
#
# བྱང་ཆུབ་སེམས: 1
#
# སེམས་ནི: 1
#
# ནི་མཁའ: 1
#
# མཁའ་ལྟར: 1
#
# ལྟར་དག་པ: 1
#
# དག་པ་ལ: 1
#
# ལ་མཚན་མ: 1
#
# མཚན་མ་གི: 1
#
# གི་རྣམ་རྟོག: 1
#
# རྣམ་རྟོག་སྒྱུ་མ: 1
#
# སྒྱུ་མ་གིས: 1
#
# གིས་ཅི: 1
#
# ཅི་བསླད: 1
#
# བསླད་ཀྱང: 1
#
# ཀྱང་རྣལ་འབྱོར: 1
#
# རྣལ་འབྱོར་སེམས་ཉིད: 1
#
# སེམས་ཉིད་དབྱིངས: 1
#
# དབྱིངས་ལ: 1
#
# ལ་འཕོ་འགྱུར: 1
#
# འཕོ་འགྱུར་མེད: 1
#
# མེད་ཆོས་དབྱིངས: 1
#
# ཆོས་དབྱིངས་བརྡལ་བ: 1
#
# བརྡལ་བ་ཆེན་པོ: 1
#
# ཆེན་པོ་གི: 1
#
# གི་དཀྱིལ་འཁོར: 1
#
# དཀྱིལ་འཁོར་ལ: 1
#
# ལ་རིག་པ: 1
#
# ཡེ་ཤེས་དུ་མ: 1
#
# དུ་མ་གིས: 1
#
# གིས་བཏབ་པ: 1
#
# བཏབ་པ་ནི: 1
#
# ནི་གསང: 1
#
# གསང་པ: 1
#
# པ་གི: 1
#
# གི་འོད: 1
#
# འོད་ཀྱི: 1
#
# ཀྱི་དཀྱིལ་འཁོར: 1
#
# དཀྱིལ་འཁོར་གསལ་བ: 1
#
# གསལ་བ་ལ: 1
#
# ལ་འཆར: 1
#
# འཆར་ཤར་བ: 1
#
# ཤར་བ་ཉིད: 1
#
# ཉིད་ཀྱི: 1
#
# ཀྱི་དོན: 1
#
# དོན་དེ: 1
#
# དེ་མ: 1
#
# མ་ཡེངས: 1
#
# ཡེངས་ལས: 1
#
# ལས་སངས་རྒྱས: 1
#
# སངས་རྒྱས་རྣམས: 1
#
# རྣམས་ལ: 1
#
# ལ་དགོངས་པ: 1
#
# དགོངས་པ་འདི: 1
#
# འདི་ལས: 1
#
# ལས་མེད: 1
#
# LL08_GN4-thig-le-drug.txt
# words
# གི: 10
#
# ལ: 5
#
# གོ: 4
#
# ལས: 3
#
# ཆོས: 3
#
# རྣམ་པར: 3
#
# མ: 3
#
# གཞན: 3
#
# ཐིག་ལེ: 2
#
# དྲུག: 2
#
# པ: 2
#
# དགོངས་པ: 2
#
# ནམ་མཁའ: 2
#
# ན: 2
#
# དང: 2
#
# མེད: 2
#
# ཀྱི: 2
#
# ནས: 2
#
# བཅོས: 2
#
# བཙལ: 2
#
# དེ: 2
#
# ཀྱང: 2
#
# འདི: 2
#
# ཅེས: 2
#
# ཀློང་རྡོལ: 1
#
# གླུ: 1
#
# བསམ་གཏན: 1
#
# སྐྱ་རེངས: 1
#
# དང་པོ: 1
#
# ཤར: 1
#
# ཙམ: 1
#
# རྒྱ་མཚོ: 1
#
# གཏིང: 1
#
# རུམ: 1
#
# དུ: 1
#
# ཀླུ: 1
#
# རྒྱལ་པོས: 1
#
# འདི་སྐད: 1
#
# མཐའ: 1
#
# དབུས: 1
#
# ལྟ་བུ: 1
#
# སྨ: 1
#
# བསམ་ཡུལ: 1
#
# འདས་པ: 1
#
# ཤོག་ལྷེ: 1
#
# ༡༧༣: 1
#
# སྐུ: 1
#
# སྲིད: 1
#
# འབྱུང: 1
#
# སྐྱེ་འགྲོ: 1
#
# དག: 1
#
# བྱས: 1
#
# དག་པ: 1
#
# གིས: 1
#
# ཀུན་གཞི: 1
#
# བྱང་ཆུབ: 1
#
# སེམས: 1
#
# མཉམ་པ: 1
#
# གཞག: 1
#
# བསྒོམ་པ: 1
#
# མཆོག: 1
#
# རིག་པ: 1
#
# དབྱིངས: 1
#
# སུ་མ: 1
#
# གྲོལ་བ: 1
#
# ལམ་མཆོག: 1
#
# དུས་གསུམ: 1
#
# བདེ་བ: 1
#
# གཤེགས་པ: 1
#
# ཉིད: 1
#
# དཔག: 1
#
# ཅིང: 1
#
# གཞལ: 1
#
# མེད་པར: 1
#
# མཇལ: 1
#
# བདག: 1
#
# ཕུང་པོ: 1
#
# གདོས་བཅས: 1
#
# བསྙིལ: 1
#
# ཀུན་བཟང: 1
#
# དབྱེ་བ: 1
#
# མེད་པ: 1
#
# ས་ལ: 1
#
# མཆི: 1
#
# གྷི: 1
#
# ཏ་མ: 1
#
# ཀོ་ལ: 1
#
# ས: 1
#
# ཨ: 1
#
# ཧོ: 1
#
# གསུངས: 1
#
# ཁོལ: 1
#
# ལུང་བསྟན: 1
#
# རྣམས: 1
#
# ཡེ་ནས: 1
#
# སངས་རྒྱས: 1
#
# པས: 1
#
# རེ: 1
# གཉིས: 1
#
# འབྲལ: 1
#
# bigrams
# ཐིག་ལེ་དྲུག: 2
#
# དྲུག་པ: 2
#
# པ་གི: 2
#
# གི་དགོངས་པ: 2
#
# ཆོས་ཀྱི: 2
#
# དགོངས་པ་ནམ་མཁའ: 1
#
# ནམ་མཁའ་ཀློང་རྡོལ: 1
#
# ཀློང་རྡོལ་གླུ: 1
#
# གླུ་གི: 1
#
# གི་བསམ་གཏན: 1
#
# བསམ་གཏན་སྐྱ་རེངས: 1
#
# སྐྱ་རེངས་དང་པོ: 1
#
# དང་པོ་ཤར: 1
#
# ཤར་ཙམ: 1
#
# ཙམ་ན: 1
#
# ན་རྒྱ་མཚོ: 1
#
# རྒྱ་མཚོ་གི: 1
#
# གི་གཏིང: 1
#
# གཏིང་རུམ: 1
#
# རུམ་དུ: 1
#
# དུ་ཀླུ: 1
#
# ཀླུ་གི: 1
#
# གི་རྒྱལ་པོས: 1
#
# རྒྱལ་པོས་འདི་སྐད: 1
#
# འདི་སྐད་གོ: 1
#
# གོ་མཐའ: 1
#
# མཐའ་དང: 1
#
# དང་དབུས: 1
#
# དབུས་མེད: 1
#
# མེད་ནམ་མཁའ: 1
#
# ནམ་མཁའ་ལྟ་བུ: 1
#
# ལྟ་བུ་ལ: 1
#
# ལ་སྨ: 1
#
# སྨ་བསམ་ཡུལ: 1
#
# བསམ་ཡུལ་ལས: 1
#
# ལས་འདས་པ: 1
#
# འདས་པ་ཤོག་ལྷེ: 1
#
# ཤོག་ལྷེ་༡༧༣: 1
#
# ༡༧༣་ཆོས: 1
#
# ཀྱི་སྐུ: 1
#
# སྐུ་སྲིད: 1
#
# སྲིད་འབྱུང: 1
#
# འབྱུང་སྐྱེ་འགྲོ: 1
#
# སྐྱེ་འགྲོ་རྣམ་པར: 1
#
# རྣམ་པར་དག: 1
#
# དག་བྱས: 1
#
# བྱས་ནས: 1
#
# ནས་མ: 1
#
# མ་བཅོས: 1
#
# བཅོས་རྣམ་པར: 1
#
# རྣམ་པར་དག་པ: 1
#
# དག་པ་གིས: 1
#
# གིས་ཀུན་གཞི: 1
#
# ཀུན་གཞི་བྱང་ཆུབ: 1
#
# བྱང་ཆུབ་སེམས: 1
#
# སེམས་མ: 1
#
# མ་བཙལ: 1
#
# བཙལ་མཉམ་པ: 1
#
# མཉམ་པ་ལ: 1
#
# ལ་གཞག: 1
#
# གཞག་ན: 1
#
# ན་བསྒོམ་པ: 1
#
# བསྒོམ་པ་གི: 1
#
# གི་མཆོག: 1
#
# མཆོག་རིག་པ: 1
#
# རིག་པ་ཆོས: 1
#
# ཀྱི་དབྱིངས: 1
#
# དབྱིངས་སུ་མ: 1
#
# སུ་མ་བཅོས: 1
#
# བཅོས་ལ: 1
#
# ལ་རྣམ་པར: 1
#
# རྣམ་པར་གྲོལ་བ: 1
#
# གྲོལ་བ་གི: 1
#
# གི་ལམ་མཆོག: 1
#
# ལམ་མཆོག་གཞན: 1
#
# གཞན་མེད: 1
#
# མེད་དེ: 1
#
# དེ་དུས་གསུམ: 1
#
# དུས་གསུམ་བདེ་བ: 1
#
# བདེ་བ་ལ: 1
#
# ལ་གཤེགས་པ: 1
#
# གཤེགས་པ་གི: 1
#
# དགོངས་པ་ཉིད: 1
#
# ཉིད་དཔག: 1
#
# དཔག་ཅིང: 1
#
# ཅིང་གཞལ: 1
#
# གཞལ་ཀྱང: 1
#
# ཀྱང་འདི: 1
#
# འདི་ལས: 1
#
# ལས་མེད་པར: 1
#
# མེད་པར་མཇལ: 1
#
# མཇལ་བདག: 1
#
# བདག་གི: 1
#
# གི་ཕུང་པོ: 1
#
# ཕུང་པོ་གདོས་བཅས: 1
#
# གདོས་བཅས་འདི: 1
#
# འདི་བསྙིལ: 1
#
# བསྙིལ་ནས: 1
#
# ནས་ཀུན་བཟང: 1
#
# ཀུན་བཟང་དབྱེ་བ: 1
#
# LL09_GN10-spyi-gcod.txt
# words
# གི: 7
#
# ལས: 4
#
# ཀྱི: 3
#
# ལ: 3
#
# ན: 3
#
# གོ: 3
#
# སྤྱི: 2
#
# གཅོད: 2
#
# ཕྱི་མ: 2
#
# ཀུན་གཞི: 2
#
# ནས: 2
#
# ཤར: 2
#
# ཤར་བ: 2
#
# ནུབ་པ: 2
#
# མ: 2
#
# བཅོས: 2
#
# པ: 2
#
# ཆོས་ཉིད: 2
#
# དུ: 2
#
# ཀྱང: 2
#
# རིག་པ: 2
#
# ཡེ་ཤེས: 2
#
# མྱོང: 2
#
# ཅེས: 2
#
# དགོངས་པ: 1
#
# གསང་བ: 1
#
# ཀློང་རྡོལ: 1
#
# གླུ: 1
#
# བསམ་གཏན: 1
#
# ཤིང: 1
#
# ནྱ: 1
#
# གྲོ: 1
#
# དྷཱའི: 1
#
# རྩ་བ: 1
#
# སྲོད: 1
#
# ཐུན: 1
#
# ལ་འཇམ: 1
#
# དཔལ: 1
#
# བཤེས་གཉེན: 1
#
# འདི་སྐད: 1
#
# ལོ: 1
#
# ཡངས་པ: 1
#
# དབྱེ་ཐང: 1
#
# དག་པ: 1
#
# ཀློང: 1
#
# ཉི་མ: 1
#
# དུས: 1
#
# མེད: 1
#
# གསལ: 1
#
# སངས་རྒྱས: 1
#
# སྔ་ཕྱི: 1
#
# གསུམ: 1
#
# གང: 1
#
# བཙལ: 1
#
# རྙེད: 1
#
# ཐབས་མེད: 1
#
# ཡངས: 1
#
# བ: 1
#
# ཅི: 1
#
# མེད་པ: 1
#
# སྒོམ: 1
#
# འདི: 1
#
# མེད་པར: 1
#
# འཁུམས: 1
#
# སེམས: 1
#
# བདུད་རྩི: 1
#
# བལྟ: 1
#
# ལྟོས: 1
#
# པདྨ: 1
#
# ཀོ་ལ: 1
#
# ཤ: 1
#
# ཨ: 1
#
# ཧོ: 1
#
# གསུངས: 1
#
# གཞན: 1
#
# ལུང: 1
#
# ཉམས: 1
#
# སུ: 1
#
# མྱོང་བ: 1
#
# བདེ་ཆེན: 1
#
# ནི: 1
#
# ཐམས་ཅད: 1
#
# གསལ་བ: 1
#
# ཞེ: 1
#
# ཕུག: 1
#
# ཡིན: 1
#
# རྫོགས་པ: 1
#
# དགོངས: 1
#
# བཅུད: 1
#
# དེ: 1
#
# བཅུ: 1
#
# bigrams
# སྤྱི་གཅོད: 2
#
# གཅོད་ཀྱི: 2
#
# མ་བཅོས: 2
#
# ཀྱི་དགོངས་པ: 1
#
# དགོངས་པ་གསང་བ: 1
#
# གསང་བ་ཀློང་རྡོལ: 1
#
# ཀློང་རྡོལ་གླུ: 1
#
# གླུ་གི: 1
#
# གི་བསམ་གཏན: 1
#
# བསམ་གཏན་ཤིང: 1
#
# ཤིང་ནྱ: 1
#
# ནྱ་གྲོ: 1
#
# གྲོ་དྷཱའི: 1
#
# དྷཱའི་རྩ་བ: 1
#
# རྩ་བ་ལ: 1
#
# ལ་སྲོད: 1
#
# སྲོད་ཐུན: 1
#
# ཐུན་ལ་འཇམ: 1
#
# ལ་འཇམ་དཔལ: 1
#
# དཔལ་བཤེས་གཉེན: 1
#
# བཤེས་གཉེན་ཕྱི་མ: 1
#
# ཕྱི་མ་འདི་སྐད: 1
#
# འདི་སྐད་ལོ: 1
#
# ལོ་ཀུན་གཞི: 1
#
# ཀུན་གཞི་ཡངས་པ: 1
#
# ཡངས་པ་གི: 1
#
# གི་དབྱེ་ཐང: 1
#
# དབྱེ་ཐང་ལ: 1
#
# ལ་དག་པ: 1
#
# དག་པ་གི: 1
#
# གི་ཀློང: 1
#
# ཀློང་ནས: 1
#
# ནས་ཉི་མ: 1
#
# ཉི་མ་ཤར: 1
#
# ཤར་ཤར་བ: 1
#
# ཤར་བ་གི: 1
#
# གི་དུས: 1
#
# དུས་ན: 1
#
# ན་ནུབ་པ: 1
#
# ནུབ་པ་མེད: 1
#
# མེད་ཤར: 1
#
# ཤར་ནས: 1
#
# ནས་མ: 1
#
# བཅོས་གསལ: 1
#
# གསལ་པ: 1
#
# པ་ལས: 1
#
# ལས་སངས་རྒྱས: 1
#
# སངས་རྒྱས་ཆོས་ཉིད: 1
#
# ཆོས་ཉིད་སྔ་ཕྱི: 1
#
# སྔ་ཕྱི་གསུམ: 1
#
# གསུམ་གང: 1
#
# གང་དུ: 1
#
# དུ་བཙལ: 1
#
# བཙལ་ཀྱང: 1
#
# ཀྱང་རྙེད: 1
#
# རྙེད་ཐབས་མེད: 1
#
# ཐབས་མེད་ཀུན་གཞི: 1
#
# ཀུན་གཞི་ཡངས: 1
#
# ཡངས་བ: 1
#
# བ་གི: 1
#
# གི་ཆོས་ཉིད: 1
#
# ཆོས་ཉིད་ལ: 1
#
# ལ་རིག་པ: 1
#
# རིག་པ་ཡེ་ཤེས: 1
#
# ཡེ་ཤེས་ཅི: 1
#
# ཅི་ཤར་བ: 1
#
# ཤར་བ་མ: 1
#
# བཅོས་ནུབ་པ: 1
#
# ནུབ་པ་མེད་པ: 1
#
# མེད་པ་ལས: 1
#
# ལས་སྒོམ: 1
#
# སྒོམ་དུ: 1
#
# དུ་འདི: 1
#
# འདི་ལས: 1
#
# ལས་མེད་པར: 1
#
# མེད་པར་འཁུམས: 1
#
# འཁུམས་མྱོང: 1
#
# མྱོང་ན: 1
#
# ན་སེམས: 1
#
# སེམས་ཀྱི: 1
#
# ཀྱི་བདུད་རྩི: 1
#
# བདུད་རྩི་མྱོང: 1
#
# མྱོང་བལྟ: 1
#
# བལྟ་ན: 1
#
# ན་རིག་པ: 1
#
# རིག་པ་གི: 1
#
# གི་ཡེ་ཤེས: 1
#
# ཡེ་ཤེས་ལྟོས: 1
#
# ལྟོས་པདྨ: 1
#
# པདྨ་ཀོ་ལ: 1
#
# ཀོ་ལ་ཤ: 1
#
# ཤ་ཨ: 1
#
# ཨ་ཧོ: 1
#
# ཧོ་ཅེས: 1
#
# ཅེས་གསུངས: 1
#
# གསུངས་གོ: 1
#
# གོ་གཞན: 1
#
# གཞན་ཀྱང: 1
#
# ཀྱང་ལུང: 1
#
# ལུང་ཕྱི་མ: 1
#
# LL10_GN8-yid-bzhin-nor-bu.txt
# words
# ལ: 7
#
# གི: 6
#
# མེད: 4
#
# གོ: 4
#
# བྱང་ཆུབ: 3
#
# སེམས: 3
#
# ཀྱི: 3
#
# རང་བཞིན: 3
#
# བདག: 3
#
# གིས: 3
#
# ཡིད་བཞིན: 2
#
# ནོར་བུ: 2
#
# པ: 2
#
# ཤར: 2
#
# སུ: 2
#
# བཅོས: 2
#
# དུ: 2
#
# མི: 2
#
# ཏེ: 2
#
# ཀྱང: 2
#
# དབྱིངས: 2
#
# མ: 2
#
# ལས: 2
#
# འདི: 2
#
# ཅེས: 2
#
# དེ: 2
#
# དགོངས་པ: 1
#
# དངོས་གྲུབ: 1
#
# ཀློང་རྡོལ: 1
#
# གླུ: 1
#
# བསམ་གཏན: 1
#
# དམར་རེངས: 1
#
# གཉིས: 1
#
# ཙམ: 1
#
# ན: 1
#
# གནོད་སྦྱིན: 1
#
# མོ: 1
#
# འདི་སྐད: 1
#
# ལོ: 1
#
# ཆོས་ཉིད: 1
#
# བླང: 1
#
# ཞིང: 1
#
# བལྟ: 1
#
# ལྟ་བ: 1
#
# གཟུགས: 1
#
# ཡོངས: 1
#
# སྣང: 1
#
# ཅིས་ཀྱང: 1
#
# བཅད: 1
#
# ཅི་ཡང: 1
#
# གནས: 1
#
# རིག་པ: 1
#
# ཡིན: 1
#
# ཇི་ལྟ: 1
#
# ལྷད: 1
#
# འགྱུར་བ: 1
#
# ཉིད: 1
#
# རིག་པས: 1
#
# བཙལ: 1
#
# སེམས་ཉིད: 1
#
# མཁའ: 1
#
# ལྟར: 1
#
# དག་པ: 1
#
# དངོས: 1
#
# མེད་པ: 1
#
# སྒོམ་པ: 1
#
# མེད་པར: 1
#
# རྟོགས: 1
#
# ཕུང་པོ: 1
#
# གདོས་བཅས: 1
#
# བསྙིལ: 1
#
# ནས: 1
#
# ཀུན་བཟང: 1
#
# ཐུགས: 1
#
# འོད་ཟེར: 1
#
# གྷི: 1
#
# ཏ་མ: 1
#
# ཀོ་ལ: 1
#
# ས: 1
#
# ཨ: 1
#
# ཧོ: 1
#
# གསུངས: 1
#
# གཞན: 1
#
# རཱ་ཧུ་ལ: 1
#
# ཆེན་པོ: 1
#
# འཁོར་བ: 1
#
# སྤངས: 1
#
# ངང: 1
#
# གསལ་བ: 1
#
# ཡེ་ཤེས: 1
#
# ཉི་མ: 1
#
# ཡི: 1
#
# ཚུལ: 1
#
# འཆར: 1
#
# དགོངས: 1
#
# བཅུད: 1
#
# བརྒྱད: 1
#
# bigrams
# ཡིད་བཞིན་ནོར་བུ: 2
#
# ནོར་བུ་གི: 2
#
# བྱང་ཆུབ་སེམས: 2
#
# སེམས་ཀྱི: 2
#
# ཀྱི་རང་བཞིན: 2
#
# གི་དགོངས་པ: 1
#
# དགོངས་པ་དངོས་གྲུབ: 1
#
# དངོས་གྲུབ་ཀློང་རྡོལ: 1
#
# ཀློང་རྡོལ་གླུ: 1
#
# གླུ་གི: 1
#
# གི་བསམ་གཏན: 1
#
# བསམ་གཏན་དམར་རེངས: 1
#
# དམར་རེངས་གཉིས: 1
#
# གཉིས་པ: 1
#
# པ་ཤར: 1
#
# ཤར་ཙམ: 1
#
# ཙམ་ན: 1
#
# ན་གནོད་སྦྱིན: 1
#
# གནོད་སྦྱིན་མོ: 1
#
# མོ་བྱང་ཆུབ: 1
#
# བྱང་ཆུབ་འདི་སྐད: 1
#
# འདི་སྐད་ལོ: 1
#
# ལོ་ཆོས་ཉིད: 1
#
# ཆོས་ཉིད་བྱང་ཆུབ: 1
#
# སེམས་ལ: 1
#
# ལ་བླང: 1
#
# བླང་ཞིང: 1
#
# ཞིང་བལྟ: 1
#
# བལྟ་མེད: 1
#
# མེད་གོ: 1
#
# གོ་ལྟ་བ: 1
#
# ལྟ་བ་གི: 1
#
# གི་གཟུགས: 1
#
# གཟུགས་སུ: 1
#
# སུ་ཡོངས: 1
#
# ཡོངས་ལ: 1
#
# ལ་སྣང: 1
#
# སྣང་ཅིས་ཀྱང: 1
#
# ཅིས་ཀྱང་བཅོས: 1
#
# བཅོས་སུ: 1
#
# སུ་མེད: 1
#
# མེད་ལ: 1
#
# ལ་བཅད: 1
#
# བཅད་དུ: 1
#
# དུ་མེད: 1
#
# མེད་སེམས: 1
#
# རང་བཞིན་ཅི་ཡང: 1
#
# ཅི་ཡང་མི: 1
#
# མི་གནས: 1
#
# གནས་ཏེ: 1
#
# ཏེ་རིག་པ: 1
#
# རིག་པ་བྱང་ཆུབ: 1
#
# རང་བཞིན་ཡིན: 1
#
# ཡིན་ཇི་ལྟ: 1
#
# ཇི་ལྟ་ལ: 1
#
# ལ་ལྷད: 1
#
# ལྷད་ཀྱང: 1
#
# ཀྱང་དབྱིངས: 1
#
# དབྱིངས་ལ: 1
#
# ལ་འགྱུར་བ: 1
#
# འགྱུར་བ་མེད: 1
#
# མེད་དབྱིངས: 1
#
# དབྱིངས་ཉིད: 1
#
# ཉིད་རིག་པས: 1
#
# རིག་པས་མི: 1
#
# མི་བཙལ: 1
#
# བཙལ་ཏེ: 1
#
# ཏེ་སེམས་ཉིད: 1
#
# སེམས་ཉིད་མཁའ: 1
#
# མཁའ་ལྟར: 1
#
# ལྟར་དག་པ: 1
#
# དག་པ་གི: 1
#
# གི་དངོས: 1
#
# དངོས་མ: 1
#
# མ་བཅོས: 1
#
# བཅོས་རང་བཞིན: 1
#
# རང་བཞིན་མེད་པ: 1
#
# མེད་པ་ལས: 1
#
# ལས་སྒོམ་པ: 1
#
# སྒོམ་པ་འདི: 1
#
# འདི་ལས: 1
#
# ལས་མེད་པར: 1
#
# མེད་པར་བདག: 1
#
# བདག་གིས: 1
#
# གིས་རྟོགས: 1
#
# རྟོགས་བདག: 1
#
# བདག་གི: 1
#
# གི་ཕུང་པོ: 1
#
# ཕུང་པོ་གདོས་བཅས: 1
#
# གདོས་བཅས་འདི: 1
#
# འདི་བསྙིལ: 1
#
# བསྙིལ་ནས: 1
#
# ནས་ཀུན་བཟང: 1
#
# ཀུན་བཟང་ཐུགས: 1
#
# ཐུགས་ཀྱི: 1
#
# ཀྱི་འོད་ཟེར: 1
#
# འོད་ཟེར་བདག: 1
#
# བདག་ལ: 1
#
# ལ་ཤར: 1
#
# ཤར་གྷི: 1
#
# LL11-GN14-kun-'dus.txt
# words
# གི: 7
#
# ལ: 7
#
# ཀུན: 4
#
# ཨ: 4
#
# བྱང་ཆུབ: 4
#
# ལས: 4
#
# ཉིད: 3
#
# ཏེ: 3
#
# སེམས: 3
#
# པ: 3
#
# གོ: 3
#
# རིན་ཆེན: 2
#
# འདུས: 2
#
# ཀྱི: 2
#
# དགོངས་པ: 2
#
# མེད: 2
#
# སངས་རྒྱས: 2
#
# གྱི: 2
#
# ཡིན: 2
#
# ཨ་ཡི: 2
#
# ཡེ་ནས: 2
#
# ཀྱང: 2
#
# མེད་པ: 2
#
# མ: 2
#
# ཅེས: 2
#
# སྐྱེ: 1
#
# ཀློང་རྡོལ: 1
#
# གླུ: 1
#
# བསམ་གཏན: 1
#
# རྒྱས་པ: 1
#
# དགོན་གནས: 1
#
# སུ: 1
#
# ནམ་སྨད: 1
#
# སྲས་མོ: 1
#
# གོ་མ: 1
#
# དེ་བཱི: 1
#
# འདི་སྐད: 1
#
# ལོ: 1
#
# ཐུགས: 1
#
# ཡི་གེ: 1
#
# རང་བཞིན: 1
#
# དངོས་པོ: 1
#
# བདེ་གཤེགས: 1
#
# འབྱུང་གནས: 1
#
# བདེན: 1
#
# གཉིས: 1
#
# ལ་སོགས: 1
#
# སྣང་སྲིད: 1
#
# ཅི: 1
#
# སྣང: 1
#
# དངོས་གཞི: 1
#
# འཕོ་འགྱུར: 1
#
# འདུ: 1
#
# འབྲལ: 1
#
# བརྟགས: 1
#
# ནས: 1
#
# སྨྲ: 1
#
# བསམ་ཡུལ: 1
#
# འདས་པ: 1
#
# དབྱིངས: 1
#
# ལྟར: 1
#
# སྐྱེ་བ: 1
#
# བཅོས་མ: 1
#
# ཡེངས: 1
#
# མཉམ་པ: 1
#
# གཞག: 1
#
# བདག: 1
#
# འདི: 1
#
# མེད་པར: 1
#
# མཇལ: 1
#
# ཆོས་ཉིད: 1
#
# དབྱེ་ཐང: 1
#
# ཆེན་པོ: 1
#
# རིག་པ: 1
#
# ཡེ་ཤེས: 1
#
# རྟ་ཕོ: 1
#
# རྒྱུག: 1
#
# ཀ་པ: 1
#
# ཀ: 1
#
# ཤ: 1
#
# ཧོ: 1
#
# གསུངས: 1
#
# གཞན: 1
#
# བདུད་རྩི: 1
#
# ཤོག་ལྷེ: 1
#
# ༡༧༩: 1
#
# འཁྱིལ་པ: 1
#
# ཐམས་ཅད: 1
#
# དུ: 1
#
# ཡིན་པ: 1
#
# བདག་ཅག: 1
#
# རྣམས: 1
#
# ཀྱིས: 1
#
# རྟོགས: 1
#
# དགོངས: 1
#
# བཅུད: 1
#
# དེ: 1
#
# བཅུ་བཞི: 1
#
# bigrams
# བྱང་ཆུབ་སེམས: 3
#
# གི་བྱང་ཆུབ: 3
#
# རིན་ཆེན་ཀུན: 2
#
# ཀུན་འདུས: 2
#
# འདུས་ཀྱི: 2
#
# ཀུན་གྱི: 2
#
# ཨ་ཡིན: 2
#
# ཡིན་ཏེ: 2
#
# མེད་པ་གི: 2
#
# ཀྱི་དགོངས་པ: 1
#
# དགོངས་པ་སྐྱེ: 1
#
# སྐྱེ་མེད: 1
#
# མེད་ཀློང་རྡོལ: 1
#
# ཀློང་རྡོལ་གླུ: 1
#
# གླུ་གི: 1
#
# གི་བསམ་གཏན: 1
#
# བསམ་གཏན་རྒྱས་པ: 1
#
# རྒྱས་པ་གི: 1
#
# གི་དགོན་གནས: 1
#
# དགོན་གནས་སུ: 1
#
# སུ་ནམ་སྨད: 1
#
# ནམ་སྨད་ལ: 1
#
# ལ་སྲས་མོ: 1
#
# སྲས་མོ་གོ་མ: 1
#
# གོ་མ་དེ་བཱི: 1
#
# དེ་བཱི་འདི་སྐད: 1
#
# འདི་སྐད་ལོ: 1
#
# ལོ་སངས་རྒྱས: 1
#
# སངས་རྒྱས་ཀུན: 1
#
# གྱི་ཐུགས: 1
#
# ཐུགས་ཉིད: 1
#
# ཉིད་ཡི་གེ: 1
#
# ཡི་གེ་ཨ: 1
#
# ཏེ་ཨ་ཡི: 1
#
# ཨ་ཡི་རང་བཞིན: 1
#
# རང་བཞིན་ཡེ་ནས: 1
#
# ཡེ་ནས་དངོས་པོ: 1
#
# དངོས་པོ་མེད: 1
#
# མེད་བདེ་གཤེགས: 1
#
# བདེ་གཤེགས་ཀུན: 1
#
# གྱི་འབྱུང་གནས: 1
#
# འབྱུང་གནས་ཨ: 1
#
# ཏེ་བདེན: 1
#
# བདེན་གཉིས: 1
#
# གཉིས་ལ་སོགས: 1
#
# ལ་སོགས་སྣང་སྲིད: 1
#
# སྣང་སྲིད་ཅི: 1
#
# ཅི་ལ: 1
#
# ལ་ཀྱང: 1
#
# ཀྱང་སྣང: 1
#
# སྣང་ཨ་ཡི: 1
#
# ཨ་ཡི་དངོས་གཞི: 1
#
# དངོས་གཞི་ཡེ་ནས: 1
#
# ཡེ་ནས་བྱང་ཆུབ: 1
#
# སེམས་འཕོ་འགྱུར: 1
#
# འཕོ་འགྱུར་འདུ: 1
#
# འདུ་འབྲལ: 1
#
# འབྲལ་བརྟགས: 1
#
# བརྟགས་ནས: 1
#
# ནས་སངས་རྒྱས: 1
#
# སངས་རྒྱས་ཏེ: 1
#
# ཏེ་སྨྲ: 1
#
# སྨྲ་བསམ་ཡུལ: 1
#
# བསམ་ཡུལ་ལས: 1
#
# ལས་འདས་པ: 1
#
# འདས་པ་གི: 1
#
# བྱང་ཆུབ་དབྱིངས: 1
#
# དབྱིངས་ཉིད: 1
#
# ཉིད་ལ: 1
#
# ལ་ཨ: 1
#
# ཨ་ལྟར: 1
#
# ལྟར་སྐྱེ་བ: 1
#
# སྐྱེ་བ་མེད་པ: 1
#
# སེམས་མ: 1
#
# མ་བཅོས་མ: 1
#
# བཅོས་མ་ཡེངས: 1
#
# ཡེངས་མཉམ་པ: 1
#
# མཉམ་པ་ལ: 1
#
# ལ་གཞག: 1
#
# གཞག་པ: 1
#
# པ་ལས: 1
#
# ལས་བདག: 1
#
# བདག་གི: 1
#
# གི་དགོངས་པ: 1
#
# དགོངས་པ་འདི: 1
#
# འདི་ལས: 1
#
# ལས་མེད་པར: 1
#
# མེད་པར་མཇལ: 1
#
# མཇལ་ཆོས་ཉིད: 1
#
# ཆོས་ཉིད་དབྱེ་ཐང: 1
#
# དབྱེ་ཐང་ཆེན་པོ: 1
#
# ཆེན་པོ་ལ: 1
#
# ལ་རིག་པ: 1
#
# རིག་པ་གི: 1
#
# གི་ཡེ་ཤེས: 1
#
# ཡེ་ཤེས་རྟ་ཕོ: 1
#
# རྟ་ཕོ་རྒྱུག: 1
#
# རྒྱུག་ཀ་པ: 1
#
# ཀ་པ་ལ: 1
#
# ལ་ཀ: 1
#
# LL12-GN18-rje-btsan-dam-pa.txt
# words
# གི: 5
#
# ལ: 5
#
# གིས: 4
#
# མ: 3
#
# དེ: 3
#
# གོ: 3
#
# དམ་པ: 2
#
# སུ: 2
#
# བཅོས: 2
#
# པ: 2
#
# ངང: 2
#
# བསླད: 2
#
# རྣམ་རྟོག: 2
#
# ལས: 2
#
# ན: 2
#
# མེད་པར: 2
#
# ཅེས: 2
#
# ཀྱང: 2
#
# རྗེ་བཙུན: 1
#
# དགོངས་པ: 1
#
# ཤེས་རབ: 1
#
# ཀློང་རྡོལ: 1
#
# གླུ: 1
#
# བསམ་གཏན: 1
#
# དབེན་པ: 1
#
# ཆེན་པོ: 1
#
# གནས: 1
#
# བུདྡྷ: 1
#
# གུཔྟ: 1
#
# འདི་སྐད: 1
#
# ལོ: 1
#
# ཆོས: 1
#
# རྣམས: 1
#
# ཐམས་ཅད: 1
#
# ཀུན: 1
#
# ཏུ: 1
#
# བཟང་པོ: 1
#
# གསལ: 1
#
# འགྱུར: 1
#
# མེད་པ: 1
#
# བྱང་སེམས: 1
#
# མཚན་མ: 1
#
# རྣམ་པར: 1
#
# རྟོག་པ: 1
#
# རང་བྱུང: 1
#
# རང: 1
#
# ཞི: 1
#
# གནས་པ: 1
#
# སྒོམ་པ: 1
#
# འདི: 1
#
# གུད: 1
#
# འཁུམས: 1
#
# སེམས: 1
#
# ཀྱི: 1
#
# མེ་ལོང: 1
#
# བལྟས: 1
#
# དྲི་མ: 1
#
# གོས: 1
#
# ཏ: 1
#
# རེ: 1
#
# པྲཛྙཱ: 1
#
# ཀོ་ས་ལ: 1
#
# ཨ: 1
#
# ཧོ: 1
#
# གསུངས: 1
#
# གཞན: 1
#
# སྒོམ: 1
#
# ལུང: 1
#
# ཆེན: 1
#
# མོ་ལ: 1
#
# ཀ: 1
#
# ནས: 1
#
# དག་པ: 1
#
# གཉིས: 1
#
# འཛིན་པ: 1
#
# ཡེ: 1
#
# མེད: 1
#
# རྗེ་བཙན: 1
#
# དགོངས: 1
#
# བཅུད: 1
#
# བཅོ་བརྒྱད: 1
#
# bigrams
# དམ་པ་གི: 2
#
# རྗེ་བཙུན་དམ་པ: 1
#
# གི་དགོངས་པ: 1
#
# དགོངས་པ་ཤེས་རབ: 1
#
# ཤེས་རབ་ཀློང་རྡོལ: 1
#
# ཀློང་རྡོལ་གླུ: 1
#
# གླུ་གི: 1
#
# གི་བསམ་གཏན: 1
#
# བསམ་གཏན་དབེན་པ: 1
#
# དབེན་པ་ཆེན་པོ: 1
#
# ཆེན་པོ་གི: 1
#
# གི་གནས: 1
#
# གནས་སུ: 1
#
# སུ་བུདྡྷ: 1
#
# བུདྡྷ་གུཔྟ: 1
#
# གུཔྟ་འདི་སྐད: 1
#
# འདི་སྐད་ལོ: 1
#
# ལོ་ཆོས: 1
#
# ཆོས་རྣམས: 1
#
# རྣམས་ཐམས་ཅད: 1
#
# ཐམས་ཅད་མ: 1
#
# མ་བཅོས: 1
#
# བཅོས་ཀུན: 1
#
# ཀུན་ཏུ: 1
#
# ཏུ་བཟང་པོ: 1
#
# བཟང་པོ་ལ: 1
#
# ལ་གསལ: 1
#
# གསལ་ལ: 1
#
# ལ་འགྱུར: 1
#
# འགྱུར་པ: 1
#
# པ་མེད་པ: 1
#
# མེད་པ་བྱང་སེམས: 1
#
# བྱང་སེམས་ངང: 1
#
# ངང་དེ: 1
#
# དེ་ལ: 1
#
# ལ་མཚན་མ: 1
#
# མཚན་མ་གི: 1
#
# གི་རྣམ་པར: 1
#
# རྣམ་པར་རྟོག་པ: 1
#
# རྟོག་པ་གིས: 1
#
# གིས་མ: 1
#
# མ་བསླད: 1
#
# བསླད་དེ: 1
#
# དེ་རྣམ་རྟོག: 1
#
# རྣམ་རྟོག་རང་བྱུང: 1
#
# རང་བྱུང་རང: 1
#
# རང་ཞི: 1
#
# ཞི་ལ: 1
#
# ལ་གནས་པ: 1
#
# གནས་པ་ལས: 1
#
# ལས་སྒོམ་པ: 1
#
# སྒོམ་པ་འདི: 1
#
# འདི་ལས: 1
#
# ལས་གུད: 1
#
# གུད་ན: 1
#
# ན་མེད་པར: 1
#
# མེད་པར་འཁུམས: 1
#
# འཁུམས་སེམས: 1
#
# སེམས་ཀྱི: 1
#
# ཀྱི་མེ་ལོང: 1
#
# མེ་ལོང་མ: 1
#
# མ་བལྟས: 1
#
# བལྟས་ན: 1
#
# ན་རྣམ་རྟོག: 1
#
# རྣམ་རྟོག་དྲི་མ: 1
#
# དྲི་མ་གིས: 1
#
# གིས་གོས: 1
#
# གོས་ཏ: 1
#
# ཏ་རེ: 1
#
# རེ་པྲཛྙཱ: 1
#
# པྲཛྙཱ་ཀོ་ས་ལ: 1
#
# ཀོ་ས་ལ་ཨ: 1
#
# ཨ་ཧོ: 1
#
# ཧོ་ཅེས: 1
#
# ཅེས་གསུངས: 1
#
# གསུངས་གོ: 1
#
# གོ་གཞན: 1
#
# གཞན་ཀྱང: 1
#
# ཀྱང་སྒོམ: 1
#
# སྒོམ་ལུང: 1
#
# ལུང་ཆེན: 1
#
# ཆེན་མོ་ལ: 1
#
# མོ་ལ་གིས: 1
#
# གིས་བཅོས: 1
#
# བཅོས་བསླད: 1
#
# བསླད་མེད་པར: 1
#
# མེད་པར་ཀ: 1
#
# ཀ་ནས: 1
#
# ནས་དག་པ: 1
#
# དག་པ་ལ: 1
#
# ལ་གཉིས: 1
#
# གཉིས་སུ: 1
#
# སུ་འཛིན་པ: 1
#
# འཛིན་པ་ཀྱང: 1
#
# ཀྱང་ཡེ: 1
#
# ཡེ་ངང: 1
#
# ངང་གིས: 1
#
# གིས་མེད: 1
#
# མེད་ཅེས: 1
#
# ཅེས་གོ: 1
