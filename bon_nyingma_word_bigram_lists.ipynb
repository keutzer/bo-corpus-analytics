# %%
from collections import Counter
from gensim.corpora import Dictionary
from nltk import ngrams
from scipy import stats

import itertools
import numpy as np
import os
import pybo

import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# Store texts in the following directory structure:
#
#     texts
#       Bon
#         file1.txt
#         file2.txt
#         ...
#       Nyingma
#         file1.txt
#         file2.txt
#         ...

# %%
tok = pybo.BoTokenizer('POS')
# Out:
# Loading Trie...
# Time: 11.93508768081665

# %% [markdown]
# Assumptions here:
# 1. Drop all non-bo text
# 2. Drop all phrase delimiters (shad)
# 3. Reduce words to lemmas
# 4. Strip beginning and ending tseks from lemmas

# %%
tsek = '་'

# Create dictionary to map document index back to filename
bon_idx2fname = {}
bon_texts = []
for filename in sorted(os.listdir("texts/Bon")):
    if ".txt" in filename:
        with open("texts/Bon/" + filename, 'r', encoding='utf-8-sig') as f:
            bon_idx2fname[len(bon_texts)] = filename
            tokens = [t for t in tok.tokenize(f.read()) if t.type != "non-bo" and t.pos != "punct"]
            lemmas = [t.lemma.strip(tsek) if t.lemma else t.content.strip(tsek) for t in tokens]
            bon_texts.append(lemmas)
            
# Now process nyingma
nyingma_idx2fname = {}
nyingma_texts = []
for filename in sorted(os.listdir("texts/Nyingma")):
    if ".txt" in filename:
        with open("texts/Nyingma/" + filename, 'r', encoding='utf-8-sig') as f:
            nyingma_idx2fname[len(nyingma_texts)] = filename
            tokens = [t for t in tok.tokenize(f.read()) if t.type != "non-bo" and t.pos != "punct"]
            lemmas = [t.lemma.strip(tsek) if t.lemma else t.content.strip(tsek) for t in tokens]
            nyingma_texts.append(lemmas)

# %%
filter_list = ['གི','ལ','གིས','དང','ནི','ནས','པ','གོ','ཀྱང','དུ','ཀྱིས','དེ','ཏེ','མ','སྟེ','སུ','ཀྱི','གྱིས','ན','ཅེས','འདི','གྱི','ཅི','བ','པར','ཡིས','ཅིང','མོ','ཅེས་པ','རྣམས','ཏུ']

bon_texts_f = []
for t in bon_texts:
    t_f = [x for x in t if x not in filter_list]
    bon_texts_f.append(t_f)

nyingma_texts_f = []
for t in nyingma_texts:
    t_f = [x for x in t if x not in filter_list]
    nyingma_texts_f.append(t_f)
    
bon_bigrams_f = []
for t in bon_texts:
    grams = [tsek.join(x) for x in ngrams(t, 2) if not set(x).intersection(filter_list)]
    bon_bigrams_f.append(grams)
    
nyingma_bigrams_f = []
for t in nyingma_texts:
    grams = [tsek.join(x) for x in ngrams(t, 2) if not set(x).intersection(filter_list)]
    nyingma_bigrams_f.append(grams)

# %% [markdown]
# ## Overall top words/bigrams

# %%
bon_words_counter = Counter(list(itertools.chain(*bon_texts_f)))
nyingma_words_counter = Counter(list(itertools.chain(*nyingma_texts_f)))

bon_bigrams_counter = Counter(list(itertools.chain(*bon_bigrams_f)))
nyingma_bigrams_counter = Counter(list(itertools.chain(*nyingma_bigrams_f)))

# %%
N = 100

print("Bon Texts Top {} words".format(N))
for k, v in bon_words_counter.most_common(N):
    print("{}: {}\n".format(k, v))

print("Nyingma Texts Top {} words".format(N))
for k, v in nyingma_words_counter.most_common(N):
    print("{}: {}\n".format(k, v))

print("Bon Texts Top {} bigrams".format(N))
for k, v in bon_bigrams_counter.most_common(N):
    print("{}: {}\n".format(k, v))

print("Bon Nyingma Top {} bigrams".format(N))
for k, v in nyingma_bigrams_counter.most_common(N):
    print("{}: {}\n".format(k, v))
# Out:
# Bon Texts Top 100 words
# སེམས: 701
#
# མི: 624
#
# ལས: 513
#
# མྱེད: 443
#
# དོན: 435
#
# བྱ: 419
#
# ཉིད: 403
#
# ཡེ་ཤེས: 332
#
# ཐམས་ཅད: 313
#
# བོན: 297
#
# ཡིན: 270
#
# ངང: 268
#
# མེད་པ: 257
#
# བྱང་ཆུབ: 255
#
# མཚན་མ: 249
#
# གསལ་བ: 238
#
# ཆེན་པོ: 232
#
# ཁུ་བྱུག: 221
#
# གསུམ: 215
#
# བདག: 206
#
# རིག་པ: 200
#
# གཉིས: 198
#
# མེད: 196
#
# ལུང: 188
#
# ནམ་མཁའ: 184
#
# གསལ: 182
#
# བྱ་བ: 178
#
# དབྱིངས: 177
#
# ཞིང: 177
#
# གནས: 172
#
# ལྷ: 171
#
# དུས: 165
#
# བསྒོམ: 161
#
# སེམས་ཉིད: 159
#
# སྟོན་པ: 158
#
# ལྔ: 157
#
# རང་བཞིན: 157
#
# རང: 156
#
# རྟོགས: 156
#
# ཀུན: 155
#
# ཙམ: 149
#
# ཡེ་ནས: 146
#
# པས: 138
#
# འོད: 136
#
# བཞི: 135
#
# བསྟན་པ: 135
#
# ཤེས་པ: 134
#
# སྤྲུལ་པ: 133
#
# ལྟར: 132
#
# སྐྱེ་བ: 131
#
# རྟོགས་པ: 128
#
# རྣམ་པར: 123
#
# ཏིང་ངེ་འཛིན: 121
#
# འབྱུང: 119
#
# བྱུང: 116
#
# གཤེན: 115
#
# ཡིད: 113
#
# ཅིག: 112
#
# སྐུ: 112
#
# སེམས་ཅན: 111
#
# གནས་པ: 111
#
# བརྣན: 111
#
# སྣང: 110
#
# ཅན: 110
#
# ཐབས: 108
#
# དེས: 105
#
# དེ་ལྟར: 105
#
# བདེ་བ: 104
#
# སྟོན: 102
#
# རྣམ་པ: 102
#
# བག་ཆགས: 102
#
# འདྲ: 102
#
# རུ: 102
#
# བཤད: 101
#
# པོ: 101
#
# གཤེན་ལྷ: 96
#
# ལུས: 96
#
# གཅིག: 95
#
# ལྡན་པ: 93
#
# རྒྱུ: 90
#
# དོན་དམ: 89
#
# བསྒོམ་པ: 89
#
# གང: 88
#
# ཐིག་ལེ: 88
#
# འབྲས་བུ: 86
#
# རྒྱལ་པོ: 86
#
# མན་ངག: 85
#
# གཡུང་དྲུང: 84
#
# འགྱུར: 84
#
# ཚིག: 84
#
# མཐའ: 84
#
# དཔེ: 83
#
# འབྱུང་བ: 83
#
# སྙིང་པོ: 83
#
# བྱེད: 82
#
# དངོས་པོ: 81
#
# དཔེར་ན: 81
#
# མེད་པར: 80
#
# གམ: 79
#
# ཐུགས: 79
#
# Nyingma Texts Top 100 words
# མི: 420
#
# མེད: 391
#
# ཀུན: 243
#
# ལས: 196
#
# ཉིད: 183
#
# མེད་པ: 157
#
# ཆོས: 151
#
# གནས: 148
#
# བྱང་ཆུབ: 145
#
# ལམ: 132
#
# ཡིན: 128
#
# ཆེན་པོ: 122
#
# སེམས: 121
#
# དོན: 121
#
# དབྱིངས: 102
#
# མཆོག: 96
#
# སངས་རྒྱས: 96
#
# ཐམས་ཅད: 95
#
# རྡོ་རྗེ: 93
#
# རང་བཞིན: 90
#
# ཡེ་ཤེས: 88
#
# བཅོམ་ལྡན་འདས: 85
#
# སྙིང་པོ: 85
#
# གཉིས: 84
#
# རྒྱུད: 78
#
# སྐུ: 76
#
# རྫོགས: 73
#
# འགྱུར: 69
#
# གཞན: 69
#
# ཕྱིར: 68
#
# བཞིན: 67
#
# ཡི: 65
#
# གསུམ: 65
#
# ཡེ་ནས: 64
#
# དེ་བཞིན: 63
#
# དེ་ནས: 63
#
# གཅིག: 62
#
# དཔལ: 61
#
# གང: 61
#
# རྣམ་པར: 61
#
# མཐའ: 60
#
# བྲལ: 60
#
# ལྷུན: 60
#
# དག་པ: 57
#
# བདེ་བ: 56
#
# དག: 55
#
# འདས: 53
#
# བདག: 51
#
# བྱ: 50
#
# དཀྱིལ་འཁོར: 50
#
# ཚིག: 48
#
# ནམ་མཁའ: 48
#
# གནས་པ: 48
#
# རྟོག: 47
#
# བཟང་པོ: 45
#
# རྒྱལ་བ: 45
#
# འཁྲུལ: 44
#
# ཕྱག: 43
#
# ཞིང: 42
#
# འཚལ: 41
#
# སྤྱོད་པ: 41
#
# རྫོགས་པ: 41
#
# ཆེན: 41
#
# སྐྱེ: 41
#
# བསྟན་པ: 41
#
# ངང: 41
#
# ཆེ: 40
#
# རྟོག་པ: 40
#
# ཐབས: 39
#
# རྒྱལ་པོ: 39
#
# འདས་པ: 38
#
# སེམས་དཔའ: 37
#
# ལུང: 37
#
# ལེའུ: 37
#
# ཐུགས: 36
#
# ཡུལ: 36
#
# གྱུར: 35
#
# པས: 35
#
# རྣལ་འབྱོར: 35
#
# ཕྱག་རྒྱ: 35
#
# དེ་བཞིན་ཉིད: 34
#
# རང: 34
#
# བསྒོམ: 34
#
# མེད་པར: 33
#
# མིན: 33
#
# ལ་སོགས: 33
#
# ཤིང: 32
#
# སྣ་ཚོགས: 32
#
# དེ་ཉིད: 32
#
# ཐིག་ལེ: 32
#
# ཡི་གེ: 32
#
# བརྗོད་པ: 31
#
# མཉམ: 31
#
# བརྗོད: 31
#
# ཡོད: 31
#
# བྱེད: 31
#
# འབྱུང: 31
#
# སྒྱུ་མ: 31
#
# ཐེག་པ: 30
#
# རྒྱུ: 30
#
# Bon Texts Top 100 bigrams
# བོན་ཉིད: 150
#
# ལུང་བརྣན: 105
#
# བྱང་ཆུབ་སེམས: 103
#
# གཤེན་ལྷ་འོད: 65
#
# འོད་དཀར: 64
#
# རྣམ་པར་ཤེས་པ: 63
#
# བདེ་བ་ཆེན་པོ: 60
#
# མྱེད་པས: 57
#
# ལས་འདས་པ: 54
#
# རང་ཤེས་རིག: 53
#
# སེམས་རིག་པ: 48
#
# སྤྲོ་ཞིང: 47
#
# ཞིང་དྭང: 42
#
# དེ་ལྟ་བུ: 39
#
# རྟོགས་ཙམ: 38
#
# རྣམ་པ་གསུམ: 36
#
# ཀུན་གཞི་བྱང་ཆུབ: 36
#
# སྙམ་བྱེད: 34
#
# མི་དམིགས: 34
#
# བརྒྱུད་དེས: 34
#
# ཙམ་ཉིད: 32
#
# ཁྱབ་བདལ: 32
#
# སེམས་ཅན་ཐམས་ཅད: 31
#
# ཡེ་ཤེས་ཆེན་པོ: 30
#
# མཚན་མ་མྱེད: 30
#
# རང་འབྱུང: 30
#
# ཉིད་བདེ་བ: 29
#
# མཚན་མ་ཐམས་ཅད: 29
#
# ལས་འདས: 28
#
# འགྱུར་རོ: 28
#
# ངང་ཉིད: 28
#
# མི་དམིགས་པ: 27
#
# མི་འགྱུར: 27
#
# མི་ཁྱབ་པ: 26
#
# རྣམ་པར་དག་པ: 26
#
# རིག་པ་ཐབས: 25
#
# བདག་སྒོམ་པ: 25
#
# རྒྱལ་པོ་བྱང་ཆུབ: 24
#
# ཐིག་ལེ་གཅིག: 24
#
# བོན་ཐམས་ཅད: 23
#
# སླུ་བ་ཡིན: 23
#
# མི་དམྱིགས: 23
#
# མཚོན་པ་མྱ་ངན: 23
#
# འཆི་མེད་གཙུག་ཕུད: 22
#
# ཉམས་སོད: 22
#
# སེམས་རང: 22
#
# རེ་སྤྲོ: 22
#
# གཉིས་མེད: 21
#
# སྣང་བ་ཐམས་ཅད: 21
#
# དཔེར་ན་ནམ་མཁའ: 21
#
# མྱ་ངན་ལས: 21
#
# གཤེན་ཕྲན: 21
#
# སྤྲོ་བ་སྐྱེ་བ: 20
#
# ལས་སོགས: 20
#
# ལས་བྱུང་བ: 20
#
# བཅུ་རྩ: 20
#
# སྣང་སྲིད་ཐམས་ཅད: 19
#
# སྤྱན་དྲངས: 19
#
# འཕྲག་དོག: 19
#
# ཐུགས་རྗེ་ཆེན་པོ: 19
#
# རྒྱལ་པོ་ཀུན་གཞི: 19
#
# ཡེ་གཤེན་གཙུག་ཕུད: 18
#
# རང་བཞིན་མེད་པ: 18
#
# སྣང་ཞིང: 18
#
# འཁོར་གཤེན: 18
#
# རྒྱུན་ཐག: 18
#
# མི་འབྱུང: 17
#
# སླུ་བ་པོ: 17
#
# མི་བསྒོམ: 17
#
# གཤེན་ལྷ་དཀར་པོ: 17
#
# སེམས་སྤྲོ་བ: 17
#
# སྐྱེ་བ་མྱེད: 17
#
# བཞི་བཅུ: 17
#
# ཡིད་ཆེས་པས: 17
#
# སྤྲུལ་ལོ: 17
#
# བཟང་པོ་གཤེན་ལྷ: 16
#
# དུས་ཅིག: 16
#
# ཐམས་ཅད་སེམས: 16
#
# སེམས་བདེ་བ: 16
#
# མཚན་མ་རྡུལ: 16
#
# རྣམ་པར་རྟོག་པ: 16
#
# གསལ་ལ་མ: 16
#
# ཡེ་ཤེས་ལྔ: 16
#
# འདུ་འབྲལ: 16
#
# དུག་ལྔ: 16
#
# སྟོན་པ་གཤེན་ལྷ: 15
#
# དབྱིངས་ཡིན: 15
#
# ཕྱག་འཚལ: 15
#
# ཏན་ཏྲ: 15
#
# དེ་ལྟར་རྟོགས: 15
#
# ནམ་མཁའ་ལྟར: 15
#
# ཐིག་ལེ་ཆེན་པོ: 15
#
# སྤྲུལ་པ་ལས: 15
#
# ཁམས་གསུམ: 15
#
# ཐམས་ཅད་བོན: 15
#
# རྩ་ལྔ: 15
#
# རིགས་ཅན་ཡིན་པ: 15
#
# ཕྲན་སླད: 15
#
# རྣམ་པ་གསུམ་པོ: 15
#
# ཐམས་ཅད་མཁྱེན་པ: 14
#
# Bon Nyingma Top 100 bigrams
# བཅོམ་ལྡན་འདས་དཔལ: 45
#
# མི་གནས: 41
#
# གཉིས་མེད: 40
#
# དེ་ནས་བཅོམ་ལྡན་འདས: 39
#
# བྱང་ཆུབ་སེམས: 39
#
# དཔལ་ཀུན: 38
#
# ཕྱག་འཚལ: 30
#
# རྒྱུད་ལས: 30
#
# རྡོ་རྗེ་སེམས་དཔའ: 28
#
# ལས་འདས: 27
#
# མི་རྟོག: 27
#
# ལས་འདས་པ: 22
#
# མི་དགོས: 21
#
# མི་འགྱུར: 21
#
# ལྷུན་རྫོགས: 19
#
# དབྱེར་མེད: 18
#
# བྱང་ཆུབ་སྙིང་པོ: 17
#
# མི་དམིགས: 16
#
# ཡི་གེ་མེད་པ: 16
#
# རྣམ་པར་དག: 15
#
# སྐྱེ་མེད: 15
#
# མི་རྙེད: 15
#
# བདེ་བ་ཆེན་པོ: 13
#
# རྣམ་པར་དག་པ: 13
#
# བཀའ་སྩལ: 13
#
# ཁམས་གསུམ: 13
#
# རྩལ་ཆེན: 13
#
# དབྱིངས་ལས: 13
#
# མི་བྱེད: 13
#
# དེ་བཞིན་གཤེགས་པ: 12
#
# ཡེ་ནས་དག་པ: 12
#
# མཐའ་ལས: 12
#
# ཕྱི་ནང: 12
#
# འཚལ་ལོ: 11
#
# རྡོ་རྗེ་ཐེག་པ: 11
#
# སེམས་ཁྱུང་ཆེན: 11
#
# ཕྲ་བཀོད་པ: 11
#
# ངོ་བོ་ཉིད: 10
#
# མི་སྐྱེ: 10
#
# དཔལ་རྡོ་རྗེ: 10
#
# མྱ་ངན་འདས: 10
#
# ཡེ་སངས་རྒྱས: 10
#
# སེམས་རྩལ: 10
#
# བཟང་པོ་ཉིད: 10
#
# གནས་མེད: 10
#
# མེད་ཕྱིར: 10
#
# མི་བལྟ: 9
#
# རང་བཞིན་གནས་པ: 9
#
# སངས་རྒྱས་ཀུན: 9
#
# དབྱིངས་ཉིད: 9
#
# ཆོས་ཐམས་ཅད: 8
#
# ཡེ་ཤེས་སྙིང་པོ: 8
#
# ཡེ་ཤེས་དབྱིངས: 8
#
# མི་གཡོ: 8
#
# ཐམས་ཅད་ཀུན: 8
#
# མེད་མི: 8
#
# བརྗོད་མེད: 8
#
# ལམ་ཆེན: 8
#
# རྡོ་རྗེ་འཛིན་པ: 8
#
# ཐེག་པ་ཆེན་པོ: 7
#
# རྣམ་པར་མི: 7
#
# མྱ་ངན་འདས་པ: 7
#
# མི་བྱ: 7
#
# སྙིང་པོ་བྱང་ཆུབ: 7
#
# རྒྱལ་བ་ཀུན: 7
#
# སངས་རྒྱས་སེམས་ཅན: 7
#
# འདུ་འབྲལ: 7
#
# རང་བྱུང་ཡེ་ཤེས: 7
#
# དོན་མི: 7
#
# བྱང་ཆུབ་ཆེན་པོ: 7
#
# ཀུན་ལས: 7
#
# རྡུལ་ཙམ: 7
#
# མེད་ཡེ: 7
#
# རྒྱ་གར་སྐད: 6
#
# བཅོམ་ལྡན་འདས་ཆེན་པོ: 6
#
# འཁོར་བ་མྱ་ངན: 6
#
# མི་སྲིད: 6
#
# བཅོམ་ལྡན་འདས་ཀུན: 6
#
# ཀུན་འདུས: 6
#
# བྱང་ཆུབ་ལམ: 6
#
# མི་རུང: 6
#
# རོ་གཅིག: 6
#
# བཀྲ་ཤིས་པ་རིག་པ: 6
#
# ཡིན་རྡོ་རྗེ: 6
#
# སྙིང་པོ་ཉིད: 6
#
# འབྱུང་འཇུག: 6
#
# མེད་ནམ་མཁའ: 6
#
# སངས་རྒྱས་ཉིད: 6
#
# ཕ་རོལ་ཕྱིན: 6
#
# བཟང་པོས་ཉིད: 6
#
# མེད་ཆོས: 6
#
# མེད་སངས་རྒྱས: 6
#
# ཇི་བཞིན་གནས: 6
#
# གནས་མི: 6
#
# ཚིག་ལས: 6
#
# མི་འབྱུང: 6
#
# མི་ཤེས: 6
#
# ཙམ་མེད: 6
#
# རྣམ་དག་བྱང་ཆུབ: 6
#
# བྲལ་ཚིག: 6

# %% [markdown]
# ## Per text top words/bigrams

# %%
N = 20

print("bon texts")
for i in range(len(bon_idx2fname)):
    words = Counter(bon_texts_f[i])
    bigrams = Counter(bon_bigrams_f[i])
    print("{} top {} words".format(bon_idx2fname[i], N))
    for k, v in words.most_common(N):
        print("{}: {}\n".format(k, v))
    print("{} top {} bigrams".format(bon_idx2fname[i], N))
    for k, v in bigrams.most_common(N):
        print("{}: {}\n".format(k, v))

print("nyingma texts")       
for i in range(len(nyingma_idx2fname)):
    words = Counter(nyingma_texts_f[i])
    bigrams = Counter(nyingma_bigrams_f[i])
    print("{} top {} words".format(nyingma_idx2fname[i], N))
    for k, v in words.most_common(N):
        print("{}: {}\n".format(k, v))
    print("{} top {} bigrams".format(nyingma_idx2fname[i], N))
    for k, v in bigrams.most_common(N):
        print("{}: {}\n".format(k, v))
# Out:
# bon texts
# 01-SMDG-gser-lung-non-che.txt top 20 words
# སེམས: 166
#
# བདག: 157
#
# ལས: 156
#
# མི: 146
#
# ལུང: 111
#
# ཡིན: 95
#
# བརྣན: 86
#
# བསྒོམ: 84
#
# མེད་པ: 81
#
# སླུ་བ: 74
#
# དོན: 72
#
# ཉིད: 72
#
# ཡིད: 66
#
# ཏིང་ངེ་འཛིན: 65
#
# ཆེན་པོ: 62
#
# མེད: 61
#
# བྱང་ཆུབ: 59
#
# གཉིས: 58
#
# བཞི: 58
#
# མཚན་མ: 58
#
# 01-SMDG-gser-lung-non-che.txt top 20 bigrams
# ལུང་བརྣན: 80
#
# སྙམ་བྱེད: 34
#
# བདག་སྒོམ་པ: 24
#
# སླུ་བ་ཡིན: 23
#
# ཉམས་སོད: 21
#
# རྣམ་པར་ཤེས་པ: 19
#
# འཕྲག་དོག: 18
#
# བོན་ཉིད: 15
#
# སླུ་བ་པོ: 15
#
# མི་ཁྱབ་པ: 13
#
# ཏན་ཏྲ: 12
#
# ཏྲ་ལས: 12
#
# རྗེས་སུ་མི: 12
#
# ལས་བྱུང་བ: 12
#
# སྤྲུལ་པ་ལས: 12
#
# འོད་དཀར: 11
#
# ཡེ་ཤེས་ཆེན་པོ: 11
#
# གཤེན་ལྷ་འོད: 10
#
# རྣམ་པ་གསུམ: 10
#
# བྱིན་ཆེ: 10
#
# 02-SMDG-gser-lung-non-chung.txt top 20 words
# མཚན་མ: 54
#
# མྱེད: 48
#
# ཐམས་ཅད: 39
#
# སེམས: 38
#
# ཉིད: 34
#
# ལས: 31
#
# ལུང: 28
#
# སེམས་ཉིད: 26
#
# བརྣན: 25
#
# དོན: 22
#
# བསྒོམ: 21
#
# བག་ཆགས: 20
#
# འབྱུང: 19
#
# བྱ་བ: 18
#
# གཤེན་ལྷ: 15
#
# རང: 15
#
# དཀར་པོ: 15
#
# ཞིང: 14
#
# མི: 14
#
# ཡེ་ཤེས: 13
#
# 02-SMDG-gser-lung-non-chung.txt top 20 bigrams
# ལུང་བརྣན: 25
#
# མཚན་མ་ཐམས་ཅད: 21
#
# སེམས་རང: 14
#
# རང་འབྱུང: 14
#
# གཤེན་ལྷ་དཀར་པོ: 14
#
# མཚན་མ་མྱེད: 10
#
# ཐམས་ཅད་ཞི: 10
#
# ཞི་ཞིང: 10
#
# ཞིང་མི་སྣང་བ: 9
#
# སེམས་མཚན་མ: 8
#
# མཐུ་རྟས་པ: 7
#
# གདོས་པ་ཅན: 6
#
# མཚན་མ་གཞོམ་པ: 6
#
# ལས་མཚན་མ: 6
#
# རྟོག་པ་མྱེད: 6
#
# ཕུང་པོ་གདོས་པ: 5
#
# སྙིང་པོ་དེས: 5
#
# འདུ་བྱེད་ལས: 5
#
# ཅེས་བྱ་བ་སེམས: 5
#
# རྣམ་པར་རྟོག་པ: 4
#
# 03-SMDG-sems-phran-rig-pa-khu-byug-sa-gcod.txt top 20 words
# སེམས: 17
#
# ཁུ་བྱུག: 14
#
# རིག་པ: 12
#
# བྱང་ཆུབ: 11
#
# བསྟན་པ: 9
#
# གསུང: 8
#
# དོན: 8
#
# བྱ: 8
#
# མྱེད: 7
#
# ལས: 7
#
# གསུམ: 7
#
# ཡན་ལག: 7
#
# སྟོན་པ: 6
#
# མཚན: 6
#
# དགུ: 5
#
# ཐམས་ཅད: 4
#
# སྙིང་པོ: 4
#
# སེམས་ཅན: 4
#
# གཉིས: 4
#
# དཔེ: 4
#
# 03-SMDG-sems-phran-rig-pa-khu-byug-sa-gcod.txt top 20 bigrams
# བྱང་ཆུབ་སེམས: 6
#
# སེམས་རིག་པ: 6
#
# ལས་མཚན: 4
#
# དངོས་མྱེད: 3
#
# མྱེད་གསུང: 3
#
# ཁུ་བྱུག་དགུ: 3
#
# རིག་པ་ཁུ་བྱུག: 2
#
# ས་གཅོད: 2
#
# སྟོན་པ་གཤེན་ལྷ: 2
#
# གཤེན་ལྷ་འོད: 2
#
# འོད་དཀར: 2
#
# རིག་པ་ལྷ: 2
#
# གདགས་ལུགས: 2
#
# དཔེ་ལས: 2
#
# དོན་ལས: 2
#
# ཅིའི་ཕྱིར་ཅེ་ན: 2
#
# སེམས་ཅན་ཐམས་ཅད: 2
#
# སེམས་སྤྲོ་བ: 2
#
# སྐྱབས་འོག: 2
#
# ཉི་ཤུ་རྩ: 2
#
# 04-SMDG-rig-pa-khu-byug-gzhung.txt top 20 words
# ཁུ་བྱུག: 62
#
# མི: 52
#
# ཡེ་ཤེས: 30
#
# མེད: 25
#
# རེ: 21
#
# སྤྲོ: 21
#
# སྒྲོགས: 20
#
# ཉིད: 19
#
# ཙམ: 19
#
# དམིགས: 19
#
# ཇི: 17
#
# ངང: 16
#
# བོན: 15
#
# རང་བཞིན: 15
#
# དཔེ: 15
#
# རྟགས: 15
#
# སྤྲུལ་པ: 14
#
# ཀུན: 14
#
# མཚན་མ: 14
#
# རིག་པ: 13
#
# 04-SMDG-rig-pa-khu-byug-gzhung.txt top 20 bigrams
# རེ་སྤྲོ: 21
#
# མི་དམིགས: 18
#
# བོན་ཉིད: 12
#
# མཚན་མ་མེད: 10
#
# དམིགས་ཡེ་ཤེས: 8
#
# ཁུ་བྱུག་བོན: 8
#
# རིག་པ་ཆེ: 8
#
# མཚོན་པ་མྱ་ངན: 8
#
# མྱ་ངན་འདས: 8
#
# རྟགས་ཅན: 7
#
# ཁུ་བྱུག་སེམས་ཉིད: 7
#
# བཅོས་ངང: 7
#
# ངང་དོན: 7
#
# ཕྱིར་ཡང་ཁུ་བྱུག: 7
#
# ཐིག་འདེབས: 7
#
# འདེབས་རིག་པ: 7
#
# འདས་སྤྲུལ་པ: 7
#
# ཁུ་བྱུག་ནམ་མཁར: 6
#
# མི་སྐྱེ: 5
#
# ཐིག་ལེ་གཅིག: 4
#
# 05-SMDG-rig-pa-khu-byug-grel.txt top 20 words
# སེམས: 207
#
# མི: 173
#
# ཁུ་བྱུག: 143
#
# བོན: 126
#
# ཉིད: 123
#
# ལས: 122
#
# བྱ: 112
#
# ཐམས་ཅད: 108
#
# རིག་པ: 105
#
# མེད་པ: 105
#
# ཆེན་པོ: 101
#
# རྟོགས: 99
#
# དོན: 96
#
# གསལ་བ: 92
#
# ནམ་མཁའ: 89
#
# བྱང་ཆུབ: 88
#
# ཞིང: 84
#
# ཡེ་ཤེས: 75
#
# སྐྱེ་བ: 75
#
# ཡིན: 70
#
# 05-SMDG-rig-pa-khu-byug-grel.txt top 20 bigrams
# བོན་ཉིད: 61
#
# རང་ཤེས་རིག: 47
#
# སྤྲོ་ཞིང: 46
#
# ཞིང་དྭང: 42
#
# སེམས་རིག་པ: 39
#
# རྣམ་པར་ཤེས་པ: 38
#
# བདེ་བ་ཆེན་པོ: 34
#
# རྟོགས་ཙམ: 32
#
# གཤེན་ལྷ་འོད: 29
#
# འོད་དཀར: 28
#
# ཉིད་བདེ་བ: 25
#
# སེམས་ཅན་ཐམས་ཅད: 22
#
# རྒྱལ་པོ་བྱང་ཆུབ: 21
#
# ཀུན་གཞི་བྱང་ཆུབ: 20
#
# གཤེན་ཕྲན: 20
#
# རིག་པ་ཐབས: 19
#
# དཔེར་ན་ནམ་མཁའ: 19
#
# བྱང་ཆུབ་སེམས: 18
#
# རྒྱལ་པོ་ཀུན་གཞི: 18
#
# འཁོར་གཤེན: 18
#
# 06-SMDG-cog-bzhag-sa-gcod.txt top 20 words
# ཅོག: 5
#
# བཞག: 5
#
# སྟོན་པ: 4
#
# སེམས: 4
#
# དོན: 4
#
# མྱེད: 3
#
# སྟོན: 3
#
# གསུམ: 3
#
# ས: 2
#
# གཅོད: 2
#
# ནང: 2
#
# གསལ: 2
#
# གསལ་བ: 2
#
# མན་ངག: 2
#
# དཀྱིལ: 2
#
# ཀླད: 2
#
# རྒྱངས: 2
#
# བསྟན: 2
#
# མདོ: 2
#
# མདོའ: 2
#
# 06-SMDG-cog-bzhag-sa-gcod.txt top 20 bigrams
# ཅོག་བཞག: 4
#
# ས་གཅོད: 2
#
# གསལ་བ་མྱེད: 2
#
# ཀླད་རྒྱངས: 2
#
# གཅོད་བཞུགས་པ: 1
#
# བཞུགས་པ་ལགས་སོ: 1
#
# ལགས་སོ་ཨེ་མ་ཧོ: 1
#
# ཨེ་མ་ཧོ་སྤུངས: 1
#
# སྨར་རོ: 1
#
# རོ་བར་སྣང: 1
#
# བར་སྣང་མཁའ: 1
#
# ཟླ་ཤར་པ: 1
#
# ཤར་པ་རྒྱ་མཚོ: 1
#
# རྒྱ་མཚོ་ཆུ: 1
#
# ཆུ་བྲན: 1
#
# བྲན་ནང: 1
#
# གསལ་རྡོ: 1
#
# རྡོ་ཤིང: 1
#
# ཤིང་ས་ལ: 1
#
# ས་ལ་གསལ་བ: 1
#
# 07-SMDG-cog-bzhag-gzhung.txt top 20 words
# རྣམ་པ: 9
#
# གསུམ་པོ: 9
#
# འདྲ: 9
#
# ཅོག: 5
#
# བཞག: 4
#
# མི: 4
#
# མྱེད: 3
#
# སྟངས: 3
#
# ཐབས: 3
#
# སྟོན་པ: 2
#
# གསུམ: 2
#
# དགུ: 2
#
# ཕྱེ: 2
#
# བཞག་པ: 2
#
# གསལ་བ: 2
#
# མཁའ: 2
#
# མན་ངག: 2
#
# ངང: 2
#
# གཞུང: 1
#
# བཞུགས: 1
#
# 07-SMDG-cog-bzhag-gzhung.txt top 20 bigrams
# རྣམ་པ་གསུམ་པོ: 9
#
# ཅོག་བཞག: 4
#
# སྟངས་རྣམ་པ: 3
#
# ཐབས་རྣམ་པ: 3
#
# གཞུང་བཞུགས: 1
#
# སྟོན་པ་ཀུན: 1
#
# བཟང་པོ་གཤེན་ལྷ: 1
#
# གཤེན་ལྷ་འོད: 1
#
# འོད་དཀར: 1
#
# དཀར་ལོ་ཕྱག: 1
#
# ལོ་ཕྱག་འཚལ: 1
#
# འཚལ་ལོ: 1
#
# ལོ་སྟོན་པ: 1
#
# སྟོན་པ་ཚད: 1
#
# ཚད་མྱེད: 1
#
# མྱེད་བཞི: 1
#
# གསུམ་གསུམ: 1
#
# གསུམ་དགུ: 1
#
# དགུ་རུ: 1
#
# རུ་ཕྱེ: 1
#
# 08-SMDG-cog-bzhag-grel.txt top 20 words
# མྱེད: 95
#
# མི: 60
#
# ཉིད: 36
#
# དོན: 32
#
# གསུམ: 30
#
# བྱ: 29
#
# ངང: 28
#
# སེམས: 27
#
# གཉིས: 25
#
# ལས: 24
#
# རྣམ་པ: 23
#
# གཞག: 23
#
# གསལ: 22
#
# ཅོག: 21
#
# པས: 20
#
# ཤེས་པ: 20
#
# བསྒོམ: 20
#
# ཆེན་པོ: 19
#
# བོན: 19
#
# འབྲས་བུ: 19
#
# 08-SMDG-cog-bzhag-grel.txt top 20 bigrams
# རྣམ་པ་གསུམ: 15
#
# བོན་ཉིད: 14
#
# མྱེད་པས: 13
#
# ཉམ་མི: 11
#
# མི་ང: 11
#
# ཙམ་ཉིད: 9
#
# ང་བར: 8
#
# ལས་འཕྲོ་དག་པ: 8
#
# འབྲས་བུ་ཐོབ: 8
#
# ཐོབ་ངེས་པ: 8
#
# བྱང་ཆུབ་སེམས: 8
#
# བདེ་བ་ཆེན་པོ: 7
#
# ཚད་མྱེད: 6
#
# རྣམ་པ་གསུམ་པོ: 6
#
# ཨེ་མ་ཧོ་གང་ཞིག: 6
#
# ཨེ་མ་ཧོ་བསྒྲུབ: 6
#
# གང་ཞིག་སྐྱེས་བུ: 5
#
# དག་ལས་འཕྲོ: 5
#
# སྟངས་རྣམ་པ: 5
#
# ལྡན་པ་ཞིག: 5
#
# 09-SMDG-rgyun-thag-sa-gcod-gzhung-grel.txt top 20 words
# མྱེད: 149
#
# སེམས: 118
#
# དོན: 72
#
# ཐམས་ཅད: 60
#
# བྱང་ཆུབ: 51
#
# པས: 51
#
# བྱ: 49
#
# ཡེ་ནས: 48
#
# ཀུན: 40
#
# མི: 39
#
# བོན: 39
#
# མཚན་མ: 36
#
# དབྱིངས: 35
#
# ཡིན: 33
#
# བརྗོད: 32
#
# རང་བཞིན: 29
#
# རིག་པ: 28
#
# ཉིད: 27
#
# ཡེ་ཤེས: 26
#
# བསྟན་པ: 26
#
# 09-SMDG-rgyun-thag-sa-gcod-gzhung-grel.txt top 20 bigrams
# བྱང་ཆུབ་སེམས: 43
#
# མྱེད་པས: 26
#
# ཡིད་ཆེས་པས: 17
#
# མཚན་མ་མྱེད: 16
#
# འདུ་འབྲལ: 15
#
# བོན་ཐམས་ཅད: 15
#
# རྒྱུན་ཐག: 14
#
# བོན་ཉིད: 14
#
# གཤེན་ལྷ་འོད: 13
#
# ཕོ་བྲང་ཡིན: 12
#
# སྐྱེ་བ་མྱེད: 12
#
# འབྲལ་མྱེད: 11
#
# བཟང་པོ་གཤེན་ལྷ: 11
#
# ཀུན་གཞི་བྱང་ཆུབ: 11
#
# སྣང་སྲིད་ཐམས་ཅད: 10
#
# འོད་དཀར: 10
#
# རིག་པ་ཀུན: 9
#
# སྐྱེ་འཆི་མྱེད: 9
#
# རྣམ་པར་དག་པ: 8
#
# དེ་ལྟ་བུ: 8
#
# 10-SMDG-sems-lung-rgyun-thag.txt top 20 words
# མི: 9
#
# མྱེད: 7
#
# བཅོས: 6
#
# དོན: 5
#
# དམྱིགས: 5
#
# ཉིད: 5
#
# སེམས: 3
#
# རྒྱུན: 3
#
# འབྲས་བུ: 3
#
# དག་པ: 3
#
# ཤེས: 3
#
# རྟོགས: 3
#
# གཡོས: 3
#
# ངང: 3
#
# འདས: 3
#
# ལུང: 2
#
# ཐག: 2
#
# སྟོན་པ: 2
#
# ཐུགས: 2
#
# ལས: 2
#
# 10-SMDG-sems-lung-rgyun-thag.txt top 20 bigrams
# མི་དམྱིགས: 5
#
# སེམས་ལུང: 2
#
# རྒྱུན་ཐག: 2
#
# ལས་དག་པ: 2
#
# མི་གཡོ: 2
#
# ཉིད་ནམ་མཁའ: 2
#
# སྤྱོད་འདས: 2
#
# བོན་ཉིད: 2
#
# ཐག་བཞུགས་པ: 1
#
# དབུ་ཕྱོགས: 1
#
# ཕྱོགས་ལགས་སོ: 1
#
# ལགས་སོ་སྟོན་པ: 1
#
# སྟོན་པ་གཤེན་ལྷ: 1
#
# གཤེན་ལྷ་འོད: 1
#
# འོད་དཀར: 1
#
# ཐུགས་ཡང་དག: 1
#
# འབྲས་བུ་ངེས་པ: 1
#
# དོན་ཕྱིས: 1
#
# ཕྱིས་བྱོན་པ: 1
#
# ཨེ་མ་ཧོ་གང: 1
#
# 11-SMDG-snang-dngos-med-mdzub-tshugs.txt top 20 words
# ཉིད: 30
#
# སེམས: 23
#
# བྱ: 22
#
# ཡིན: 20
#
# ངང: 19
#
# ལས: 15
#
# མྱེད: 15
#
# ནམ་མཁའ: 14
#
# དོན: 14
#
# མི: 14
#
# བོན: 13
#
# ཡེ་ཤེས: 13
#
# བྱང་ཆུབ: 12
#
# གསལ་བ: 11
#
# དམྱིགས: 11
#
# རང་བཞིན: 9
#
# བཅོས: 9
#
# གཅིག: 8
#
# རྟོགས་པ: 8
#
# གནས་པ: 8
#
# 11-SMDG-snang-dngos-med-mdzub-tshugs.txt top 20 bigrams
# བོན་ཉིད: 11
#
# བྱང་ཆུབ་སེམས: 10
#
# མི་དམྱིགས: 9
#
# ལས་འདས་པ: 5
#
# ནམ་མཁའ་ལྟར: 5
#
# ཡེ་ཤེས་ཆེན་པོ: 5
#
# ངང་ཉིད: 4
#
# ཉིད་ནམ་མཁའ: 4
#
# ཕྱི་ནང: 3
#
# མྱ་ངན་ལས: 3
#
# ལ་མ་ཡེངས་པ: 3
#
# སེམས་ནམ་མཁའ: 3
#
# ལྟར་ཡེ་ཤེས: 3
#
# ཁྱབ་བདལ: 3
#
# རང་བཞིན་མྱེད: 3
#
# ཙམ་ཉིད: 3
#
# རྒྱུན་ཐག: 2
#
# གཤེན་ལྷ་འོད: 2
#
# འོད་དཀར: 2
#
# དེ་ཡན་ཆད: 2
#
# 12-SMDG-sgron-ma-gsal-ba.txt top 20 words
# མི: 50
#
# མྱེད: 45
#
# ངང: 30
#
# ཚིག: 23
#
# བྱ་བ: 22
#
# ཡེ་ཤེས: 21
#
# སེམས: 20
#
# བསྟན་པ: 19
#
# དོན: 18
#
# གསལ: 17
#
# བསྒོམ: 15
#
# ཙམ: 15
#
# ཉིད: 14
#
# སེམས་ཉིད: 14
#
# ཡང་ན: 14
#
# བཤད: 13
#
# བོན: 12
#
# སྤྱོད་པ: 11
#
# དེ་ནས: 11
#
# མཚོན: 11
#
# 12-SMDG-sgron-ma-gsal-ba.txt top 20 bigrams
# བོན་ཉིད: 12
#
# ཡེ་ཤེས་ངང: 11
#
# མི་མཚོན: 9
#
# མི་བཤད: 9
#
# མི་བསྒོམ: 9
#
# ཡེ་ཤེས་གསལ: 8
#
# གསལ་བོན: 8
#
# མྱེད་པས: 8
#
# ཡེངས་པ་ཙམ: 7
#
# ཡང་ན་སེམས: 5
#
# མི་དམྱིགས: 3
#
# སེམས་ཡེ་ནས: 3
#
# མི་རྟོག: 3
#
# གསལ་བ་ཙམ: 3
#
# མན་ངག་ལྷུག: 2
#
# ཚད་མྱེད: 2
#
# མྱེད་འོད་ལྡན: 2
#
# དེ་ནས་ངང: 2
#
# དེ་ནས་མཚོན: 2
#
# དེ་ནས་བཤད: 2
#
# 13-ngang-thag-bskal-pa'i-sgron-ma_TTN-175-195.txt top 20 words
# ལྔ: 62
#
# ངང: 56
#
# སེམས: 50
#
# བྱ: 48
#
# མི: 36
#
# ལས: 35
#
# མྱེད: 35
#
# ཡེ་ཤེས: 31
#
# ཐག: 28
#
# ཀ: 26
#
# འི: 24
#
# རྩལ: 24
#
# དུས: 24
#
# ལྟ: 23
#
# ས: 23
#
# དུག: 23
#
# རང: 22
#
# འོད: 21
#
# གསལ: 21
#
# ང: 21
#
# 13-ngang-thag-bskal-pa'i-sgron-ma_TTN-175-195.txt top 20 bigrams
# དུག་ལྔ: 14
#
# ངང་ཐག: 12
#
# བྱང་ཆུབ་སེམས: 11
#
# ལྟ་ཀ: 11
#
# འོད་ལྔ: 10
#
# ངང་ཉིད: 8
#
# ཐག་བཅད: 8
#
# མེ་ཆུ: 8
#
# ལས་འདས: 8
#
# གཤེན་ལྟ: 7
#
# ཆུ་ས: 7
#
# བར་དོལ: 6
#
# ས་རླུང: 6
#
# ཡེ་ཤེས་ལྔ: 6
#
# ལྷ་ལྔ: 5
#
# བྱ་རྩལ: 5
#
# རྩལ་གསུམ: 5
#
# ལྷ་ཀ: 5
#
# གཤེརྣ་ལྷ: 4
#
# འ་ཛན: 4
#
# 14-SMDG-thig-le-dbyings-kyi-ti-ka.txt top 20 words
# ལས: 86
#
# བྱ: 82
#
# དོན: 73
#
# ཡེ་ཤེས: 65
#
# ལྷ: 64
#
# གནས: 45
#
# དབྱིངས: 41
#
# ལྔ: 41
#
# སྤྲུལ: 36
#
# བོན: 33
#
# མེད་པ: 32
#
# གསལ་བ: 31
#
# སྐུ: 31
#
# བྱ་བ: 29
#
# བཞི: 29
#
# རང: 28
#
# གསུམ: 28
#
# བདག: 28
#
# ཐམས་ཅད: 26
#
# གསའ: 26
#
# 14-SMDG-thig-le-dbyings-kyi-ti-ka.txt top 20 bigrams
# སྤྲུལ་ལོ: 17
#
# བརྒྱུད་དེས: 17
#
# བཞི་བཅུ: 13
#
# བཅུ་རྩ: 10
#
# རྩ་ལྔ: 9
#
# རང་འབྱུང: 8
#
# དེ་ལྟ་བུ: 8
#
# ལྷ་མོ་ལས: 8
#
# ཐིག་ལེ་དབྱིངས: 7
#
# ཡོངས་སུ་རྫོགས་པ: 7
#
# ལས་འདས་པ: 7
#
# ཡེ་གཤེན་གཙུག་ཕུད: 7
#
# བོན་ཉིད: 7
#
# རུ་སྤྲུལ: 7
#
# གཡུང་དྲུང་ཡོངས་སུ: 6
#
# གསང་བ་འདུས་པ: 6
#
# ཁྲི་བཞི་ནམ: 6
#
# བཞི་ནམ་ཏིང: 6
#
# མཁའ་འགྱིང: 6
#
# ཐུགས་ཉིད: 5
#
# nyingma texts
# L1-rig-pa'i-khu-byug_p302-324.txt top 20 words
# མི: 79
#
# ཀུན: 54
#
# རྡོ་རྗེ: 52
#
# ཆེན་པོ: 40
#
# མེད: 39
#
# ལས: 38
#
# ཐམས་ཅད: 33
#
# བཅོམ་ལྡན་འདས: 30
#
# སྐུ: 29
#
# ཉིད: 27
#
# མཆོག: 26
#
# ཡེ་ཤེས: 25
#
# ཆོས: 24
#
# མེད་པ: 22
#
# ཡིན: 21
#
# སངས་རྒྱས: 21
#
# ཐེག་པ: 20
#
# ཕྱིར: 20
#
# ལམ: 20
#
# ཁྱོད: 20
#
# L1-rig-pa'i-khu-byug_p302-324.txt top 20 bigrams
# དེ་ནས་བཅོམ་ལྡན་འདས: 15
#
# ཕྱག་འཚལ: 13
#
# བཅོམ་ལྡན་འདས་དཔལ: 11
#
# དཔལ་ཀུན: 11
#
# རྡོ་རྗེ་ཐེག་པ: 11
#
# རྡོ་རྗེ་སེམས་དཔའ: 10
#
# དེ་བཞིན་གཤེགས་པ: 7
#
# ཆོས་ཐམས་ཅད: 6
#
# ལས་འདས: 6
#
# མི་རྟོག: 6
#
# བཀྲ་ཤིས་པ་རིག་པ: 6
#
# བཅོམ་ལྡན་འདས་ཆེན་པོ: 5
#
# ཐེག་པ་ཆེན་པོ: 5
#
# ལས་འདས་པ: 5
#
# རྒྱུད་ལས: 5
#
# དཀྱིལ་འཁོར་ཆེན་པོ: 5
#
# རྟག་ཕྱག: 5
#
# རྡོ་རྗེ་འཛིན་པ: 5
#
# ངོ་བོ་ཉིད: 4
#
# རྣམ་པར་དག་པ: 4
#
# L2-rtsal-chen_p436-447་.txt top 20 words
# མི: 41
#
# མེད: 41
#
# ཉིད: 30
#
# ཀུན: 29
#
# ལས: 27
#
# བཅོམ་ལྡན་འདས: 26
#
# ཆོས: 26
#
# དོན: 25
#
# བྱང་ཆུབ: 19
#
# སེམས: 19
#
# དེ་ནས: 18
#
# གཉིས: 18
#
# གནས: 18
#
# རྒྱུད: 17
#
# དཔལ: 17
#
# སངས་རྒྱས: 17
#
# ལམ: 17
#
# རྩལ: 16
#
# ཆེན: 16
#
# མེད་པ: 15
#
# L2-rtsal-chen_p436-447་.txt top 20 bigrams
# བཅོམ་ལྡན་འདས་དཔལ: 16
#
# དེ་ནས་བཅོམ་ལྡན་འདས: 14
#
# གཉིས་མེད: 14
#
# བྱང་ཆུབ་སེམས: 12
#
# རྩལ་ཆེན: 12
#
# དཔལ་ཀུན: 11
#
# སེམས་རྩལ: 10
#
# རྒྱུད་ལས: 9
#
# དཔལ་རྡོ་རྗེ: 5
#
# རྡོ་རྗེ་སེམས་དཔའ: 5
#
# བཅོམ་ལྡན་འདས་ཀུན: 5
#
# ཆེན་སྤྲུགས་པ: 5
#
# ཕྱག་འཚལ: 4
#
# རྣམ་པར་དག་པ: 4
#
# བཀའ་སྩལ: 4
#
# མི་གནས: 4
#
# རྣམ་པར་དག: 4
#
# ནོར་བུ་རིན་པོ་ཆེ: 3
#
# རྩལ་སྤྲུགས: 3
#
# སངས་རྒྱས་སེམས་ཅན: 3
#
# L3-khyung-chen_p447-468.txt top 20 words
# མི: 130
#
# མེད: 71
#
# ཉིད: 66
#
# གནས: 56
#
# ཀུན: 50
#
# ལམ: 45
#
# བྱང་ཆུབ: 39
#
# ཆོས: 31
#
# ཡིན: 31
#
# ལས: 31
#
# དོན: 26
#
# སངས་རྒྱས: 26
#
# སྙིང་པོ: 23
#
# མཆོག: 20
#
# རང་བཞིན: 20
#
# རྒྱུད: 20
#
# སེམས: 19
#
# དེ་བཞིན: 19
#
# གནས་པ: 19
#
# ཐམས་ཅད: 19
#
# L3-khyung-chen_p447-468.txt top 20 bigrams
# མི་གནས: 22
#
# མི་དགོས: 15
#
# བཅོམ་ལྡན་འདས་དཔལ: 13
#
# དཔལ་ཀུན: 11
#
# སེམས་ཁྱུང་ཆེན: 11
#
# དེ་ནས་བཅོམ་ལྡན་འདས: 10
#
# རྒྱུད་ལས: 10
#
# མི་རྙེད: 9
#
# མི་རྟོག: 7
#
# བཟང་པོ་ཉིད: 6
#
# མི་བྱེད: 6
#
# བྱང་ཆུབ་སེམས: 6
#
# མི་འགྱུར: 5
#
# ལྷུན་རྫོགས: 5
#
# རྡོ་རྗེ་སེམས་དཔའ: 4
#
# ལམ་མི: 4
#
# ཆོས་ལམ: 4
#
# རང་བཞིན་གནས་པ: 4
#
# བྱང་ཆུབ་སྙིང་པོ: 4
#
# གནས་མེད: 4
#
# L4_byang-sems-bsgom-rdo-la-gser-zhun-p416-425.txt top 20 words
# མི: 50
#
# མེད: 47
#
# ཀུན: 24
#
# ལམ: 23
#
# ཡིན: 22
#
# གནས: 20
#
# ཆོས: 18
#
# ཕྱིར: 18
#
# ལས: 17
#
# འགྱུར: 16
#
# སེམས: 15
#
# བྱང་ཆུབ: 13
#
# དེ་དག: 13
#
# ཤེས: 12
#
# ཤིང: 12
#
# ཉིད: 11
#
# རྟོག: 11
#
# ཞིང: 11
#
# གྱུར་པ: 9
#
# གང: 9
#
# L4_byang-sems-bsgom-rdo-la-gser-zhun-p416-425.txt top 20 bigrams
# མེད་ཕྱིར: 9
#
# མི་འགྱུར: 5
#
# མི་བྱེད: 5
#
# མི་གནས: 5
#
# བྱང་ཆུབ་སེམས: 4
#
# མི་རྟོག: 4
#
# རྒྱལ་བ་ཀུན: 3
#
# རྒྱལ་བས་གསུངས: 3
#
# སྣ་ཚོགས་དག: 3
#
# མཐའ་ཡ: 3
#
# སྒོམ་པ་རྡོ: 2
#
# གསེར་ཞུན: 2
#
# ཉིད་བདེ་གཤེགས: 2
#
# འཇམ་དཔལ་གཞོན་ནུ: 2
#
# ཕ་རོལ་ཕྱིན: 2
#
# རྡོ་རྗེ་རྩེ་མོ: 2
#
# བྱང་ཆུབ་སེམས་ཉིད: 2
#
# བྱང་ཆུབ་སེམས་དཔའ: 2
#
# མི་འབྱུང: 2
#
# ལམ་ཉིད: 2
#
# L5_nam-mkha'-che-rgyas-pa-yi-ge-med-pa_V8-p.468-473.txt top 20 words
# མེད་པ: 23
#
# ཡི་གེ: 22
#
# མཆོག: 12
#
# དེ་ནས: 11
#
# ལས: 11
#
# མེད: 11
#
# རྒྱུད: 8
#
# དོན: 8
#
# ཡི: 8
#
# བཀག: 8
#
# འཁོར: 7
#
# གཤེགས་པ: 7
#
# ལེའུ: 7
#
# ནམ་མཁའ: 6
#
# མཚན་མ: 6
#
# བདག་པོ: 6
#
# དོན་དམ: 6
#
# ཡེ་ཤེས: 6
#
# ལ་སོགས: 5
#
# ཞུས་པ: 5
#
# L5_nam-mkha'-che-rgyas-pa-yi-ge-med-pa_V8-p.468-473.txt top 20 bigrams
# ཡི་གེ་མེད་པ: 16
#
# མེད་པ་ལས: 4
#
# དེ་ནས་བདག་པོ: 4
#
# བཀའ་སྩལ: 4
#
# ཡི་གེ་མེད: 3
#
# སྔོན་མ་ཐོས་པ: 2
#
# དེ་ནས་འཁོར: 2
#
# དེ་བཞིན་གཤེགས་པ: 2
#
# གསོལ་ཡི་གེ: 2
#
# ཤིན་ཏུ་བཟློག: 2
#
# མགྲིན་གཅིག: 2
#
# གཤེགས་པ་ཡི་གེ: 2
#
# རིན་ཆེན་རིགས: 2
#
# ཡི་དོན: 2
#
# རྒྱུད་མཆོག: 2
#
# རང་བཞིན་གནས་པ: 2
#
# གང་ལྡན་པ: 2
#
# ཡི་གེ་མེད་པར: 2
#
# སེམས་དཔའ་དགྱེས་པ: 2
#
# དགྱེས་པ་ལ་སོགས: 2
#
# LL01_L14_rtse-mo-byung-rgyal_vol8-p480-491.txt top 20 words
# མེད: 33
#
# དབྱིངས: 30
#
# ཆོས: 22
#
# བྱང་ཆུབ: 22
#
# མི: 22
#
# ལས: 20
#
# ཀུན: 20
#
# དོན: 17
#
# སེམས: 15
#
# དཀྱིལ་འཁོར: 15
#
# རྣམ་པར: 15
#
# རྣམ་དག: 14
#
# ཆེན་པོ: 13
#
# ཡེ་ཤེས: 12
#
# སྐུ: 12
#
# བདག: 12
#
# རྣལ་འབྱོར: 12
#
# སངས་རྒྱས: 12
#
# འགྱུར: 12
#
# རྫོགས: 11
#
# LL01_L14_rtse-mo-byung-rgyal_vol8-p480-491.txt top 20 bigrams
# བྱང་ཆུབ་སེམས: 9
#
# བྱང་ཆུབ་སྙིང་པོ: 9
#
# གཉིས་མེད: 7
#
# རྣམ་པར་དག: 7
#
# ལྷུན་རྫོགས: 6
#
# དབྱིངས་ལས: 5
#
# སྐྱེ་མེད: 5
#
# བདེ་བ་ཆེན་པོ: 4
#
# ཕྱི་ནང: 4
#
# མི་རྟོག: 4
#
# རྣམ་དག་བྱང་ཆུབ: 3
#
# མཉམ་སྦྱོར: 3
#
# རྣམ་གྲངས: 3
#
# མི་གནས: 3
#
# རྡུལ་ཙམ: 3
#
# ཙམ་མེད: 3
#
# ཡེ་ནས་ལྷུན་གྲུབ: 3
#
# རྟོག་པ་མི: 3
#
# མེད་དོན: 3
#
# ཆོ་འཕྲུལ་སྣ་ཚོགས: 3
#
# LL02_་nam-mkha'-rgyal-po_vol8-v475-480.txt top 20 words
# མེད: 51
#
# མི: 25
#
# ནམ་མཁའ: 20
#
# ལས: 15
#
# བྲལ: 14
#
# ཀུན: 10
#
# ཡེ་ཤེས: 10
#
# སེམས: 10
#
# མེད་པ: 10
#
# སྒྱུ་མ: 10
#
# དབྱིངས: 9
#
# ཉིད: 8
#
# འདས་པ: 8
#
# མཐའ: 8
#
# བརྗོད: 7
#
# ཚིག: 7
#
# བྲལ་བ: 7
#
# མཚན་ཉིད: 6
#
# དེ་ཉིད: 6
#
# འདས: 6
#
# LL02_་nam-mkha'-rgyal-po_vol8-v475-480.txt top 20 bigrams
# ལས་འདས: 6
#
# ལས་འདས་པ: 5
#
# བརྗོད་མེད: 4
#
# མི་གནས: 4
#
# མེད་ལས: 3
#
# མི་ནུས: 3
#
# མཐའ་ཀུན: 3
#
# དབྱིངས་ལས: 3
#
# ནམ་མཁའ་ཆེ: 2
#
# མེད་ནམ་མཁའ: 2
#
# ནམ་མཁའ: 2
#
# དབུས་མཐའ: 2
#
# མེད་དབང་པོ: 2
#
# གཉིས་མེད: 2
#
# སེམས་མེད: 2
#
# ཞིང་རྟོགས་པ: 2
#
# ཀུན་མེད: 2
#
# མཐའ་ལས: 2
#
# མེད་དག: 2
#
# འཛིན་མེད: 2
#
# LL03_L16_bde-ba-phra-bkod_V8-p.495-498.txt top 20 words
# མེད: 28
#
# མེད་པ: 15
#
# ཕྲ: 11
#
# བཀོད་པ: 11
#
# མི: 11
#
# བདེ་བ: 10
#
# བྲལ: 8
#
# སྐྱེ: 8
#
# ཀློང: 8
#
# རང: 8
#
# ཀུན: 7
#
# སེམས: 6
#
# དོན: 6
#
# ལས: 6
#
# དབྱིངས: 6
#
# ཡིན: 6
#
# བྲལ་བ: 6
#
# ཡེ: 6
#
# ལྷུན: 5
#
# གྲུབ་པ: 5
#
# LL03_L16_bde-ba-phra-bkod_V8-p.495-498.txt top 20 bigrams
# ཕྲ་བཀོད་པ: 10
#
# མི་སྐྱེ: 4
#
# སྐྱེ་མེད: 3
#
# སྣང་བ་རང: 3
#
# བདེ་བ་ཕྲ: 2
#
# སྤང་ལེན: 2
#
# མྱ་ངན་འདས: 2
#
# བདེ་བ་རང: 2
#
# དབུས་མེད: 2
#
# དངོས་པོ་ཀུན: 2
#
# མེད་དབྱིངས: 2
#
# ལས་འདས: 2
#
# འཁོར་བ་མྱ་ངན: 2
#
# སྡུག་བསྔལ་བྲལ་བ: 2
#
# བྲལ་བ་ཡིན: 2
#
# ཡེ་བརྡལ: 2
#
# མེད་སྣང་བ: 2
#
# སྐྱེ་དབྱིངས: 2
#
# རིག་པ་རང: 2
#
# ཤར་དོན་དམ: 2
#
# LL04_byang-chub-sems-tig.txt top 20 words
# མེད: 6
#
# ཚོལ: 4
#
# ལས: 3
#
# བདེ་བ: 3
#
# སངས་རྒྱས: 3
#
# མི: 3
#
# བྱང་ཆུབ: 2
#
# ལུས: 2
#
# འདས་པ: 2
#
# ཀློང: 2
#
# དབྱེར: 2
#
# ཉམས: 2
#
# ཡེ་ནས: 2
#
# དག་པ: 2
#
# ཡིན: 2
#
# ཡེ: 2
#
# མེད་པ: 2
#
# ཚིག: 2
#
# བལྟ: 2
#
# དོན: 2
#
# LL04_byang-chub-sems-tig.txt top 20 bigrams
# དབྱེར་མེད: 2
#
# ཡེ་ནས་དག་པ: 2
#
# མེད་ཡེ: 2
#
# ཡེ་སངས་རྒྱས: 2
#
# མི་བལྟ: 2
#
# སེམས་ཏིག: 1
#
# ཏིག་ཆོས: 1
#
# ལུས་དབྱིངས: 1
#
# རྒྱུ་གཅིག་པ: 1
#
# འཁོར་བ་མྱ: 1
#
# མྱ་ངན: 1
#
# ངན་འདས་པ: 1
#
# འདས་པ་གཉིས: 1
#
# གཉིས་མེད: 1
#
# ཀློང་དབྱེར: 1
#
# མེད་ཀློང: 1
#
# ཀློང་ལས: 1
#
# ཉམས་བདེ་བ: 1
#
# སྐུ་སྣང་སྲིད: 1
#
# ལུས་ཡེ་ནས: 1
#
# LL05_spyi-bcings-spyi-chings_Liljenberg-p268ff.txt top 20 words
# མི: 17
#
# ལུང: 14
#
# ཆེན་པོ: 14
#
# རྟོག་པ: 12
#
# གསུམ: 10
#
# སྔགས: 9
#
# གཅིག: 9
#
# གསལ་བ: 8
#
# བདག: 8
#
# མེད་པ: 7
#
# ཉིད: 7
#
# ལས: 7
#
# ཡིན: 7
#
# མེད: 6
#
# ངང: 6
#
# དག: 6
#
# རྒྱུ: 6
#
# རྫོགས་པ: 5
#
# ཆེ: 5
#
# འགྱུར: 5
#
# LL05_spyi-bcings-spyi-chings_Liljenberg-p268ff.txt top 20 bigrams
# སྤྱི་བཅིངས: 2
#
# བཤད་དེ་བ: 2
#
# མི་རུང: 2
#
# རྣམ་པར་མི: 2
#
# མི་རྟོག་པ: 2
#
# ཉེན་ཆེ: 2
#
# རྫོགས་པ་ཆེན་པོ: 2
#
# རྟག་པ་ཆེན་པོ: 2
#
# ལུང་ཆེན་པོ: 2
#
# མི་བཏུབ: 2
#
# མི་ཁྱབ་པ: 2
#
# ཕྱི་ནང: 2
#
# ཚིག་གསུམ: 2
#
# དཔལ་ཀུན: 1
#
# ཕྱག་འཚལ: 1
#
# འཚལ་ལོ: 1
#
# ལོ་སྤྱི: 1
#
# བཅིངས་སྔགས: 1
#
# འདྲེས་གསལ་བ: 1
#
# བདག་ཉིད་༢༠༢༡: 1
#
# LL06_L15_bde-ba-rab-'byams_vol8-p.473-475-not-sure.txt top 20 words
# མེད་པ: 18
#
# དབྱིངས: 12
#
# མེད: 12
#
# ཐིག་ལེ: 12
#
# ཉིད: 11
#
# བདེ: 8
#
# རྫོགས: 6
#
# ཆེ: 6
#
# མི: 4
#
# ལྷུན: 4
#
# ཐམས་ཅད: 4
#
# ལས: 4
#
# བྱང་ཆུབ: 4
#
# ཀུན: 3
#
# བཙལ: 3
#
# དབྱེར: 3
#
# ཡེ་ཤེས: 3
#
# ཡེ་ནས: 3
#
# སྐུ: 3
#
# རྡོ་རྗེ: 3
#
# LL06_L15_bde-ba-rab-'byams_vol8-p.473-475-not-sure.txt top 20 bigrams
# ཐིག་ལེ་བདེ: 4
#
# དབྱེར་མེད: 3
#
# ལྷུན་རྫོགས: 3
#
# རྫོགས་ཐིག་ལེ: 3
#
# དབྱིངས་ཉིད: 3
#
# བྱང་ཆུབ་སྐུ: 3
#
# བདེ་འབྱམས: 2
#
# མེད་ལྷུན: 2
#
# ཉིད་ཆེ: 2
#
# བྱ་བ་མེད་པ: 2
#
# ཉིད་ལས: 2
#
# སྐུ་ཐིག་ལེ: 2
# ཐིག་ལེ་མེད་པ: 2
#
# ནུབ་པ་མེད: 2
#
# མེད་བསྒོམ་པ: 2
#
# འགྱུར་བ་མེད་པ: 2
#
# བལ་ནག: 2
#
# དེ་ནས་འཁོར: 1
#
# བསྒོམ་བསྒྲུབ: 1
#
# བསྒྲུབ་ཀུན: 1
#
# LL07_L10_srog-gi-'khor-lo_v8.p491-494.txt top 20 words
# མེད: 12
#
# མི: 10
#
# རང་བཞིན: 8
#
# ཆོས་དབྱིངས: 8
#
# དབྱིངས: 7
#
# འཁོར་ལོ: 6
#
# ངང: 6
#
# སྐུ་གསུང་ཐུགས: 6
#
# རྒྱལ་བ: 6
#
# ཡོངས: 6
#
# ཐུགས: 6
#
# རྫོགས: 6
#
# ཀུན: 5
#
# བྱང་ཆུབ: 5
#
# སྙིང་པོ: 5
#
# འདུས: 5
#
# རྒྱ་མཚོ: 5
#
# མེད་པ: 5
#
# སྲོག: 4
#
# ཐབས: 4
#
# LL07_L10_srog-gi-'khor-lo_v8.p491-494.txt top 20 bigrams
# བྱང་ཆུབ་སེམས: 3
#
# མི་ཟད་རྒྱན: 3
#
# རྣལ་འབྱོར་ཡོངས: 2
#
# རང་རིག་དབང་ཕྱུག: 2
#
# སྐྱེ་མེད: 2
#
# མྱ་ངན་འདས: 2
#
# ང་མེད: 2
#
# མེད་བདག: 2
#
# མེད་པ་ཡུམ: 2
#
# ཡེ་ཤེས་དབྱིངས: 2
#
# མཆོག་མི་ཟད: 2
#
# རྒྱུ་གཅིག: 2
#
# བསམ་མི: 2
#
# མི་ཁྱབ: 2
#
# འཁོར་ལོ་བཅོམ་ལྡན་འདས: 1
#
# བཅོམ་ལྡན་འདས་ཏེ་མ: 1
#
# ཏེ་མ་ལུས: 1
#
# ལུས་ཀུན: 1
#
# དཔལ་ཐུགས་རྗེ: 1
#
# ཐུགས་རྗེ་ཐབས: 1
#
# LL08_thig-le-drug-pa-NGB-vol33.txt top 20 words
# ཀུན: 16
#
# མེད: 15
#
# མི: 15
#
# གནས: 10
#
# ལམ: 10
#
# ལས: 6
#
# ཤིང: 6
#
# ཆོས: 6
#
# ཉིད: 6
#
# བྲལ: 6
#
# ཡུལ: 6
#
# སེམས: 5
#
# གཉིས: 5
#
# མཐའ: 5
#
# རང་བཞིན: 5
#
# ཆེན་པོ: 4
#
# བྱང་ཆུབ: 4
#
# རྒྱུད: 4
#
# རང: 4
#
# དག: 4
#
# LL08_thig-le-drug-pa-NGB-vol33.txt top 20 bigrams
# རྒྱུད་ལས: 3
#
# གཉིས་མེད: 3
#
# རྫོགས་པ་ཆེན་པོ: 2
#
# རྒྱ་མཚོ་གནས: 2
#
# སངས་རྒྱས་ཀུན: 2
#
# བྱང་ཆུབ་སེམས: 2
#
# མེད་སྔོན: 2
#
# མེད་ཡང་དག: 2
#
# མེད་འདྲེས: 2
#
# འདྲེས་ཤིང: 2
#
# མི་བྱེད: 2
#
# བྲལ་ཟིན་པ: 2
#
# ཆེན་པོ་ཆོས་ཉིད: 1
#
# ཆོས་ཉིད་བྱང་ཆུབ: 1
#
# སེམས་ཐིག་ལེ: 1
#
# ཐིག་ལེ་རྒྱ་མཚོ: 1
#
# ལས་ཞུས་པ: 1
#
# དེ་ནས་སངས་རྒྱས: 1
#
# བསྟོད་བྱས: 1
#
# བྱས་ཤིང: 1
#
# LL09_spyi-gcod_vol8_p.498.txt top 20 words
# མེད: 6
#
# བལྟ: 4
#
# བདེ་བ: 3
#
# སངས་རྒྱས: 3
#
# ཚོལ: 3
#
# དོན: 3
#
# མི: 3
#
# བྱང་ཆུབ: 2
#
# ལུས: 2
#
# འདས་པ: 2
#
# ཀློང: 2
#
# དབྱེར: 2
#
# ཉམས: 2
#
# ཡེ་ནས: 2
#
# དག་པ: 2
#
# ཡིན: 2
#
# ཡེ: 2
#
# མེད་པ: 2
#
# ཚིག: 2
#
# ལས: 2
#
# LL09_spyi-gcod_vol8_p.498.txt top 20 bigrams
# དབྱེར་མེད: 2
#
# ཡེ་ནས་དག་པ: 2
#
# མེད་ཡེ: 2
#
# ཡེ་སངས་རྒྱས: 2
#
# མི་བལྟ: 2
#
# བསྲུངས་ཕྲ: 1
#
# ཕྲ་བཀོད་པ: 1
#
# སེམས་རྫོགས་པ: 1
#
# རྫོགས་པ་སྤྱི: 1
#
# སྤྱི་གཅོད: 1
#
# ཟེར་ཏིག: 1
#
# ཏིག་ཆོས: 1
#
# ལུས་དབྱིངས: 1
#
# རྒྱུ་གཅིག་པ: 1
#
# འཁོར་བ་མྱ་ངན: 1
#
# མྱ་ངན་འདས་པ: 1
#
# འདས་པ་གཉིས: 1
#
# གཉིས་མེད: 1
#
# ཀློང་དབྱེར: 1
#
# མེད་ཀློང: 1
#
# LL10_yid-bzhin-nor-bu-431.txt top 20 words
# མེད: 3
#
# ལས: 2
#
# ཆེན་པོ: 2
#
# རྟག: 2
#
# སྤྱོད་ཡུལ: 2
#
# དེ་ནས: 1
#
# བཅོམ་ལྡན: 1
#
# བཀའ: 1
#
# སྩལ: 1
#
# ཁམས: 1
#
# གསུམ: 1
#
# འདས: 1
#
# རིན་ཆེན: 1
#
# དག: 1
#
# བགྲོད: 1
#
# རྣམ་གྲོལ: 1
#
# ལམ: 1
#
# སྟོན་པ: 1
#
# གཞན: 1
#
# རྙེད་པ: 1
#
# LL10_yid-bzhin-nor-bu-431.txt top 20 bigrams
# དེ་ནས་བཅོམ་ལྡན: 1
#
# བཅོམ་ལྡན་བཀའ: 1
#
# བཀའ་སྩལ: 1
#
# ཁམས་གསུམ: 1
#
# གསུམ་ལས: 1
#
# ལས་འདས: 1
#
# འདས་རིན་ཆེན: 1
#
# རིན་ཆེན་དག: 1
#
# དག་བགྲོད: 1
#
# བགྲོད་མེད: 1
#
# མེད་རྣམ་གྲོལ: 1
#
# རྣམ་གྲོལ་ལམ: 1
#
# ལམ་སྟོན་པ: 1
#
# སྟོན་པ་གཞན: 1
#
# མི་འགྱུར: 1
#
# ཐིག་ལེ་ཆེན་པོ: 1
#
# ཆེན་པོ་ཀུན་ཁྱབ: 1
#
# ཀུན་ཁྱབ་གནས: 1
#
# གནས་རང་བྱུང: 1
#
# བཅོས་ཡེ་ནས: 1
#
# LL11_kun-'dus-NGB-mtshams-brag-vol1-624-626་.txt top 20 words
# ཀུན: 6
#
# ཐམས་ཅད: 5
#
# ཡུལ: 4
#
# ལས: 4
#
# བྱང་ཆུབ: 4
#
# མེད: 4
#
# འདུས: 3
#
# ཡེ་ནས: 3
#
# དབྱིངས: 3
#
# དགུ: 3
#
# གམ: 3
#
# ལྷུན: 3
#
# ཀློང: 3
#
# གསལ: 3
#
# བདེ་བ: 2
#
# ངང: 2
#
# ཕྱིར: 2
#
# མཐའ: 2
#
# གཅིག: 2
#
# སྣང: 2
#
# LL11_kun-'dus-NGB-mtshams-brag-vol1-624-626་.txt top 20 bigrams
# ཀུན་འདུས: 2
#
# བྱང་ཆུབ་མཆོག: 2
#
# རྒྱ་གར་སྐད: 1
#
# ས་རྦ: 1
#
# རྦ་ཨ: 1
#
# ཨ་ཏ: 1
#
# ཏ་བོད་སྐད: 1
#
# འདུས་བཅོམ་ལྡན་འདས: 1
#
# བཅོམ་ལྡན་འདས་བྱ་བྲལ: 1
#
# བྱ་བྲལ་བདེ་བ: 1
#
# ཕྱག་འཚལ: 1
#
# འཚལ་ལོ: 1
#
# ལོ་ཆོས་སྐུ: 1
#
# ཆོས་སྐུ་ཡེ་ནས: 1
#
# ཡེ་ནས་རྣམ་པར: 1
#
# རྣམ་པར་རབ: 1
#
# རབ་དབེན་པ: 1
#
# རྣམ་རྟོག: 1
#
# རྟོག་བླ་དགས: 1
#
# བླ་དགས་ཡུལ: 1
#
# LL12_rje-btsan-dam-pa_NGB-vol34-p63-64.txt top 20 words
# ཀུན: 6
#
# དོན: 4
#
# ལུང: 4
#
# རྗེ་བཙན: 3
#
# རྣལ་འབྱོར: 3
#
# དམ་པ: 2
#
# ལྷ: 2
#
# ལས: 2
#
# མཆོག: 2
#
# འཕགས་པ: 2
#
# རྡོ་རྗེ: 2
#
# རྫོགས་པ: 2
#
# ཡིན: 2
#
# ངེས་པ: 2
#
# ཆེན: 2
#
# རྒྱ་གར: 1
#
# སྐད: 1
#
# ཙ་ར: 1
#
# ཤ: 1
#
# ཨ: 1
#
# LL12_rje-btsan-dam-pa_NGB-vol34-p63-64.txt top 20 bigrams
# རྗེ་བཙན་དམ་པ: 2
#
# རྒྱ་གར་སྐད: 1
#
# ཙ་ར་ཤ: 1
#
# ཤ་ཨ: 1
#
# ཐུ་བོད་སྐད: 1
#
# དམ་པ་བཅོམ་ལྡན་འདས: 1
#
# བཅོམ་ལྡན་འདས་དཔལ: 1
#
# དཔལ་ཀུན: 1
#
# ཕྱག་འཚལ: 1
#
# འཚལ་ལོ: 1
#
# ལོ་ཁྲེན: 1
#
# རྣལ་འབྱོར་ལྷ: 1
#
# ལྷ་ཡི: 1
#
# ཡི་ལྷ: 1
#
# ལྷ་རྣལ་འབྱོར: 1
#
# རྣལ་འབྱོར་ལས: 1
#
# རྣལ་འབྱོར་མཆོག: 1
#
# མཆོག་འཕགས་པ: 1
#
# འཕགས་པ་ལས: 1
#
# རྡོ་རྗེ་རྒྱལ་བ: 1
#
# LL13-sgom-pa-don-grubdocx.txt top 20 words
# སེམས: 6
#
# མེད: 5
#
# བྱང་ཆུབ: 4
#
# ཆོས: 4
#
# ཀུན: 3
#
# ཆེན་པོ: 3
#
# མི: 3
#
# བསྒོམ་པ: 3
#
# སྒོམ་པ: 2
#
# བྱ་བ: 2
#
# བདེ་བ: 2
#
# སེམས་ཅན: 2
#
# ཁྱབ: 2
#
# བྱ: 2
#
# ཆོས་ཉིད: 2
#
# རྟོགས་པ: 2
#
# གཉིས: 2
#
# རང་བཞིན: 2
#
# གཞན: 2
#
# ཅི་ཡང: 2
#
# LL13-sgom-pa-don-grubdocx.txt top 20 bigrams
# མེད་སེམས: 2
#
# བྱང་ཆུབ་སེམས: 2
#
# རྒྱ་གར་སྐད: 1
#
# བོ་དྷི་ཙི་ཏ: 1
#
# ཙི་ཏ་ས་མ་ཏི: 1
#
# ས་མ་ཏི་ཨ་མོ་གྷ: 1
#
# ཨ་མོ་གྷ་ཙ་ན: 1
#
# སེམས་སྒོམ་པ: 1
#
# སྒོམ་པ་དོན་གྲུབ: 1
#
# བྱ་བ་དཔལ: 1
#
# དཔལ་ཀུན: 1
#
# བཟང་པོ་བདེ་བ: 1
#
# བདེ་བ་ཆེན་པོ: 1
#
# ཕྱག་འཚལ: 1
#
# འཚལ་ཐུག: 1
#
# ཐུག་རྗེ: 1
#
# རྗེ་རྒྱ་མཚོ: 1
#
# རྒྱ་མཚོ་སེམས་ཅན: 1
#
# སེམས་ཅན་ཀུན: 1
#
# ཁྱབ་ལྷ: 1
